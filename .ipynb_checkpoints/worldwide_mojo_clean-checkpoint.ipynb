# %% [markdown]
# # PROJECT - 2

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
import dateutil.parser

# %% [markdown]
# ### Getting  information from a movie page

# %%
url = 'https://www.boxofficemojo.com/title/tt2488496/?ref_=bo_cso_table_1'
response = requests.get(url)
page = response.text
soup = BeautifulSoup(page, 'lxml')
# soup.prettify()

# %% [markdown]
# #### Movie Title

# %%
soup.find('title').text
title_string = soup.find('title').text
title_string
# Out:
# 'Star Wars: Episode VII - The Force Awakens - Box Office Mojo'

# %%
title = title_string[:-18]
title
# Out:
# 'Star Wars: Episode VII - The Force Awakens'

# %% [markdown]
# #### Domestic Gross

# %%
soup.find(class_='mojo-performance-summary-table').find_all('span',class_='money')
# Out:
# [<span class="money">$936,662,225</span>,
#  <span class="money">$1,131,791,908</span>,
#  <span class="money">$2,068,454,133</span>]

# %%
dom_gross = soup.find(class_='mojo-performance-summary-table').find_all('span',class_='money')[0].text
dom_gross
# Out:
# '$936,662,225'

# %% [markdown]
# #### International Gross

# %%
intl_gross = soup.find(class_='mojo-performance-summary-table').find_all('span',class_='money')[1].text
intl_gross
# Out:
# '$1,131,791,908'

# %% [markdown]
# #### Worldwide Gross

# %%
world_gross = soup.find(class_='mojo-performance-summary-table').find_all('span',class_='money')[2].text
world_gross
# Out:
# '$2,068,454,133'

# %% [markdown]
# #### Domestic Openig Gross

# %%
dom_opening_gross = soup.find(class_='mojo-summary-values').find_all('span', class_ = 'money')[0]
dom_opening_gross
# Out:
# <span class="money">$247,966,675</span>

# %% [markdown]
# #### Budget

# %%
prod_budget = soup.find(class_='mojo-summary-values').find_all('span', class_ = 'money')[1]
prod_budget
# Out:
# <span class="money">$245,000,000</span>

# %% [markdown]
# #### Domestic Distributor

# %%
soup.find(class_='mojo-summary-values').find_all('span', class_ = 'money')
# Out:
# [<span class="money">$247,966,675</span>,
#  <span class="money">$245,000,000</span>]

# %%
distributor_reggex = re.compile('Distributor')
soup.find(text=distributor_reggex)
# Out:
# 'Domestic Distributor'

# %%
distr_string = find(text=distributor_reggex).findNext('span').text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-6c59da8698ec> in <module>
# ----> 1 distr_string = find(text=distributor_reggex).findNext('span').text
#
# NameError: name 'find' is not defined

# %%
dist_string = soup.find(text=distributor_reggex).findNext('span').text[:18]
dom_dist = dist_string
dom_dist
# Out:
# 'Walt Disney Studio'

# %% [markdown]
# ### Get Movie (findNext) Values

# %%
def get_movie_value(soup, field_name):
    
    """
    Get a value fro the movie page and take the string attribute of a movie on the page and return
    the value of the next sibling object or None if nothing is found.
    
    """
    obj = soup.find(text=re.compile(field_name))
    if not obj:
        return None
    next_element = obj.findNext()
    
    if next_element:
        return next_element.text
    else:
        return None

# %% [markdown]
# #### Domestic Opening Gross

# %%
dom_opening_gross = soup.find(class_='mojo-summary-values').find_all('span', class_ = 'money')[0].text
dom_opening_gross
# Out:
# '$247,966,675'

# %%
production_budget = soup.find(class_='mojo-summary-values').find_all('span', class_ = 'money')[1].text
production_budget
# Out:
# '$245,000,000'

# %% [markdown]
# #### Runtime

# %%
runtime = get_movie_value(soup, 'Running')
print(runtime)
# Out:
# 2 hr 18 min

# %% [markdown]
# #### Rating

# %%
rating = get_movie_value(soup, 'MPAA')
print(rating)
# Out:
# PG-13

# %% [markdown]
# #### Release Date

# %%
rel_date = get_movie_value(soup, 'Release Date')
print(rel_date)
# Out:
# December 16, 2015
#             (EMEA, APAC)

# %% [markdown]
# #### Genres

# %%
genres = get_movie_value(soup, 'Genres').split()
genres
# Out:
# ['Action', 'Adventure', 'Sci-Fi']

# %% [markdown]
# #### Distributor

# %%
distributor = get_movie_value(soup, 'Distributor')[:35]
distributor
# Out:
# 'Walt Disney Studios Motion Pictures'

# %% [markdown]
# ### Function to convert money and time string into integer values

# %%
def money_to_int(moneystring):
    
    """
    replaces the $ sign and removing the comma separator from the money string
    returns the integer value
    """
    
    moneystring = moneystring.replace('$', '').replace(',', '')
    return int(moneystring)

def runtime_to_minutes(runtimestring):
    
    """
    takes runtimestring in _hr_min format and returns it's value in number of minutes
    """
    
    runtime = runtimestring.split()
    try:
        minutes = int(runtime[0]) * 60 + int(runtime[2])
        return minutes
    except:
        return None

# %%
raw_dom_gross = dom_gross
domestic_gross = money_to_int(raw_dom_gross)

raw_intl_gross = intl_gross
international_gross = money_to_int(raw_intl_gross)

raw_world_gross = world_gross
worldwide_gross = money_to_int(raw_world_gross)

raw_opening_gross = dom_opening_gross
domestic_opening_gross = money_to_int(raw_opening_gross)

raw_budget = production_budget
budget = money_to_int(raw_budget)

# %%
raw_runtime = get_movie_value(soup, 'Running')
runtime_minutes = runtime_to_minutes(raw_runtime)
runtime_minutes
# Out:
# 138

# %%
release_month = rel_date.split()[0]
release_month
# Out:
# 'December'

# %% [markdown]
# #### Actors

# %%
url = 'https://www.boxofficemojo.com/title/tt2488496/credits/?ref_=bo_tt_tab'
response = requests.get(url)
actor_page = response.text
actor_soup = BeautifulSoup(actor_page, 'lxml')

# %%
casts = actor_soup.find('table', id = 'principalCast').find_all('a', attrs={'class':'a-link-normal'})
actors = []
for cast in casts:
    cast = cast.text.split('\n')[0]
    actors += [cast]
actors
# Out:
# ['Daisy Ridley', 'John Boyega', 'Oscar Isaac', 'Domhnall Gleeson']

# %% [markdown]
# ### Getting the lifetime ranking table

# %%
url = 'https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?offset=200&area=XWW'
response = requests.get(url)
page = response.text
soup = BeautifulSoup(page, 'lxml')
# print(soup.prettify())

# %%
# finding the table
table = soup.find('table')
# table

# %%
rows = [row for row in table.find_all('tr')]
rows[1].find_all('td')
# Out:
# [<td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">201</td>,
#  <td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt3874544/?ref_=bo_cso_table_1">The Boss Baby</a></td>,
#  <td class="a-text-right mojo-field-type-money">$527,965,936</td>,
#  <td class="a-text-right mojo-field-type-money">$175,003,033</td>,
#  <td class="a-text-right mojo-field-type-percent">33.2%</td>,
#  <td class="a-text-right mojo-field-type-money">$352,962,903</td>,
#  <td class="a-text-right mojo-field-type-percent">66.8%</td>,
#  <td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2017/?ref_=bo_cso_table_1">2017</a></td>]

# %%
rows[1].find_all('td')[1].find('a')['href']
# Out:
# '/title/tt3874544/?ref_=bo_cso_table_1'

# %% [markdown]
# #### Previewing Lifetime Movie Data

# %%
movies = {}

for row in rows[1:201]:
    items = row.find_all('td')
    link = items[1].find('a')
    title = link.text
    url = link['href']
    movies[title] = [url]+ [i.text for i in items]

# movies

# %%
lifetime_movies = pd.DataFrame(movies).T
lifetime_movies.columns = ['link_stub', 'rank', 'title', 'WW_gross', 'domestic_gross','dom_%', 'foreign_gross','for_%','release_year']
lifetime_movies[190:200]
# Out:
#                                                     link_stub rank  \
# Peter Rabbit          /title/tt5117670/?ref_=bo_cso_table_193  395
# Speed                 /title/tt0111257/?ref_=bo_cso_table_194  396
# Dinosaur              /title/tt0130623/?ref_=bo_cso_table_195  397
# Mary Poppins Returns  /title/tt5028340/?ref_=bo_cso_table_196  398
# The Lorax             /title/tt1482459/?ref_=bo_cso_table_197  399
# The Maze Runner       /title/tt1790864/?ref_=bo_cso_table_198  400
# The Smurfs 2          /title/tt2017020/?ref_=bo_cso_table_199  401
# National Treasure     /title/tt0368891/?ref_=bo_cso_table_200  402
#
#                                      title      WW_gross domestic_gross  \
# Peter Rabbit                  Peter Rabbit  $351,266,433   $115,253,424
# Speed                                Speed  $350,448,145   $121,248,145
# Dinosaur                          Dinosaur  $349,822,765   $137,748,063
# Mary Poppins Returns  Mary Poppins Returns  $349,546,142   $171,958,438
# The Lorax                        The Lorax  $348,840,316   $214,030,500
# The Maze Runner            The Maze Runner  $348,319,861   $102,427,862
# The Smurfs 2                  The Smurfs 2  $347,545,360    $71,017,784
# National Treasure        National Treasure  $347,512,318   $173,008,894
#
#                       dom_% foreign_gross  for_% release_year
# Peter Rabbit          32.8%  $236,013,009  67.2%         2018
# Speed                 34.6%  $229,200,000  65.4%         1994
# Dinosaur              39.4%  $212,074,702  60.6%         2000
# Mary Poppins Returns  49.2%  $177,587,704  50.8%         2018
# The Lorax             61.4%  $134,809,816  38.6%         2012
# The Maze Runner       29.4%  $245,891,999  70.6%         2014
# The Smurfs 2          20.4%  $276,527,576  79.6%         2013
# National Treasure     49.8%  $174,503,424  50.2%         2004

# %% [markdown]
# #### Storing movie page data into a dictionary

# %%
def get_movie_dict(link):
    """
    From BoxOfficeMojo link stub, request movie html, parse with BeautifulSoup, and
    collect 
        - title 
        - domestic gross
        - runtime 
        - MPAA rating
        - full release date
    Return information as a dictionary
    
    """
    
    base_url = 'https://www.boxofficemojo.com'
    
    #Create full url to scrape
    url = base_url + link
    
    #Request HTML and parse
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page,"lxml")
    
    headers = ['title', 'domestic_opening_gross', 'budget', 'domestic_gross', 'international_gross', 
               'worldwide_gross','runtime_minutes', 'rating', 'release_month', 'genres', 'actors']
    
    #Get title
    title_string = soup.find('title').text
    title = title_string[:-18]

    #Get domestic gross
    raw_dom_gross = soup.find(class_='mojo-performance-summary-table').find_all('span',class_='money')[0].text
    domestic_gross = money_to_int(raw_dom_gross)
    
    #dom_gross = money_to_int(dom_gross)
    
    #Get international_gross
    raw_intl_gross = soup.find(class_='mojo-performance-summary-table').find_all('span',class_='money')[1].text
    international_gross = money_to_int(raw_intl_gross)
    
    #Get worldwide gross
    raw_world_gross = soup.find(class_='mojo-performance-summary-table').find_all('span',class_='money')[2].text
    worldwide_gross = money_to_int(raw_world_gross)
    
    #Get domestic opening gross
    raw_opening_gross = soup.find(class_='mojo-summary-values').find_all('span', class_ = 'money')[0].text
    domestic_opening_gross = money_to_int(raw_opening_gross)
    
    #Get budget
    raw_budget = production_budget
    budget = money_to_int(raw_budget)
    
    #Get distributor
    distributor = get_movie_value(soup, 'Distributor')[:18]
    
    #Get runtime
    raw_runtime = get_movie_value(soup, 'Running')
    runtime_minutes = runtime_to_minutes(raw_runtime)
    
    #Get rating
    rating = get_movie_value(soup, 'MPAA')
    
    #Get genres
    genres = get_movie_value(soup, 'Genres').split()
    
    #Get release month
    rel_date = get_movie_value(soup, 'Release Date')
    release_month = rel_date.split()[0]
    
    #Get actors
    casts = actor_soup.find('table', id = 'principalCast').find_all('a', attrs={'class':'a-link-normal'})
    actors = []
    for cast in casts:
        cast = cast.text.split('\n')[0]
        actors += [cast]
    
    #Create movie dictionary and return
    movie_dict = dict(zip(headers, [title,
                                    domestic_opening_gross,
                                    budget,
                                    domestic_gross,
                                    international_gross,
                                    worldwide_gross,
                                    runtime_minutes,
                                    rating,
                                    release_month,
                                    genres,
                                    actors]))

    return movie_dict

# %%
lifetime_movie_data = []
for link in lifetime_movies.link_stub:
    lifetime_movie_data.append(get_movie_dict(link))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-69-e2e90a4bca7f> in <module>
#       1 lifetime_movie_data = []
#       2 for link in lifetime_movies.link_stub:
# ----> 3     lifetime_movie_data.append(get_movie_dict(link))
#
# <ipython-input-68-06510ecf284b> in get_movie_dict(link)
#      44
#      45     #Get domestic opening gross
# ---> 46     raw_opening_gross = soup.find(class_='mojo-summary-values').find_all('span', class_ = 'money')[0].text
#      47     domestic_opening_gross = money_to_int(raw_opening_gross)
#      48
#
# IndexError: list index out of range

# %%
lifetime_movie_data
# Out:
# [{'title': 'Avengers: Endgame',
#   'domestic_opening_gross': 357115007,
#   'budget': 245000000,
#   'domestic_gross': 858373000,
#   'international_gross': 1939427564,
#   'worldwide_gross': 2797800564,
#   'runtime_minutes': 181,
#   'rating': 'PG-13',
#   'release_month': 'April',
#   'genres': ['Action', 'Adventure', 'Drama', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Avatar',
#   'domestic_opening_gross': 77025481,
#   'budget': 245000000,
#   'domestic_gross': 760507625,
#   'international_gross': 2029931467,
#   'worldwide_gross': 2790439092,
#   'runtime_minutes': 162,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Titanic',
#   'domestic_opening_gross': 28638131,
#   'budget': 245000000,
#   'domestic_gross': 659363944,
#   'international_gross': 1812387978,
#   'worldwide_gross': 2471751922,
#   'runtime_minutes': 194,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Drama', 'Romance'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Star Wars: Episode VII - The Force Awakens',
#   'domestic_opening_gross': 247966675,
#   'budget': 245000000,
#   'domestic_gross': 936662225,
#   'international_gross': 1131791908,
#   'worldwide_gross': 2068454133,
#   'runtime_minutes': 138,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Avengers: Infinity War',
#   'domestic_opening_gross': 257698183,
#   'budget': 245000000,
#   'domestic_gross': 678815482,
#   'international_gross': 1369544272,
#   'worldwide_gross': 2048359754,
#   'runtime_minutes': 149,
#   'rating': 'PG-13',
#   'release_month': 'April',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Jurassic World',
#   'domestic_opening_gross': 208806270,
#   'budget': 245000000,
#   'domestic_gross': 652295625,
#   'international_gross': 1018130819,
#   'worldwide_gross': 1670426444,
#   'runtime_minutes': 124,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Lion King',
#   'domestic_opening_gross': 1586753,
#   'budget': 245000000,
#   'domestic_gross': 422783777,
#   'international_gross': 660936730,
#   'worldwide_gross': 1083720507,
#   'runtime_minutes': 88,
#   'rating': 'G',
#   'release_month': 'June',
#   'genres': ['Adventure', 'Animation', 'Drama', 'Family', 'Musical'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Avengers',
#   'domestic_opening_gross': 207438708,
#   'budget': 245000000,
#   'domestic_gross': 623357910,
#   'international_gross': 895457605,
#   'worldwide_gross': 1518815515,
#   'runtime_minutes': 143,
#   'rating': 'PG-13',
#   'release_month': 'April',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Furious 7',
#   'domestic_opening_gross': 147187040,
#   'budget': 245000000,
#   'domestic_gross': 353007020,
#   'international_gross': 1162246868,
#   'worldwide_gross': 1515253888,
#   'runtime_minutes': 137,
#   'rating': 'PG-13',
#   'release_month': 'April',
#   'genres': ['Action', 'Adventure', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Frozen II',
#   'domestic_opening_gross': 130263358,
#   'budget': 245000000,
#   'domestic_gross': 477373578,
#   'international_gross': 972653355,
#   'worldwide_gross': 1450026933,
#   'runtime_minutes': 103,
#   'rating': 'PG',
#   'release_month': 'November',
#   'genres': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Musical'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Avengers: Age of Ultron',
#   'domestic_opening_gross': 191271109,
#   'budget': 245000000,
#   'domestic_gross': 459005868,
#   'international_gross': 943803672,
#   'worldwide_gross': 1402809540,
#   'runtime_minutes': 141,
#   'rating': 'PG-13',
#   'release_month': 'April',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Black Panther',
#   'domestic_opening_gross': 202003951,
#   'budget': 245000000,
#   'domestic_gross': 700426566,
#   'international_gross': 647171407,
#   'worldwide_gross': 1347597973,
#   'runtime_minutes': 134,
#   'rating': 'PG-13',
#   'release_month': 'February',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'domestic_opening_gross': 169189427,
#   'budget': 245000000,
#   'domestic_gross': 381409310,
#   'international_gross': 960814625,
#   'worldwide_gross': 1342223936,
#   'runtime_minutes': 130,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Adventure', 'Drama', 'Fantasy', 'Mystery'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Star Wars: Episode VIII - The Last Jedi',
#   'domestic_opening_gross': 220009584,
#   'budget': 245000000,
#   'domestic_gross': 620181382,
#   'international_gross': 712516117,
#   'worldwide_gross': 1332697499,
#   'runtime_minutes': 152,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Jurassic World: Fallen Kingdom',
#   'domestic_opening_gross': 148024610,
#   'budget': 245000000,
#   'domestic_gross': 417719760,
#   'international_gross': 892744920,
#   'worldwide_gross': 1310464680,
#   'runtime_minutes': 128,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Frozen',
#   'domestic_opening_gross': 243390,
#   'budget': 245000000,
#   'domestic_gross': 400953009,
#   'international_gross': 880066266,
#   'worldwide_gross': 1281019275,
#   'runtime_minutes': 102,
#   'rating': 'PG',
#   'release_month': 'November',
#   'genres': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Musical'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Beauty and the Beast',
#   'domestic_opening_gross': 174750616,
#   'budget': 245000000,
#   'domestic_gross': 504481165,
#   'international_gross': 759583666,
#   'worldwide_gross': 1264064831,
#   'runtime_minutes': 129,
#   'rating': 'PG',
#   'release_month': 'March',
#   'genres': ['Family', 'Fantasy', 'Musical', 'Romance'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Incredibles 2',
#   'domestic_opening_gross': 182687905,
#   'budget': 245000000,
#   'domestic_gross': 608581744,
#   'international_gross': 634507470,
#   'worldwide_gross': 1243089214,
#   'runtime_minutes': 118,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Animation', 'Comedy', 'Family', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Fate of the Furious',
#   'domestic_opening_gross': 98786705,
#   'budget': 245000000,
#   'domestic_gross': 226008385,
#   'international_gross': 1009996733,
#   'worldwide_gross': 1236005118,
#   'runtime_minutes': 136,
#   'rating': 'PG-13',
#   'release_month': 'April',
#   'genres': ['Action', 'Adventure', 'Crime', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Iron Man 3',
#   'domestic_opening_gross': 174144585,
#   'budget': 245000000,
#   'domestic_gross': 409013994,
#   'international_gross': 805797258,
#   'worldwide_gross': 1214811252,
#   'runtime_minutes': 130,
#   'rating': 'PG-13',
#   'release_month': 'April',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Minions',
#   'domestic_opening_gross': 115718405,
#   'budget': 245000000,
#   'domestic_gross': 336045770,
#   'international_gross': 823398892,
#   'worldwide_gross': 1159444662,
#   'runtime_minutes': 91,
#   'rating': 'PG',
#   'release_month': 'April',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Captain America: Civil War',
#   'domestic_opening_gross': 179139142,
#   'budget': 245000000,
#   'domestic_gross': 408084349,
#   'international_gross': 745477300,
#   'worldwide_gross': 1153561649,
#   'runtime_minutes': 147,
#   'rating': 'PG-13',
#   'release_month': 'April',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Aquaman',
#   'domestic_opening_gross': 67873522,
#   'budget': 245000000,
#   'domestic_gross': 335061807,
#   'international_gross': 813424079,
#   'worldwide_gross': 1148485886,
#   'runtime_minutes': 143,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Lord of the Rings: The Return of the King',
#   'domestic_opening_gross': 72629713,
#   'budget': 245000000,
#   'domestic_gross': 377845905,
#   'international_gross': 764611082,
#   'worldwide_gross': 1142456987,
#   'runtime_minutes': 201,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Drama', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Spider-Man: Far from Home',
#   'domestic_opening_gross': 92579212,
#   'budget': 245000000,
#   'domestic_gross': 390532085,
#   'international_gross': 741395911,
#   'worldwide_gross': 1131927996,
#   'runtime_minutes': 129,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Captain Marvel',
#   'domestic_opening_gross': 153433423,
#   'budget': 245000000,
#   'domestic_gross': 426829839,
#   'international_gross': 701633133,
#   'worldwide_gross': 1128462972,
#   'runtime_minutes': 123,
#   'rating': 'PG-13',
#   'release_month': 'March',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Transformers: Dark of the Moon',
#   'domestic_opening_gross': 97852865,
#   'budget': 245000000,
#   'domestic_gross': 352390543,
#   'international_gross': 771403536,
#   'worldwide_gross': 1123794079,
#   'runtime_minutes': 154,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Skyfall',
#   'domestic_opening_gross': 88364714,
#   'budget': 245000000,
#   'domestic_gross': 304360277,
#   'international_gross': 804200736,
#   'worldwide_gross': 1108561013,
#   'runtime_minutes': 143,
#   'rating': 'PG-13',
#   'release_month': 'October',
#   'genres': ['Action', 'Adventure', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Fast & Furious Presents: Hobbs & Shaw',
#   'domestic_opening_gross': 60038950,
#   'budget': 245000000,
#   'domestic_gross': 173956935,
#   'international_gross': 585100000,
#   'worldwide_gross': 1104826325,
#   'runtime_minutes': 137,
#   'rating': None,
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Transformers: Age of Extinction',
#   'domestic_opening_gross': 100038390,
#   'budget': 245000000,
#   'domestic_gross': 245439076,
#   'international_gross': 858614996,
#   'worldwide_gross': 1104054072,
#   'runtime_minutes': 165,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Dark Knight Rises',
#   'domestic_opening_gross': 160887295,
#   'budget': 245000000,
#   'domestic_gross': 448139099,
#   'international_gross': 633002336,
#   'worldwide_gross': 1081141435,
#   'runtime_minutes': 164,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Joker',
#   'domestic_opening_gross': 96202337,
#   'budget': 245000000,
#   'domestic_gross': 335451311,
#   'international_gross': 738800000,
#   'worldwide_gross': 1074251311,
#   'runtime_minutes': 122,
#   'rating': 'R',
#   'release_month': 'October',
#   'genres': ['Crime', 'Drama', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Star Wars: Episode IX - The Rise of Skywalker',
#   'domestic_opening_gross': 177383864,
#   'budget': 245000000,
#   'domestic_gross': 515202542,
#   'international_gross': 558941706,
#   'worldwide_gross': 1074144248,
#   'runtime_minutes': 141,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Toy Story 4',
#   'domestic_opening_gross': 120908065,
#   'budget': 245000000,
#   'domestic_gross': 434038008,
#   'international_gross': 639356585,
#   'worldwide_gross': 1073394593,
#   'runtime_minutes': 100,
#   'rating': 'G',
#   'release_month': 'June',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Toy Story 3',
#   'domestic_opening_gross': 110307189,
#   'budget': 245000000,
#   'domestic_gross': 415004880,
#   'international_gross': 651965015,
#   'worldwide_gross': 1066969895,
#   'runtime_minutes': 103,
#   'rating': None,
#   'release_month': 'June',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': "Pirates of the Caribbean: Dead Man's Chest",
#   'domestic_opening_gross': 135634554,
#   'budget': 245000000,
#   'domestic_gross': 423315812,
#   'international_gross': 642863935,
#   'worldwide_gross': 1066179747,
#   'runtime_minutes': 151,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Rogue One: A Star Wars Story',
#   'domestic_opening_gross': 155081681,
#   'budget': 245000000,
#   'domestic_gross': 532177324,
#   'international_gross': 523880396,
#   'worldwide_gross': 1056057720,
#   'runtime_minutes': 133,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Aladdin',
#   'domestic_opening_gross': 91500929,
#   'budget': 245000000,
#   'domestic_gross': 355559216,
#   'international_gross': 695134737,
#   'worldwide_gross': 1050693953,
#   'runtime_minutes': 128,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Adventure', 'Family', 'Fantasy', 'Musical', 'Romance'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Pirates of the Caribbean: On Stranger Tides',
#   'domestic_opening_gross': 90151958,
#   'budget': 245000000,
#   'domestic_gross': 241071802,
#   'international_gross': 804642000,
#   'worldwide_gross': 1045713802,
#   'runtime_minutes': 137,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Despicable Me 3',
#   'domestic_opening_gross': 72434025,
#   'budget': 245000000,
#   'domestic_gross': 264624300,
#   'international_gross': 770175831,
#   'worldwide_gross': 1034800131,
#   'runtime_minutes': 89,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Jurassic Park',
#   'domestic_opening_gross': 47026828,
#   'budget': 245000000,
#   'domestic_gross': 404214720,
#   'international_gross': 629712302,
#   'worldwide_gross': 1033927022,
#   'runtime_minutes': 127,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Finding Dory',
#   'domestic_opening_gross': 135060273,
#   'budget': 245000000,
#   'domestic_gross': 486295561,
#   'international_gross': 542275328,
#   'worldwide_gross': 1028570889,
#   'runtime_minutes': 97,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Star Wars: Episode I - The Phantom Menace',
#   'domestic_opening_gross': 64820970,
#   'budget': 245000000,
#   'domestic_gross': 474544677,
#   'international_gross': 552538030,
#   'worldwide_gross': 1027082707,
#   'runtime_minutes': 136,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Alice in Wonderland',
#   'domestic_opening_gross': 116101023,
#   'budget': 245000000,
#   'domestic_gross': 334191110,
#   'international_gross': 691277106,
#   'worldwide_gross': 1025468216,
#   'runtime_minutes': 108,
#   'rating': 'PG',
#   'release_month': 'March',
#   'genres': ['Adventure', 'Family', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Zootopia',
#   'domestic_opening_gross': 75063401,
#   'budget': 245000000,
#   'domestic_gross': 341268248,
#   'international_gross': 682524310,
#   'worldwide_gross': 1023792558,
#   'runtime_minutes': 108,
#   'rating': 'PG',
#   'release_month': 'February',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Crime', 'Family', 'Mystery'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Hobbit: An Unexpected Journey',
#   'domestic_opening_gross': 84617303,
#   'budget': 245000000,
#   'domestic_gross': 303003568,
#   'international_gross': 714000000,
#   'worldwide_gross': 1017003568,
#   'runtime_minutes': 169,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Adventure', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': "Harry Potter and the Sorcerer's Stone",
#   'domestic_opening_gross': 90294621,
#   'budget': 245000000,
#   'domestic_gross': 318087620,
#   'international_gross': 688830041,
#   'worldwide_gross': 1006917662,
#   'runtime_minutes': 152,
#   'rating': 'PG',
#   'release_month': 'November',
#   'genres': ['Adventure', 'Family', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Dark Knight',
#   'domestic_opening_gross': 158411483,
#   'budget': 245000000,
#   'domestic_gross': 534858444,
#   'international_gross': 471115201,
#   'worldwide_gross': 1005973645,
#   'runtime_minutes': 152,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Crime', 'Drama', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 1',
#   'domestic_opening_gross': 125017372,
#   'budget': 245000000,
#   'domestic_gross': 296347721,
#   'international_gross': 680651521,
#   'worldwide_gross': 976999243,
#   'runtime_minutes': 146,
#   'rating': 'PG-13',
#   'release_month': 'November',
#   'genres': ['Adventure', 'Family', 'Fantasy', 'Mystery'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Despicable Me 2',
#   'domestic_opening_gross': 83517315,
#   'budget': 245000000,
#   'domestic_gross': 368065385,
#   'international_gross': 602700620,
#   'worldwide_gross': 970766005,
#   'runtime_minutes': 98,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Crime',
#    'Family',
#    'Fantasy',
#    'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Jungle Book',
#   'domestic_opening_gross': 103261464,
#   'budget': 245000000,
#   'domestic_gross': 364001123,
#   'international_gross': 602553806,
#   'worldwide_gross': 966554929,
#   'runtime_minutes': 106,
#   'rating': 'PG',
#   'release_month': 'April',
#   'genres': ['Adventure', 'Drama', 'Family', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Jumanji: Welcome to the Jungle',
#   'domestic_opening_gross': 36169328,
#   'budget': 245000000,
#   'domestic_gross': 404540171,
#   'international_gross': 557563180,
#   'worldwide_gross': 962103351,
#   'runtime_minutes': 119,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Comedy', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': "Pirates of the Caribbean: At World's End",
#   'domestic_opening_gross': 114732820,
#   'budget': 245000000,
#   'domestic_gross': 309420425,
#   'international_gross': 651576067,
#   'worldwide_gross': 960996492,
#   'runtime_minutes': 169,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Hobbit: The Desolation of Smaug',
#   'domestic_opening_gross': 73645197,
#   'budget': 245000000,
#   'domestic_gross': 258366855,
#   'international_gross': 700000000,
#   'worldwide_gross': 958366855,
#   'runtime_minutes': 161,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Adventure', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Hobbit: The Battle of the Five Armies',
#   'domestic_opening_gross': 54724334,
#   'budget': 245000000,
#   'domestic_gross': 255119788,
#   'international_gross': 700900000,
#   'worldwide_gross': 956019788,
#   'runtime_minutes': 144,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Adventure', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Lord of the Rings: The Two Towers',
#   'domestic_opening_gross': 62007528,
#   'budget': 245000000,
#   'domestic_gross': 342551365,
#   'international_gross': 600844768,
#   'worldwide_gross': 943396133,
#   'runtime_minutes': 179,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Drama', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Harry Potter and the Order of the Phoenix',
#   'domestic_opening_gross': 77108414,
#   'budget': 245000000,
#   'domestic_gross': 292353413,
#   'international_gross': 649818982,
#   'worldwide_gross': 942172396,
#   'runtime_minutes': 138,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Family', 'Fantasy', 'Mystery'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Finding Nemo',
#   'domestic_opening_gross': 70251710,
#   'budget': 245000000,
#   'domestic_gross': 380843261,
#   'international_gross': 559506933,
#   'worldwide_gross': 940350194,
#   'runtime_minutes': 100,
#   'rating': None,
#   'release_month': 'May',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Harry Potter and the Half-Blood Prince',
#   'domestic_opening_gross': 77835727,
#   'budget': 245000000,
#   'domestic_gross': 302305431,
#   'international_gross': 632148664,
#   'worldwide_gross': 934454096,
#   'runtime_minutes': 153,
#   'rating': 'PG',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Family', 'Fantasy', 'Mystery'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Shrek 2',
#   'domestic_opening_gross': 108037878,
#   'budget': 245000000,
#   'domestic_gross': 441226247,
#   'international_gross': 487534523,
#   'worldwide_gross': 928760770,
#   'runtime_minutes': 93,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Romance'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Bohemian Rhapsody',
#   'domestic_opening_gross': 51061119,
#   'budget': 245000000,
#   'domestic_gross': 216668042,
#   'international_gross': 688566435,
#   'worldwide_gross': 905234477,
#   'runtime_minutes': 134,
#   'rating': 'PG-13',
#   'release_month': 'October',
#   'genres': ['Biography', 'Drama', 'Music'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Harry Potter and the Goblet of Fire',
#   'domestic_opening_gross': 102685961,
#   'budget': 245000000,
#   'domestic_gross': 290417905,
#   'international_gross': 606002856,
#   'worldwide_gross': 896420762,
#   'runtime_minutes': 157,
#   'rating': 'PG-13',
#   'release_month': 'November',
#   'genres': ['Adventure', 'Family', 'Fantasy', 'Mystery'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Spider-Man 3',
#   'domestic_opening_gross': 151116516,
#   'budget': 245000000,
#   'domestic_gross': 336530303,
#   'international_gross': 558453070,
#   'worldwide_gross': 894983373,
#   'runtime_minutes': 139,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'domestic_opening_gross': 47211490,
#   'budget': 245000000,
#   'domestic_gross': 315544750,
#   'international_gross': 572614342,
#   'worldwide_gross': 888159092,
#   'runtime_minutes': 178,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Drama', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Ice Age: Dawn of the Dinosaurs',
#   'domestic_opening_gross': 41690382,
#   'budget': 245000000,
#   'domestic_gross': 196573705,
#   'international_gross': 690113112,
#   'worldwide_gross': 886686817,
#   'runtime_minutes': 94,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Spectre',
#   'domestic_opening_gross': 70403148,
#   'budget': 245000000,
#   'domestic_gross': 200074609,
#   'international_gross': 680600000,
#   'worldwide_gross': 880674609,
#   'runtime_minutes': 148,
#   'rating': 'PG-13',
#   'release_month': 'October',
#   'genres': ['Action', 'Adventure', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Spider-Man: Homecoming',
#   'domestic_opening_gross': 117027503,
#   'budget': 245000000,
#   'domestic_gross': 334201140,
#   'international_gross': 545965784,
#   'worldwide_gross': 880166924,
#   'runtime_minutes': 133,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Harry Potter and the Chamber of Secrets',
#   'domestic_opening_gross': 88357488,
#   'budget': 245000000,
#   'domestic_gross': 262450136,
#   'international_gross': 617152229,
#   'worldwide_gross': 879602366,
#   'runtime_minutes': 161,
#   'rating': 'PG',
#   'release_month': 'November',
#   'genres': ['Adventure', 'Family', 'Fantasy', 'Mystery'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Ice Age: Continental Drift',
#   'domestic_opening_gross': 46629259,
#   'budget': 245000000,
#   'domestic_gross': 161321843,
#   'international_gross': 715922939,
#   'worldwide_gross': 877244782,
#   'runtime_minutes': 88,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Secret Life of Pets',
#   'domestic_opening_gross': 104352905,
#   'budget': 245000000,
#   'domestic_gross': 368384330,
#   'international_gross': 507074301,
#   'worldwide_gross': 875458631,
#   'runtime_minutes': 87,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Batman v Superman: Dawn of Justice',
#   'domestic_opening_gross': 166007347,
#   'budget': 245000000,
#   'domestic_gross': 330360194,
#   'international_gross': 543277334,
#   'worldwide_gross': 873637528,
#   'runtime_minutes': 152,
#   'rating': 'PG-13',
#   'release_month': 'March',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Wolf Warrior 2',
#   'domestic_opening_gross': 219022,
#   'budget': 245000000,
#   'domestic_gross': 2721100,
#   'international_gross': 867604339,
#   'worldwide_gross': 870325439,
#   'runtime_minutes': 123,
#   'rating': None,
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Drama', 'Thriller', 'War'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Star Wars: Episode III - Revenge of the Sith',
#   'domestic_opening_gross': 108435841,
#   'budget': 245000000,
#   'domestic_gross': 380270577,
#   'international_gross': 488119983,
#   'worldwide_gross': 868390560,
#   'runtime_minutes': 140,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Hunger Games: Catching Fire',
#   'domestic_opening_gross': 158074286,
#   'budget': 245000000,
#   'domestic_gross': 424668047,
#   'international_gross': 440343699,
#   'worldwide_gross': 865011746,
#   'runtime_minutes': 146,
#   'rating': 'PG-13',
#   'release_month': 'November',
#   'genres': ['Action', 'Adventure', 'Mystery', 'Sci-Fi', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Guardians of the Galaxy Vol. 2',
#   'domestic_opening_gross': 146510104,
#   'budget': 245000000,
#   'domestic_gross': 389813101,
#   'international_gross': 473942950,
#   'worldwide_gross': 863756051,
#   'runtime_minutes': 136,
#   'rating': 'PG-13',
#   'release_month': 'April',
#   'genres': ['Action', 'Adventure', 'Comedy', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Inside Out',
#   'domestic_opening_gross': 90440272,
#   'budget': 245000000,
#   'domestic_gross': 356921711,
#   'international_gross': 501149639,
#   'worldwide_gross': 858071350,
#   'runtime_minutes': 95,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Drama', 'Family', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Venom',
#   'domestic_opening_gross': 80255756,
#   'budget': 245000000,
#   'domestic_gross': 213515506,
#   'international_gross': 642569645,
#   'worldwide_gross': 856085151,
#   'runtime_minutes': 112,
#   'rating': 'PG-13',
#   'release_month': 'October',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Thor: Ragnarok',
#   'domestic_opening_gross': 122744989,
#   'budget': 245000000,
#   'domestic_gross': 315058289,
#   'international_gross': 538925540,
#   'worldwide_gross': 853983829,
#   'runtime_minutes': 130,
#   'rating': 'PG-13',
#   'release_month': 'October',
#   'genres': ['Action', 'Adventure', 'Comedy', 'Fantasy', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Inception',
#   'domestic_opening_gross': 62785337,
#   'budget': 245000000,
#   'domestic_gross': 292576195,
#   'international_gross': 544260772,
#   'worldwide_gross': 836836967,
#   'runtime_minutes': 148,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Transformers: Revenge of the Fallen',
#   'domestic_opening_gross': 108966307,
#   'budget': 245000000,
#   'domestic_gross': 402111870,
#   'international_gross': 434191823,
#   'worldwide_gross': 836303693,
#   'runtime_minutes': 149,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Twilight Saga: Breaking Dawn - Part 2',
#   'domestic_opening_gross': 141067634,
#   'budget': 245000000,
#   'domestic_gross': 292324737,
#   'international_gross': 537422917,
#   'worldwide_gross': 829747654,
#   'runtime_minutes': 115,
#   'rating': 'PG-13',
#   'release_month': 'November',
#   'genres': ['Adventure', 'Drama', 'Fantasy', 'Romance'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Spider-Man',
#   'domestic_opening_gross': 114844116,
#   'budget': 245000000,
#   'domestic_gross': 407022860,
#   'international_gross': 418002176,
#   'worldwide_gross': 825025036,
#   'runtime_minutes': 121,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Wonder Woman',
#   'domestic_opening_gross': 103251471,
#   'budget': 245000000,
#   'domestic_gross': 412815408,
#   'international_gross': 409488097,
#   'worldwide_gross': 822303505,
#   'runtime_minutes': 141,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi', 'War'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Independence Day',
#   'domestic_opening_gross': 50228264,
#   'budget': 245000000,
#   'domestic_gross': 306169268,
#   'international_gross': 511231623,
#   'worldwide_gross': 817400891,
#   'runtime_minutes': 145,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Fantastic Beasts and Where to Find Them',
#   'domestic_opening_gross': 74403387,
#   'budget': 245000000,
#   'domestic_gross': 234037575,
#   'international_gross': 580006426,
#   'worldwide_gross': 814044001,
#   'runtime_minutes': 132,
#   'rating': 'PG-13',
#   'release_month': 'November',
#   'genres': ['Adventure', 'Family', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Shrek the Third',
#   'domestic_opening_gross': 121629270,
#   'budget': 245000000,
#   'domestic_gross': 322719944,
#   'international_gross': 490647436,
#   'worldwide_gross': 813367380,
#   'runtime_minutes': 93,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Coco',
#   'domestic_opening_gross': 50802605,
#   'budget': 245000000,
#   'domestic_gross': 210460015,
#   'international_gross': 597357873,
#   'worldwide_gross': 807817888,
#   'runtime_minutes': 105,
#   'rating': 'PG',
#   'release_month': 'October',
#   'genres': ['Adventure',
#    'Animation',
#    'Family',
#    'Fantasy',
#    'Music',
#    'Mystery'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Jumanji: The Next Level',
#   'domestic_opening_gross': 59251543,
#   'budget': 245000000,
#   'domestic_gross': 320314960,
#   'international_gross': 479744747,
#   'worldwide_gross': 800059707,
#   'runtime_minutes': 123,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Comedy', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Harry Potter and the Prisoner of Azkaban',
#   'domestic_opening_gross': 93687367,
#   'budget': 245000000,
#   'domestic_gross': 249975996,
#   'international_gross': 546245909,
#   'worldwide_gross': 796221906,
#   'runtime_minutes': 142,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Adventure', 'Family', 'Fantasy', 'Mystery'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Pirates of the Caribbean: Dead Men Tell No Tales',
#   'domestic_opening_gross': 62983253,
#   'budget': 245000000,
#   'domestic_gross': 172558876,
#   'international_gross': 622322566,
#   'worldwide_gross': 794881442,
#   'runtime_minutes': 129,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'E.T. the Extra-Terrestrial',
#   'domestic_opening_gross': 11835389,
#   'budget': 245000000,
#   'domestic_gross': 435110554,
#   'international_gross': 304203888,
#   'worldwide_gross': 792910554,
#   'runtime_minutes': 115,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Family', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': '2012',
#   'domestic_opening_gross': 65237614,
#   'budget': 245000000,
#   'domestic_gross': 166112167,
#   'international_gross': 625105659,
#   'worldwide_gross': 791217826,
#   'runtime_minutes': 158,
#   'rating': 'PG-13',
#   'release_month': 'November',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Mission: Impossible - Fallout',
#   'domestic_opening_gross': 61236534,
#   'budget': 245000000,
#   'domestic_gross': 220159104,
#   'international_gross': 570961322,
#   'worldwide_gross': 791120426,
#   'runtime_minutes': 147,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Indiana Jones and the Kingdom of the Crystal Skull',
#   'domestic_opening_gross': 100137835,
#   'budget': 245000000,
#   'domestic_gross': 317101119,
#   'international_gross': 473552823,
#   'worldwide_gross': 790653942,
#   'runtime_minutes': 122,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Spider-Man 2',
#   'domestic_opening_gross': 88156227,
#   'budget': 245000000,
#   'domestic_gross': 373585825,
#   'international_gross': 415390628,
#   'worldwide_gross': 788976453,
#   'runtime_minutes': 127,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Fast & Furious 6',
#   'domestic_opening_gross': 97375245,
#   'budget': 245000000,
#   'domestic_gross': 238679850,
#   'international_gross': 550001118,
#   'worldwide_gross': 788680968,
#   'runtime_minutes': 130,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Deadpool 2',
#   'domestic_opening_gross': 125507153,
#   'budget': 245000000,
#   'domestic_gross': 324591735,
#   'international_gross': 461202609,
#   'worldwide_gross': 785794344,
#   'runtime_minutes': 119,
#   'rating': 'R',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Comedy', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Deadpool',
#   'domestic_opening_gross': 132434639,
#   'budget': 245000000,
#   'domestic_gross': 363070709,
#   'international_gross': 419542002,
#   'worldwide_gross': 782612711,
#   'runtime_minutes': 108,
#   'rating': 'R',
#   'release_month': 'February',
#   'genres': ['Action', 'Adventure', 'Comedy', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Star Wars: Episode IV - A New Hope',
#   'domestic_opening_gross': 1554475,
#   'budget': 245000000,
#   'domestic_gross': 460998507,
#   'international_gross': 195751992,
#   'worldwide_gross': 775398007,
#   'runtime_minutes': 121,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Guardians of the Galaxy',
#   'domestic_opening_gross': 94320883,
#   'budget': 245000000,
#   'domestic_gross': 333718600,
#   'international_gross': 439631528,
#   'worldwide_gross': 773350128,
#   'runtime_minutes': 121,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Comedy', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Da Vinci Code',
#   'domestic_opening_gross': 77073388,
#   'budget': 245000000,
#   'domestic_gross': 217536138,
#   'international_gross': 542470807,
#   'worldwide_gross': 760006945,
#   'runtime_minutes': 149,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Mystery', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Maleficent',
#   'domestic_opening_gross': 69431298,
#   'budget': 245000000,
#   'domestic_gross': 241410378,
#   'international_gross': 517001401,
#   'worldwide_gross': 758411779,
#   'runtime_minutes': 97,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Family', 'Fantasy', 'Romance'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Amazing Spider-Man',
#   'domestic_opening_gross': 62004688,
#   'budget': 245000000,
#   'domestic_gross': 262030663,
#   'international_gross': 495900000,
#   'worldwide_gross': 757930663,
#   'runtime_minutes': 136,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Hunger Games: Mockingjay - Part 1',
#   'domestic_opening_gross': 121897634,
#   'budget': 245000000,
#   'domestic_gross': 337135885,
#   'international_gross': 418220826,
#   'worldwide_gross': 755356711,
#   'runtime_minutes': 123,
#   'rating': 'PG-13',
#   'release_month': 'November',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Shrek Forever After',
#   'domestic_opening_gross': 70838207,
#   'budget': 245000000,
#   'domestic_gross': 238736787,
#   'international_gross': 513864080,
#   'worldwide_gross': 752600867,
#   'runtime_minutes': 93,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Romance'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': "Madagascar 3: Europe's Most Wanted",
#   'domestic_opening_gross': 60316738,
#   'budget': 245000000,
#   'domestic_gross': 216391482,
#   'international_gross': 530529792,
#   'worldwide_gross': 746921274,
#   'runtime_minutes': 95,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Suicide Squad',
#   'domestic_opening_gross': 133682248,
#   'budget': 245000000,
#   'domestic_gross': 325100054,
#   'international_gross': 421746840,
#   'worldwide_gross': 746846894,
#   'runtime_minutes': 123,
#   'rating': 'PG-13',
#   'release_month': 'August',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'X-Men: Days of Future Past',
#   'domestic_opening_gross': 90823660,
#   'budget': 245000000,
#   'domestic_gross': 233921534,
#   'international_gross': 512124166,
#   'worldwide_gross': 746045700,
#   'runtime_minutes': 132,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#   'domestic_opening_gross': 65556312,
#   'budget': 245000000,
#   'domestic_gross': 291710957,
#   'international_gross': 453302158,
#   'worldwide_gross': 745013115,
#   'runtime_minutes': 143,
#   'rating': 'PG',
#   'release_month': 'December',
#   'genres': ['Adventure', 'Family', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Monsters University',
#   'domestic_opening_gross': 82429469,
#   'budget': 245000000,
#   'domestic_gross': 268492764,
#   'international_gross': 475066843,
#   'worldwide_gross': 743559607,
#   'runtime_minutes': 104,
#   'rating': 'G',
#   'release_month': 'June',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Matrix Reloaded',
#   'domestic_opening_gross': 91774413,
#   'budget': 245000000,
#   'domestic_gross': 281576461,
#   'international_gross': 460271476,
#   'worldwide_gross': 741847937,
#   'runtime_minutes': 138,
#   'rating': 'R',
#   'release_month': 'May',
#   'genres': ['Action', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Up',
#   'domestic_opening_gross': 68108790,
#   'budget': 245000000,
#   'domestic_gross': 293004164,
#   'international_gross': 442094938,
#   'worldwide_gross': 735099102,
#   'runtime_minutes': 96,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Ne Zha',
#   'domestic_opening_gross': 1015755,
#   'budget': 245000000,
#   'domestic_gross': 3695533,
#   'international_gross': 722367938,
#   'worldwide_gross': 726063471,
#   'runtime_minutes': 110,
#   'rating': None,
#   'release_month': 'July',
#   'genres': ['Action',
#    'Adventure',
#    'Animation',
#    'Family',
#    'Fantasy',
#    'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Gravity',
#   'domestic_opening_gross': 55785112,
#   'budget': 245000000,
#   'domestic_gross': 274092705,
#   'international_gross': 449100000,
#   'worldwide_gross': 723192705,
#   'runtime_minutes': 91,
#   'rating': 'PG-13',
#   'release_month': 'October',
#   'genres': ['Drama', 'Sci-Fi', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Captain America: The Winter Soldier',
#   'domestic_opening_gross': 95023721,
#   'budget': 245000000,
# ...
#   'budget': 245000000,
#   'domestic_gross': 130168683,
#   'international_gross': 475256474,
#   'worldwide_gross': 605425157,
#   'runtime_minutes': 154,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Madagascar: Escape 2 Africa',
#   'domestic_opening_gross': 63106589,
#   'budget': 245000000,
#   'domestic_gross': 180010950,
#   'international_gross': 423889404,
#   'worldwide_gross': 603900354,
#   'runtime_minutes': 89,
#   'rating': 'PG',
#   'release_month': 'October',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'War of the Worlds',
#   'domestic_opening_gross': 64878725,
#   'budget': 245000000,
#   'domestic_gross': 234280354,
#   'international_gross': 369592765,
#   'worldwide_gross': 603873119,
#   'runtime_minutes': 116,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Adventure', 'Sci-Fi', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Tangled',
#   'domestic_opening_gross': 48767052,
#   'budget': 245000000,
#   'domestic_gross': 200821936,
#   'international_gross': 391640023,
#   'worldwide_gross': 592461959,
#   'runtime_minutes': 100,
#   'rating': 'PG',
#   'release_month': 'November',
#   'genres': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Musical',
#    'Romance'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Quantum of Solace',
#   'domestic_opening_gross': 67528882,
#   'budget': 245000000,
#   'domestic_gross': 168368427,
#   'international_gross': 421212055,
#   'worldwide_gross': 589580482,
#   'runtime_minutes': 106,
#   'rating': 'PG-13',
#   'release_month': 'October',
#   'genres': ['Action', 'Adventure', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Men in Black',
#   'domestic_opening_gross': 51068455,
#   'budget': 245000000,
#   'domestic_gross': 250690539,
#   'international_gross': 338700000,
#   'worldwide_gross': 589390539,
#   'runtime_minutes': 98,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Comedy', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Croods',
#   'domestic_opening_gross': 43639736,
#   'budget': 245000000,
#   'domestic_gross': 187168425,
#   'international_gross': 400036894,
#   'worldwide_gross': 587205319,
#   'runtime_minutes': 98,
#   'rating': 'PG',
#   'release_month': 'March',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Hangover Part II',
#   'domestic_opening_gross': 85946294,
#   'budget': 245000000,
#   'domestic_gross': 254464305,
#   'international_gross': 332300000,
#   'worldwide_gross': 586764305,
#   'runtime_minutes': 102,
#   'rating': 'R',
#   'release_month': 'May',
#   'genres': ['Comedy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Iron Man',
#   'domestic_opening_gross': 98618668,
#   'budget': 245000000,
#   'domestic_gross': 319034126,
#   'international_gross': 266762121,
#   'worldwide_gross': 585796247,
#   'runtime_minutes': 126,
#   'rating': 'PG-13',
#   'release_month': 'April',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'I Am Legend',
#   'domestic_opening_gross': 77211321,
#   'budget': 245000000,
#   'domestic_gross': 256393010,
#   'international_gross': 329017042,
#   'worldwide_gross': 585410052,
#   'runtime_minutes': 101,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Drama', 'Sci-Fi', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Ready Player One',
#   'domestic_opening_gross': 41764050,
#   'budget': 245000000,
#   'domestic_gross': 137690172,
#   'international_gross': 445203499,
#   'worldwide_gross': 582893671,
#   'runtime_minutes': 140,
#   'rating': 'PG-13',
#   'release_month': 'March',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Monsters, Inc.',
#   'domestic_opening_gross': 62577067,
#   'budget': 245000000,
#   'domestic_gross': 290642256,
#   'international_gross': 289064814,
#   'worldwide_gross': 579707070,
#   'runtime_minutes': 92,
#   'rating': 'G',
#   'release_month': 'November',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Operation Red Sea',
#   'domestic_opening_gross': 436059,
#   'budget': 245000000,
#   'domestic_gross': 1543547,
#   'international_gross': 577786879,
#   'worldwide_gross': 579330426,
#   'runtime_minutes': 142,
#   'rating': None,
#   'release_month': 'February',
#   'genres': ['Action', 'Drama', 'Thriller', 'War'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Night at the Museum',
#   'domestic_opening_gross': 30433781,
#   'budget': 245000000,
#   'domestic_gross': 250863268,
#   'international_gross': 323617961,
#   'worldwide_gross': 574481229,
#   'runtime_minutes': 108,
#   'rating': 'PG',
#   'release_month': 'December',
#   'genres': ['Adventure', 'Comedy', 'Family', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Fifty Shades of Grey',
#   'domestic_opening_gross': 85171450,
#   'budget': 245000000,
#   'domestic_gross': 166167230,
#   'international_gross': 403484237,
#   'worldwide_gross': 569651467,
#   'runtime_minutes': 125,
#   'rating': 'R',
#   'release_month': 'February',
#   'genres': ['Drama', 'Romance', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Kong: Skull Island',
#   'domestic_opening_gross': 61025472,
#   'budget': 245000000,
#   'domestic_gross': 168052812,
#   'international_gross': 398600000,
#   'worldwide_gross': 566652812,
#   'runtime_minutes': 118,
#   'rating': 'PG-13',
#   'release_month': 'March',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Smurfs',
#   'domestic_opening_gross': 35611637,
#   'budget': 245000000,
#   'domestic_gross': 142614158,
#   'international_gross': 421135165,
#   'worldwide_gross': 563749323,
#   'runtime_minutes': 103,
#   'rating': 'PG',
#   'release_month': 'July',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'King Kong',
#   'domestic_opening_gross': 50130145,
#   'budget': 245000000,
#   'domestic_gross': 218080025,
#   'international_gross': 344283424,
#   'worldwide_gross': 562363449,
#   'runtime_minutes': 187,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Drama', 'Romance'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Cars 2',
#   'domestic_opening_gross': 66135507,
#   'budget': 245000000,
#   'domestic_gross': 191452396,
#   'international_gross': 368400000,
#   'worldwide_gross': 559852396,
#   'runtime_minutes': 106,
#   'rating': 'G',
#   'release_month': 'June',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Sci-Fi', 'Sport'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Puss in Boots',
#   'domestic_opening_gross': 34077439,
#   'budget': 245000000,
#   'domestic_gross': 149260504,
#   'international_gross': 405726973,
#   'worldwide_gross': 554987477,
#   'runtime_minutes': 90,
#   'rating': 'PG',
#   'release_month': 'October',
#   'genres': ['Action',
#    'Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Mystery'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Mermaid',
#   'domestic_opening_gross': 985052,
#   'budget': 245000000,
#   'domestic_gross': 3232685,
#   'international_gross': 550577543,
#   'worldwide_gross': 553810228,
#   'runtime_minutes': 94,
#   'rating': 'R',
#   'release_month': 'February',
#   'genres': ['Comedy', 'Drama', 'Fantasy', 'Romance'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Armageddon',
#   'domestic_opening_gross': 36089972,
#   'budget': 245000000,
#   'domestic_gross': 201578182,
#   'international_gross': 352131606,
#   'worldwide_gross': 553709788,
#   'runtime_minutes': 151,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Day After Tomorrow',
#   'domestic_opening_gross': 68743584,
#   'budget': 245000000,
#   'domestic_gross': 186740799,
#   'international_gross': 365898772,
#   'worldwide_gross': 552639571,
#   'runtime_minutes': 124,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Ted',
#   'domestic_opening_gross': 54415205,
#   'budget': 245000000,
#   'domestic_gross': 218815487,
#   'international_gross': 330552828,
#   'worldwide_gross': 549368315,
#   'runtime_minutes': 106,
#   'rating': 'R',
#   'release_month': 'June',
#   'genres': ['Comedy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'American Sniper',
#   'domestic_opening_gross': 633456,
#   'budget': 245000000,
#   'domestic_gross': 350126372,
#   'international_gross': 197300000,
#   'worldwide_gross': 547426372,
#   'runtime_minutes': 133,
#   'rating': 'R',
#   'release_month': 'December',
#   'genres': ['Action', 'Biography', 'Drama', 'War'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Mission: Impossible II',
#   'domestic_opening_gross': 57845297,
#   'budget': 245000000,
#   'domestic_gross': 215409889,
#   'international_gross': 330978219,
#   'worldwide_gross': 546388108,
#   'runtime_minutes': 123,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Detective Chinatown 2',
#   'domestic_opening_gross': 704047,
#   'budget': 245000000,
#   'domestic_gross': 1983984,
#   'international_gross': 542201172,
#   'worldwide_gross': 544185156,
#   'runtime_minutes': 121,
#   'rating': 'R',
#   'release_month': 'February',
#   'genres': ['Action', 'Comedy', 'Mystery'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'X-Men: Apocalypse',
#   'domestic_opening_gross': 65769562,
#   'budget': 245000000,
#   'domestic_gross': 155442489,
#   'international_gross': 388491616,
#   'worldwide_gross': 543934105,
#   'runtime_minutes': 144,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Sherlock Holmes: A Game of Shadows',
#   'domestic_opening_gross': 39637079,
#   'budget': 245000000,
#   'domestic_gross': 186848418,
#   'international_gross': 357000000,
#   'worldwide_gross': 543848418,
#   'runtime_minutes': 129,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Mystery'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Despicable Me',
#   'domestic_opening_gross': 56397125,
#   'budget': 245000000,
#   'domestic_gross': 251513985,
#   'international_gross': 291600000,
#   'worldwide_gross': 543113985,
#   'runtime_minutes': 95,
#   'rating': 'PG',
#   'release_month': 'July',
#   'genres': ['Animation', 'Comedy', 'Crime', 'Family', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Cinderella',
#   'domestic_opening_gross': 67877361,
#   'budget': 245000000,
#   'domestic_gross': 201151353,
#   'international_gross': 341206978,
#   'worldwide_gross': 542358331,
#   'runtime_minutes': 105,
#   'rating': 'PG',
#   'release_month': 'March',
#   'genres': ['Drama', 'Family', 'Fantasy', 'Romance'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Madagascar',
#   'domestic_opening_gross': 47224594,
#   'budget': 245000000,
#   'domestic_gross': 193595521,
#   'international_gross': 348468325,
#   'worldwide_gross': 542063846,
#   'runtime_minutes': 86,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'World War Z',
#   'domestic_opening_gross': 66411834,
#   'budget': 245000000,
#   'domestic_gross': 202359711,
#   'international_gross': 337648165,
#   'worldwide_gross': 540007876,
#   'runtime_minutes': 116,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Horror', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Brave',
#   'domestic_opening_gross': 66323594,
#   'budget': 245000000,
#   'domestic_gross': 237283207,
#   'international_gross': 301700000,
#   'worldwide_gross': 538983207,
#   'runtime_minutes': 93,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Star Wars: Episode V - The Empire Strikes Back',
#   'domestic_opening_gross': 4910483,
#   'budget': 245000000,
#   'domestic_gross': 292753960,
#   'international_gross': 190685234,
#   'worldwide_gross': 538375067,
#   'runtime_minutes': 124,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Simpsons Movie',
#   'domestic_opening_gross': 74036787,
#   'budget': 245000000,
#   'domestic_gross': 183135014,
#   'international_gross': 353279279,
#   'worldwide_gross': 536414293,
#   'runtime_minutes': 87,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Adventure', 'Animation', 'Comedy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Revenant',
#   'domestic_opening_gross': 474560,
#   'budget': 245000000,
#   'domestic_gross': 183637894,
#   'international_gross': 349312609,
#   'worldwide_gross': 532950503,
#   'runtime_minutes': 156,
#   'rating': 'R',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Drama', 'History', 'Western'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'The Meg',
#   'domestic_opening_gross': 45402195,
#   'budget': 245000000,
#   'domestic_gross': 145443742,
#   'international_gross': 384815731,
#   'worldwide_gross': 530259473,
#   'runtime_minutes': 113,
#   'rating': 'PG-13',
#   'release_month': 'August',
#   'genres': ['Action', 'Horror', 'Sci-Fi', 'Thriller'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']},
#  {'title': 'Ralph Breaks the Internet',
#   'domestic_opening_gross': 56237634,
#   'budget': 245000000,
#   'domestic_gross': 201091711,
#   'international_gross': 328232251,
#   'worldwide_gross': 529323962,
#   'runtime_minutes': 112,
#   'rating': 'PG',
#   'release_month': 'November',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy'],
#   'actors': ['Daisy Ridley',
#    'John Boyega',
#    'Oscar Isaac',
#    'Domhnall Gleeson']}]

# %%
lifetime_movies_info = pd.DataFrame(lifetime_movie_data)
lifetime_movies_info.set_index('title', inplace = True)

# %%
lifetime_movies_info
# Out:
#                                             domestic_opening_gross     budget  \
# title
# Avengers: Endgame                                        357115007  356000000
# Avatar                                                    77025481  237000000
# Titanic                                                   28638131  200000000
# Star Wars: Episode VII - The Force Awakens               247966675  245000000
#
#                                             domestic_gross  \
# title
# Avengers: Endgame                                858373000
# Avatar                                           760507625
# Titanic                                          659363944
# Star Wars: Episode VII - The Force Awakens       936662225
#
#                                             international_gross  \
# title
# Avengers: Endgame                                    1939427564
# Avatar                                               2029931467
# Titanic                                              1812387978
# Star Wars: Episode VII - The Force Awakens           1131791908
#
#                                             worldwide_gross  runtime_minutes  \
# title
# Avengers: Endgame                                2797800564              181
# Avatar                                           2790439092              162
# Titanic                                          2471751922              194
# Star Wars: Episode VII - The Force Awakens       2068454133              138
#
#                                            rating release_month  \
# title
# Avengers: Endgame                           PG-13         April
# Avatar                                      PG-13      December
# Titanic                                     PG-13      December
# Star Wars: Episode VII - The Force Awakens  PG-13      December
#
#                                                                           genres  \
# title
# Avengers: Endgame                             [Action, Adventure, Drama, Sci-Fi]
# Avatar                                      [Action, Adventure, Fantasy, Sci-Fi]
# Titanic                                                         [Drama, Romance]
# Star Wars: Episode VII - The Force Awakens           [Action, Adventure, Sci-Fi]
#
#                                                                                        actors
# title
# Avengers: Endgame                           [Daisy Ridley, John Boyega, Oscar Isaac, Domhn...
# Avatar                                      [Daisy Ridley, John Boyega, Oscar Isaac, Domhn...
# Titanic                                     [Daisy Ridley, John Boyega, Oscar Isaac, Domhn...
# Star Wars: Episode VII - The Force Awakens  [Daisy Ridley, John Boyega, Oscar Isaac, Domhn...

# %%
lifetime_movies = lifetime_movies.merge(lifetime_movies_info, left_index=True, right_index=True)

lifetime_movies.head()
# Out:
#                                                                         link_stub  \
# Avengers: Endgame                           /title/tt4154796/?ref_=bo_cso_table_1
# Avatar                                      /title/tt0499549/?ref_=bo_cso_table_2
# Titanic                                     /title/tt0120338/?ref_=bo_cso_table_3
# Star Wars: Episode VII - The Force Awakens  /title/tt2488496/?ref_=bo_cso_table_4
# Avengers: Infinity War                      /title/tt4154756/?ref_=bo_cso_table_5
#
#                                            rank  \
# Avengers: Endgame                             1
# Avatar                                        2
# Titanic                                       3
# Star Wars: Episode VII - The Force Awakens    4
# Avengers: Infinity War                        5
#
#                                                                                  title  \
# Avengers: Endgame                                                    Avengers: Endgame
# Avatar                                                                          Avatar
# Titanic                                                                        Titanic
# Star Wars: Episode VII - The Force Awakens  Star Wars: Episode VII - The Force Awakens
# Avengers: Infinity War                                          Avengers: Infinity War
#
#                                                   WW_gross domestic_gross_x  \
# Avengers: Endgame                           $2,797,800,564     $858,373,000
# Avatar                                      $2,790,439,092     $760,507,625
# Titanic                                     $2,471,751,922     $659,363,944
# Star Wars: Episode VII - The Force Awakens  $2,068,454,133     $936,662,225
# Avengers: Infinity War                      $2,048,359,754     $678,815,482
#
#                                             dom_%   foreign_gross  for_%  \
# Avengers: Endgame                           30.7%  $1,939,427,564  69.3%
# Avatar                                      27.2%  $2,029,931,467  72.8%
# Titanic                                     26.7%  $1,812,387,978  73.3%
# Star Wars: Episode VII - The Force Awakens  45.3%  $1,131,791,908  54.7%
# Avengers: Infinity War                      33.1%  $1,369,544,272  66.9%
#
#                                            release_year  \
# Avengers: Endgame                                  2019
# Avatar                                             2009
# Titanic                                            1997
# Star Wars: Episode VII - The Force Awakens         2015
# Avengers: Infinity War                             2018
#
#                                             domestic_opening_gross     budget  \
# Avengers: Endgame                                        357115007  245000000
# Avatar                                                    77025481  245000000
# Titanic                                                   28638131  245000000
# Star Wars: Episode VII - The Force Awakens               247966675  245000000
# Avengers: Infinity War                                   257698183  245000000
#
#                                             domestic_gross_y  \
# Avengers: Endgame                                  858373000
# Avatar                                             760507625
# Titanic                                            659363944
# Star Wars: Episode VII - The Force Awakens         936662225
# Avengers: Infinity War                             678815482
#
#                                             international_gross  \
# Avengers: Endgame                                    1939427564
# Avatar                                               2029931467
# Titanic                                              1812387978
# Star Wars: Episode VII - The Force Awakens           1131791908
# Avengers: Infinity War                               1369544272
#
#                                             worldwide_gross  runtime_minutes  \
# Avengers: Endgame                                2797800564            181.0
# Avatar                                           2790439092            162.0
# Titanic                                          2471751922            194.0
# Star Wars: Episode VII - The Force Awakens       2068454133            138.0
# Avengers: Infinity War                           2048359754            149.0
#
#                                            rating release_month  \
# Avengers: Endgame                           PG-13         April
# Avatar                                      PG-13      December
# Titanic                                     PG-13      December
# Star Wars: Episode VII - The Force Awakens  PG-13      December
# Avengers: Infinity War                      PG-13         April
#
#                                                                           genres  \
# Avengers: Endgame                             [Action, Adventure, Drama, Sci-Fi]
# Avatar                                      [Action, Adventure, Fantasy, Sci-Fi]
# Titanic                                                         [Drama, Romance]
# Star Wars: Episode VII - The Force Awakens           [Action, Adventure, Sci-Fi]
# Avengers: Infinity War                               [Action, Adventure, Sci-Fi]
#
#                                                                                        actors
# Avengers: Endgame                           [Daisy Ridley, John Boyega, Oscar Isaac, Domhn...
# Avatar                                      [Daisy Ridley, John Boyega, Oscar Isaac, Domhn...
# Titanic                                     [Daisy Ridley, John Boyega, Oscar Isaac, Domhn...
# Star Wars: Episode VII - The Force Awakens  [Daisy Ridley, John Boyega, Oscar Isaac, Domhn...
# Avengers: Infinity War                      [Daisy Ridley, John Boyega, Oscar Isaac, Domhn...

# %%
lifetime_movies.to_csv('lifetime_movies.csv')

# %% [markdown]
# ### IMDB Top 100 Actors 2018

# %%
url = 'https://www.imdb.com/list/ls023242359/'
response = requests.get(url)
page = response.text
soup = BeautifulSoup(page, 'lxml')

# %%
soup.find_all('span', class_='lister-item-index')[0].text

# %%
soup.find('div', class_='lister-item-content').find_all('a')

# %%
soup.find('div', class_='lister-item-content').find('a').text.split('\n')[0]

# %%
top_list = soup.find('div', class_='lister-list').find_all('a')
top_list

# %%
soup.find('div', class_='lister-list').find_all('a')[1].text.split('\n')[0]

# %%
top_actor = []
for top in top_list:
    top = top.text.split('\n')[0]
    top_actor += [top]
  
top_actor

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver
driver = webdriver.Chrome(chromedriver)
driver.get('https://www.imdb.com/list/ls023242359/')

assert "imdb" in driver.title

continue_link = driver.find_element_by_tag_name('a')
elem = driver.find_elements_by_xpath("//*[@href]/name*")
#x = str(continue_link)
#print(continue_link)
print(elem)

# %%
soup.find('div', class_='lister-list').find_all('a').get('href', ref_='nmls_hd')
