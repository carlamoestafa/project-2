# %% [markdown]
# # IMPORTING LIBRARIES

# %%
# import libraries

import pandas as pd
import requests
import json
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# !pip install pytrends
from pytrends.request import TrendReq
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# # ACQUIRING DATA

# %% [markdown]
# ## GoogleTrends Data

# %% [markdown]
# ## OECD Data

# %%
url = 'https://www.fiaformula2.com/Calendar' 

response = requests.get(url)
response.status_code
# Out:
# 200

# %%
response.text[:1000]
# Out:
# '<!DOCTYPE html><html lang="en"><head><title>Calendar &amp; Results for the FIA Formula 2 2021 Championship: The Road to F1.</title><meta charSet="utf-8"/><meta name="viewport" content="initial-scale=1.0, width=device-width"/><meta name="description" content="Calendar &amp; Results for the FIA Formula 2 2021 Championship: The Road to F1.Round: 1 Sakhir Bahrain 26-28 Mar 2021,Round: 2 Monte Carlo Monaco 20-22 May 2021,Round: 3 Baku Azerbaijan 04-06 Jun 2021,Round: 4 Silverstone Great Britain 16-18 Jul 2021,Round: 5 Monza Italy 10-12 Sept 2021,Round: 6 Sochi Russia 24-26 Sept 2021,Round: 7 Jeddah Saudi Arabia 03-05 Dec 2021,Round: 8 Yas Island United Arab Emirates 10-12 Dec 2021"/><meta name="theme-color" content="#000000"/><meta property="fb:pages" content="568665409957112"/><meta property="fb:app_id" content="833421847009900"/><meta property="fb:admins" content="568665409957112"/><meta property="og:title" content="Calendar &amp; Results for the FIA Formula 2 2021 Championship: The Ro
# ...

# %%
page = response.text

# %%
response.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
soup = BeautifulSoup(page, "lxml")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    Calendar &amp; Results for the FIA Formula 2 2021 Championship: The Road to F1.
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="initial-scale=1.0, width=device-width" name="viewport"/>
#   <meta content="Calendar &amp; Results for the FIA Formula 2 2021 Championship: The Road to F1.Round: 1 Sakhir Bahrain 26-28 Mar 2021,Round: 2 Monte Carlo Monaco 20-22 May 2021,Round: 3 Baku Azerbaijan 04-06 Jun 2021,Round: 4 Silverstone Great Britain 16-18 Jul 2021,Round: 5 Monza Italy 10-12 Sept 2021,Round: 6 Sochi Russia 24-26 Sept 2021,Round: 7 Jeddah Saudi Arabia 03-05 Dec 2021,Round: 8 Yas Island United Arab Emirates 10-12 Dec 2021" name="description"/>
#   <meta content="#000000" name="theme-color"/>
#   <meta content="568665409957112" property="fb:pages"/>
#   <meta content="833421847009900" property="fb:app_id"/>
#   <meta content="568665409957112" property="fb:admins"/>
# ...

# %%
next_page = soup.find('div', id = "__next")
print(next_page.prettify())
# Out:
# <div id="__next">
#  <div class="theme-f2 site-wrapper">
#   <header class="site-nav">
#    <div class="nav-mobile-wrapper remove-for-app">
#     <div class="nav-mobile-header mobile-nav-helper">
#      <div class="nav-burger">
#       <button aria-label="Toggle Menu" class="menu open" name="button" type="button">
#        <span class="text-hide">
#         Toggle Navigation&gt;
#        </span>
#       </button>
#      </div>
#      <div class="logo menu open">
#       <a href="/">
#        <span>
#         <img alt="Formula 2" src="data:image/svg+xml;base64,..."/>
#        </span>
#       </a>
#      </div>
#      <div class="fia-logo-mb">
#       <a href="https://www.fia.com/" rel="noopener" target="_blank">
#        <img alt="Federation Internationale de l'Automobile" src="data:image/png;base64,..."/>
#       </a>
#      </div>
#     </div>
#     <div class="nav-wrapper">
#      <div class="nav-primary table-footer-group" id="primaryNav">
#       <div class="nav-width">
# ...

# %%
season = soup.find(class_='col-xl-6')
print(season.prettify())
# Out:
# <div class="col-xl-6">
#  <h1>
#   Calendar
#   <span>
#    Formula 2 2021
#   </span>
#  </h1>
# </div>

# %%
standing = soup.find(class_='col-xl-6 standing-form')
print(standing.prettify())
# Out:
# <div class="col-xl-6 standing-form">
#  <form>
#   <div class="form-item">
#    <label class="" for="inlineFormCustomSelect">
#     Select Season:
#    </label>
#    <div class="custom-select-wrapper">
#     <select class="custom-select" id="inlineFormCustomSelect">
#      <option selected="" value="178">
#       Formula 2 2021
#      </option>
#      <option value="177">
#       Formula 2 2020
#      </option>
#      <option value="176">
#       Formula 2 2019
#      </option>
#      <option value="175">
#       Formula 2 2018
#      </option>
#      <option value="174">
#       Formula 2 2017
#      </option>
#     </select>
#     <i class="icon icon-Arrow-dropdown">
#     </i>
#    </div>
#   </div>
#   <div class="btn-wrapper">
#    <button class="cta--primary" type="submit">
#     Go
#     <i class="icon icon-Chevron-Right">
#     </i>
#    </button>
#   </div>
#  </form>
# </div>

# %%
report = soup.find(class_='col-12 col-md-7 col-lg-7')
print(report.prettify())
report.text
# Out:
# <div class="col-12 col-md-7 col-lg-7">
#  <div class="rich-text font-text-body">
#   <p>
#    The fifth FIA Formula 2 season is set to commence at Bahrain in March. The campaign will comprise a total of eight rounds, all support events of the Formula 1 World Championship.
#   </p>
#   <p>
#    Following a change to the Sporting Regulations, the new season will see three races per round - the previous total was two - forming a 24-race season. The new race weekend format can be found
#    <a href="https://www.fiaformula2.com/About/DyImndAsBNFcqYOOm4yWS/the-regulations-f2">
#     HERE
#    </a>
#    .
#   </p>
#   <p>
#    Make sure you're watching to see who will follow in the footsteps of 2020 F2 Champion Mick Schumacher.
#   </p>
#  </div>
# </div>
# ...

# %%
calendar = soup.find(class_='container calendar-layout')
print(calendar.prettify())
# Out:
# <div class="container calendar-layout">
#  <div class="row">
#  </div>
#  <div class="row">
#   <div class="col-12 col-sm-6 col-lg-4 col-xl-3 result-card">
#    <a href="/Results?raceid=1027">
#     <div class="container wrapper card-upcoming">
#      <h6>
#       Round
#       <!-- -->
#       1
#      </h6>
#      <div class="row card-header">
#       <div class="col-8">
#        <p class="date">
#         <span class="start-date">
#          26
#         </span>
#         <span>
#          -
#         </span>
#         <span class="end-date">
#          28
#         </span>
#         <span class="month">
#          March
#         </span>
#        </p>
#       </div>
#       <div class="col-4">
#        <span class="flag">
#         <img data-src="https://res.cloudinary.com/prod-f2f3/c_fill,dpr_1.0,f_auto,g_auto,w_36/v1/f2/global/flags/BH" loading="lazy" width="36"/>
#        </span>
#       </div>
#      </div>
#      <div class="row">
#       <div class="col">
# ...

# %%
result_card = soup.find(class_='col-12 col-sm-6 col-lg-4 col-xl-3 result-card')
print(result_card.prettify())
# Out:
# <div class="col-12 col-sm-6 col-lg-4 col-xl-3 result-card">
#  <a href="/Results?raceid=1027">
#   <div class="container wrapper card-upcoming">
#    <h6>
#     Round
#     <!-- -->
#     1
#    </h6>
#    <div class="row card-header">
#     <div class="col-8">
#      <p class="date">
#       <span class="start-date">
#        26
#       </span>
#       <span>
#        -
#       </span>
#       <span class="end-date">
#        28
#       </span>
#       <span class="month">
#        March
#       </span>
#      </p>
#     </div>
#     <div class="col-4">
#      <span class="flag">
#       <img data-src="https://res.cloudinary.com/prod-f2f3/c_fill,dpr_1.0,f_auto,g_auto,w_36/v1/f2/global/flags/BH" loading="lazy" width="36"/>
#      </span>
#     </div>
#    </div>
#    <div class="row">
#     <div class="col">
#      <div class="events">
#       <span class="event-place">
#        <span class="ellipsis">
#         Sakhir
#        </span>
#        <i class="icon icon-Chevron-Right">
# ...

# %%
result_header = soup.find(class_='row card-header')
print(result_header.prettify())
# Out:
# <div class="row card-header">
#  <div class="col-8">
#   <p class="date">
#    <span class="start-date">
#     26
#    </span>
#    <span>
#     -
#    </span>
#    <span class="end-date">
#     28
#    </span>
#    <span class="month">
#     March
#    </span>
#   </p>
#  </div>
#  <div class="col-4">
#   <span class="flag">
#    <img data-src="https://res.cloudinary.com/prod-f2f3/c_fill,dpr_1.0,f_auto,g_auto,w_36/v1/f2/global/flags/BH" loading="lazy" width="36"/>
#   </span>
#  </div>
# </div>

# %%
card_row = soup.find(class_='row')
print(card_row.prettify())
# Out:
# <div class="row">
#  <div class="col-xl-6">
#   <h1>
#    Calendar
#    <span>
#     Formula 2 2021
#    </span>
#   </h1>
#  </div>
#  <div class="col-xl-6 standing-form">
#   <form>
#    <div class="form-item">
#     <label class="" for="inlineFormCustomSelect">
#      Select Season:
#     </label>
#     <div class="custom-select-wrapper">
#      <select class="custom-select" id="inlineFormCustomSelect">
#       <option selected="" value="178">
#        Formula 2 2021
#       </option>
#       <option value="177">
#        Formula 2 2020
#       </option>
#       <option value="176">
#        Formula 2 2019
#       </option>
#       <option value="175">
#        Formula 2 2018
#       </option>
#       <option value="174">
#        Formula 2 2017
#       </option>
#      </select>
#      <i class="icon icon-Arrow-dropdown">
#      </i>
#     </div>
#    </div>
#    <div class="btn-wrapper">
#     <button class="cta--primary" type="submit">
#      Go
# ...

# %%
driver_row = soup.find(class_='row drivers')
print(driver_row.prettify())
# Out:
# <div class="row drivers">
#  <div class="col">
#   <div class="img-wrapper">
#    <img data-src="https://res.cloudinary.com/prod-f2f3/ar_16:9,c_fill,dpr_1.0,f_auto,g_auto,w_300/v1/f2/global/circuits/icons-positive/BH" loading="lazy" width="300"/>
#   </div>
#  </div>
# </div>

# %%
for element in soup.find_all(class_='nav-mainlink'):
    print(element.prettify())
# Out:
# <a class="nav-mainlink" href="/Teams-and-Drivers">
#  TEAMS &amp; DRIVERS
# </a>
# <a class="nav-mainlink" href="/Standings/Driver">
#  STANDINGS
# </a>
# <a class="nav-mainlink" href="/Calendar">
#  CALENDAR &amp; RESULTS
# </a>
# <a class="nav-mainlink" href="/Latest/Tag/47uLuvOOatsFsJnhohv3aA/Guide-To">
#  Guide To f2
# </a>
# <a class="nav-mainlink" href="/Latest">
#  LATEST NEWS
# </a>
# <a class="nav-mainlink" href="/livetiming/index.html">
#  LIVE TIMING
# </a>

# %% [markdown]
# ## Let see 2019 season
