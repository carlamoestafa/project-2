# %% [markdown]
# # IMPORTING LIBRARIES

# %%
# import libraries

import pandas as pd
import requests
import json
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# !pip install pytrends
from pytrends.request import TrendReq
from bs4 import BeautifulSoup
import requests
# Out:
# Requirement already satisfied: pytrends in /Users/carlamoestafa/opt/anaconda3/lib/python3.8/site-packages (4.7.3)
# Requirement already satisfied: lxml in /Users/carlamoestafa/opt/anaconda3/lib/python3.8/site-packages (from pytrends) (4.5.2)
# Requirement already satisfied: pandas>=0.25 in /Users/carlamoestafa/opt/anaconda3/lib/python3.8/site-packages (from pytrends) (1.0.5)
# Requirement already satisfied: requests in /Users/carlamoestafa/opt/anaconda3/lib/python3.8/site-packages (from pytrends) (2.24.0)
# Requirement already satisfied: numpy>=1.13.3 in /Users/carlamoestafa/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25->pytrends) (1.18.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/carlamoestafa/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25->pytrends) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/carlamoestafa/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25->pytrends) (2020.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/carlamoestafa/opt/anaconda3/lib/python3.8/site-packages (from requests->pytrends) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/carlamoestafa/opt/anaconda3/lib/python3.8/site-packages (from requests->pytrends) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /Users/carlamoestafa/opt/anaconda3/lib/python3.8/site-packages (from requests->pytrends) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/carlamoestafa/opt/anaconda3/lib/python3.8/site-packages (from requests->pytrends) (3.0.4)
# Requirement already satisfied: six>=1.5 in /Users/carlamoestafa/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.6.1->pandas>=0.25->pytrends) (1.15.0)

# %% [markdown]
# # ACQUIRING DATA

# %% [markdown]
# ## GoogleTrends Data

# %% [markdown]
# ## OECD Data

# %%
url = 'https://data.oecd.org' 

response = requests.get(url)
response.status_code
# Out:
# 200

# %%
response.text[:1000]
# Out:
# '<!DOCTYPE html>\r\n<html lang="en">\r\n<head>\r\n<meta charset="utf-8">\r\n<title>OECD Data</title>\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0">\r\n<meta name="referrer" content="always">\r\n<meta name="description" content="Find, compare and share the latest OECD data: charts, maps, tables and related publications" />\n\r\n<meta name="keywords" content="OECD statistics, country comparison, country profile, OECD data" />\n  \r\n<script type="text/javascript">\r\n  var languageSwitch = \'<a href="">â\x80º </a><a href="/fr/accueil/">Fran&ccedil;ais</a><!--<a href="/home/">English</a>-->\';\r\n</script>\r\n<script>\r\ndataLayer = [{\r\n\t\'siteName\':"data",\r\n\t\'siteEnvironment\':"live",\r\n\t\'pageLanguage\':"en",\r\n}];\r\n</script><meta name="twitter:card" content="summary">\r\n<meta name="twitter:description" content="Find, compare and share OECD data.">\r\n<meta name="twitter:image" content="http://data.oecd.org/media/dataportal/custo'

# %%
page = response.text

# %%
soup = BeautifulSoup(page, "lxml")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>OECD Data</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <meta content="always" name="referrer"/>
# <meta content="Find, compare and share the latest OECD data: charts, maps, tables and related publications" name="description"/>
# <meta content="OECD statistics, country comparison, country profile, OECD data" name="keywords"/>
# <script type="text/javascript">
#   var languageSwitch = '<a href="">âº </a><a href="/fr/accueil/">Fran&ccedil;ais</a><!--<a href="/home/">English</a>-->';
# </script>
# <script>
# dataLayer = [{
# 	'siteName':"data",
# 	'siteEnvironment':"live",
# 	'pageLanguage':"en",
# }];
# </script><meta content="summary" name="twitter:card"/>
# <meta content="Find, compare and share OECD data." name="twitter:description"/>
# <meta content="http://data.oecd.org/media/dataportal/custom/OECD_110x110.png" name="twitter:image"/>
# <meta content="@OECD" name="twitter:site"/>
# <meta content="website" property="og:type"/>
# <meta content="Find, compare and share OECD data." property="og:description"/>
# <meta content="http://data.oecd.org/media/dataportal/custom/OECD_110x110.png" property="og:image"/>
# <meta content="theOECD" property="og:site_name"/>
# <meta content="OECD data" name="twitter:title"/>
# <meta content="OECD data" property="og:title"/>
# <meta content="http://data.oecd.org" property="og:url"/>
# <!-- Bootstrap stylesheet, necessary dependency -->
# <!--bootstrap-3-0-0.css-->
# <link href="/media/dataportal/stylesheets/lib/bootstrap-3-0-0.css" media="" rel="stylesheet" type="text/css"/>
# <!--end of bootstrap-->
# <!-- Stylesheet for the OECD headers and footers, shared on differet sites -->
# <!--oecd-headers-footers.css-->
# <link href="/media/dataportal/stylesheets/oecd-headers-footers.css" media="" rel="stylesheet" type="text/css"/>
# <!-- Stylesheet for the OECD Data Portal only -->
# <!--main-oecd.css-->
# <!--t4 type="media" id="306057" formatter="css/*"/-->
# <link href="/media/oecdorg/styleassets/images/favicon.ico" rel="icon" type="image/x-icon"/>
# <!-- apple-touch-icon.png -->
# <link href="/media/dataportal/images/apple-touch-icon.png" rel="apple-touch-icon-precomposed"/>
# <!-- apple-touch-icon-72x72.png -->
# <link href="/media/dataportal/images/apple-touch-icon-72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
# <!-- apple-touch-icon-114x114.png -->
# <link href="/media/dataportal/images/apple-touch-icon-114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <!-- apple-touch-icon-144x144.png -->
# <link href="/media/dataportal/images/apple-touch-icon-144x144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <!-- Media query polyfill and HTML5 shim for IE < 9 -->
# <!-- respond-1.4.2.min.js -->
# <!--[if lt IE 9]>
# <script type="text/javascript" src="/media/dataportal/scripts/respond-1.4.2.min.js"></script>
# <script>
# 'abbr article aside audio canvas details figcaption figure footer header main mark meter nav output progress section summary time video'.replace(/\w+/g,function(n){document.createElement(n)})
# </script>
# <![endif]-->
# <!--call custom style-->
# <!-- main.css -->
# <link href="/media/dataportal/stylesheets/main.css" media="" rel="stylesheet" type="text/css"/>
# <!-- cuistom oecd -->
# <link href="/media/dataportal/stylesheets/custom.oecd.css" media="" rel="stylesheet" type="text/css"/>
# <!-- Existing link in Old Style -->
# <link href="/header/index.xml" rel="alternate" title="RSS" type="application/rss+xml"/>
# <script async="" defer="" src="//survey.g.doubleclick.net/async_survey?site=eq5fyz327wxea5asg3u7bva5ge"></script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-WZ3XJR');</script>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-P5JSM4P');</script>
# <!-- End Google Tag Manager -->
# </head>
# <body>
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-WZ3XJR" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-P5JSM4P" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager -->
# <header class="oecd-header oecd-header--bg-light-blue oecd-header--primary-hidden">
# <nav class="container">
# <div class="row">
# <div class="col-sm-1 oecd-header__item oecd-header__logo-and-toggle">
# <div class="oecd-header__logo">
# <div class="sr-only">
#             Organisation for Economic Co-operation and Development (OECD)
#           </div>
# </div>
# <button class="oecd-header__primary-toggle" title="Toggle Menu">
# <span class="oecd-header__menu-open"></span>
# <span class="oecd-header__menu-close">Ã</span>
# <span class="sr-only">Menu</span>
# </button>
# </div>
# <ul class="oecd-header__primary">
# <li class="col-sm-2 oecd-header__item">
# <a class="oecd-header__link" href="http://oecd.org/">OECD.org</a>
# </li>
# <li class="col-sm-2 oecd-header__item oecd-header__item--active">
# <strong class="oecd-header__current-page">Data</strong>
# </li>
# <li class="col-sm-2 oecd-header__item">
# <a class="oecd-header__link" href="http://www.oecd-ilibrary.org/">Publications</a>
# </li>
# <li class="col-sm-2 oecd-header__item oecd-header__secondary-container">
# <a class="oecd-header__link oecd-header__secondary-toggle" href="">More sites</a>
# <ul class="sr-only oecd-header__secondary">
# <li class="oecd-header__item oecd-header__secondary-item oecd-header__secondary-item-first">
# <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecdbetterlifeindex.org/">OECD Better Life Index</a>
# </li>
# <li class="oecd-header__item oecd-header__secondary-item">
# <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecd-ilibrary.org/">OECD iLibrary</a>
# </li>
# <li class="oecd-header__item oecd-header__secondary-item">
# <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecdobserver.org/">OECD Observer</a>
# </li>
# <li class="oecd-header__item oecd-header__secondary-item">
# <a class="oecd-header__link oecd-header__secondary-link" href="http://oecdinsights.org/">OECD Insights blog</a>
# </li>
# <li class="oecd-header__item oecd-header__secondary-item">
# <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecd.org/dev/">OECD Development Centre</a>
# </li>
# <li class="oecd-header__item oecd-header__secondary-item">
# <a class="oecd-header__link oecd-header__secondary-link" href="http://www.fatf-gafi.org/">FATF - Financial Action Task Force</a>
# </li>
# <li class="oecd-header__item oecd-header__secondary-item">
# <a class="oecd-header__link oecd-header__secondary-link" href="http://www.iea.org/">IEA â International Energy Agency</a>
# </li>
# <li class="oecd-header__item oecd-header__secondary-item">
# <a class="oecd-header__link oecd-header__secondary-link" href="http://www.itf-oecd.org/">ITF â International Transport Forum</a>
# </li>
# <li class="oecd-header__item oecd-header__secondary-item">
# <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecd-nea.org/">NEA â Nuclear Energy Agency</a>
# </li>
# <li class="oecd-header__item oecd-header__secondary-item oecd-header__secondary-item-last">
# <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecd.org/swac/">SWAC â Sahel and West Africa Club</a>
# </li>
# </ul>
# </li>
# <li class="col-sm-1 oecd-header__item">
# <a class="oecd-header__link" href="http://oecd.org/newsroom/">News</a>
# </li>
# <li class="col-sm-2 oecd-header__item">
# <a class="oecd-header__link" href="http://oecd.org/careers/">Job vacancies</a>
# </li>
# </ul>
# </div><!-- /row -->
# </nav><!-- /container -->
# </header><!-- /oecd-header -->
# <div class="ddp-root">
# <header>
# <!-- Header with search form -->
# <div class="header-statistics">
# <div class="container">
# <div class="header-statistics-inner">
# <div class="left">
# <div class="logo"></div>
# <h1 class="site-title">
# <a class="home-link" href="/">Data</a>
# </h1>
# <!-- There are two language switches due to the different layouts. The first is shown on mobile, the second on desktop. Both should point to the same site. -->
# <div class="toggle-search-form">
# <i class="icon-ddp-search"></i>
# </div>
# <div class="language-switch language-switch-left">
# <a href="">âº
#     </a><a href="/fr/header/#d.fr.406188">Français</a>
# <!--
#     <a href="/header/#d.en.406188">English</a>
#     -->
# </div>
# </div><!-- /left -->
# <div class="right">
# <div class="language-switch language-switch-right">
# <a href="">âº
#     </a><a href="/fr/header/#d.fr.406188">Français</a>
# <!--
#     <a href="/header/#d.en.406188">English</a>
#     -->
# </div>
# <form action="/searchresults/" class="search-form header-search-form">
# <input class="search-field livesearch" name="q" placeholder="Search for OECD data" type="search"/>
# <button class="btn-search" type="submit">
# <i class="icon-ddp-search"></i>
# <span class="accessible-hide">Search</span>
# </button>
# </form>
# </div><!-- /right -->
# </div><!-- /header-statistics-inner -->
# </div><!-- /container -->
# </div><!-- /header-statistics -->
# <!--meta itemprop="context" content="topic"-->
# <div class="container breadcrumbs" id="breadcrumbs">
# <ul>
# <li><a href="/">OECD Data</a></li>
# <li class="bd-01">Header</li>
# </ul>
# </div><!-- /breadcrumbs -->
# </header>
# <main role="main">
# <div class="container">
# <div class="notifications"></div>
# </div>
# <div class="container">
# <div class="home-jumbotron">
# <div class="row home-jumbotron-row">
# <div class="col-7">
# <p>
# <span class="line">Find, compare and share the latest <b>OECD data</b>: </span><span class="line">charts, maps, tables and related publications â¦</span>
# </p>
# </div>
# <div class="col-4 col-offset-1 home-jumbotron-browse">
# <p class="home-jumbotron-browse-by">Browse by</p>
# <div class="home-jumbotron-dropdowns">
# <div class="dropdown columnisable home-jumbotron-dropdown-topics">
# <a class="dropdown-button home-jumbotron-dropdown-button" href="">
#               topic <i class="icon-ddp-expand-down"></i>
# </a>
# <div class="dropdown-list with-icons topics">
# <ul>
# <li><a href="/agriculture.htm">
# <i class="icon-ddp-agriculture"></i>
# <span class="topic-name">Agriculture</span>
# <small>Agricultural output, Agricultural policy, Fisheries, Sustainable agriculture</small>
# </a></li>
# <li><a href="/development.htm">
# <i class="icon-ddp-development"></i>
# <span class="topic-name">Development</span>
# <small>Development resource flows, Official development assistance (ODA)</small>
# </a></li>
# <li><a href="/economy.htm">
# <i class="icon-ddp-economics"></i>
# <span class="topic-name">Economy</span>
# <small>Corporate sector, Foreign direct investment (FDI), GDP and spending, Household accounts, International trade, Leading indicators, National income, Prices, Productivity</small>
# </a></li>
# <li><a href="/education.htm">
# <i class="icon-ddp-education"></i>
# <span class="topic-name">Education</span>
# <small>Education attainment, Education resources, International student assessment (PISA), Students, Teachers, Youth and the labour market</small>
# </a></li>
# <li><a href="/energy.htm">
# <i class="icon-ddp-energy"></i>
# <span class="topic-name">Energy</span>
# <small>Energy, Transport</small>
# </a></li>
# <li><a href="/environment.htm">
# <i class="icon-ddp-environment"></i>
# <span class="topic-name">Environment</span>
# <small>Air and climate, Biodiversity, Environmental policy, Forest, Materials, Waste, Water</small>
# </a></li>
# <li><a href="/finance.htm">
# <i class="icon-ddp-finance"></i>
# <span class="topic-name">Finance</span>
# <small>Conversion rates, Insurance, Interest rates, Monetary aggregates, Pensions</small>
# </a></li>
# <li><a href="/government.htm">
# <i class="icon-ddp-government"></i>
# <span class="topic-name">Government</span>
# <small>General government, Tax</small>
# </a></li>
# <li><a href="/health.htm">
# <i class="icon-ddp-health"></i>
# <span class="topic-name">Health</span>
# <small>Health care use, Health equipment, Health resources, Health risks, Health status</small>
# </a></li>
# <li><a href="/innovation-and-technology.htm">
# <i class="icon-ddp-science"></i>
# <span class="topic-name">Innovation and Technology</span>
# <small>Broadband access, Entrepreneurship, Industry, Information and communication technology (ICT), Research and development (R&amp;D)</small>
# </a></li>
# <li><a href="/jobs.htm">
# <i class="icon-ddp-jobs"></i>
# <span class="topic-name">Jobs</span>
# <small>Benefits and wages, Earnings and wages, Employment, Unemployment</small>
# </a></li>
# <li><a href="/society.htm">
# <i class="icon-ddp-society"></i>
# <span class="topic-name">Society</span>
# <small>Demography, Inequality, Migration, Population by region, Social protection</small>
# </a></li>
# </ul>
# </div><!-- /dropdown-list -->
# </div><!-- /dropdown -->
# <span class="home-jumbotron-browse-by-or">or</span>
# <div class="dropdown columnisable dropdown-countries home-jumbotron-dropdown-countries">
# <a class="dropdown-button home-jumbotron-dropdown-button" href="">
#               country <i class="icon-ddp-expand-down"></i>
# </a>
# <div class="dropdown-list">
# <p class="dropdown-search">
# <input class="search-country" placeholder="Type to search for a country" type="search"/>
# </p>
# <ul class="countries">
# <li><a href="/australia.htm">Australia</a></li><li><a href="/austria.htm">Austria</a></li><li><a href="/belgium.htm">Belgium</a></li><li><a href="/brazil.htm">Brazil</a></li><li><a href="/canada.htm">Canada</a></li><li><a href="/chile.htm">Chile</a></li><li><a href="/china-people-s-republic-of.htm">China, People's Republic of</a></li><li><a href="/colombia.htm">Colombia</a></li><li><a href="/czech-republic.htm">Czech Republic</a></li><li><a href="/denmark.htm">Denmark</a></li><li><a href="/estonia.htm">Estonia</a></li><li><a href="/finland.htm">Finland</a></li><li><a href="/france.htm">France</a></li><li><a href="/germany.htm">Germany</a></li><li><a href="/greece.htm">Greece</a></li><li><a href="/hungary.htm">Hungary</a></li><li><a href="/iceland.htm">Iceland</a></li><li><a href="/india.htm">India</a></li><li><a href="/indonesia.htm">Indonesia</a></li><li><a href="/ireland.htm">Ireland</a></li><li><a href="/israel.htm">Israel</a></li><li><a href="/italy.htm">Italy</a></li><li><a href="/japan.htm">Japan</a></li><li><a href="/korea.htm">Korea</a></li><li><a href="/latvia.htm">Latvia</a></li><li><a href="/lithuania.htm">Lithuania</a></li><li><a href="/luxembourg.htm">Luxembourg</a></li><li><a href="/mexico.htm">Mexico</a></li><li><a href="/netherlands.htm">Netherlands</a></li><li><a href="/new-zealand.htm">New Zealand</a></li><li><a href="/norway.htm">Norway</a></li><li><a href="/poland.htm">Poland</a></li><li><a href="/portugal.htm">Portugal</a></li><li><a href="/russian-federation.htm">Russian Federation</a></li><li><a href="/slovak-republic.htm">Slovak Republic</a></li><li><a href="/slovenia.htm">Slovenia</a></li><li><a href="/south-africa.htm">South Africa</a></li><li><a href="/spain.htm">Spain</a></li><li><a href="/sweden.htm">Sweden</a></li><li><a href="/switzerland.htm">Switzerland</a></li><li><a href="/turkey.htm">Turkey</a></li><li><a href="/united-kingdom.htm">United Kingdom</a></li><li><a href="/united-states.htm">United States</a></li>
# </ul>
# </div><!-- /dropdown-list -->
# </div><!-- /dropdown -->
# </div>
# </div>
# </div>
# <div class="row home-jumbotron-row">
# <div class="col-7">
# <form action="/searchresults/" class="home-jumbotron-search-form">
# <div class="home-jumbotron-search-item">
# <label class="home-jumbotron-search-label" for="livesearch">
#               Search
#             </label>
# </div>
# <div class="home-jumbotron-search-item">
# <input class="home-jumbotron-search-field livesearch" id="livesearch" name="q" placeholder="" type="search"/>
# </div>
# <div class="home-jumbotron-search-item">
# <button class="home-jumbotron-btn-search" type="submit">
# <i class="icon-ddp-search"></i>
# <span class="accessible-hide">Search</span>
# </button>
# </div>
# </form>
# </div>
# <div class="col-4 col-offset-1">
# <ul class="home-jumbotron-links">
# <li class="home-jumbotron-search-tips">
# <div class="info-tooltip" tabindex="0">
# <p>
# <i class="icon-ddp-info"></i>
#                 Search tips
#               </p>
# <p class="info-tooltip-content">
#                 Start with one or two short search terms, then refine your results by adding more words.
#               </p>
# </div>
# </li>
# <li class="home-jumbotron-catalogue-oecd">
# <a href="/searchresults/?r=+f/type/datasets">Catalogue of OECD databases</a>
# </li>
# </ul>
# </div>
# </div><!-- /home-jumbotron-row -->
# </div><!-- /home-jumbotron -->
# <div class="breadcrumbs">
# <ul>
# <li><a href="/">OECD Data</a></li>
# </ul>
# </div><!-- /breadcrumbs -->
# <div class="row">
# <section class="col-7 featured-charts">
# <h2 class="line-top">
#         Featured Charts
#       </h2>
# <p>• <b>OECD unemployment rate</b> further declines to 6.9% in November 2020. See <a href="https://oe.cd/3r4">news</a>.• <b>OECD annual inflation</b> slows further in December 2020. See <a href="https:// oe.cd/3qE">news</a>.</p>
# <!-- Featured Chart -->
# <div class="ddp-chart featured-chart" data-baseline-comparison="OECD" data-compact-header="false" data-end-time="2020-12" data-frequency="M" data-highlighted-locations="JPN, USA, EA19" data-indicator="HUR" data-locations="JPN,  OECD, USA, EA19" data-measure="PC_LF" data-referrer="https://data.oecd.org/unemp/harmonised-unemployment-rate-hur.htm" data-source="OECD (2020), Unemployment rate (indicator). doi: 10.1787/52570002-en" data-start-time="2019-01" data-subject="TOT" data-type="line" data-use-latest-data="false"></div>
# <div class="ddp-chart featured-chart" data-baseline-comparison="OECD" data-compact-header="false" data-end-time="2020-11" data-frequency="M" data-highlighted-locations="EA19, USA" data-indicator="CPI" data-locations="CAN, DEU, EA19, FRA, GBR, ITA, JPN, OECD, USA" data-measure="AGRWTH" data-referrer="https://data.oecd.org/price/inflation-cpi.htm" data-source="OECD (2021), Inflation (CPI). doi: https://doi.org/10.1787/eee82e6e-en" data-start-time="2020-11" data-subject="TOT, FOOD, ENRG, TOT_FOODENRG" data-type="line" data-use-latest-data="true"></div>
# </section><!-- /featured-charts -->
# <section class="col-4 col-offset-1">
# <section class="home-news">
# <h2 class="line-top">Latest news</h2>
# <!-- Highlights -->
# <div class="item no-icon">
# <h3 class="item-title">Statistical news releases</h3>
# <p></p><p>See recent statistical <a href="http://www.oecd.org/std/statisticsnewsreleases.htm">news releases</a>.</p>
# </div><div class="item no-icon">
# <h3 class="item-title">Data Insights</h3>
# <p></p><p>Discover <em><a href="http://www.oecd.org/coronavirus/en/data-insights" title="Data insights">Data Insights</a> </em>featuring data visualisations related to the Covid-19 crisis.</p>
# </div>
# </section><!-- /home-news -->
# <section class="home-resources">
# <h2 class="line-top">Statistical resources</h2>
# <!-- resources -->
# <div class="item line-top no-icon">
# <a href="http://stats.oecd.org/">
# <h3 class="item-title">Database access</h3>
# <span class="item-thumbnail"><img alt="" class="fit" src="/media/dataportal/images/placeholders/databaseaccessSmall.png"/></span>
# </a>
# <p>Make your own queries on large databases in our data warehouse, OECD.Stat.</p>
# <p><a class="link-more" href="http://stats.oecd.org/">Query databases</a></p>
# </div><!-- /item --><div class="item line-top no-icon">
# <a href="http://www.oecd.org/statistics/statisticalresources.htm">
# <h3 class="item-title">Statistical tools</h3>
# </a>
# <p>Learn about OECD methodologies and stay informed through statistical newsletters.</p>
# <p><a class="link-more" href="http://www.oecd.org/statistics/statisticalresources.htm">Go to statistical tools </a></p>
# </div><!-- /item --><div class="item line-top no-icon">
# <a href="/api/">
# <h3 class="item-title">Developer API</h3>
# </a>
# <p>Learn about OECDâs application programming interface (API) for accessing data.</p>
# <p><a class="link-more" href="/api/">Go to API for developers</a></p>
# </div><!-- /item -->
# </section><!-- /home-resources -->
# </section><!-- /col -->
# </div><!-- /row -->
# </div><!-- /container -->
# <style type="text/css">
#   #breadcrumbs { display: none; }
# </style>
# <script>
#   var showSearchBar = false;
# </script></main>
# <!-- Chart sharing overlay (hidden per default) -->
# <div class="sharebox">
# <div class="container sharebox-inner">
# <div class="sharebox-row">
# <div class="sharebox-left">
# <a class="sharebox-close" href="" title="Close">
# <i class="icon-ddp-close-circle"></i>
# </a>
# <div class="share-selection">
# <h2>Your selection for sharing:</h2>
# <p class="share-selection-title"></p>
# <div class="share-selection-details"></div>
# </div>
# <div class="saving-options">
# <ul>
# <li>
# <label>
# <input checked="" name="save-method" type="radio" value="with-data"/>
# <span class="label-text">
#
#                   Snapshot of data for a fixed period (data will not change even if updated on the site)
#                 </span>
# </label>
# </li>
# <li>
# <label>
# <input name="save-method" type="radio" value="fixed-period"/>
# <span class="label-text">
#                   Latest available data for a fixed period,
#                   <span class="time-period-fixed-period"></span>
# </span>
# </label>
# </li>
# <li>
# <label>
# <input name="save-method" type="radio" value="latest-data"/>
# <span class="label-text">
#                   Latest available data,
#                   <span class="time-period-latest-data"></span>
# </span>
# </label>
# </li>
# </ul>
# </div><!-- /saving-options -->
# </div><!-- /sharebox-left -->
# <div class="sharebox-right">
# <h2>Sharing options</h2>
# <ul class="share-buttons">
# <li><button class="btn-dark share-facebook">Facebook</button></li>
# <li><button class="btn-dark share-twitter">Twitter</button></li>
# <li><button class="btn-dark share-email">E-Mail</button></li>
# </ul>
# <h3>Permanent URL</h3>
# <p><input class="url" name="url" type="text" value=""/></p>
# <p class="form-hint">Copy the URL to open this chart with all your selections.</p>
# <h3>Embed code</h3>
# <p><textarea class="embed-code" name="embed-code"></textarea></p>
# <p class="form-hint">Use this code to embed the visualisation into your website.</p>
# <p class="share-embedding-settings">
#             Width: <input class="width" name="width" size="4" type="text" value="860"/> px
#            <button class="btn pull-right preview" title="Preview embedded chart in new window">Preview Embedding</button>
# </p>
# <p class="sharebox-footer"><a href="http://www.oecd.org">OECD</a></p>
# </div><!-- /sharebox-right -->
# </div><!-- /sharebox-row -->
# </div><!-- /sharebox-inner -->
# </div><!-- /sharebox -->
# <div class="below-sticky"></div>
# <!-- DDP-specific institutional footer + shared OECD footer -->
# <footer class="oecd-footer">
# <div class="oecd-institutional-footer">
# <div class="container">
# <div class="row">
# <div class="col-xs-3 col-sm-6 oecd-institutional-footer__name">
# <a href="/">Data</a>
# </div>
# <div class="col-xs-3 col-sm-2">
# <a class="oecd-institutional-footer__link" href="/searchresults/?r=+f/type/indicators">Catalogue of OECD Indicators</a>
# </div>
# <div class="col-xs-3 col-sm-2">
# <a class="oecd-institutional-footer__link" href="http://www.oecdbetterlifeindex.org">Better Life Index</a>
# </div>
# <div class="col-xs-3 col-sm-2">
# <a class="oecd-institutional-footer__link" href="http://www.oecd.org/contact/">Contact Us</a>
# </div>
# </div><!-- /row -->
# </div><!-- /container -->
# </div><!-- /oecd-institutional-footer -->
# <div class="oecd-shared-footer oecd-shared-footer--light">
# <div class="container">
# <div class="row">
# <div class="col-xs-7 col-sm-5 oecd-shared-footer__logo-and-copyright">
# <div class="oecd-shared-footer__logo"></div>
# <div class="oecd-shared-footer__copyright">
# <span class="oecd-shared-footer__copyright-first">
#               ©
#               Organisation for Economic
#             </span>
# <span class="oecd-shared-footer__copyright-second">
#               Co-operation and Development
#             </span>
# </div>
# </div>
# <div class="col-xs-5 col-sm-3 oecd-shared-footer__terms">
# <ul class="oecd-shared-footer__links">
# <li class="oecd-shared-footer__link-item">
# <a class="oecd-shared-footer__link" href="http://www.oecd.org/termsandconditions/">Terms &amp; Conditions</a></li>
# <li class="oecd-shared-footer__link-item">
# <a class="oecd-shared-footer__link" href="http://www.oecd.org/privacy/">Privacy Policy</a>
# </li>
# </ul>
# </div>
# <div class="col-xs-12 col-sm-4 oecd-shared-footer__social-media">
# <p><a href="http://www.oecd.org/social-media/">Follow us (More platforms):</a></p>
# <ul class="oecd-shared-footer__icons">
# <li class="oecd-shared-footer__icon">
# <a class="oecd-shared-footer__icon-link oecd-shared-footer__facebook" href="http://www.facebook.com/theOECD">Facebook</a>
# </li>
# <li class="oecd-shared-footer__icon">
# <a class="oecd-shared-footer__icon-link oecd-shared-footer__twitter" href="http://twitter.com/oecd">Twitter</a>
# </li>
# <li class="oecd-shared-footer__icon">
# <a class="oecd-shared-footer__icon-link oecd-shared-footer__youtube" href="http://www.youtube.com/oecd">YouTube</a>
# </li>
# <li class="oecd-shared-footer__icon">
# <a class="oecd-shared-footer__icon-link oecd-shared-footer__linkedin" href="https://www.linkedin.com/company/organisation-eco-cooperation-development-organisation-cooperation-developpement-eco">LinkedIn</a>
# </li>
# <li class="oecd-shared-footer__icon">
# <a class="oecd-shared-footer__icon-link oecd-shared-footer__flickr" href="https://www.flickr.com/photos/oecd">Flickr</a>
# </li>
# <li class="oecd-shared-footer__icon">
# <a class="oecd-shared-footer__icon-link oecd-shared-footer__instagram" href="https://www.instagram.com/the_OECD">Instagram</a>
# </li>
# <li class="oecd-shared-footer__icon">
# <a class="oecd-shared-footer__icon-link oecd-shared-footer__rss" href="http://oecd.org/rssfeeds/">RSS</a>
# </li>
# <li class="oecd-shared-footer__icon">
# <a class="oecd-shared-footer__icon-link oecd-shared-footer__oecddirect" href="http://www.oecd.org/about/publishing/oecddirect.htm">Oecd Direct</a>
# </li>
# </ul>
# </div>
# </div><!-- /row -->
# </div><!-- /container -->
# </div><!-- /oecd-shared-footer -->
# </footer><!-- /oecd-footer -->
# </div><!-- /ddp-root -->
# <!-- jQuery, necessary dependencies -->
# <!-- jquery.min js -->
# <script src="/media/dataportal/scripts/jquery.min.js" type="text/javascript"></script> <!-- 262712 was used  -->
# <!-- Script for the OECD headers/footers -->
# <!-- oecd-headers-footers.js -->
# <script src="/media/dataportal/scripts/oecd-headers-footers.js" type="text/javascript"></script>
# <!-- Scripts for the OECD Data Portal only -->
# <!--call custom scripts-->
# <script>
# if($('#html_lang')){
#   var html_lang = $('#html_lang').attr('value');
#   $('html').attr('lang', html_lang);
# }
# </script>
# <!-- ddp-chart-config.js -->
# <script src="/media/dataportal/scripts/ddp-chart-config.js" type="text/javascript"></script>
# <!-- application.js -->
# <script src="/media/dataportal/scripts/application.js" type="text/javascript"></script> <script type="text/javascript">
# $(function() {
# 	$(".home-jumbotron-search-form").submit(function() {
# 	    var form = $(this);
# 	    var url = $(this).attr('action');
# 	    // to fix a bug related to empty parameter
# 	    var $q = form.find('input[name=q]');
# 	    if ( !$q.val() ) $q.detach();
# 	    if (url != '') {
# 	        var attributesString = url.split('?')[1];
# 	        var attributes = attributesString.split('&');
# 	        $.each(attributes, function(index, value) {
# 	            var elemName = value.split('=')[0];
# 	            var elemValue = value.split('=')[1];
# 	            var str = "<input type='hidden' name='"+elemName+"' value='"+elemValue+"' />";
# 	            form.append(str);
# 	        });
# 	    }
# 	});
#
# 	/*$("a.catalogue-oecd").click(function(event){
# 		var sPath = $(this).attr("href");
# 		if(sPath.indexOf("?") >= 0) {
# 			var sPathSplited = sPath.split("?");
# 			var attributes = sPathSplited[1].split("&");
#
# 			sPath = sPathSplited[0] + "?";
# 			$.each(attributes, function(idx, value) {
# 				if(idx > 0) sPath += "&";
# 				sPath += attributes[idx];
# 			});
# 			sPath += "&";
# 		}else sPath += "?";
# 		sPath += "r=+f/type/datasets";
# 		$(this).attr("href", sPath);
# 	});*/
#
# 	$('ul.list-filters>li').click(function() {
# 		$(this).addClass('current').siblings().removeClass('current');
# 	});
#
# 	$('.main-nav ul.tab>li>a').attr('href','#');
#
# 	/*FIX Language Switch on Home Page*/
# 	$('.language-switch a').each(function(idx, item) {
# 		var $item = $(item);
# 		if ( $item.attr('href').indexOf('/fr/accueil') > -1 ) {
# 			$item.attr('href','/fr');
# 		} else if ( $item.attr('href').indexOf('/home') > -1 ) {
# 			$item.attr('href','/');
# 		}
# 	});
#
# });
# </script><!--search bar -->
# <script>
# $(function(){
#   var display = (typeof showSearchBar !== "undefined" && showSearchBar == false) ? "none" : "block";
#   $('.ddp-root .header-statistics-inner .right .header-search-form').css("display",display);
# });
# </script>
# <script type="text/javascript">
#   $(function () {
#       $('.language-switch').empty().html(languageSwitch);
#   });
# </script>
# <!--Google Analytics code-->
# <script type="text/javascript">
#
#   /*var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-51805530-1']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();*/
#
# </script>
# <!-- POP UP -->
# <script src="/media/oecdorg/satellitesites/finconet/js/jquery-ui.min.js" type="text/javascript"></script><!--jquery-ui.js-->
# <script src="/media/oecdorg/oecdsatellitetempl/lib/js/bootstrap.min.js" type="text/javascript"></script><!--bootstrap.min.js-->
# <script src="/media/oecdorg/styleassets/responsive/satellite-sites/js/sat_site_popup.js" type="text/javascript"></script><!--sat_site_popup.js-->
# <script src="/media/dataportal/scripts/dp-gtm-code.js" type="text/javascript"></script><!--dp-gtm-code.js-->
# <script></script>
# <!--t4 type="navigation" id="572"/-->
# <!-- POP UP END -->
# </body>
# </html>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    OECD Data
#   </title>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
#   <meta content="always" name="referrer"/>
#   <meta content="Find, compare and share the latest OECD data: charts, maps, tables and related publications" name="description"/>
#   <meta content="OECD statistics, country comparison, country profile, OECD data" name="keywords"/>
#   <script type="text/javascript">
#    var languageSwitch = '<a href="">âº </a><a href="/fr/accueil/">Fran&ccedil;ais</a><!--<a href="/home/">English</a>-->';
#   </script>
#   <script>
#    dataLayer = [{
# 	'siteName':"data",
# 	'siteEnvironment':"live",
# 	'pageLanguage':"en",
# }];
#   </script>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="Find, compare and share OECD data." name="twitter:description"/>
#   <meta content="http://data.oecd.org/media/dataportal/custom/OECD_110x110.png" name="twitter:image"/>
#   <meta content="@OECD" name="twitter:site"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Find, compare and share OECD data." property="og:description"/>
#   <meta content="http://data.oecd.org/media/dataportal/custom/OECD_110x110.png" property="og:image"/>
#   <meta content="theOECD" property="og:site_name"/>
#   <meta content="OECD data" name="twitter:title"/>
#   <meta content="OECD data" property="og:title"/>
#   <meta content="http://data.oecd.org" property="og:url"/>
#   <!-- Bootstrap stylesheet, necessary dependency -->
#   <!--bootstrap-3-0-0.css-->
#   <link href="/media/dataportal/stylesheets/lib/bootstrap-3-0-0.css" media="" rel="stylesheet" type="text/css"/>
#   <!--end of bootstrap-->
#   <!-- Stylesheet for the OECD headers and footers, shared on differet sites -->
#   <!--oecd-headers-footers.css-->
#   <link href="/media/dataportal/stylesheets/oecd-headers-footers.css" media="" rel="stylesheet" type="text/css"/>
#   <!-- Stylesheet for the OECD Data Portal only -->
#   <!--main-oecd.css-->
#   <!--t4 type="media" id="306057" formatter="css/*"/-->
#   <link href="/media/oecdorg/styleassets/images/favicon.ico" rel="icon" type="image/x-icon"/>
#   <!-- apple-touch-icon.png -->
#   <link href="/media/dataportal/images/apple-touch-icon.png" rel="apple-touch-icon-precomposed"/>
#   <!-- apple-touch-icon-72x72.png -->
#   <link href="/media/dataportal/images/apple-touch-icon-72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#   <!-- apple-touch-icon-114x114.png -->
#   <link href="/media/dataportal/images/apple-touch-icon-114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#   <!-- apple-touch-icon-144x144.png -->
#   <link href="/media/dataportal/images/apple-touch-icon-144x144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#   <!-- Media query polyfill and HTML5 shim for IE < 9 -->
#   <!-- respond-1.4.2.min.js -->
#   <!--[if lt IE 9]>
# <script type="text/javascript" src="/media/dataportal/scripts/respond-1.4.2.min.js"></script>
# <script>
# 'abbr article aside audio canvas details figcaption figure footer header main mark meter nav output progress section summary time video'.replace(/\w+/g,function(n){document.createElement(n)})
# </script>
# <![endif]-->
#   <!--call custom style-->
#   <!-- main.css -->
#   <link href="/media/dataportal/stylesheets/main.css" media="" rel="stylesheet" type="text/css"/>
#   <!-- cuistom oecd -->
#   <link href="/media/dataportal/stylesheets/custom.oecd.css" media="" rel="stylesheet" type="text/css"/>
#   <!-- Existing link in Old Style -->
#   <link href="/header/index.xml" rel="alternate" title="RSS" type="application/rss+xml"/>
#   <script async="" defer="" src="//survey.g.doubleclick.net/async_survey?site=eq5fyz327wxea5asg3u7bva5ge">
#   </script>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-WZ3XJR');
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-P5JSM4P');
#   </script>
#   <!-- End Google Tag Manager -->
#  </head>
#  <body>
#   <!-- Google Tag Manager -->
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-WZ3XJR" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-P5JSM4P" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager -->
#   <header class="oecd-header oecd-header--bg-light-blue oecd-header--primary-hidden">
#    <nav class="container">
#     <div class="row">
#      <div class="col-sm-1 oecd-header__item oecd-header__logo-and-toggle">
#       <div class="oecd-header__logo">
#        <div class="sr-only">
#         Organisation for Economic Co-operation and Development (OECD)
#        </div>
#       </div>
#       <button class="oecd-header__primary-toggle" title="Toggle Menu">
#        <span class="oecd-header__menu-open">
#        </span>
#        <span class="oecd-header__menu-close">
#         Ã
#        </span>
#        <span class="sr-only">
#         Menu
#        </span>
#       </button>
#      </div>
#      <ul class="oecd-header__primary">
#       <li class="col-sm-2 oecd-header__item">
#        <a class="oecd-header__link" href="http://oecd.org/">
#         OECD.org
#        </a>
#       </li>
#       <li class="col-sm-2 oecd-header__item oecd-header__item--active">
#        <strong class="oecd-header__current-page">
#         Data
#        </strong>
#       </li>
#       <li class="col-sm-2 oecd-header__item">
#        <a class="oecd-header__link" href="http://www.oecd-ilibrary.org/">
#         Publications
#        </a>
#       </li>
#       <li class="col-sm-2 oecd-header__item oecd-header__secondary-container">
#        <a class="oecd-header__link oecd-header__secondary-toggle" href="">
#         More sites
#        </a>
#        <ul class="sr-only oecd-header__secondary">
#         <li class="oecd-header__item oecd-header__secondary-item oecd-header__secondary-item-first">
#          <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecdbetterlifeindex.org/">
#           OECD Better Life Index
#          </a>
#         </li>
#         <li class="oecd-header__item oecd-header__secondary-item">
#          <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecd-ilibrary.org/">
#           OECD iLibrary
#          </a>
#         </li>
#         <li class="oecd-header__item oecd-header__secondary-item">
#          <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecdobserver.org/">
#           OECD Observer
#          </a>
#         </li>
#         <li class="oecd-header__item oecd-header__secondary-item">
#          <a class="oecd-header__link oecd-header__secondary-link" href="http://oecdinsights.org/">
#           OECD Insights blog
#          </a>
#         </li>
#         <li class="oecd-header__item oecd-header__secondary-item">
#          <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecd.org/dev/">
#           OECD Development Centre
#          </a>
#         </li>
#         <li class="oecd-header__item oecd-header__secondary-item">
#          <a class="oecd-header__link oecd-header__secondary-link" href="http://www.fatf-gafi.org/">
#           FATF - Financial Action Task Force
#          </a>
#         </li>
#         <li class="oecd-header__item oecd-header__secondary-item">
#          <a class="oecd-header__link oecd-header__secondary-link" href="http://www.iea.org/">
#           IEA â International Energy Agency
#          </a>
#         </li>
#         <li class="oecd-header__item oecd-header__secondary-item">
#          <a class="oecd-header__link oecd-header__secondary-link" href="http://www.itf-oecd.org/">
#           ITF â International Transport Forum
#          </a>
#         </li>
#         <li class="oecd-header__item oecd-header__secondary-item">
#          <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecd-nea.org/">
#           NEA â Nuclear Energy Agency
#          </a>
#         </li>
#         <li class="oecd-header__item oecd-header__secondary-item oecd-header__secondary-item-last">
#          <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecd.org/swac/">
#           SWAC â Sahel and West Africa Club
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="col-sm-1 oecd-header__item">
#        <a class="oecd-header__link" href="http://oecd.org/newsroom/">
#         News
#        </a>
#       </li>
#       <li class="col-sm-2 oecd-header__item">
#        <a class="oecd-header__link" href="http://oecd.org/careers/">
#         Job vacancies
#        </a>
#       </li>
#      </ul>
#     </div>
#     <!-- /row -->
#    </nav>
#    <!-- /container -->
#   </header>
#   <!-- /oecd-header -->
#   <div class="ddp-root">
#    <header>
#     <!-- Header with search form -->
#     <div class="header-statistics">
#      <div class="container">
#       <div class="header-statistics-inner">
#        <div class="left">
#         <div class="logo">
#         </div>
#         <h1 class="site-title">
#          <a class="home-link" href="/">
#           Data
#          </a>
#         </h1>
#         <!-- There are two language switches due to the different layouts. The first is shown on mobile, the second on desktop. Both should point to the same site. -->
#         <div class="toggle-search-form">
#          <i class="icon-ddp-search">
#          </i>
#         </div>
#         <div class="language-switch language-switch-left">
#          <a href="">
#           âº
#          </a>
#          <a href="/fr/header/#d.fr.406188">
#           Français
#          </a>
#          <!--
#     <a href="/header/#d.en.406188">English</a>
#     -->
#         </div>
#        </div>
#        <!-- /left -->
#        <div class="right">
#         <div class="language-switch language-switch-right">
#          <a href="">
#           âº
#          </a>
#          <a href="/fr/header/#d.fr.406188">
#           Français
#          </a>
#          <!--
#     <a href="/header/#d.en.406188">English</a>
#     -->
#         </div>
#         <form action="/searchresults/" class="search-form header-search-form">
#          <input class="search-field livesearch" name="q" placeholder="Search for OECD data" type="search"/>
#          <button class="btn-search" type="submit">
#           <i class="icon-ddp-search">
#           </i>
#           <span class="accessible-hide">
#            Search
#           </span>
#          </button>
#         </form>
#        </div>
#        <!-- /right -->
#       </div>
#       <!-- /header-statistics-inner -->
#      </div>
#      <!-- /container -->
#     </div>
#     <!-- /header-statistics -->
#     <!--meta itemprop="context" content="topic"-->
#     <div class="container breadcrumbs" id="breadcrumbs">
#      <ul>
#       <li>
#        <a href="/">
#         OECD Data
#        </a>
#       </li>
#       <li class="bd-01">
#        Header
#       </li>
#      </ul>
#     </div>
#     <!-- /breadcrumbs -->
#    </header>
#    <main role="main">
#     <div class="container">
#      <div class="notifications">
#      </div>
#     </div>
#     <div class="container">
#      <div class="home-jumbotron">
#       <div class="row home-jumbotron-row">
#        <div class="col-7">
#         <p>
#          <span class="line">
#           Find, compare and share the latest
#           <b>
#            OECD data
#           </b>
#           :
#          </span>
#          <span class="line">
#           charts, maps, tables and related publications â¦
#          </span>
#         </p>
#        </div>
#        <div class="col-4 col-offset-1 home-jumbotron-browse">
#         <p class="home-jumbotron-browse-by">
#          Browse by
#         </p>
#         <div class="home-jumbotron-dropdowns">
#          <div class="dropdown columnisable home-jumbotron-dropdown-topics">
#           <a class="dropdown-button home-jumbotron-dropdown-button" href="">
#            topic
#            <i class="icon-ddp-expand-down">
#            </i>
#           </a>
#           <div class="dropdown-list with-icons topics">
#            <ul>
#             <li>
#              <a href="/agriculture.htm">
#               <i class="icon-ddp-agriculture">
#               </i>
#               <span class="topic-name">
#                Agriculture
#               </span>
#               <small>
#                Agricultural output, Agricultural policy, Fisheries, Sustainable agriculture
#               </small>
#              </a>
#             </li>
#             <li>
#              <a href="/development.htm">
#               <i class="icon-ddp-development">
#               </i>
#               <span class="topic-name">
#                Development
#               </span>
#               <small>
#                Development resource flows, Official development assistance (ODA)
#               </small>
#              </a>
#             </li>
#             <li>
#              <a href="/economy.htm">
#               <i class="icon-ddp-economics">
#               </i>
#               <span class="topic-name">
#                Economy
#               </span>
#               <small>
#                Corporate sector, Foreign direct investment (FDI), GDP and spending, Household accounts, International trade, Leading indicators, National income, Prices, Productivity
#               </small>
#              </a>
#             </li>
#             <li>
#              <a href="/education.htm">
#               <i class="icon-ddp-education">
#               </i>
#               <span class="topic-name">
#                Education
#               </span>
#               <small>
#                Education attainment, Education resources, International student assessment (PISA), Students, Teachers, Youth and the labour market
#               </small>
#              </a>
#             </li>
#             <li>
#              <a href="/energy.htm">
#               <i class="icon-ddp-energy">
#               </i>
#               <span class="topic-name">
#                Energy
#               </span>
#               <small>
#                Energy, Transport
#               </small>
#              </a>
#             </li>
#             <li>
#              <a href="/environment.htm">
#               <i class="icon-ddp-environment">
#               </i>
#               <span class="topic-name">
#                Environment
#               </span>
#               <small>
#                Air and climate, Biodiversity, Environmental policy, Forest, Materials, Waste, Water
#               </small>
#              </a>
#             </li>
#             <li>
#              <a href="/finance.htm">
#               <i class="icon-ddp-finance">
#               </i>
#               <span class="topic-name">
#                Finance
#               </span>
#               <small>
#                Conversion rates, Insurance, Interest rates, Monetary aggregates, Pensions
#               </small>
#              </a>
#             </li>
#             <li>
#              <a href="/government.htm">
#               <i class="icon-ddp-government">
#               </i>
#               <span class="topic-name">
#                Government
#               </span>
#               <small>
#                General government, Tax
#               </small>
#              </a>
#             </li>
#             <li>
#              <a href="/health.htm">
#               <i class="icon-ddp-health">
#               </i>
#               <span class="topic-name">
#                Health
#               </span>
#               <small>
#                Health care use, Health equipment, Health resources, Health risks, Health status
#               </small>
#              </a>
#             </li>
#             <li>
#              <a href="/innovation-and-technology.htm">
#               <i class="icon-ddp-science">
#               </i>
#               <span class="topic-name">
#                Innovation and Technology
#               </span>
#               <small>
#                Broadband access, Entrepreneurship, Industry, Information and communication technology (ICT), Research and development (R&amp;D)
#               </small>
#              </a>
#             </li>
#             <li>
#              <a href="/jobs.htm">
#               <i class="icon-ddp-jobs">
#               </i>
#               <span class="topic-name">
#                Jobs
#               </span>
#               <small>
#                Benefits and wages, Earnings and wages, Employment, Unemployment
#               </small>
#              </a>
#             </li>
#             <li>
#              <a href="/society.htm">
#               <i class="icon-ddp-society">
#               </i>
#               <span class="topic-name">
#                Society
#               </span>
#               <small>
#                Demography, Inequality, Migration, Population by region, Social protection
#               </small>
#              </a>
#             </li>
#            </ul>
#           </div>
#           <!-- /dropdown-list -->
#          </div>
#          <!-- /dropdown -->
#          <span class="home-jumbotron-browse-by-or">
#           or
#          </span>
#          <div class="dropdown columnisable dropdown-countries home-jumbotron-dropdown-countries">
#           <a class="dropdown-button home-jumbotron-dropdown-button" href="">
#            country
#            <i class="icon-ddp-expand-down">
#            </i>
#           </a>
#           <div class="dropdown-list">
#            <p class="dropdown-search">
#             <input class="search-country" placeholder="Type to search for a country" type="search"/>
#            </p>
#            <ul class="countries">
#             <li>
#              <a href="/australia.htm">
#               Australia
#              </a>
#             </li>
#             <li>
#              <a href="/austria.htm">
#               Austria
#              </a>
#             </li>
#             <li>
#              <a href="/belgium.htm">
#               Belgium
#              </a>
#             </li>
#             <li>
#              <a href="/brazil.htm">
#               Brazil
#              </a>
#             </li>
#             <li>
#              <a href="/canada.htm">
#               Canada
#              </a>
#             </li>
#             <li>
#              <a href="/chile.htm">
#               Chile
#              </a>
#             </li>
#             <li>
#              <a href="/china-people-s-republic-of.htm">
#               China, People's Republic of
#              </a>
#             </li>
#             <li>
#              <a href="/colombia.htm">
#               Colombia
#              </a>
#             </li>
#             <li>
#              <a href="/czech-republic.htm">
#               Czech Republic
#              </a>
#             </li>
#             <li>
#              <a href="/denmark.htm">
#               Denmark
#              </a>
#             </li>
#             <li>
#              <a href="/estonia.htm">
#               Estonia
#              </a>
#             </li>
#             <li>
#              <a href="/finland.htm">
#               Finland
#              </a>
#             </li>
#             <li>
#              <a href="/france.htm">
#               France
#              </a>
#             </li>
#             <li>
#              <a href="/germany.htm">
#               Germany
#              </a>
#             </li>
#             <li>
#              <a href="/greece.htm">
#               Greece
#              </a>
#             </li>
#             <li>
#              <a href="/hungary.htm">
#               Hungary
#              </a>
#             </li>
#             <li>
#              <a href="/iceland.htm">
#               Iceland
#              </a>
#             </li>
#             <li>
#              <a href="/india.htm">
#               India
#              </a>
#             </li>
#             <li>
#              <a href="/indonesia.htm">
#               Indonesia
#              </a>
#             </li>
#             <li>
#              <a href="/ireland.htm">
#               Ireland
#              </a>
#             </li>
#             <li>
#              <a href="/israel.htm">
#               Israel
#              </a>
#             </li>
#             <li>
#              <a href="/italy.htm">
#               Italy
#              </a>
#             </li>
#             <li>
#              <a href="/japan.htm">
#               Japan
#              </a>
#             </li>
#             <li>
#              <a href="/korea.htm">
#               Korea
#              </a>
#             </li>
#             <li>
#              <a href="/latvia.htm">
#               Latvia
#              </a>
#             </li>
#             <li>
#              <a href="/lithuania.htm">
#               Lithuania
#              </a>
#             </li>
#             <li>
#              <a href="/luxembourg.htm">
#               Luxembourg
#              </a>
#             </li>
#             <li>
#              <a href="/mexico.htm">
#               Mexico
#              </a>
#             </li>
#             <li>
#              <a href="/netherlands.htm">
#               Netherlands
#              </a>
#             </li>
#             <li>
#              <a href="/new-zealand.htm">
#               New Zealand
#              </a>
#             </li>
#             <li>
#              <a href="/norway.htm">
#               Norway
#              </a>
#             </li>
#             <li>
#              <a href="/poland.htm">
#               Poland
#              </a>
#             </li>
#             <li>
#              <a href="/portugal.htm">
#               Portugal
#              </a>
#             </li>
#             <li>
#              <a href="/russian-federation.htm">
#               Russian Federation
#              </a>
#             </li>
#             <li>
#              <a href="/slovak-republic.htm">
#               Slovak Republic
#              </a>
#             </li>
#             <li>
#              <a href="/slovenia.htm">
#               Slovenia
#              </a>
#             </li>
#             <li>
#              <a href="/south-africa.htm">
#               South Africa
#              </a>
#             </li>
#             <li>
#              <a href="/spain.htm">
#               Spain
#              </a>
#             </li>
#             <li>
#              <a href="/sweden.htm">
#               Sweden
#              </a>
#             </li>
#             <li>
#              <a href="/switzerland.htm">
#               Switzerland
#              </a>
#             </li>
#             <li>
#              <a href="/turkey.htm">
#               Turkey
#              </a>
#             </li>
#             <li>
#              <a href="/united-kingdom.htm">
#               United Kingdom
#              </a>
#             </li>
#             <li>
#              <a href="/united-states.htm">
#               United States
#              </a>
#             </li>
#            </ul>
#           </div>
#           <!-- /dropdown-list -->
#          </div>
#          <!-- /dropdown -->
#         </div>
#        </div>
#       </div>
#       <div class="row home-jumbotron-row">
#        <div class="col-7">
#         <form action="/searchresults/" class="home-jumbotron-search-form">
#          <div class="home-jumbotron-search-item">
#           <label class="home-jumbotron-search-label" for="livesearch">
#            Search
#           </label>
#          </div>
#          <div class="home-jumbotron-search-item">
#           <input class="home-jumbotron-search-field livesearch" id="livesearch" name="q" placeholder="" type="search"/>
#          </div>
#          <div class="home-jumbotron-search-item">
#           <button class="home-jumbotron-btn-search" type="submit">
#            <i class="icon-ddp-search">
#            </i>
#            <span class="accessible-hide">
#             Search
#            </span>
#           </button>
#          </div>
#         </form>
#        </div>
#        <div class="col-4 col-offset-1">
#         <ul class="home-jumbotron-links">
#          <li class="home-jumbotron-search-tips">
#           <div class="info-tooltip" tabindex="0">
#            <p>
#             <i class="icon-ddp-info">
#             </i>
#             Search tips
#            </p>
#            <p class="info-tooltip-content">
#             Start with one or two short search terms, then refine your results by adding more words.
#            </p>
#           </div>
#          </li>
#          <li class="home-jumbotron-catalogue-oecd">
#           <a href="/searchresults/?r=+f/type/datasets">
#            Catalogue of OECD databases
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <!-- /home-jumbotron-row -->
#      </div>
#      <!-- /home-jumbotron -->
#      <div class="breadcrumbs">
#       <ul>
#        <li>
#         <a href="/">
#          OECD Data
#         </a>
#        </li>
#       </ul>
#      </div>
#      <!-- /breadcrumbs -->
#      <div class="row">
#       <section class="col-7 featured-charts">
#        <h2 class="line-top">
#         Featured Charts
#        </h2>
#        <p>
#         •
#         <b>
#          OECD unemployment rate
#         </b>
#         further declines to 6.9% in November 2020. See
#         <a href="https://oe.cd/3r4">
#          news
#         </a>
#         .•
#         <b>
#          OECD annual inflation
#         </b>
#         slows further in December 2020. See
#         <a href="https:// oe.cd/3qE">
#          news
#         </a>
#         .
#        </p>
#        <!-- Featured Chart -->
#        <div class="ddp-chart featured-chart" data-baseline-comparison="OECD" data-compact-header="false" data-end-time="2020-12" data-frequency="M" data-highlighted-locations="JPN, USA, EA19" data-indicator="HUR" data-locations="JPN,  OECD, USA, EA19" data-measure="PC_LF" data-referrer="https://data.oecd.org/unemp/harmonised-unemployment-rate-hur.htm" data-source="OECD (2020), Unemployment rate (indicator). doi: 10.1787/52570002-en" data-start-time="2019-01" data-subject="TOT" data-type="line" data-use-latest-data="false">
#        </div>
#        <div class="ddp-chart featured-chart" data-baseline-comparison="OECD" data-compact-header="false" data-end-time="2020-11" data-frequency="M" data-highlighted-locations="EA19, USA" data-indicator="CPI" data-locations="CAN, DEU, EA19, FRA, GBR, ITA, JPN, OECD, USA" data-measure="AGRWTH" data-referrer="https://data.oecd.org/price/inflation-cpi.htm" data-source="OECD (2021), Inflation (CPI). doi: https://doi.org/10.1787/eee82e6e-en" data-start-time="2020-11" data-subject="TOT, FOOD, ENRG, TOT_FOODENRG" data-type="line" data-use-latest-data="true">
#        </div>
#       </section>
#       <!-- /featured-charts -->
#       <section class="col-4 col-offset-1">
#        <section class="home-news">
#         <h2 class="line-top">
#          Latest news
#         </h2>
#         <!-- Highlights -->
#         <div class="item no-icon">
#          <h3 class="item-title">
#           Statistical news releases
#          </h3>
#          <p>
#          </p>
#          <p>
#           See recent statistical
#           <a href="http://www.oecd.org/std/statisticsnewsreleases.htm">
#            news releases
#           </a>
#           .
#          </p>
#         </div>
#         <div class="item no-icon">
#          <h3 class="item-title">
#           Data Insights
#          </h3>
#          <p>
#          </p>
#          <p>
#           Discover
#           <em>
#            <a href="http://www.oecd.org/coronavirus/en/data-insights" title="Data insights">
#             Data Insights
#            </a>
#           </em>
#           featuring data visualisations related to the Covid-19 crisis.
#          </p>
#         </div>
#        </section>
#        <!-- /home-news -->
#        <section class="home-resources">
#         <h2 class="line-top">
#          Statistical resources
#         </h2>
#         <!-- resources -->
#         <div class="item line-top no-icon">
#          <a href="http://stats.oecd.org/">
#           <h3 class="item-title">
#            Database access
#           </h3>
#           <span class="item-thumbnail">
#            <img alt="" class="fit" src="/media/dataportal/images/placeholders/databaseaccessSmall.png"/>
#           </span>
#          </a>
#          <p>
#           Make your own queries on large databases in our data warehouse, OECD.Stat.
#          </p>
#          <p>
#           <a class="link-more" href="http://stats.oecd.org/">
#            Query databases
#           </a>
#          </p>
#         </div>
#         <!-- /item -->
#         <div class="item line-top no-icon">
#          <a href="http://www.oecd.org/statistics/statisticalresources.htm">
#           <h3 class="item-title">
#            Statistical tools
#           </h3>
#          </a>
#          <p>
#           Learn about OECD methodologies and stay informed through statistical newsletters.
#          </p>
#          <p>
#           <a class="link-more" href="http://www.oecd.org/statistics/statisticalresources.htm">
#            Go to statistical tools
#           </a>
#          </p>
#         </div>
#         <!-- /item -->
#         <div class="item line-top no-icon">
#          <a href="/api/">
#           <h3 class="item-title">
#            Developer API
#           </h3>
#          </a>
#          <p>
#           Learn about OECDâs application programming interface (API) for accessing data.
#          </p>
#          <p>
#           <a class="link-more" href="/api/">
#            Go to API for developers
#           </a>
#          </p>
#         </div>
#         <!-- /item -->
#        </section>
#        <!-- /home-resources -->
#       </section>
#       <!-- /col -->
#      </div>
#      <!-- /row -->
#     </div>
#     <!-- /container -->
#     <style type="text/css">
#      #breadcrumbs { display: none; }
#     </style>
#     <script>
#      var showSearchBar = false;
#     </script>
#    </main>
#    <!-- Chart sharing overlay (hidden per default) -->
#    <div class="sharebox">
#     <div class="container sharebox-inner">
#      <div class="sharebox-row">
#       <div class="sharebox-left">
#        <a class="sharebox-close" href="" title="Close">
#         <i class="icon-ddp-close-circle">
#         </i>
#        </a>
#        <div class="share-selection">
#         <h2>
#          Your selection for sharing:
#         </h2>
#         <p class="share-selection-title">
#         </p>
#         <div class="share-selection-details">
#         </div>
#        </div>
#        <div class="saving-options">
#         <ul>
#          <li>
#           <label>
#            <input checked="" name="save-method" type="radio" value="with-data"/>
#            <span class="label-text">
#             Snapshot of data for a fixed period (data will not change even if updated on the site)
#            </span>
#           </label>
#          </li>
#          <li>
#           <label>
#            <input name="save-method" type="radio" value="fixed-period"/>
#            <span class="label-text">
#             Latest available data for a fixed period,
#             <span class="time-period-fixed-period">
#             </span>
#            </span>
#           </label>
#          </li>
#          <li>
#           <label>
#            <input name="save-method" type="radio" value="latest-data"/>
#            <span class="label-text">
#             Latest available data,
#             <span class="time-period-latest-data">
#             </span>
#            </span>
#           </label>
#          </li>
#         </ul>
#        </div>
#        <!-- /saving-options -->
#       </div>
#       <!-- /sharebox-left -->
#       <div class="sharebox-right">
#        <h2>
#         Sharing options
#        </h2>
#        <ul class="share-buttons">
#         <li>
#          <button class="btn-dark share-facebook">
#           Facebook
#          </button>
#         </li>
#         <li>
#          <button class="btn-dark share-twitter">
#           Twitter
#          </button>
#         </li>
#         <li>
#          <button class="btn-dark share-email">
#           E-Mail
#          </button>
#         </li>
#        </ul>
#        <h3>
#         Permanent URL
#        </h3>
#        <p>
#         <input class="url" name="url" type="text" value=""/>
#        </p>
#        <p class="form-hint">
#         Copy the URL to open this chart with all your selections.
#        </p>
#        <h3>
#         Embed code
#        </h3>
#        <p>
#         <textarea class="embed-code" name="embed-code"></textarea>
#        </p>
#        <p class="form-hint">
#         Use this code to embed the visualisation into your website.
#        </p>
#        <p class="share-embedding-settings">
#         Width:
#         <input class="width" name="width" size="4" type="text" value="860"/>
#         px
#         <button class="btn pull-right preview" title="Preview embedded chart in new window">
#          Preview Embedding
#         </button>
#        </p>
#        <p class="sharebox-footer">
#         <a href="http://www.oecd.org">
#          OECD
#         </a>
#        </p>
#       </div>
#       <!-- /sharebox-right -->
#      </div>
#      <!-- /sharebox-row -->
#     </div>
#     <!-- /sharebox-inner -->
#    </div>
#    <!-- /sharebox -->
#    <div class="below-sticky">
#    </div>
#    <!-- DDP-specific institutional footer + shared OECD footer -->
#    <footer class="oecd-footer">
#     <div class="oecd-institutional-footer">
#      <div class="container">
#       <div class="row">
#        <div class="col-xs-3 col-sm-6 oecd-institutional-footer__name">
#         <a href="/">
#          Data
#         </a>
#        </div>
#        <div class="col-xs-3 col-sm-2">
#         <a class="oecd-institutional-footer__link" href="/searchresults/?r=+f/type/indicators">
#          Catalogue of OECD Indicators
#         </a>
#        </div>
#        <div class="col-xs-3 col-sm-2">
#         <a class="oecd-institutional-footer__link" href="http://www.oecdbetterlifeindex.org">
#          Better Life Index
#         </a>
#        </div>
#        <div class="col-xs-3 col-sm-2">
#         <a class="oecd-institutional-footer__link" href="http://www.oecd.org/contact/">
#          Contact Us
#         </a>
#        </div>
#       </div>
#       <!-- /row -->
#      </div>
#      <!-- /container -->
#     </div>
#     <!-- /oecd-institutional-footer -->
#     <div class="oecd-shared-footer oecd-shared-footer--light">
#      <div class="container">
#       <div class="row">
#        <div class="col-xs-7 col-sm-5 oecd-shared-footer__logo-and-copyright">
#         <div class="oecd-shared-footer__logo">
#         </div>
#         <div class="oecd-shared-footer__copyright">
#          <span class="oecd-shared-footer__copyright-first">
#           ©
#               Organisation for Economic
#          </span>
#          <span class="oecd-shared-footer__copyright-second">
#           Co-operation and Development
#          </span>
#         </div>
#        </div>
#        <div class="col-xs-5 col-sm-3 oecd-shared-footer__terms">
#         <ul class="oecd-shared-footer__links">
#          <li class="oecd-shared-footer__link-item">
#           <a class="oecd-shared-footer__link" href="http://www.oecd.org/termsandconditions/">
#            Terms &amp; Conditions
#           </a>
#          </li>
#          <li class="oecd-shared-footer__link-item">
#           <a class="oecd-shared-footer__link" href="http://www.oecd.org/privacy/">
#            Privacy Policy
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-xs-12 col-sm-4 oecd-shared-footer__social-media">
#         <p>
#          <a href="http://www.oecd.org/social-media/">
#           Follow us (More platforms):
#          </a>
#         </p>
#         <ul class="oecd-shared-footer__icons">
#          <li class="oecd-shared-footer__icon">
#           <a class="oecd-shared-footer__icon-link oecd-shared-footer__facebook" href="http://www.facebook.com/theOECD">
#            Facebook
#           </a>
#          </li>
#          <li class="oecd-shared-footer__icon">
#           <a class="oecd-shared-footer__icon-link oecd-shared-footer__twitter" href="http://twitter.com/oecd">
#            Twitter
#           </a>
#          </li>
#          <li class="oecd-shared-footer__icon">
#           <a class="oecd-shared-footer__icon-link oecd-shared-footer__youtube" href="http://www.youtube.com/oecd">
#            YouTube
#           </a>
#          </li>
#          <li class="oecd-shared-footer__icon">
#           <a class="oecd-shared-footer__icon-link oecd-shared-footer__linkedin" href="https://www.linkedin.com/company/organisation-eco-cooperation-development-organisation-cooperation-developpement-eco">
#            LinkedIn
#           </a>
#          </li>
#          <li class="oecd-shared-footer__icon">
#           <a class="oecd-shared-footer__icon-link oecd-shared-footer__flickr" href="https://www.flickr.com/photos/oecd">
#            Flickr
#           </a>
#          </li>
#          <li class="oecd-shared-footer__icon">
#           <a class="oecd-shared-footer__icon-link oecd-shared-footer__instagram" href="https://www.instagram.com/the_OECD">
#            Instagram
#           </a>
#          </li>
#          <li class="oecd-shared-footer__icon">
#           <a class="oecd-shared-footer__icon-link oecd-shared-footer__rss" href="http://oecd.org/rssfeeds/">
#            RSS
#           </a>
#          </li>
#          <li class="oecd-shared-footer__icon">
#           <a class="oecd-shared-footer__icon-link oecd-shared-footer__oecddirect" href="http://www.oecd.org/about/publishing/oecddirect.htm">
#            Oecd Direct
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <!-- /row -->
#      </div>
#      <!-- /container -->
#     </div>
#     <!-- /oecd-shared-footer -->
#    </footer>
#    <!-- /oecd-footer -->
#   </div>
#   <!-- /ddp-root -->
#   <!-- jQuery, necessary dependencies -->
#   <!-- jquery.min js -->
#   <script src="/media/dataportal/scripts/jquery.min.js" type="text/javascript">
#   </script>
#   <!-- 262712 was used  -->
#   <!-- Script for the OECD headers/footers -->
#   <!-- oecd-headers-footers.js -->
#   <script src="/media/dataportal/scripts/oecd-headers-footers.js" type="text/javascript">
#   </script>
#   <!-- Scripts for the OECD Data Portal only -->
#   <!--call custom scripts-->
#   <script>
#    if($('#html_lang')){
#   var html_lang = $('#html_lang').attr('value');
#   $('html').attr('lang', html_lang);
# }
#   </script>
#   <!-- ddp-chart-config.js -->
#   <script src="/media/dataportal/scripts/ddp-chart-config.js" type="text/javascript">
#   </script>
#   <!-- application.js -->
#   <script src="/media/dataportal/scripts/application.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    $(function() {
# 	$(".home-jumbotron-search-form").submit(function() {
# 	    var form = $(this);
# 	    var url = $(this).attr('action');
# 	    // to fix a bug related to empty parameter
# 	    var $q = form.find('input[name=q]');
# 	    if ( !$q.val() ) $q.detach();
# 	    if (url != '') {
# 	        var attributesString = url.split('?')[1];
# 	        var attributes = attributesString.split('&');
# 	        $.each(attributes, function(index, value) {
# 	            var elemName = value.split('=')[0];
# 	            var elemValue = value.split('=')[1];
# 	            var str = "<input type='hidden' name='"+elemName+"' value='"+elemValue+"' />";
# 	            form.append(str);
# 	        });
# 	    }
# 	});
#
# 	/*$("a.catalogue-oecd").click(function(event){
# 		var sPath = $(this).attr("href");
# 		if(sPath.indexOf("?") >= 0) {
# 			var sPathSplited = sPath.split("?");
# 			var attributes = sPathSplited[1].split("&");
#
# 			sPath = sPathSplited[0] + "?";
# 			$.each(attributes, function(idx, value) {
# 				if(idx > 0) sPath += "&";
# 				sPath += attributes[idx];
# 			});
# 			sPath += "&";
# 		}else sPath += "?";
# 		sPath += "r=+f/type/datasets";
# 		$(this).attr("href", sPath);
# 	});*/
#
# 	$('ul.list-filters>li').click(function() {
# 		$(this).addClass('current').siblings().removeClass('current');
# 	});
#
# 	$('.main-nav ul.tab>li>a').attr('href','#');
#
# 	/*FIX Language Switch on Home Page*/
# 	$('.language-switch a').each(function(idx, item) {
# 		var $item = $(item);
# 		if ( $item.attr('href').indexOf('/fr/accueil') > -1 ) {
# 			$item.attr('href','/fr');
# 		} else if ( $item.attr('href').indexOf('/home') > -1 ) {
# 			$item.attr('href','/');
# 		}
# 	});
#
# });
#   </script>
#   <!--search bar -->
#   <script>
#    $(function(){
#   var display = (typeof showSearchBar !== "undefined" && showSearchBar == false) ? "none" : "block";
#   $('.ddp-root .header-statistics-inner .right .header-search-form').css("display",display);
# });
#   </script>
#   <script type="text/javascript">
#    $(function () {
#       $('.language-switch').empty().html(languageSwitch);
#   });
#   </script>
#   <!--Google Analytics code-->
#   <script type="text/javascript">
#    /*var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-51805530-1']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();*/
#   </script>
#   <!-- POP UP -->
#   <script src="/media/oecdorg/satellitesites/finconet/js/jquery-ui.min.js" type="text/javascript">
#   </script>
#   <!--jquery-ui.js-->
#   <script src="/media/oecdorg/oecdsatellitetempl/lib/js/bootstrap.min.js" type="text/javascript">
#   </script>
#   <!--bootstrap.min.js-->
#   <script src="/media/oecdorg/styleassets/responsive/satellite-sites/js/sat_site_popup.js" type="text/javascript">
#   </script>
#   <!--sat_site_popup.js-->
#   <script src="/media/dataportal/scripts/dp-gtm-code.js" type="text/javascript">
#   </script>
#   <!--dp-gtm-code.js-->
#   <script>
#   </script>
#   <!--t4 type="navigation" id="572"/-->
#   <!-- POP UP END -->
#  </body>
# </html>

# %%
for link in soup.find_all('a')[:5]:
    print(link, '\n')
# Out:
# <a class="oecd-header__link" href="http://oecd.org/">OECD.org</a>
#
# <a class="oecd-header__link" href="http://www.oecd-ilibrary.org/">Publications</a>
#
# <a class="oecd-header__link oecd-header__secondary-toggle" href="">More sites</a>
#
# <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecdbetterlifeindex.org/">OECD Better Life Index</a>
#
# <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecd-ilibrary.org/">OECD iLibrary</a>

# %%
for element in soup.find_all(class_='oecd-header__primary'):
    print(element.prettify())
# Out:
# <ul class="oecd-header__primary">
#  <li class="col-sm-2 oecd-header__item">
#   <a class="oecd-header__link" href="http://oecd.org/">
#    OECD.org
#   </a>
#  </li>
#  <li class="col-sm-2 oecd-header__item oecd-header__item--active">
#   <strong class="oecd-header__current-page">
#    Data
#   </strong>
#  </li>
#  <li class="col-sm-2 oecd-header__item">
#   <a class="oecd-header__link" href="http://www.oecd-ilibrary.org/">
#    Publications
#   </a>
#  </li>
#  <li class="col-sm-2 oecd-header__item oecd-header__secondary-container">
#   <a class="oecd-header__link oecd-header__secondary-toggle" href="">
#    More sites
#   </a>
#   <ul class="sr-only oecd-header__secondary">
#    <li class="oecd-header__item oecd-header__secondary-item oecd-header__secondary-item-first">
#     <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecdbetterlifeindex.org/">
#      OECD Better Life Index
#     </a>
#    </li>
#    <li class="oecd-header__item oecd-header__secondary-item">
#     <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecd-ilibrary.org/">
#      OECD iLibrary
#     </a>
#    </li>
#    <li class="oecd-header__item oecd-header__secondary-item">
#     <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecdobserver.org/">
#      OECD Observer
#     </a>
#    </li>
#    <li class="oecd-header__item oecd-header__secondary-item">
#     <a class="oecd-header__link oecd-header__secondary-link" href="http://oecdinsights.org/">
#      OECD Insights blog
#     </a>
#    </li>
#    <li class="oecd-header__item oecd-header__secondary-item">
#     <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecd.org/dev/">
#      OECD Development Centre
#     </a>
#    </li>
#    <li class="oecd-header__item oecd-header__secondary-item">
#     <a class="oecd-header__link oecd-header__secondary-link" href="http://www.fatf-gafi.org/">
#      FATF - Financial Action Task Force
#     </a>
#    </li>
#    <li class="oecd-header__item oecd-header__secondary-item">
#     <a class="oecd-header__link oecd-header__secondary-link" href="http://www.iea.org/">
#      IEA â International Energy Agency
#     </a>
#    </li>
#    <li class="oecd-header__item oecd-header__secondary-item">
#     <a class="oecd-header__link oecd-header__secondary-link" href="http://www.itf-oecd.org/">
#      ITF â International Transport Forum
#     </a>
#    </li>
#    <li class="oecd-header__item oecd-header__secondary-item">
#     <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecd-nea.org/">
#      NEA â Nuclear Energy Agency
#     </a>
#    </li>
#    <li class="oecd-header__item oecd-header__secondary-item oecd-header__secondary-item-last">
#     <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecd.org/swac/">
#      SWAC â Sahel and West Africa Club
#     </a>
#    </li>
#   </ul>
#  </li>
#  <li class="col-sm-1 oecd-header__item">
#   <a class="oecd-header__link" href="http://oecd.org/newsroom/">
#    News
#   </a>
#  </li>
#  <li class="col-sm-2 oecd-header__item">
#   <a class="oecd-header__link" href="http://oecd.org/careers/">
#    Job vacancies
#   </a>
#  </li>
# </ul>

# %%
for element in soup.find_all(class_='country profile'):
    print(element.prettify())
