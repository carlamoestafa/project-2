# %% [markdown]
# # PROJECT - 2

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
import dateutil.parser

# %% [markdown]
# ### Getting  information from a movie page

# %%
url = 'https://www.boxofficemojo.com/title/tt2488496/?ref_=bo_cso_table_1'
response = requests.get(url)
page = response.text
soup = BeautifulSoup(page, 'lxml')
# soup.prettify()

# %% [markdown]
# #### Movie Title

# %%
soup.find('title').text
title_string = soup.find('title').text
title_string
# Out:
# 'Star Wars: Episode VII - The Force Awakens - Box Office Mojo'

# %%
title = title_string[:-18]
title
# Out:
# 'Star Wars: Episode VII - The Force Awakens'

# %% [markdown]
# #### Domestic Gross

# %%
soup.find(class_='mojo-performance-summary-table').find_all('span',class_='money')
# Out:
# [<span class="money">$936,662,225</span>,
#  <span class="money">$1,131,791,908</span>,
#  <span class="money">$2,068,454,133</span>]

# %%
dom_gross = soup.find(class_='mojo-performance-summary-table').find_all('span',class_='money')[0].text
dom_gross
# Out:
# '$936,662,225'

# %% [markdown]
# #### International Gross

# %%
intl_gross = soup.find(class_='mojo-performance-summary-table').find_all('span',class_='money')[1].text
intl_gross
# Out:
# '$1,131,791,908'

# %% [markdown]
# #### Worldwide Gross

# %%
world_gross = soup.find(class_='mojo-performance-summary-table').find_all('span',class_='money')[2].text
world_gross
# Out:
# '$2,068,454,133'

# %% [markdown]
# #### Domestic Distributor

# %%
soup.find(class_='mojo-summary-values').find_all('span', class_ = 'money')
# Out:
# [<span class="money">$247,966,675</span>,
#  <span class="money">$245,000,000</span>]

# %%
distributor_reggex = re.compile('Distributor')
soup.find(text=distributor_reggex)
# Out:
# 'Domestic Distributor'

# %%
distr_string = find(text=distributor_reggex).findNext('span').text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-6c59da8698ec> in <module>
# ----> 1 distr_string = find(text=distributor_reggex).findNext('span').text
#
# NameError: name 'find' is not defined

# %%
dist_string = soup.find(text=distributor_reggex).findNext('span').text[:18]
dom_dist = dist_string
dom_dist
# Out:
# 'Walt Disney Studio'

# %% [markdown]
# #### Domestic Opening Gross

# %%
dom_open_gross = soup.find(class_='mojo-summary-values').find_all('span', class_ = 'money')
domopening_reggex = re.compile('Domestic Open')
soup.find(text=domopening_reggex)
# Out:
# 'Domestic Opening'

# %%
dom_opening_gross = soup.find(text=domopening_reggex).findNext(class_='money').text
dom_opening_gross
# Out:
# '$247,966,675'

# %% [markdown]
# #### Budget

# %% [markdown]
# ####  Release Month

# %%
release_reggex = re.compile('Release Date')
soup.find(text=release_reggex).findNext().text.split()[0]
release_month = soup.find(text=release_reggex).findNext().text.split()[0]
release_month
# Out:
# 'December'

# %% [markdown]
# #### Get Movie Values

# %% [markdown]
# #### Getting findNext object value

# %%
def get_movie_value(soup, field_name):
    
    """
    Get a value fro the movie page and take the string attribute of a movie on the page and return
    the value of the next sibling object or None if nothing is found.
    
    """
    obj = soup.find(text=re.compile(field_name))
    if not obj:
        return None
    next_element = obj.findNext()
    
    if next_element:
        return next_element.text
    else:
        return None

# %%
dom_open_gross = get_movie_value(soup,'Domestic Open')
print(dom_open_gross)
# Out:
# $247,966,675

# %%
runtime = get_movie_value(soup, 'Running')
print(runtime)
# Out:
# 2 hr 18 min

# %%
rating = get_movie_value(soup, 'MPAA')
print(rating)
# Out:
# PG-13

# %%
rel_date = get_movie_value(soup, 'Release Date')
print(rel_date)
# Out:
# December 16, 2015
#             (APAC, EMEA)

# %%
genres = get_movie_value(soup, 'Genres').split()
genres
# Out:
# ['Action', 'Adventure', 'Sci-Fi']

# %%
distributor = get_movie_value(soup, 'Distributor')[:35]
distributor
# Out:
# 'Walt Disney Studios Motion Pictures'

# %%
def money_to_int(moneystring):
    
    """
    replaces the $ sign and removing the comma separator from the money string
    returns the integer value
    """
    
    moneystring = moneystring.replace('$', '').replace(',', '')
    return int(moneystring)

def runtime_to_minutes(runtimestring):
    
    """
    takes runtimestring in _hr_min format and returns it's value in number of minutes
    """
    
    runtime = runtimestring.split()
    try:
        minutes = int(runtime[0]) * 60 + int(runtime[2])
        return minutes
    except:
        return None

def to_date(datestring):
    
    """
    """
    
    date = dateutil.parser.parse(datestring)
    return date

# %%
raw_dom_gross = dom_gross
domestic_gross = money_to_int(raw_dom_gross)

raw_intl_gross = intl_gross
international_gross = money_to_int(raw_intl_gross)

raw_world_gross = world_gross
worldwide_gross = money_to_int(raw_world_gross)

raw_opening_gross = dom_opening_gross
domestic_opening_gross = money_to_int(raw_opening_gross)

# %%
raw_runtime = get_movie_value(soup, 'Running')
runtime_minutes = runtime_to_minutes(raw_runtime)
runtime_minutes
# Out:
# 138

# %%
release_month = rel_date.split()[0]
release_month
# Out:
# 'December'

# %% [markdown]
# #### Movie Page Dictionary

# %%
headers = ['movie title', 'domestic total gross', 'international total gross','domestic opening gross','runtime (mins)',
           'rating', 'release month', 'genre']

movie_data = []
movie_dict = dict(zip(headers,[title,
                               domestic_gross,
                               international_gross,
                               domestic_opening_gross,
                               runtime_minutes,
                               rating,
                               release_month,
                               genres]))
movie_data.append(movie_dict)
movie_data
# Out:
# [{'movie title': 'Star Wars: Episode VII - The Force Awakens',
#   'domestic total gross': 936662225,
#   'international total gross': 1131791908,
#   'domestic opening gross': 247966675,
#   'runtime (mins)': 138,
#   'rating': 'PG-13',
#   'release month': 'December',
#   'genre': ['Action', 'Adventure', 'Sci-Fi']}]

# %% [markdown]
# ### Getting the lifetime ranking table

# %%
url = 'https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?area=XWW'
response = requests.get(url)
page = response.text
soup = BeautifulSoup(page, 'lxml')
# print(soup.prettify())

# %%
# finding the table
table = soup.find('table')
# table

# %%
rows = [row for row in table.find_all('tr')]
rows[1].find_all('td')
# Out:
# [<td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">1</td>,
#  <td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt4154796/?ref_=bo_cso_table_1">Avengers: Endgame</a></td>,
#  <td class="a-text-right mojo-field-type-money">$2,797,800,564</td>,
#  <td class="a-text-right mojo-field-type-money">$858,373,000</td>,
#  <td class="a-text-right mojo-field-type-percent">30.7%</td>,
#  <td class="a-text-right mojo-field-type-money">$1,939,427,564</td>,
#  <td class="a-text-right mojo-field-type-percent">69.3%</td>,
#  <td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2019/?ref_=bo_cso_table_1">2019</a></td>]

# %%
rows[1].find_all('td')[1].find('a')['href']
# Out:
# '/title/tt4154796/?ref_=bo_cso_table_1'

# %%
movies = {}

for row in rows[1:200]:
    items = row.find_all('td')
    link = items[1].find('a')
    title = link.text
    url = link['href']
    movies[title] = [url]+ [i.text for i in items]

movies
# Out:
# {'Avengers: Endgame': ['/title/tt4154796/?ref_=bo_cso_table_1',
#   '1',
#   'Avengers: Endgame',
#   '$2,797,800,564',
#   '$858,373,000',
#   '30.7%',
#   '$1,939,427,564',
#   '69.3%',
#   '2019'],
#  'Avatar': ['/title/tt0499549/?ref_=bo_cso_table_2',
#   '2',
#   'Avatar',
#   '$2,790,439,092',
#   '$760,507,625',
#   '27.2%',
#   '$2,029,931,467',
#   '72.8%',
#   '2009'],
#  'Titanic': ['/title/tt0120338/?ref_=bo_cso_table_3',
#   '3',
#   'Titanic',
#   '$2,471,751,922',
#   '$659,363,944',
#   '26.7%',
#   '$1,812,387,978',
#   '73.3%',
#   '1997'],
#  'Star Wars: Episode VII - The Force Awakens': ['/title/tt2488496/?ref_=bo_cso_table_4',
#   '4',
#   'Star Wars: Episode VII - The Force Awakens',
#   '$2,068,454,133',
#   '$936,662,225',
#   '45.3%',
#   '$1,131,791,908',
#   '54.7%',
#   '2015'],
#  'Avengers: Infinity War': ['/title/tt4154756/?ref_=bo_cso_table_5',
#   '5',
#   'Avengers: Infinity War',
#   '$2,048,359,754',
#   '$678,815,482',
#   '33.1%',
#   '$1,369,544,272',
#   '66.9%',
#   '2018'],
#  'Jurassic World': ['/title/tt0369610/?ref_=bo_cso_table_6',
#   '6',
#   'Jurassic World',
#   '$1,670,426,444',
#   '$652,295,625',
#   '39%',
#   '$1,018,130,819',
#   '61%',
#   '2015'],
#  'The Lion King': ['/title/tt0110357/?ref_=bo_cso_table_31',
#   '31',
#   'The Lion King',
#   '$1,083,720,507',
#   '$422,783,777',
#   '39%',
#   '$660,936,730',
#   '61%',
#   '1994'],
#  'The Avengers': ['/title/tt0848228/?ref_=bo_cso_table_8',
#   '8',
#   'The Avengers',
#   '$1,518,815,515',
#   '$623,357,910',
#   '41%',
#   '$895,457,605',
#   '59%',
#   '2012'],
#  'Furious 7': ['/title/tt2820852/?ref_=bo_cso_table_9',
#   '9',
#   'Furious 7',
#   '$1,515,253,888',
#   '$353,007,020',
#   '23.3%',
#   '$1,162,246,868',
#   '76.7%',
#   '2015'],
#  'Frozen II': ['/title/tt4520988/?ref_=bo_cso_table_10',
#   '10',
#   'Frozen II',
#   '$1,450,026,933',
#   '$477,373,578',
#   '32.9%',
#   '$972,653,355',
#   '67.1%',
#   '2019'],
#  'Avengers: Age of Ultron': ['/title/tt2395427/?ref_=bo_cso_table_11',
#   '11',
#   'Avengers: Age of Ultron',
#   '$1,402,809,540',
#   '$459,005,868',
#   '32.7%',
#   '$943,803,672',
#   '67.3%',
#   '2015'],
#  'Black Panther': ['/title/tt1825683/?ref_=bo_cso_table_12',
#   '12',
#   'Black Panther',
#   '$1,347,597,973',
#   '$700,426,566',
#   '52%',
#   '$647,171,407',
#   '48%',
#   '2018'],
#  'Harry Potter and the Deathly Hallows: Part 2': ['/title/tt1201607/?ref_=bo_cso_table_13',
#   '13',
#   'Harry Potter and the Deathly Hallows: Part 2',
#   '$1,342,223,936',
#   '$381,409,310',
#   '28.4%',
#   '$960,814,626',
#   '71.6%',
#   '2011'],
#  'Star Wars: Episode VIII - The Last Jedi': ['/title/tt2527336/?ref_=bo_cso_table_14',
#   '14',
#   'Star Wars: Episode VIII - The Last Jedi',
#   '$1,332,697,499',
#   '$620,181,382',
#   '46.5%',
#   '$712,516,117',
#   '53.5%',
#   '2017'],
#  'Jurassic World: Fallen Kingdom': ['/title/tt4881806/?ref_=bo_cso_table_15',
#   '15',
#   'Jurassic World: Fallen Kingdom',
#   '$1,310,464,680',
#   '$417,719,760',
#   '31.9%',
#   '$892,744,920',
#   '68.1%',
#   '2018'],
#  'Frozen': ['/title/tt2294629/?ref_=bo_cso_table_16',
#   '16',
#   'Frozen',
#   '$1,281,019,275',
#   '$400,953,009',
#   '31.3%',
#   '$880,066,266',
#   '68.7%',
#   '2013'],
#  'Beauty and the Beast': ['/title/tt2771200/?ref_=bo_cso_table_17',
#   '17',
#   'Beauty and the Beast',
#   '$1,264,064,831',
#   '$504,481,165',
#   '39.9%',
#   '$759,583,666',
#   '60.1%',
#   '2017'],
#  'Incredibles 2': ['/title/tt3606756/?ref_=bo_cso_table_18',
#   '18',
#   'Incredibles 2',
#   '$1,243,089,214',
#   '$608,581,744',
#   '49%',
#   '$634,507,470',
#   '51%',
#   '2018'],
#  'The Fate of the Furious': ['/title/tt4630562/?ref_=bo_cso_table_19',
#   '19',
#   'The Fate of the Furious',
#   '$1,236,005,118',
#   '$226,008,385',
#   '18.3%',
#   '$1,009,996,733',
#   '81.7%',
#   '2017'],
#  'Iron Man 3': ['/title/tt1300854/?ref_=bo_cso_table_20',
#   '20',
#   'Iron Man 3',
#   '$1,214,811,252',
#   '$409,013,994',
#   '33.7%',
#   '$805,797,258',
#   '66.3%',
#   '2013'],
#  'Minions': ['/title/tt2293640/?ref_=bo_cso_table_21',
#   '21',
#   'Minions',
#   '$1,159,444,662',
#   '$336,045,770',
#   '29%',
#   '$823,398,892',
#   '71%',
#   '2015'],
#  'Captain America: Civil War': ['/title/tt3498820/?ref_=bo_cso_table_22',
#   '22',
#   'Captain America: Civil War',
#   '$1,153,561,649',
#   '$408,084,349',
#   '35.4%',
#   '$745,477,300',
#   '64.6%',
#   '2016'],
#  'Aquaman': ['/title/tt1477834/?ref_=bo_cso_table_23',
#   '23',
#   'Aquaman',
#   '$1,148,485,886',
#   '$335,061,807',
#   '29.2%',
#   '$813,424,079',
#   '70.8%',
#   '2018'],
#  'The Lord of the Rings: The Return of the King': ['/title/tt0167260/?ref_=bo_cso_table_24',
#   '24',
#   'The Lord of the Rings: The Return of the King',
#   '$1,142,456,987',
#   '$377,845,905',
#   '33.1%',
#   '$764,611,082',
#   '66.9%',
#   '2003'],
#  'Spider-Man: Far from Home': ['/title/tt6320628/?ref_=bo_cso_table_25',
#   '25',
#   'Spider-Man: Far from Home',
#   '$1,131,927,996',
#   '$390,532,085',
#   '34.5%',
#   '$741,395,911',
#   '65.5%',
#   '2019'],
#  'Captain Marvel': ['/title/tt4154664/?ref_=bo_cso_table_26',
#   '26',
#   'Captain Marvel',
#   '$1,128,462,972',
#   '$426,829,839',
#   '37.8%',
#   '$701,633,133',
#   '62.2%',
#   '2019'],
#  'Transformers: Dark of the Moon': ['/title/tt1399103/?ref_=bo_cso_table_27',
#   '27',
#   'Transformers: Dark of the Moon',
#   '$1,123,794,079',
#   '$352,390,543',
#   '31.4%',
#   '$771,403,536',
#   '68.6%',
#   '2011'],
#  'Skyfall': ['/title/tt1074638/?ref_=bo_cso_table_28',
#   '28',
#   'Skyfall',
#   '$1,108,561,013',
#   '$304,360,277',
#   '27.5%',
#   '$804,200,736',
#   '72.5%',
#   '2012'],
#  'Fast & Furious Presents: Hobbs & Shaw': ['/title/tt6806448/?ref_=bo_cso_table_29',
#   '29',
#   'Fast & Furious Presents: Hobbs & Shaw',
#   '$1,104,826,325',
#   '$173,956,935',
#   '15.8%',
#   '$930,869,390',
#   '84.2%',
#   '2019'],
#  'Transformers: Age of Extinction': ['/title/tt2109248/?ref_=bo_cso_table_30',
#   '30',
#   'Transformers: Age of Extinction',
#   '$1,104,054,072',
#   '$245,439,076',
#   '22.2%',
#   '$858,614,996',
#   '77.8%',
#   '2014'],
#  'The Dark Knight Rises': ['/title/tt1345836/?ref_=bo_cso_table_32',
#   '32',
#   'The Dark Knight Rises',
#   '$1,081,141,435',
#   '$448,139,099',
#   '41.4%',
#   '$633,002,336',
#   '58.6%',
#   '2012'],
#  'Joker': ['/title/tt7286456/?ref_=bo_cso_table_33',
#   '33',
#   'Joker',
#   '$1,074,251,311',
#   '$335,451,311',
#   '31.2%',
#   '$738,800,000',
#   '68.8%',
#   '2019'],
#  'Star Wars: Episode IX - The Rise of Skywalker': ['/title/tt2527338/?ref_=bo_cso_table_34',
#   '34',
#   'Star Wars: Episode IX - The Rise of Skywalker',
#   '$1,074,144,248',
#   '$515,202,542',
#   '48%',
#   '$558,941,706',
#   '52%',
#   '2019'],
#  'Toy Story 4': ['/title/tt1979376/?ref_=bo_cso_table_35',
#   '35',
#   'Toy Story 4',
#   '$1,073,394,593',
#   '$434,038,008',
#   '40.4%',
#   '$639,356,585',
#   '59.6%',
#   '2019'],
#  'Toy Story 3': ['/title/tt0435761/?ref_=bo_cso_table_36',
#   '36',
#   'Toy Story 3',
#   '$1,066,969,895',
#   '$415,004,880',
#   '38.9%',
#   '$651,965,015',
#   '61.1%',
#   '2010'],
#  "Pirates of the Caribbean: Dead Man's Chest": ['/title/tt0383574/?ref_=bo_cso_table_37',
#   '37',
#   "Pirates of the Caribbean: Dead Man's Chest",
#   '$1,066,179,747',
#   '$423,315,812',
#   '39.7%',
#   '$642,863,935',
#   '60.3%',
#   '2006'],
#  'Rogue One: A Star Wars Story': ['/title/tt3748528/?ref_=bo_cso_table_38',
#   '38',
#   'Rogue One: A Star Wars Story',
#   '$1,056,057,720',
#   '$532,177,324',
#   '50.4%',
#   '$523,880,396',
#   '49.6%',
#   '2016'],
#  'Aladdin': ['/title/tt6139732/?ref_=bo_cso_table_39',
#   '39',
#   'Aladdin',
#   '$1,050,693,953',
#   '$355,559,216',
#   '33.8%',
#   '$695,134,737',
#   '66.2%',
#   '2019'],
#  'Pirates of the Caribbean: On Stranger Tides': ['/title/tt1298650/?ref_=bo_cso_table_40',
#   '40',
#   'Pirates of the Caribbean: On Stranger Tides',
#   '$1,045,713,802',
#   '$241,071,802',
#   '23%',
#   '$804,642,000',
#   '77%',
#   '2011'],
#  'Despicable Me 3': ['/title/tt3469046/?ref_=bo_cso_table_41',
#   '41',
#   'Despicable Me 3',
#   '$1,034,800,131',
#   '$264,624,300',
#   '25.6%',
#   '$770,175,831',
#   '74.4%',
#   '2017'],
#  'Jurassic Park': ['/title/tt0107290/?ref_=bo_cso_table_42',
#   '42',
#   'Jurassic Park',
#   '$1,033,927,022',
#   '$404,214,720',
#   '39.1%',
#   '$629,712,302',
#   '60.9%',
#   '1993'],
#  'Finding Dory': ['/title/tt2277860/?ref_=bo_cso_table_43',
#   '43',
#   'Finding Dory',
#   '$1,028,570,889',
#   '$486,295,561',
#   '47.3%',
#   '$542,275,328',
#   '52.7%',
#   '2016'],
#  'Star Wars: Episode I - The Phantom Menace': ['/title/tt0120915/?ref_=bo_cso_table_44',
#   '44',
#   'Star Wars: Episode I - The Phantom Menace',
#   '$1,027,082,707',
#   '$474,544,677',
#   '46.2%',
#   '$552,538,030',
#   '53.8%',
#   '1999'],
#  'Alice in Wonderland': ['/title/tt1014759/?ref_=bo_cso_table_45',
#   '45',
#   'Alice in Wonderland',
#   '$1,025,468,216',
#   '$334,191,110',
#   '32.6%',
#   '$691,277,106',
#   '67.4%',
#   '2010'],
#  'Zootopia': ['/title/tt2948356/?ref_=bo_cso_table_46',
#   '46',
#   'Zootopia',
#   '$1,023,792,558',
#   '$341,268,248',
#   '33.3%',
#   '$682,524,310',
#   '66.7%',
#   '2016'],
#  'The Hobbit: An Unexpected Journey': ['/title/tt0903624/?ref_=bo_cso_table_47',
#   '47',
#   'The Hobbit: An Unexpected Journey',
#   '$1,017,003,568',
#   '$303,003,568',
#   '29.8%',
#   '$714,000,000',
#   '70.2%',
#   '2012'],
#  "Harry Potter and the Sorcerer's Stone": ['/title/tt0241527/?ref_=bo_cso_table_48',
#   '48',
#   "Harry Potter and the Sorcerer's Stone",
#   '$1,006,917,662',
#   '$318,087,620',
#   '31.6%',
#   '$688,830,042',
#   '68.4%',
#   '2001'],
#  'The Dark Knight': ['/title/tt0468569/?ref_=bo_cso_table_49',
#   '49',
#   'The Dark Knight',
#   '$1,005,973,645',
#   '$534,858,444',
#   '53.2%',
#   '$471,115,201',
#   '46.8%',
#   '2008'],
#  'Harry Potter and the Deathly Hallows: Part 1': ['/title/tt0926084/?ref_=bo_cso_table_50',
#   '50',
#   'Harry Potter and the Deathly Hallows: Part 1',
#   '$976,999,243',
#   '$296,347,721',
#   '30.3%',
#   '$680,651,522',
#   '69.7%',
#   '2010'],
#  'Despicable Me 2': ['/title/tt1690953/?ref_=bo_cso_table_51',
#   '51',
#   'Despicable Me 2',
#   '$970,766,005',
#   '$368,065,385',
#   '37.9%',
#   '$602,700,620',
#   '62.1%',
#   '2013'],
#  'The Jungle Book': ['/title/tt3040964/?ref_=bo_cso_table_52',
#   '52',
#   'The Jungle Book',
#   '$966,554,929',
#   '$364,001,123',
#   '37.7%',
#   '$602,553,806',
#   '62.3%',
#   '2016'],
#  'Jumanji: Welcome to the Jungle': ['/title/tt2283362/?ref_=bo_cso_table_53',
#   '53',
#   'Jumanji: Welcome to the Jungle',
#   '$962,103,351',
#   '$404,540,171',
#   '42%',
#   '$557,563,180',
#   '58%',
#   '2017'],
#  "Pirates of the Caribbean: At World's End": ['/title/tt0449088/?ref_=bo_cso_table_54',
#   '54',
#   "Pirates of the Caribbean: At World's End",
#   '$960,996,492',
#   '$309,420,425',
#   '32.2%',
#   '$651,576,067',
#   '67.8%',
#   '2007'],
#  'The Hobbit: The Desolation of Smaug': ['/title/tt1170358/?ref_=bo_cso_table_55',
#   '55',
#   'The Hobbit: The Desolation of Smaug',
#   '$958,366,855',
#   '$258,366,855',
#   '27%',
#   '$700,000,000',
#   '73%',
#   '2013'],
#  'The Hobbit: The Battle of the Five Armies': ['/title/tt2310332/?ref_=bo_cso_table_56',
#   '56',
#   'The Hobbit: The Battle of the Five Armies',
#   '$956,019,788',
#   '$255,119,788',
#   '26.7%',
#   '$700,900,000',
#   '73.3%',
#   '2014'],
#  'The Lord of the Rings: The Two Towers': ['/title/tt0167261/?ref_=bo_cso_table_57',
#   '57',
#   'The Lord of the Rings: The Two Towers',
#   '$943,396,133',
#   '$342,551,365',
#   '36.3%',
#   '$600,844,768',
#   '63.7%',
#   '2002'],
#  'Harry Potter and the Order of the Phoenix': ['/title/tt0373889/?ref_=bo_cso_table_58',
#   '58',
#   'Harry Potter and the Order of the Phoenix',
#   '$942,172,396',
#   '$292,353,413',
#   '31%',
#   '$649,818,983',
#   '69%',
#   '2007'],
#  'Finding Nemo': ['/title/tt0266543/?ref_=bo_cso_table_59',
#   '59',
#   'Finding Nemo',
#   '$940,350,194',
#   '$380,843,261',
#   '40.5%',
#   '$559,506,933',
#   '59.5%',
#   '2003'],
#  'Harry Potter and the Half-Blood Prince': ['/title/tt0417741/?ref_=bo_cso_table_60',
#   '60',
#   'Harry Potter and the Half-Blood Prince',
#   '$934,454,096',
#   '$302,305,431',
#   '32.4%',
#   '$632,148,665',
#   '67.6%',
#   '2009'],
#  'Shrek 2': ['/title/tt0298148/?ref_=bo_cso_table_61',
#   '61',
#   'Shrek 2',
#   '$928,760,770',
#   '$441,226,247',
#   '47.5%',
#   '$487,534,523',
#   '52.5%',
#   '2004'],
#  'Bohemian Rhapsody': ['/title/tt1727824/?ref_=bo_cso_table_62',
#   '62',
#   'Bohemian Rhapsody',
#   '$905,234,477',
#   '$216,668,042',
#   '23.9%',
#   '$688,566,435',
#   '76.1%',
#   '2018'],
#  'Harry Potter and the Goblet of Fire': ['/title/tt0330373/?ref_=bo_cso_table_63',
#   '63',
#   'Harry Potter and the Goblet of Fire',
#   '$896,420,762',
#   '$290,417,905',
#   '32.4%',
#   '$606,002,857',
#   '67.6%',
#   '2005'],
#  'Spider-Man 3': ['/title/tt0413300/?ref_=bo_cso_table_64',
#   '64',
#   'Spider-Man 3',
#   '$894,983,373',
#   '$336,530,303',
#   '37.6%',
#   '$558,453,070',
#   '62.4%',
#   '2007'],
#  'The Lord of the Rings: The Fellowship of the Ring': ['/title/tt0120737/?ref_=bo_cso_table_65',
#   '65',
#   'The Lord of the Rings: The Fellowship of the Ring',
#   '$888,159,092',
#   '$315,544,750',
#   '35.5%',
#   '$572,614,342',
#   '64.5%',
#   '2001'],
#  'Ice Age: Dawn of the Dinosaurs': ['/title/tt1080016/?ref_=bo_cso_table_66',
#   '66',
#   'Ice Age: Dawn of the Dinosaurs',
#   '$886,686,817',
#   '$196,573,705',
#   '22.2%',
#   '$690,113,112',
#   '77.8%',
#   '2009'],
#  'Spectre': ['/title/tt2379713/?ref_=bo_cso_table_67',
#   '67',
#   'Spectre',
#   '$880,674,609',
#   '$200,074,609',
#   '22.7%',
#   '$680,600,000',
#   '77.3%',
#   '2015'],
#  'Spider-Man: Homecoming': ['/title/tt2250912/?ref_=bo_cso_table_68',
#   '68',
#   'Spider-Man: Homecoming',
#   '$880,166,924',
#   '$334,201,140',
#   '38%',
#   '$545,965,784',
#   '62%',
#   '2017'],
#  'Harry Potter and the Chamber of Secrets': ['/title/tt0295297/?ref_=bo_cso_table_69',
#   '69',
#   'Harry Potter and the Chamber of Secrets',
#   '$879,602,366',
#   '$262,450,136',
#   '29.8%',
#   '$617,152,230',
#   '70.2%',
#   '2002'],
#  'Ice Age: Continental Drift': ['/title/tt1667889/?ref_=bo_cso_table_70',
#   '70',
#   'Ice Age: Continental Drift',
#   '$877,244,782',
#   '$161,321,843',
#   '18.4%',
#   '$715,922,939',
#   '81.6%',
#   '2012'],
#  'The Secret Life of Pets': ['/title/tt2709768/?ref_=bo_cso_table_71',
#   '71',
#   'The Secret Life of Pets',
#   '$875,458,631',
#   '$368,384,330',
#   '42.1%',
#   '$507,074,301',
#   '57.9%',
#   '2016'],
#  'Batman v Superman: Dawn of Justice': ['/title/tt2975590/?ref_=bo_cso_table_72',
#   '72',
#   'Batman v Superman: Dawn of Justice',
#   '$873,637,528',
#   '$330,360,194',
#   '37.8%',
#   '$543,277,334',
#   '62.2%',
#   '2016'],
#  'Wolf Warrior 2': ['/title/tt7131870/?ref_=bo_cso_table_73',
#   '73',
#   'Wolf Warrior 2',
#   '$870,325,439',
#   '$2,721,100',
#   '0.3%',
#   '$867,604,339',
#   '99.7%',
#   '2017'],
#  'Star Wars: Episode III - Revenge of the Sith': ['/title/tt0121766/?ref_=bo_cso_table_74',
#   '74',
#   'Star Wars: Episode III - Revenge of the Sith',
#   '$868,390,560',
#   '$380,270,577',
#   '43.8%',
#   '$488,119,983',
#   '56.2%',
#   '2005'],
#  'The Hunger Games: Catching Fire': ['/title/tt1951264/?ref_=bo_cso_table_75',
#   '75',
#   'The Hunger Games: Catching Fire',
#   '$865,011,746',
#   '$424,668,047',
#   '49.1%',
#   '$440,343,699',
#   '50.9%',
#   '2013'],
#  'Guardians of the Galaxy Vol. 2': ['/title/tt3896198/?ref_=bo_cso_table_76',
#   '76',
#   'Guardians of the Galaxy Vol. 2',
#   '$863,756,051',
#   '$389,813,101',
#   '45.1%',
#   '$473,942,950',
#   '54.9%',
#   '2017'],
#  'Inside Out': ['/title/tt2096673/?ref_=bo_cso_table_77',
#   '77',
#   'Inside Out',
#   '$858,071,350',
#   '$356,921,711',
#   '41.6%',
#   '$501,149,639',
#   '58.4%',
#   '2015'],
#  'Venom': ['/title/tt1270797/?ref_=bo_cso_table_78',
#   '78',
#   'Venom',
#   '$856,085,151',
#   '$213,515,506',
#   '24.9%',
#   '$642,569,645',
#   '75.1%',
#   '2018'],
#  'Thor: Ragnarok': ['/title/tt3501632/?ref_=bo_cso_table_79',
#   '79',
#   'Thor: Ragnarok',
#   '$853,983,829',
#   '$315,058,289',
#   '36.9%',
#   '$538,925,540',
#   '63.1%',
#   '2017'],
#  'Inception': ['/title/tt1375666/?ref_=bo_cso_table_80',
#   '80',
#   'Inception',
#   '$836,836,967',
#   '$292,576,195',
#   '35%',
#   '$544,260,772',
#   '65%',
#   '2010'],
#  'Transformers: Revenge of the Fallen': ['/title/tt1055369/?ref_=bo_cso_table_81',
#   '81',
#   'Transformers: Revenge of the Fallen',
#   '$836,303,693',
#   '$402,111,870',
#   '48.1%',
#   '$434,191,823',
#   '51.9%',
#   '2009'],
#  'The Twilight Saga: Breaking Dawn - Part 2': ['/title/tt1673434/?ref_=bo_cso_table_82',
#   '82',
#   'The Twilight Saga: Breaking Dawn - Part 2',
#   '$829,747,654',
#   '$292,324,737',
#   '35.2%',
#   '$537,422,917',
#   '64.8%',
#   '2012'],
#  'Spider-Man': ['/title/tt0145487/?ref_=bo_cso_table_83',
#   '83',
#   'Spider-Man',
#   '$825,025,036',
#   '$407,022,860',
#   '49.3%',
#   '$418,002,176',
#   '50.7%',
#   '2002'],
#  'Wonder Woman': ['/title/tt0451279/?ref_=bo_cso_table_84',
#   '84',
#   'Wonder Woman',
#   '$822,303,505',
#   '$412,815,408',
#   '50.2%',
#   '$409,488,097',
#   '49.8%',
#   '2017'],
#  'Independence Day': ['/title/tt0116629/?ref_=bo_cso_table_85',
#   '85',
#   'Independence Day',
#   '$817,400,891',
#   '$306,169,268',
#   '37.5%',
#   '$511,231,623',
#   '62.5%',
#   '1996'],
#  'Fantastic Beasts and Where to Find Them': ['/title/tt3183660/?ref_=bo_cso_table_86',
#   '86',
#   'Fantastic Beasts and Where to Find Them',
#   '$814,044,001',
#   '$234,037,575',
#   '28.8%',
#   '$580,006,426',
#   '71.2%',
#   '2016'],
#  'Shrek the Third': ['/title/tt0413267/?ref_=bo_cso_table_87',
#   '87',
#   'Shrek the Third',
#   '$813,367,380',
#   '$322,719,944',
#   '39.7%',
#   '$490,647,436',
#   '60.3%',
#   '2007'],
#  'Coco': ['/title/tt2380307/?ref_=bo_cso_table_88',
#   '88',
#   'Coco',
#   '$807,817,888',
#   '$210,460,015',
#   '26%',
#   '$597,357,873',
#   '74%',
#   '2017'],
#  'Jumanji: The Next Level': ['/title/tt7975244/?ref_=bo_cso_table_89',
#   '89',
#   'Jumanji: The Next Level',
#   '$800,059,707',
#   '$320,314,960',
#   '40%',
#   '$479,744,747',
#   '60%',
#   '2019'],
#  'Harry Potter and the Prisoner of Azkaban': ['/title/tt0304141/?ref_=bo_cso_table_90',
#   '90',
#   'Harry Potter and the Prisoner of Azkaban',
#   '$796,221,906',
#   '$249,975,996',
#   '31.4%',
#   '$546,245,910',
#   '68.6%',
#   '2004'],
#  'Pirates of the Caribbean: Dead Men Tell No Tales': ['/title/tt1790809/?ref_=bo_cso_table_91',
#   '91',
#   'Pirates of the Caribbean: Dead Men Tell No Tales',
#   '$794,881,442',
#   '$172,558,876',
#   '21.7%',
#   '$622,322,566',
#   '78.3%',
#   '2017'],
#  'E.T. the Extra-Terrestrial': ['/title/tt0083866/?ref_=bo_cso_table_92',
#   '92',
#   'E.T. the Extra-Terrestrial',
#   '$792,910,554',
#   '$435,110,554',
#   '54.9%',
#   '$357,800,000',
#   '45.1%',
#   '1982'],
#  '2012': ['/title/tt1190080/?ref_=bo_cso_table_93',
#   '93',
#   '2012',
#   '$791,217,826',
#   '$166,112,167',
#   '21%',
#   '$625,105,659',
#   '79%',
#   '2009'],
#  'Mission: Impossible - Fallout': ['/title/tt4912910/?ref_=bo_cso_table_94',
#   '94',
#   'Mission: Impossible - Fallout',
#   '$791,120,426',
#   '$220,159,104',
#   '27.8%',
#   '$570,961,322',
#   '72.2%',
#   '2018'],
#  'Indiana Jones and the Kingdom of the Crystal Skull': ['/title/tt0367882/?ref_=bo_cso_table_95',
#   '95',
#   'Indiana Jones and the Kingdom of the Crystal Skull',
#   '$790,653,942',
#   '$317,101,119',
#   '40.1%',
#   '$473,552,823',
#   '59.9%',
#   '2008'],
#  'Spider-Man 2': ['/title/tt0316654/?ref_=bo_cso_table_96',
#   '96',
#   'Spider-Man 2',
#   '$788,976,453',
#   '$373,585,825',
#   '47.4%',
#   '$415,390,628',
#   '52.6%',
#   '2004'],
#  'Fast & Furious 6': ['/title/tt1905041/?ref_=bo_cso_table_97',
#   '97',
#   'Fast & Furious 6',
#   '$788,680,968',
#   '$238,679,850',
#   '30.3%',
#   '$550,001,118',
#   '69.7%',
#   '2013'],
#  'Deadpool 2': ['/title/tt5463162/?ref_=bo_cso_table_98',
#   '98',
#   'Deadpool 2',
#   '$785,794,344',
#   '$324,591,735',
#   '41.3%',
#   '$461,202,609',
#   '58.7%',
#   '2018'],
#  'Deadpool': ['/title/tt1431045/?ref_=bo_cso_table_99',
#   '99',
#   'Deadpool',
#   '$782,612,711',
#   '$363,070,709',
#   '46.4%',
#   '$419,542,002',
#   '53.6%',
#   '2016'],
#  'Star Wars: Episode IV - A New Hope': ['/title/tt0076759/?ref_=bo_cso_table_100',
#   '100',
#   'Star Wars: Episode IV - A New Hope',
#   '$775,398,007',
#   '$460,998,507',
#   '59.4%',
#   '$314,399,500',
#   '40.6%',
#   '1977'],
#  'Guardians of the Galaxy': ['/title/tt2015381/?ref_=bo_cso_table_101',
#   '101',
#   'Guardians of the Galaxy',
#   '$773,350,128',
#   '$333,718,600',
#   '43.2%',
#   '$439,631,528',
#   '56.8%',
#   '2014'],
#  'The Da Vinci Code': ['/title/tt0382625/?ref_=bo_cso_table_102',
#   '102',
#   'The Da Vinci Code',
#   '$760,006,945',
#   '$217,536,138',
#   '28.6%',
#   '$542,470,807',
#   '71.4%',
#   '2006'],
#  'Maleficent': ['/title/tt1587310/?ref_=bo_cso_table_103',
#   '103',
#   'Maleficent',
#   '$758,411,779',
#   '$241,410,378',
#   '31.8%',
#   '$517,001,401',
#   '68.2%',
#   '2014'],
#  'The Amazing Spider-Man': ['/title/tt0948470/?ref_=bo_cso_table_104',
#   '104',
#   'The Amazing Spider-Man',
#   '$757,930,663',
#   '$262,030,663',
#   '34.6%',
#   '$495,900,000',
#   '65.4%',
#   '2012'],
#  'The Hunger Games: Mockingjay - Part 1': ['/title/tt1951265/?ref_=bo_cso_table_105',
#   '105',
#   'The Hunger Games: Mockingjay - Part 1',
#   '$755,356,711',
#   '$337,135,885',
#   '44.6%',
#   '$418,220,826',
#   '55.4%',
#   '2014'],
#  'Shrek Forever After': ['/title/tt0892791/?ref_=bo_cso_table_106',
#   '106',
#   'Shrek Forever After',
#   '$752,600,867',
#   '$238,736,787',
#   '31.7%',
#   '$513,864,080',
#   '68.3%',
#   '2010'],
#  "Madagascar 3: Europe's Most Wanted": ['/title/tt1277953/?ref_=bo_cso_table_107',
#   '107',
#   "Madagascar 3: Europe's Most Wanted",
#   '$746,921,274',
#   '$216,391,482',
#   '29%',
#   '$530,529,792',
#   '71%',
#   '2012'],
#  'Suicide Squad': ['/title/tt1386697/?ref_=bo_cso_table_108',
#   '108',
#   'Suicide Squad',
#   '$746,846,894',
#   '$325,100,054',
#   '43.5%',
#   '$421,746,840',
#   '56.5%',
#   '2016'],
#  'X-Men: Days of Future Past': ['/title/tt1877832/?ref_=bo_cso_table_109',
#   '109',
#   'X-Men: Days of Future Past',
#   '$746,045,700',
#   '$233,921,534',
#   '31.4%',
#   '$512,124,166',
#   '68.6%',
#   '2014'],
#  'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe': ['/title/tt0363771/?ref_=bo_cso_table_110',
#   '110',
#   'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#   '$745,013,115',
#   '$291,710,957',
#   '39.2%',
#   '$453,302,158',
#   '60.8%',
#   '2005'],
#  'Monsters University': ['/title/tt1453405/?ref_=bo_cso_table_111',
#   '111',
#   'Monsters University',
#   '$743,559,607',
#   '$268,492,764',
#   '36.1%',
#   '$475,066,843',
#   '63.9%',
#   '2013'],
#  'The Matrix Reloaded': ['/title/tt0234215/?ref_=bo_cso_table_112',
#   '112',
#   'The Matrix Reloaded',
#   '$741,847,937',
#   '$281,576,461',
#   '38%',
#   '$460,271,476',
#   '62%',
#   '2003'],
#  'Up': ['/title/tt1049413/?ref_=bo_cso_table_113',
#   '113',
#   'Up',
#   '$735,099,102',
#   '$293,004,164',
#   '39.9%',
#   '$442,094,938',
#   '60.1%',
#   '2009'],
#  'Ne Zha': ['/title/tt10627720/?ref_=bo_cso_table_114',
#   '114',
#   'Ne Zha',
#   '$726,063,471',
#   '$3,695,533',
#   '0.5%',
#   '$722,367,938',
#   '99.5%',
#   '2019'],
#  'Gravity': ['/title/tt1454468/?ref_=bo_cso_table_115',
#   '115',
#   'Gravity',
#   '$723,192,705',
#   '$274,092,705',
#   '37.9%',
#   '$449,100,000',
#   '62.1%',
#   '2013'],
#  'Captain America: The Winter Soldier': ['/title/tt1843866/?ref_=bo_cso_table_116',
#   '116',
#   'Captain America: The Winter Soldier',
#   '$714,421,503',
#   '$259,766,572',
#   '36.4%',
#   '$454,654,931',
#   '63.6%',
#   '2014'],
#  'The Twilight Saga: Breaking Dawn - Part 1': ['/title/tt1324999/?ref_=bo_cso_table_117',
#   '117',
#   'The Twilight Saga: Breaking Dawn - Part 1',
#   '$712,205,856',
#   '$281,287,133',
#   '39.5%',
#   '$430,918,723',
#   '60.5%',
#   '2011'],
#  'The Twilight Saga: New Moon': ['/title/tt1259571/?ref_=bo_cso_table_118',
#   '118',
#   'The Twilight Saga: New Moon',
#   '$711,025,481',
#   '$297,816,253',
#   '41.9%',
#   '$413,209,228',
#   '58.1%',
#   '2009'],
#  'Dawn of the Planet of the Apes': ['/title/tt2103281/?ref_=bo_cso_table_119',
#   '119',
#   'Dawn of the Planet of the Apes',
#   '$710,644,566',
#   '$208,545,589',
#   '29.4%',
#   '$502,098,977',
#   '70.6%',
#   '2014'],
#  'Transformers': ['/title/tt0418279/?ref_=bo_cso_table_120',
#   '120',
#   'Transformers',
#   '$709,709,780',
#   '$319,246,193',
#   '45%',
#   '$390,463,587',
#   '55%',
#   '2007'],
#  'The Amazing Spider-Man 2': ['/title/tt1872181/?ref_=bo_cso_table_121',
#   '121',
#   'The Amazing Spider-Man 2',
#   '$708,982,323',
#   '$202,853,933',
#   '28.6%',
#   '$506,128,390',
#   '71.4%',
#   '2014'],
#  'It': ['/title/tt1396484/?ref_=bo_cso_table_122',
#   '122',
#   'It',
#   '$701,796,444',
#   '$328,828,874',
#   '46.9%',
#   '$372,967,570',
#   '53.1%',
#   '2017'],
#  'Interstellar': ['/title/tt0816692/?ref_=bo_cso_table_123',
#   '123',
#   'Interstellar',
#   '$701,795,571',
#   '$188,020,017',
#   '26.8%',
#   '$513,775,554',
#   '73.2%',
#   '2014'],
#  'The Wandering Earth': ['/title/tt7605074/?ref_=bo_cso_table_124',
#   '124',
#   'The Wandering Earth',
#   '$699,856,699',
#   '$5,971,413',
#   '0.8%',
#   '$693,885,286',
#   '99.2%',
#   '2019'],
#  'The Twilight Saga: Eclipse': ['/title/tt1325004/?ref_=bo_cso_table_125',
#   '125',
#   'The Twilight Saga: Eclipse',
#   '$698,491,347',
#   '$300,531,751',
#   '43%',
#   '$397,959,596',
#   '57%',
#   '2010'],
#  'Mission: Impossible - Ghost Protocol': ['/title/tt1229238/?ref_=bo_cso_table_126',
#   '126',
#   'Mission: Impossible - Ghost Protocol',
#   '$694,713,380',
#   '$209,397,903',
#   '30.1%',
#   '$485,315,477',
#   '69.9%',
#   '2011'],
#  'The Hunger Games': ['/title/tt1392170/?ref_=bo_cso_table_127',
#   '127',
#   'The Hunger Games',
#   '$694,394,724',
#   '$408,010,692',
#   '58.8%',
#   '$286,384,032',
#   '41.2%',
#   '2012'],
#  'It Chapter Two': ['/title/tt7349950/?ref_=bo_cso_table_128',
#   '128',
#   'It Chapter Two',
#   '$683,955,083',
#   '$211,593,228',
#   '30.9%',
#   '$472,361,855',
#   '69.1%',
#   '2019'],
#  'Mission: Impossible - Rogue Nation': ['/title/tt2381249/?ref_=bo_cso_table_129',
#   '129',
#   'Mission: Impossible - Rogue Nation',
#   '$682,716,636',
#   '$195,042,377',
#   '28.6%',
#   '$487,674,259',
#   '71.4%',
#   '2015'],
#  'Forrest Gump': ['/title/tt0109830/?ref_=bo_cso_table_130',
#   '130',
#   'Forrest Gump',
#   '$678,226,133',
#   '$330,455,270',
#   '48.7%',
#   '$347,770,863',
#   '51.3%',
#   '1994'],
#  'Doctor Strange': ['/title/tt1211837/?ref_=bo_cso_table_131',
#   '131',
#   'Doctor Strange',
#   '$677,796,076',
#   '$232,641,920',
#   '34.3%',
#   '$445,154,156',
#   '65.7%',
#   '2016'],
#  'The Sixth Sense': ['/title/tt0167404/?ref_=bo_cso_table_132',
#   '132',
#   'The Sixth Sense',
#   '$672,806,292',
#   '$293,506,292',
#   '43.6%',
#   '$379,300,000',
#   '56.4%',
#   '1999'],
#  'Man of Steel': ['/title/tt0770828/?ref_=bo_cso_table_133',
#   '133',
#   'Man of Steel',
#   '$668,045,518',
#   '$291,045,518',
#   '43.6%',
#   '$377,000,000',
#   '56.4%',
#   '2013'],
#  'Ice Age: The Meltdown': ['/title/tt0438097/?ref_=bo_cso_table_134',
#   '134',
#   'Ice Age: The Meltdown',
#   '$667,094,506',
#   '$195,330,621',
#   '29.3%',
#   '$471,763,885',
#   '70.7%',
#   '2006'],
#  'Kung Fu Panda 2': ['/title/tt1302011/?ref_=bo_cso_table_135',
#   '135',
#   'Kung Fu Panda 2',
#   '$665,692,281',
#   '$165,249,063',
#   '24.8%',
#   '$500,443,218',
#   '75.2%',
#   '2011'],
#  'The Hunger Games: Mockingjay - Part 2': ['/title/tt1951266/?ref_=bo_cso_table_136',
#   '136',
#   'The Hunger Games: Mockingjay - Part 2',
#   '$658,344,137',
#   '$281,723,902',
#   '42.8%',
#   '$376,620,235',
#   '57.2%',
#   '2015'],
#  'Justice League': ['/title/tt0974015/?ref_=bo_cso_table_137',
#   '137',
#   'Justice League',
#   '$657,926,987',
#   '$229,024,295',
#   '34.8%',
#   '$428,902,692',
#   '65.2%',
#   '2017'],
#  'Big Hero 6': ['/title/tt2245084/?ref_=bo_cso_table_138',
#   '138',
#   'Big Hero 6',
#   '$657,869,501',
#   '$222,527,828',
#   '33.8%',
#   '$435,341,673',
#   '66.2%',
#   '2014'],
#  'Fantastic Beasts: The Crimes of Grindelwald': ['/title/tt4123430/?ref_=bo_cso_table_139',
#   '139',
#   'Fantastic Beasts: The Crimes of Grindelwald',
#   '$654,855,901',
#   '$159,555,901',
#   '24.4%',
#   '$495,300,000',
#   '75.6%',
#   '2018'],
#  'Pirates of the Caribbean: The Curse of the Black Pearl': ['/title/tt0325980/?ref_=bo_cso_table_140',
#   '140',
#   'Pirates of the Caribbean: The Curse of the Black Pearl',
#   '$654,264,015',
#   '$305,413,918',
#   '46.7%',
#   '$348,850,097',
#   '53.3%',
#   '2003'],
#  'Star Wars: Episode II - Attack of the Clones': ['/title/tt0121765/?ref_=bo_cso_table_141',
#   '141',
#   'Star Wars: Episode II - Attack of the Clones',
#   '$653,779,970',
#   '$310,676,740',
#   '47.5%',
#   '$343,103,230',
#   '52.5%',
#   '2002'],
#  'Thor: The Dark World': ['/title/tt1981115/?ref_=bo_cso_table_142',
#   '142',
#   'Thor: The Dark World',
#   '$644,783,140',
#   '$206,362,140',
#   '32%',
#   '$438,421,000',
#   '68%',
#   '2013'],
#  'Moana': ['/title/tt3521164/?ref_=bo_cso_table_143',
#   '143',
#   'Moana',
#   '$643,350,998',
#   '$248,757,044',
#   '38.7%',
#   '$394,593,954',
#   '61.3%',
#   '2016'],
#  'Sing': ['/title/tt3470600/?ref_=bo_cso_table_144',
#   '144',
#   'Sing',
#   '$634,181,922',
#   '$270,422,425',
#   '42.6%',
#   '$363,759,497',
#   '57.4%',
#   '2016'],
#  'Kung Fu Panda': ['/title/tt0441773/?ref_=bo_cso_table_145',
#   '145',
#   'Kung Fu Panda',
#   '$631,746,197',
#   '$215,434,591',
#   '34.1%',
#   '$416,311,606',
#   '65.9%',
#   '2008'],
#  'The Incredibles': ['/title/tt0317705/?ref_=bo_cso_table_146',
#   '146',
#   'The Incredibles',
#   '$631,606,713',
#   '$261,441,092',
#   '41.4%',
#   '$370,165,621',
#   '58.6%',
#   '2004'],
#  'The Martian': ['/title/tt3659388/?ref_=bo_cso_table_147',
#   '147',
#   'The Martian',
#   '$630,162,235',
#   '$228,433,663',
#   '36.2%',
#   '$401,728,572',
#   '63.8%',
#   '2015'],
#  'Hancock': ['/title/tt0448157/?ref_=bo_cso_table_148',
#   '148',
#   'Hancock',
#   '$629,443,428',
#   '$227,946,274',
#   '36.2%',
#   '$401,497,154',
#   '63.8%',
#   '2008'],
#  'Fast Five': ['/title/tt1596343/?ref_=bo_cso_table_149',
#   '149',
#   'Fast Five',
#   '$626,137,675',
#   '$209,837,675',
#   '33.5%',
#   '$416,300,000',
#   '66.5%',
#   '2011'],
#  'Men in Black 3': ['/title/tt1409024/?ref_=bo_cso_table_150',
#   '150',
#   'Men in Black 3',
#   '$624,026,776',
#   '$179,020,854',
#   '28.7%',
#   '$445,005,922',
#   '71.3%',
#   '2012'],
#  'Iron Man 2': ['/title/tt1228705/?ref_=bo_cso_table_151',
#   '151',
#   'Iron Man 2',
#   '$623,933,331',
#   '$312,433,331',
#   '50.1%',
#   '$311,500,000',
#   '49.9%',
#   '2010'],
#  'Ratatouille': ['/title/tt0382932/?ref_=bo_cso_table_152',
#   '152',
#   'Ratatouille',
#   '$623,726,085',
#   '$206,445,654',
#   '33.1%',
#   '$417,280,431',
#   '66.9%',
#   '2007'],
#  'Ant-Man and the Wasp': ['/title/tt5095030/?ref_=bo_cso_table_153',
#   '153',
#   'Ant-Man and the Wasp',
#   '$622,674,139',
#   '$216,648,740',
#   '34.8%',
#   '$406,025,399',
#   '65.2%',
#   '2018'],
#  'How to Train Your Dragon 2': ['/title/tt1646971/?ref_=bo_cso_table_154',
#   '154',
#   'How to Train Your Dragon 2',
#   '$621,537,519',
#   '$177,002,924',
#   '28.5%',
#   '$444,534,595',
#   '71.5%',
#   '2014'],
#  'Logan': ['/title/tt3315342/?ref_=bo_cso_table_155',
#   '155',
#   'Logan',
#   '$619,021,436',
#   '$226,277,068',
#   '36.6%',
#   '$392,744,368',
#   '63.4%',
#   '2017'],
#  'The Lost World: Jurassic Park': ['/title/tt0119567/?ref_=bo_cso_table_156',
#   '156',
#   'The Lost World: Jurassic Park',
#   '$618,638,999',
#   '$229,086,679',
#   '37%',
#   '$389,552,320',
#   '63%',
#   '1997'],
#  'Casino Royale': ['/title/tt0381061/?ref_=bo_cso_table_157',
#   '157',
#   'Casino Royale',
#   '$616,501,619',
#   '$167,445,960',
#   '27.2%',
#   '$449,055,659',
#   '72.8%',
#   '2006'],
#  'The Passion of the Christ': ['/title/tt0335345/?ref_=bo_cso_table_158',
#   '158',
#   'The Passion of the Christ',
#   '$612,054,428',
#   '$370,782,930',
#   '60.6%',
#   '$241,271,498',
#   '39.4%',
#   '2004'],
#  'Mamma Mia!': ['/title/tt0795421/?ref_=bo_cso_table_159',
#   '159',
#   'Mamma Mia!',
#   '$609,914,735',
#   '$144,169,664',
#   '23.6%',
#   '$465,745,071',
#   '76.4%',
#   '2008'],
#  'Life of Pi': ['/title/tt0454876/?ref_=bo_cso_table_160',
#   '160',
#   'Life of Pi',
#   '$609,016,565',
#   '$124,987,023',
#   '20.5%',
#   '$484,029,542',
#   '79.5%',
#   '2012'],
#  'Transformers: The Last Knight': ['/title/tt3371366/?ref_=bo_cso_table_161',
#   '161',
#   'Transformers: The Last Knight',
#   '$605,425,157',
#   '$130,168,683',
#   '21.5%',
#   '$475,256,474',
#   '78.5%',
#   '2017'],
#  'Madagascar: Escape 2 Africa': ['/title/tt0479952/?ref_=bo_cso_table_162',
#   '162',
#   'Madagascar: Escape 2 Africa',
#   '$603,900,354',
#   '$180,010,950',
#   '29.8%',
#   '$423,889,404',
#   '70.2%',
#   '2008'],
#  'War of the Worlds': ['/title/tt0407304/?ref_=bo_cso_table_163',
#   '163',
#   'War of the Worlds',
#   '$603,873,119',
#   '$234,280,354',
#   '38.8%',
#   '$369,592,765',
#   '61.2%',
#   '2005'],
#  'Tangled': ['/title/tt0398286/?ref_=bo_cso_table_164',
#   '164',
#   'Tangled',
#   '$592,461,959',
#   '$200,821,936',
#   '33.9%',
#   '$391,640,023',
#   '66.1%',
#   '2010'],
#  'Quantum of Solace': ['/title/tt0830515/?ref_=bo_cso_table_165',
#   '165',
#   'Quantum of Solace',
#   '$589,580,482',
#   '$168,368,427',
#   '28.6%',
#   '$421,212,055',
#   '71.4%',
#   '2008'],
#  'Men in Black': ['/title/tt0119654/?ref_=bo_cso_table_166',
#   '166',
#   'Men in Black',
#   '$589,390,539',
#   '$250,690,539',
#   '42.5%',
#   '$338,700,000',
#   '57.5%',
#   '1997'],
#  'The Croods': ['/title/tt0481499/?ref_=bo_cso_table_167',
#   '167',
#   'The Croods',
#   '$587,205,319',
#   '$187,168,425',
#   '31.9%',
#   '$400,036,894',
#   '68.1%',
#   '2013'],
#  'The Hangover Part II': ['/title/tt1411697/?ref_=bo_cso_table_168',
#   '168',
#   'The Hangover Part II',
#   '$586,764,305',
#   '$254,464,305',
#   '43.4%',
#   '$332,300,000',
#   '56.6%',
#   '2011'],
#  'Iron Man': ['/title/tt0371746/?ref_=bo_cso_table_169',
#   '169',
#   'Iron Man',
#   '$585,796,247',
#   '$319,034,126',
#   '54.5%',
#   '$266,762,121',
#   '45.5%',
#   '2008'],
#  'I Am Legend': ['/title/tt0480249/?ref_=bo_cso_table_170',
#   '170',
#   'I Am Legend',
#   '$585,410,052',
#   '$256,393,010',
#   '43.8%',
#   '$329,017,042',
#   '56.2%',
#   '2007'],
#  'Ready Player One': ['/title/tt1677720/?ref_=bo_cso_table_171',
#   '171',
#   'Ready Player One',
#   '$582,893,671',
#   '$137,690,172',
#   '23.6%',
#   '$445,203,499',
#   '76.4%',
#   '2018'],
#  'Monsters, Inc.': ['/title/tt0198781/?ref_=bo_cso_table_172',
#   '172',
#   'Monsters, Inc.',
#   '$579,707,070',
#   '$290,642,256',
#   '50.1%',
#   '$289,064,814',
#   '49.9%',
#   '2001'],
#  'Operation Red Sea': ['/title/tt6878882/?ref_=bo_cso_table_173',
#   '173',
#   'Operation Red Sea',
#   '$579,330,426',
#   '$1,543,547',
#   '0.3%',
#   '$577,786,879',
#   '99.7%',
#   '2018'],
#  'Night at the Museum': ['/title/tt0477347/?ref_=bo_cso_table_174',
#   '174',
#   'Night at the Museum',
#   '$574,481,229',
#   '$250,863,268',
#   '43.7%',
#   '$323,617,961',
#   '56.3%',
#   '2006'],
#  'Fifty Shades of Grey': ['/title/tt2322441/?ref_=bo_cso_table_175',
#   '175',
#   'Fifty Shades of Grey',
#   '$569,651,467',
#   '$166,167,230',
#   '29.2%',
#   '$403,484,237',
#   '70.8%',
#   '2015'],
#  'Kong: Skull Island': ['/title/tt3731562/?ref_=bo_cso_table_176',
#   '176',
#   'Kong: Skull Island',
#   '$566,652,812',
#   '$168,052,812',
#   '29.7%',
#   '$398,600,000',
#   '70.3%',
#   '2017'],
#  'The Smurfs': ['/title/tt0472181/?ref_=bo_cso_table_177',
#   '177',
#   'The Smurfs',
#   '$563,749,323',
#   '$142,614,158',
#   '25.3%',
#   '$421,135,165',
#   '74.7%',
#   '2011'],
#  'King Kong': ['/title/tt0360717/?ref_=bo_cso_table_178',
#   '178',
#   'King Kong',
#   '$562,363,449',
#   '$218,080,025',
#   '38.8%',
#   '$344,283,424',
#   '61.2%',
#   '2005'],
#  'Cars 2': ['/title/tt1216475/?ref_=bo_cso_table_179',
#   '179',
#   'Cars 2',
#   '$559,852,396',
#   '$191,452,396',
#   '34.2%',
#   '$368,400,000',
#   '65.8%',
#   '2011'],
#  'Puss in Boots': ['/title/tt0448694/?ref_=bo_cso_table_180',
#   '180',
#   'Puss in Boots',
#   '$554,987,477',
#   '$149,260,504',
#   '26.9%',
#   '$405,726,973',
#   '73.1%',
#   '2011'],
#  'The Mermaid': ['/title/tt4701660/?ref_=bo_cso_table_181',
#   '181',
#   'The Mermaid',
#   '$553,810,228',
#   '$3,232,685',
#   '0.6%',
#   '$550,577,543',
#   '99.4%',
#   '2016'],
#  'Armageddon': ['/title/tt0120591/?ref_=bo_cso_table_182',
#   '182',
#   'Armageddon',
#   '$553,709,788',
#   '$201,578,182',
#   '36.4%',
#   '$352,131,606',
#   '63.6%',
#   '1998'],
#  'The Day After Tomorrow': ['/title/tt0319262/?ref_=bo_cso_table_183',
#   '183',
#   'The Day After Tomorrow',
#   '$552,639,571',
#   '$186,740,799',
#   '33.8%',
#   '$365,898,772',
#   '66.2%',
#   '2004'],
#  'Ted': ['/title/tt1637725/?ref_=bo_cso_table_184',
#   '184',
#   'Ted',
#   '$549,368,315',
#   '$218,815,487',
#   '39.8%',
#   '$330,552,828',
#   '60.2%',
#   '2012'],
#  'American Sniper': ['/title/tt2179136/?ref_=bo_cso_table_185',
#   '185',
#   'American Sniper',
#   '$547,426,372',
#   '$350,126,372',
#   '64%',
#   '$197,300,000',
#   '36%',
#   '2014'],
#  'Mission: Impossible II': ['/title/tt0120755/?ref_=bo_cso_table_186',
#   '186',
#   'Mission: Impossible II',
#   '$546,388,108',
#   '$215,409,889',
#   '39.4%',
#   '$330,978,219',
#   '60.6%',
#   '2000'],
#  'Detective Chinatown 2': ['/title/tt7752454/?ref_=bo_cso_table_187',
#   '187',
#   'Detective Chinatown 2',
#   '$544,185,156',
#   '$1,983,984',
#   '0.4%',
#   '$542,201,172',
#   '99.6%',
#   '2018'],
#  'X-Men: Apocalypse': ['/title/tt3385516/?ref_=bo_cso_table_188',
#   '188',
#   'X-Men: Apocalypse',
#   '$543,934,105',
#   '$155,442,489',
#   '28.6%',
#   '$388,491,616',
#   '71.4%',
#   '2016'],
#  'Sherlock Holmes: A Game of Shadows': ['/title/tt1515091/?ref_=bo_cso_table_189',
#   '189',
#   'Sherlock Holmes: A Game of Shadows',
#   '$543,848,418',
#   '$186,848,418',
#   '34.4%',
#   '$357,000,000',
#   '65.6%',
#   '2011'],
#  'Despicable Me': ['/title/tt1323594/?ref_=bo_cso_table_190',
#   '190',
#   'Despicable Me',
#   '$543,113,985',
#   '$251,513,985',
#   '46.3%',
#   '$291,600,000',
#   '53.7%',
#   '2010'],
#  'Cinderella': ['/title/tt1661199/?ref_=bo_cso_table_191',
#   '191',
#   'Cinderella',
#   '$542,358,331',
#   '$201,151,353',
#   '37.1%',
#   '$341,206,978',
#   '62.9%',
#   '2015'],
#  'Madagascar': ['/title/tt0351283/?ref_=bo_cso_table_192',
#   '192',
#   'Madagascar',
#   '$542,063,846',
#   '$193,595,521',
#   '35.7%',
#   '$348,468,325',
#   '64.3%',
#   '2005'],
#  'World War Z': ['/title/tt0816711/?ref_=bo_cso_table_193',
#   '193',
#   'World War Z',
#   '$540,007,876',
#   '$202,359,711',
#   '37.5%',
#   '$337,648,165',
#   '62.5%',
#   '2013'],
#  'Brave': ['/title/tt1217209/?ref_=bo_cso_table_194',
#   '194',
#   'Brave',
#   '$538,983,207',
#   '$237,283,207',
#   '44%',
#   '$301,700,000',
#   '56%',
#   '2012'],
#  'Star Wars: Episode V - The Empire Strikes Back': ['/title/tt0080684/?ref_=bo_cso_table_195',
#   '195',
#   'Star Wars: Episode V - The Empire Strikes Back',
#   '$538,375,067',
#   '$292,753,960',
#   '54.4%',
#   '$245,621,107',
#   '45.6%',
#   '1980'],
#  'The Simpsons Movie': ['/title/tt0462538/?ref_=bo_cso_table_196',
#   '196',
#   'The Simpsons Movie',
#   '$536,414,293',
#   '$183,135,014',
#   '34.1%',
#   '$353,279,279',
#   '65.9%',
#   '2007'],
#  'The Revenant': ['/title/tt1663202/?ref_=bo_cso_table_197',
#   '197',
#   'The Revenant',
#   '$532,950,503',
#   '$183,637,894',
#   '34.5%',
#   '$349,312,609',
#   '65.5%',
#   '2015'],
#  'The Meg': ['/title/tt4779682/?ref_=bo_cso_table_198',
#   '198',
#   'The Meg',
#   '$530,259,473',
#   '$145,443,742',
#   '27.4%',
#   '$384,815,731',
#   '72.6%',
#   '2018'],
#  'Ralph Breaks the Internet': ['/title/tt5848272/?ref_=bo_cso_table_199',
#   '199',
#   'Ralph Breaks the Internet',
#   '$529,323,962',
#   '$201,091,711',
#   '38%',
#   '$328,232,251',
#   '62%',
#   '2018']}

# %%
lifetime_movies = pd.DataFrame(movies).T
lifetime_movies.columns = ['link_stub', 'rank', 'title', 'WW_gross', 'domestic_gross','dom_%', 'foreign_gross','for_%','release_year']
lifetime_movies.head()
# Out:
#                                                                         link_stub  \
# Avengers: Endgame                           /title/tt4154796/?ref_=bo_cso_table_1
# Avatar                                      /title/tt0499549/?ref_=bo_cso_table_2
# Titanic                                     /title/tt0120338/?ref_=bo_cso_table_3
# Star Wars: Episode VII - The Force Awakens  /title/tt2488496/?ref_=bo_cso_table_4
# Avengers: Infinity War                      /title/tt4154756/?ref_=bo_cso_table_5
#
#                                            rank  \
# Avengers: Endgame                             1
# Avatar                                        2
# Titanic                                       3
# Star Wars: Episode VII - The Force Awakens    4
# Avengers: Infinity War                        5
#
#                                                                                  title  \
# Avengers: Endgame                                                    Avengers: Endgame
# Avatar                                                                          Avatar
# Titanic                                                                        Titanic
# Star Wars: Episode VII - The Force Awakens  Star Wars: Episode VII - The Force Awakens
# Avengers: Infinity War                                          Avengers: Infinity War
#
#                                                   WW_gross domestic_gross  \
# Avengers: Endgame                           $2,797,800,564   $858,373,000
# Avatar                                      $2,790,439,092   $760,507,625
# Titanic                                     $2,471,751,922   $659,363,944
# Star Wars: Episode VII - The Force Awakens  $2,068,454,133   $936,662,225
# Avengers: Infinity War                      $2,048,359,754   $678,815,482
#
#                                             dom_%   foreign_gross  for_%  \
# Avengers: Endgame                           30.7%  $1,939,427,564  69.3%
# Avatar                                      27.2%  $2,029,931,467  72.8%
# Titanic                                     26.7%  $1,812,387,978  73.3%
# Star Wars: Episode VII - The Force Awakens  45.3%  $1,131,791,908  54.7%
# Avengers: Infinity War                      33.1%  $1,369,544,272  66.9%
#
#                                            release_year
# Avengers: Endgame                                  2019
# Avatar                                             2009
# Titanic                                            1997
# Star Wars: Episode VII - The Force Awakens         2015
# Avengers: Infinity War                             2018

# %%
def get_movie_dict(link):
    """
    From BoxOfficeMojo link stub, request movie html, parse with BeautifulSoup, and
    collect 
        - title 
        - domestic gross
        - runtime 
        - MPAA rating
        - full release date
    Return information as a dictionary
    
    """
    
    base_url = 'https://www.boxofficemojo.com'
    
    #Create full url to scrape
    url = base_url + link
    
    #Request HTML and parse
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page,"lxml")
    
    headers = ['title', 'domestic_gross', 'domestic_opening_gross', 'international_gross', 'worldwide_gross',
               'runtime_minutes', 'rating', 'release_month', 'genres']
    
    #Get title
    title_string = soup.find('title').text
    title = title_string[:-18]

    #Get domestic gross
    raw_dom_gross = soup.find(class_='mojo-performance-summary-table').find_all('span',class_='money')[0].text
    domestic_gross = money_to_int(raw_dom_gross)
    
    #dom_gross = money_to_int(dom_gross)
    
    #Get international_gross
    raw_intl_gross = soup.find(class_='mojo-performance-summary-table').find_all('span',class_='money')[1].text
    international_gross = money_to_int(raw_intl_gross)
    
    #Get worldwide gross
    raw_world_gross = soup.find(class_='mojo-performance-summary-table').find_all('span',class_='money')[2].text
    worldwide_gross = money_to_int(raw_world_gross)
    
    #Get domestic opening gross
    raw_opening_gross = dom_opening_gross
    domestic_opening_gross = money_to_int(raw_opening_gross)
    
    #Get distributor
    distributor = get_movie_value(soup, 'Distributor')[:18]
    
    #Get runtime
    raw_runtime = get_movie_value(soup, 'Running')
    runtime_minutes = runtime_to_minutes(raw_runtime)
    
    #Get rating
    rating = get_movie_value(soup, 'MPAA')
    
    #Get genres
    genres = get_movie_value(soup, 'Genres').split()
    
    #Get release month
    rel_date = get_movie_value(soup, 'Release Date')
    release_month = rel_date.split()[0]
    
    
    #Create movie dictionary and return
    movie_dict = dict(zip(headers, [title,
                                    domestic_gross,
                                    domestic_opening_gross,
                                    international_gross,
                                    worldwide_gross,
                                    runtime_minutes,
                                    rating,
                                    release_month,
                                    genres]))

    return movie_dict

# %%
lifetime_movie_data = []
for link in lifetime_movies.link_stub:
    lifetime_movie_data.append(get_movie_dict(link))

# %%
lifetime_movie_data
# Out:
# [{'title': 'Avengers: Endgame',
#   'domestic_gross': 858373000,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 1939427564,
#   'worldwide_gross': 2797800564,
#   'runtime_minutes': 181,
#   'rating': 'PG-13',
#   'release_month': 'April',
#   'genres': ['Action', 'Adventure', 'Drama', 'Sci-Fi']},
#  {'title': 'Avatar',
#   'domestic_gross': 760507625,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 2029931467,
#   'worldwide_gross': 2790439092,
#   'runtime_minutes': 162,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'title': 'Titanic',
#   'domestic_gross': 659363944,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 1812387978,
#   'worldwide_gross': 2471751922,
#   'runtime_minutes': 194,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Drama', 'Romance']},
#  {'title': 'Star Wars: Episode VII - The Force Awakens',
#   'domestic_gross': 936662225,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 1131791908,
#   'worldwide_gross': 2068454133,
#   'runtime_minutes': 138,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Avengers: Infinity War',
#   'domestic_gross': 678815482,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 1369544272,
#   'worldwide_gross': 2048359754,
#   'runtime_minutes': 149,
#   'rating': 'PG-13',
#   'release_month': 'April',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Jurassic World',
#   'domestic_gross': 652295625,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 1018130819,
#   'worldwide_gross': 1670426444,
#   'runtime_minutes': 124,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'The Lion King',
#   'domestic_gross': 422783777,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 660936730,
#   'worldwide_gross': 1083720507,
#   'runtime_minutes': 88,
#   'rating': 'G',
#   'release_month': 'June',
#   'genres': ['Adventure', 'Animation', 'Drama', 'Family', 'Musical']},
#  {'title': 'The Avengers',
#   'domestic_gross': 623357910,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 895457605,
#   'worldwide_gross': 1518815515,
#   'runtime_minutes': 143,
#   'rating': 'PG-13',
#   'release_month': 'April',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Furious 7',
#   'domestic_gross': 353007020,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 1162246868,
#   'worldwide_gross': 1515253888,
#   'runtime_minutes': 137,
#   'rating': 'PG-13',
#   'release_month': 'April',
#   'genres': ['Action', 'Adventure', 'Thriller']},
#  {'title': 'Frozen II',
#   'domestic_gross': 477373578,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 972653355,
#   'worldwide_gross': 1450026933,
#   'runtime_minutes': 103,
#   'rating': 'PG',
#   'release_month': 'November',
#   'genres': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Musical']},
#  {'title': 'Avengers: Age of Ultron',
#   'domestic_gross': 459005868,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 943803672,
#   'worldwide_gross': 1402809540,
#   'runtime_minutes': 141,
#   'rating': 'PG-13',
#   'release_month': 'April',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Black Panther',
#   'domestic_gross': 700426566,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 647171407,
#   'worldwide_gross': 1347597973,
#   'runtime_minutes': 134,
#   'rating': 'PG-13',
#   'release_month': 'February',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'domestic_gross': 381409310,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 960814625,
#   'worldwide_gross': 1342223936,
#   'runtime_minutes': 130,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Adventure', 'Drama', 'Fantasy', 'Mystery']},
#  {'title': 'Star Wars: Episode VIII - The Last Jedi',
#   'domestic_gross': 620181382,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 712516117,
#   'worldwide_gross': 1332697499,
#   'runtime_minutes': 152,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'title': 'Jurassic World: Fallen Kingdom',
#   'domestic_gross': 417719760,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 892744920,
#   'worldwide_gross': 1310464680,
#   'runtime_minutes': 128,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Frozen',
#   'domestic_gross': 400953009,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 880066266,
#   'worldwide_gross': 1281019275,
#   'runtime_minutes': 102,
#   'rating': 'PG',
#   'release_month': 'November',
#   'genres': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Musical']},
#  {'title': 'Beauty and the Beast',
#   'domestic_gross': 504481165,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 759583666,
#   'worldwide_gross': 1264064831,
#   'runtime_minutes': 129,
#   'rating': 'PG',
#   'release_month': 'March',
#   'genres': ['Family', 'Fantasy', 'Musical', 'Romance']},
#  {'title': 'Incredibles 2',
#   'domestic_gross': 608581744,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 634507470,
#   'worldwide_gross': 1243089214,
#   'runtime_minutes': 118,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Action',
#    'Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Sci-Fi']},
#  {'title': 'The Fate of the Furious',
#   'domestic_gross': 226008385,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 1009996733,
#   'worldwide_gross': 1236005118,
#   'runtime_minutes': 136,
#   'rating': 'PG-13',
#   'release_month': 'April',
#   'genres': ['Action', 'Adventure', 'Crime', 'Thriller']},
#  {'title': 'Iron Man 3',
#   'domestic_gross': 409013994,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 805797258,
#   'worldwide_gross': 1214811252,
#   'runtime_minutes': 130,
#   'rating': 'PG-13',
#   'release_month': 'April',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Minions',
#   'domestic_gross': 336045770,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 823398892,
#   'worldwide_gross': 1159444662,
#   'runtime_minutes': 91,
#   'rating': 'PG',
#   'release_month': 'April',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Sci-Fi']},
#  {'title': 'Captain America: Civil War',
#   'domestic_gross': 408084349,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 745477300,
#   'worldwide_gross': 1153561649,
#   'runtime_minutes': 147,
#   'rating': 'PG-13',
#   'release_month': 'April',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Aquaman',
#   'domestic_gross': 335061807,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 813424079,
#   'worldwide_gross': 1148485886,
#   'runtime_minutes': 143,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'title': 'The Lord of the Rings: The Return of the King',
#   'domestic_gross': 377845905,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 764611082,
#   'worldwide_gross': 1142456987,
#   'runtime_minutes': 201,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Drama', 'Fantasy']},
#  {'title': 'Spider-Man: Far from Home',
#   'domestic_gross': 390532085,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 741395911,
#   'worldwide_gross': 1131927996,
#   'runtime_minutes': 129,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Captain Marvel',
#   'domestic_gross': 426829839,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 701633133,
#   'worldwide_gross': 1128462972,
#   'runtime_minutes': 123,
#   'rating': 'PG-13',
#   'release_month': 'March',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Transformers: Dark of the Moon',
#   'domestic_gross': 352390543,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 771403536,
#   'worldwide_gross': 1123794079,
#   'runtime_minutes': 154,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Skyfall',
#   'domestic_gross': 304360277,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 804200736,
#   'worldwide_gross': 1108561013,
#   'runtime_minutes': 143,
#   'rating': 'PG-13',
#   'release_month': 'October',
#   'genres': ['Action', 'Adventure', 'Thriller']},
#  {'title': 'Fast & Furious Presents: Hobbs & Shaw',
#   'domestic_gross': 173956935,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 585100000,
#   'worldwide_gross': 1104826325,
#   'runtime_minutes': 137,
#   'rating': None,
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Thriller']},
#  {'title': 'Transformers: Age of Extinction',
#   'domestic_gross': 245439076,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 858614996,
#   'worldwide_gross': 1104054072,
#   'runtime_minutes': 165,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'The Dark Knight Rises',
#   'domestic_gross': 448139099,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 633002336,
#   'worldwide_gross': 1081141435,
#   'runtime_minutes': 164,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure']},
#  {'title': 'Joker',
#   'domestic_gross': 335451311,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 738800000,
#   'worldwide_gross': 1074251311,
#   'runtime_minutes': 122,
#   'rating': 'R',
#   'release_month': 'October',
#   'genres': ['Crime', 'Drama', 'Thriller']},
#  {'title': 'Star Wars: Episode IX - The Rise of Skywalker',
#   'domestic_gross': 515202542,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 558941706,
#   'worldwide_gross': 1074144248,
#   'runtime_minutes': 141,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'title': 'Toy Story 4',
#   'domestic_gross': 434038008,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 639356585,
#   'worldwide_gross': 1073394593,
#   'runtime_minutes': 100,
#   'rating': 'G',
#   'release_month': 'June',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'title': 'Toy Story 3',
#   'domestic_gross': 415004880,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 651965015,
#   'worldwide_gross': 1066969895,
#   'runtime_minutes': 103,
#   'rating': None,
#   'release_month': 'June',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'title': "Pirates of the Caribbean: Dead Man's Chest",
#   'domestic_gross': 423315812,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 642863935,
#   'worldwide_gross': 1066179747,
#   'runtime_minutes': 151,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Fantasy']},
#  {'title': 'Rogue One: A Star Wars Story',
#   'domestic_gross': 532177324,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 523880396,
#   'worldwide_gross': 1056057720,
#   'runtime_minutes': 133,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Aladdin',
#   'domestic_gross': 355559216,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 695134737,
#   'worldwide_gross': 1050693953,
#   'runtime_minutes': 128,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Adventure', 'Family', 'Fantasy', 'Musical', 'Romance']},
#  {'title': 'Pirates of the Caribbean: On Stranger Tides',
#   'domestic_gross': 241071802,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 804642000,
#   'worldwide_gross': 1045713802,
#   'runtime_minutes': 137,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Fantasy']},
#  {'title': 'Despicable Me 3',
#   'domestic_gross': 264624300,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 770175831,
#   'worldwide_gross': 1034800131,
#   'runtime_minutes': 89,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Sci-Fi']},
#  {'title': 'Jurassic Park',
#   'domestic_gross': 404214720,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 629712302,
#   'worldwide_gross': 1033927022,
#   'runtime_minutes': 127,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller']},
#  {'title': 'Finding Dory',
#   'domestic_gross': 486295561,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 542275328,
#   'worldwide_gross': 1028570889,
#   'runtime_minutes': 97,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family']},
#  {'title': 'Star Wars: Episode I - The Phantom Menace',
#   'domestic_gross': 474544677,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 552538030,
#   'worldwide_gross': 1027082707,
#   'runtime_minutes': 136,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'title': 'Alice in Wonderland',
#   'domestic_gross': 334191110,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 691277106,
#   'worldwide_gross': 1025468216,
#   'runtime_minutes': 108,
#   'rating': 'PG',
#   'release_month': 'March',
#   'genres': ['Adventure', 'Family', 'Fantasy']},
#  {'title': 'Zootopia',
#   'domestic_gross': 341268248,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 682524310,
#   'worldwide_gross': 1023792558,
#   'runtime_minutes': 108,
#   'rating': 'PG',
#   'release_month': 'February',
#   'genres': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Crime',
#    'Family',
#    'Mystery']},
#  {'title': 'The Hobbit: An Unexpected Journey',
#   'domestic_gross': 303003568,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 714000000,
#   'worldwide_gross': 1017003568,
#   'runtime_minutes': 169,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Adventure', 'Fantasy']},
#  {'title': "Harry Potter and the Sorcerer's Stone",
#   'domestic_gross': 318087620,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 688830041,
#   'worldwide_gross': 1006917662,
#   'runtime_minutes': 152,
#   'rating': 'PG',
#   'release_month': 'November',
#   'genres': ['Adventure', 'Family', 'Fantasy']},
#  {'title': 'The Dark Knight',
#   'domestic_gross': 534858444,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 471115201,
#   'worldwide_gross': 1005973645,
#   'runtime_minutes': 152,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Crime', 'Drama', 'Thriller']},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 1',
#   'domestic_gross': 296347721,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 680651521,
#   'worldwide_gross': 976999243,
#   'runtime_minutes': 146,
#   'rating': 'PG-13',
#   'release_month': 'November',
#   'genres': ['Adventure', 'Family', 'Fantasy', 'Mystery']},
#  {'title': 'Despicable Me 2',
#   'domestic_gross': 368065385,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 602700620,
#   'worldwide_gross': 970766005,
#   'runtime_minutes': 98,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Crime',
#    'Family',
#    'Fantasy',
#    'Sci-Fi']},
#  {'title': 'The Jungle Book',
#   'domestic_gross': 364001123,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 602553806,
#   'worldwide_gross': 966554929,
#   'runtime_minutes': 106,
#   'rating': 'PG',
#   'release_month': 'April',
#   'genres': ['Adventure', 'Drama', 'Family', 'Fantasy']},
#  {'title': 'Jumanji: Welcome to the Jungle',
#   'domestic_gross': 404540171,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 557563180,
#   'worldwide_gross': 962103351,
#   'runtime_minutes': 119,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Comedy', 'Fantasy']},
#  {'title': "Pirates of the Caribbean: At World's End",
#   'domestic_gross': 309420425,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 651576067,
#   'worldwide_gross': 960996492,
#   'runtime_minutes': 169,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Fantasy']},
#  {'title': 'The Hobbit: The Desolation of Smaug',
#   'domestic_gross': 258366855,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 700000000,
#   'worldwide_gross': 958366855,
#   'runtime_minutes': 161,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Adventure', 'Fantasy']},
#  {'title': 'The Hobbit: The Battle of the Five Armies',
#   'domestic_gross': 255119788,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 700900000,
#   'worldwide_gross': 956019788,
#   'runtime_minutes': 144,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Adventure', 'Fantasy']},
#  {'title': 'The Lord of the Rings: The Two Towers',
#   'domestic_gross': 342551365,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 600844768,
#   'worldwide_gross': 943396133,
#   'runtime_minutes': 179,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Drama', 'Fantasy']},
#  {'title': 'Harry Potter and the Order of the Phoenix',
#   'domestic_gross': 292353413,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 649818982,
#   'worldwide_gross': 942172396,
#   'runtime_minutes': 138,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Family', 'Fantasy', 'Mystery']},
#  {'title': 'Finding Nemo',
#   'domestic_gross': 380843261,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 559506933,
#   'worldwide_gross': 940350194,
#   'runtime_minutes': 100,
#   'rating': None,
#   'release_month': 'May',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family']},
#  {'title': 'Harry Potter and the Half-Blood Prince',
#   'domestic_gross': 302305431,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 632148664,
#   'worldwide_gross': 934454096,
#   'runtime_minutes': 153,
#   'rating': 'PG',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Family', 'Fantasy', 'Mystery']},
#  {'title': 'Shrek 2',
#   'domestic_gross': 441226247,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 487534523,
#   'worldwide_gross': 928760770,
#   'runtime_minutes': 93,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Romance']},
#  {'title': 'Bohemian Rhapsody',
#   'domestic_gross': 216668042,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 688566435,
#   'worldwide_gross': 905234477,
#   'runtime_minutes': 134,
#   'rating': 'PG-13',
#   'release_month': 'October',
#   'genres': ['Biography', 'Drama', 'Music']},
#  {'title': 'Harry Potter and the Goblet of Fire',
#   'domestic_gross': 290417905,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 606002856,
#   'worldwide_gross': 896420762,
#   'runtime_minutes': 157,
#   'rating': 'PG-13',
#   'release_month': 'November',
#   'genres': ['Adventure', 'Family', 'Fantasy', 'Mystery']},
#  {'title': 'Spider-Man 3',
#   'domestic_gross': 336530303,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 558453070,
#   'worldwide_gross': 894983373,
#   'runtime_minutes': 139,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'domestic_gross': 315544750,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 572614342,
#   'worldwide_gross': 888159092,
#   'runtime_minutes': 178,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Drama', 'Fantasy']},
#  {'title': 'Ice Age: Dawn of the Dinosaurs',
#   'domestic_gross': 196573705,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 690113112,
#   'worldwide_gross': 886686817,
#   'runtime_minutes': 94,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'title': 'Spectre',
#   'domestic_gross': 200074609,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 680600000,
#   'worldwide_gross': 880674609,
#   'runtime_minutes': 148,
#   'rating': 'PG-13',
#   'release_month': 'October',
#   'genres': ['Action', 'Adventure', 'Thriller']},
#  {'title': 'Spider-Man: Homecoming',
#   'domestic_gross': 334201140,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 545965784,
#   'worldwide_gross': 880166924,
#   'runtime_minutes': 133,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Harry Potter and the Chamber of Secrets',
#   'domestic_gross': 262450136,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 617152229,
#   'worldwide_gross': 879602366,
#   'runtime_minutes': 161,
#   'rating': 'PG',
#   'release_month': 'November',
#   'genres': ['Adventure', 'Family', 'Fantasy', 'Mystery']},
#  {'title': 'Ice Age: Continental Drift',
#   'domestic_gross': 161321843,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 715922939,
#   'worldwide_gross': 877244782,
#   'runtime_minutes': 88,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'title': 'The Secret Life of Pets',
#   'domestic_gross': 368384330,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 507074301,
#   'worldwide_gross': 875458631,
#   'runtime_minutes': 87,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family']},
#  {'title': 'Batman v Superman: Dawn of Justice',
#   'domestic_gross': 330360194,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 543277334,
#   'worldwide_gross': 873637528,
#   'runtime_minutes': 152,
#   'rating': 'PG-13',
#   'release_month': 'March',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Wolf Warrior 2',
#   'domestic_gross': 2721100,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 867604339,
#   'worldwide_gross': 870325439,
#   'runtime_minutes': 123,
#   'rating': None,
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Drama', 'Thriller', 'War']},
#  {'title': 'Star Wars: Episode III - Revenge of the Sith',
#   'domestic_gross': 380270577,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 488119983,
#   'worldwide_gross': 868390560,
#   'runtime_minutes': 140,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'title': 'The Hunger Games: Catching Fire',
#   'domestic_gross': 424668047,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 440343699,
#   'worldwide_gross': 865011746,
#   'runtime_minutes': 146,
#   'rating': 'PG-13',
#   'release_month': 'November',
#   'genres': ['Action', 'Adventure', 'Mystery', 'Sci-Fi', 'Thriller']},
#  {'title': 'Guardians of the Galaxy Vol. 2',
#   'domestic_gross': 389813101,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 473942950,
#   'worldwide_gross': 863756051,
#   'runtime_minutes': 136,
#   'rating': 'PG-13',
#   'release_month': 'April',
#   'genres': ['Action', 'Adventure', 'Comedy', 'Sci-Fi']},
#  {'title': 'Inside Out',
#   'domestic_gross': 356921711,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 501149639,
#   'worldwide_gross': 858071350,
#   'runtime_minutes': 95,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Drama',
#    'Family',
#    'Fantasy']},
#  {'title': 'Venom',
#   'domestic_gross': 213515506,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 642569645,
#   'worldwide_gross': 856085151,
#   'runtime_minutes': 112,
#   'rating': 'PG-13',
#   'release_month': 'October',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Thor: Ragnarok',
#   'domestic_gross': 315058289,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 538925540,
#   'worldwide_gross': 853983829,
#   'runtime_minutes': 130,
#   'rating': 'PG-13',
#   'release_month': 'October',
#   'genres': ['Action', 'Adventure', 'Comedy', 'Fantasy', 'Sci-Fi']},
#  {'title': 'Inception',
#   'domestic_gross': 292576195,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 544260772,
#   'worldwide_gross': 836836967,
#   'runtime_minutes': 148,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller']},
#  {'title': 'Transformers: Revenge of the Fallen',
#   'domestic_gross': 402111870,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 434191823,
#   'worldwide_gross': 836303693,
#   'runtime_minutes': 149,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'The Twilight Saga: Breaking Dawn - Part 2',
#   'domestic_gross': 292324737,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 537422917,
#   'worldwide_gross': 829747654,
#   'runtime_minutes': 115,
#   'rating': 'PG-13',
#   'release_month': 'November',
#   'genres': ['Adventure', 'Drama', 'Fantasy', 'Romance']},
#  {'title': 'Spider-Man',
#   'domestic_gross': 407022860,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 418002176,
#   'worldwide_gross': 825025036,
#   'runtime_minutes': 121,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Wonder Woman',
#   'domestic_gross': 412815408,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 409488097,
#   'worldwide_gross': 822303505,
#   'runtime_minutes': 141,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi', 'War']},
#  {'title': 'Independence Day',
#   'domestic_gross': 306169268,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 511231623,
#   'worldwide_gross': 817400891,
#   'runtime_minutes': 145,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Fantastic Beasts and Where to Find Them',
#   'domestic_gross': 234037575,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 580006426,
#   'worldwide_gross': 814044001,
#   'runtime_minutes': 132,
#   'rating': 'PG-13',
#   'release_month': 'November',
#   'genres': ['Adventure', 'Family', 'Fantasy']},
#  {'title': 'Shrek the Third',
#   'domestic_gross': 322719944,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 490647436,
#   'worldwide_gross': 813367380,
#   'runtime_minutes': 93,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'title': 'Coco',
#   'domestic_gross': 210460015,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 597357873,
#   'worldwide_gross': 807817888,
#   'runtime_minutes': 105,
#   'rating': 'PG',
#   'release_month': 'October',
#   'genres': ['Adventure',
#    'Animation',
#    'Family',
#    'Fantasy',
#    'Music',
#    'Mystery']},
#  {'title': 'Jumanji: The Next Level',
#   'domestic_gross': 320314960,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 479744747,
#   'worldwide_gross': 800059707,
#   'runtime_minutes': 123,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Comedy', 'Fantasy']},
#  {'title': 'Harry Potter and the Prisoner of Azkaban',
#   'domestic_gross': 249975996,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 546245909,
#   'worldwide_gross': 796221906,
#   'runtime_minutes': 142,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Adventure', 'Family', 'Fantasy', 'Mystery']},
#  {'title': 'Pirates of the Caribbean: Dead Men Tell No Tales',
#   'domestic_gross': 172558876,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 622322566,
#   'worldwide_gross': 794881442,
#   'runtime_minutes': 129,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Fantasy']},
#  {'title': 'E.T. the Extra-Terrestrial',
#   'domestic_gross': 435110554,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 304203888,
#   'worldwide_gross': 792910554,
#   'runtime_minutes': 115,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Family', 'Sci-Fi']},
#  {'title': '2012',
#   'domestic_gross': 166112167,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 625105659,
#   'worldwide_gross': 791217826,
#   'runtime_minutes': 158,
#   'rating': 'PG-13',
#   'release_month': 'November',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Mission: Impossible - Fallout',
#   'domestic_gross': 220159104,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 570961322,
#   'worldwide_gross': 791120426,
#   'runtime_minutes': 147,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Thriller']},
#  {'title': 'Indiana Jones and the Kingdom of the Crystal Skull',
#   'domestic_gross': 317101119,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 473552823,
#   'worldwide_gross': 790653942,
#   'runtime_minutes': 122,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure']},
#  {'title': 'Spider-Man 2',
#   'domestic_gross': 373585825,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 415390628,
#   'worldwide_gross': 788976453,
#   'runtime_minutes': 127,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Fast & Furious 6',
#   'domestic_gross': 238679850,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 550001118,
#   'worldwide_gross': 788680968,
#   'runtime_minutes': 130,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Thriller']},
#  {'title': 'Deadpool 2',
#   'domestic_gross': 324591735,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 461202609,
#   'worldwide_gross': 785794344,
#   'runtime_minutes': 119,
#   'rating': 'R',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Comedy', 'Sci-Fi']},
#  {'title': 'Deadpool',
#   'domestic_gross': 363070709,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 419542002,
#   'worldwide_gross': 782612711,
#   'runtime_minutes': 108,
#   'rating': 'R',
#   'release_month': 'February',
#   'genres': ['Action', 'Adventure', 'Comedy', 'Sci-Fi']},
#  {'title': 'Star Wars: Episode IV - A New Hope',
#   'domestic_gross': 460998507,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 195751992,
#   'worldwide_gross': 775398007,
#   'runtime_minutes': 121,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'title': 'Guardians of the Galaxy',
#   'domestic_gross': 333718600,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 439631528,
#   'worldwide_gross': 773350128,
#   'runtime_minutes': 121,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Comedy', 'Sci-Fi']},
#  {'title': 'The Da Vinci Code',
#   'domestic_gross': 217536138,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 542470807,
#   'worldwide_gross': 760006945,
#   'runtime_minutes': 149,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Mystery', 'Thriller']},
#  {'title': 'Maleficent',
#   'domestic_gross': 241410378,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 517001401,
#   'worldwide_gross': 758411779,
#   'runtime_minutes': 97,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Family', 'Fantasy', 'Romance']},
#  {'title': 'The Amazing Spider-Man',
#   'domestic_gross': 262030663,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 495900000,
#   'worldwide_gross': 757930663,
#   'runtime_minutes': 136,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'The Hunger Games: Mockingjay - Part 1',
#   'domestic_gross': 337135885,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 418220826,
#   'worldwide_gross': 755356711,
#   'runtime_minutes': 123,
#   'rating': 'PG-13',
#   'release_month': 'November',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller']},
#  {'title': 'Shrek Forever After',
#   'domestic_gross': 238736787,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 513864080,
#   'worldwide_gross': 752600867,
#   'runtime_minutes': 93,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Romance']},
#  {'title': "Madagascar 3: Europe's Most Wanted",
#   'domestic_gross': 216391482,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 530529792,
#   'worldwide_gross': 746921274,
#   'runtime_minutes': 95,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family']},
#  {'title': 'Suicide Squad',
#   'domestic_gross': 325100054,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 421746840,
#   'worldwide_gross': 746846894,
#   'runtime_minutes': 123,
#   'rating': 'PG-13',
#   'release_month': 'August',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'title': 'X-Men: Days of Future Past',
#   'domestic_gross': 233921534,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 512124166,
#   'worldwide_gross': 746045700,
#   'runtime_minutes': 132,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller']},
#  {'title': 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#   'domestic_gross': 291710957,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 453302158,
#   'worldwide_gross': 745013115,
#   'runtime_minutes': 143,
#   'rating': 'PG',
#   'release_month': 'December',
#   'genres': ['Adventure', 'Family', 'Fantasy']},
#  {'title': 'Monsters University',
#   'domestic_gross': 268492764,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 475066843,
#   'worldwide_gross': 743559607,
#   'runtime_minutes': 104,
#   'rating': 'G',
#   'release_month': 'June',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'title': 'The Matrix Reloaded',
#   'domestic_gross': 281576461,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 460271476,
#   'worldwide_gross': 741847937,
#   'runtime_minutes': 138,
#   'rating': 'R',
#   'release_month': 'May',
#   'genres': ['Action', 'Sci-Fi']},
#  {'title': 'Up',
#   'domestic_gross': 293004164,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 442094938,
#   'worldwide_gross': 735099102,
#   'runtime_minutes': 96,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family']},
#  {'title': 'Ne Zha',
#   'domestic_gross': 3695533,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 722367938,
#   'worldwide_gross': 726063471,
#   'runtime_minutes': 110,
#   'rating': None,
#   'release_month': 'July',
#   'genres': ['Action',
#    'Adventure',
#    'Animation',
#    'Family',
#    'Fantasy',
#    'Thriller']},
#  {'title': 'Gravity',
#   'domestic_gross': 274092705,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 449100000,
#   'worldwide_gross': 723192705,
#   'runtime_minutes': 91,
#   'rating': 'PG-13',
#   'release_month': 'October',
#   'genres': ['Drama', 'Sci-Fi', 'Thriller']},
#  {'title': 'Captain America: The Winter Soldier',
#   'domestic_gross': 259766572,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 454654931,
#   'worldwide_gross': 714421503,
#   'runtime_minutes': 136,
#   'rating': 'PG-13',
#   'release_month': 'March',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller']},
#  {'title': 'The Twilight Saga: Breaking Dawn - Part 1',
#   'domestic_gross': 281287133,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 430918723,
#   'worldwide_gross': 712205856,
#   'runtime_minutes': 117,
#   'rating': 'PG-13',
#   'release_month': 'November',
#   'genres': ['Adventure', 'Drama', 'Fantasy', 'Romance', 'Thriller']},
#  {'title': 'The Twilight Saga: New Moon',
#   'domestic_gross': 297816253,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 413209228,
#   'worldwide_gross': 711025481,
#   'runtime_minutes': 130,
#   'rating': 'PG-13',
#   'release_month': 'November',
#   'genres': ['Adventure', 'Drama', 'Fantasy', 'Romance']},
#  {'title': 'Dawn of the Planet of the Apes',
#   'domestic_gross': 208545589,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 502098977,
#   'worldwide_gross': 710644566,
#   'runtime_minutes': 130,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Drama', 'Sci-Fi']},
#  {'title': 'Transformers',
#   'domestic_gross': 319246193,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 390463587,
#   'worldwide_gross': 709709780,
#   'runtime_minutes': 144,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'The Amazing Spider-Man 2',
#   'domestic_gross': 202853933,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 506128390,
#   'worldwide_gross': 708982323,
#   'runtime_minutes': 142,
#   'rating': 'PG-13',
#   'release_month': 'April',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'It',
#   'domestic_gross': 328828874,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 372967570,
#   'worldwide_gross': 701796444,
#   'runtime_minutes': 135,
#   'rating': 'R',
#   'release_month': 'September',
#   'genres': ['Horror']},
#  {'title': 'Interstellar',
#   'domestic_gross': 188020017,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 513775554,
#   'worldwide_gross': 701795571,
#   'runtime_minutes': 169,
#   'rating': 'PG-13',
#   'release_month': 'November',
#   'genres': ['Adventure', 'Drama', 'Sci-Fi']},
#  {'title': 'The Wandering Earth',
#   'domestic_gross': 5971413,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 693885286,
#   'worldwide_gross': 699856699,
#   'runtime_minutes': 125,
#   'rating': None,
#   'release_month': 'January',
#   'genres': ['Action', 'Sci-Fi']},
#  {'title': 'The Twilight Saga: Eclipse',
#   'domestic_gross': 300531751,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 397959596,
#   'worldwide_gross': 698491347,
#   'runtime_minutes': 124,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action',
#    'Adventure',
#    'Drama',
#    'Fantasy',
#    'Romance',
#    'Thriller']},
#  {'title': 'Mission: Impossible - Ghost Protocol',
#   'domestic_gross': 209397903,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 485315477,
#   'worldwide_gross': 694713380,
#   'runtime_minutes': 132,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Thriller']},
#  {'title': 'The Hunger Games',
#   'domestic_gross': 408010692,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 286384032,
#   'worldwide_gross': 694394724,
#   'runtime_minutes': 142,
#   'rating': 'PG-13',
#   'release_month': 'March',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller']},
#  {'title': 'It Chapter Two',
#   'domestic_gross': 211593228,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 261500000,
#   'worldwide_gross': 683955083,
#   'runtime_minutes': 169,
#   'rating': 'R',
#   'release_month': 'September',
#   'genres': ['Drama', 'Fantasy', 'Horror']},
#  {'title': 'Mission: Impossible - Rogue Nation',
#   'domestic_gross': 195042377,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 487674259,
#   'worldwide_gross': 682716636,
#   'runtime_minutes': 131,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Thriller']},
#  {'title': 'Forrest Gump',
#   'domestic_gross': 330455270,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 347770863,
#   'worldwide_gross': 678226133,
#   'runtime_minutes': 142,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Drama', 'Romance']},
#  {'title': 'Doctor Strange',
#   'domestic_gross': 232641920,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 445154156,
#   'worldwide_gross': 677796076,
#   'runtime_minutes': 115,
#   'rating': 'PG-13',
#   'release_month': 'October',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'title': 'The Sixth Sense',
#   'domestic_gross': 293506292,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 379300000,
#   'worldwide_gross': 672806292,
#   'runtime_minutes': 107,
#   'rating': 'PG-13',
#   'release_month': 'August',
#   'genres': ['Drama', 'Mystery', 'Thriller']},
#  {'title': 'Man of Steel',
#   'domestic_gross': 291045518,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 377000000,
#   'worldwide_gross': 668045518,
#   'runtime_minutes': 143,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Ice Age: The Meltdown',
#   'domestic_gross': 195330621,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 471763885,
#   'worldwide_gross': 667094506,
#   'runtime_minutes': 91,
#   'rating': 'PG',
#   'release_month': 'March',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'title': 'Kung Fu Panda 2',
#   'domestic_gross': 165249063,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 500443218,
#   'worldwide_gross': 665692281,
#   'runtime_minutes': 90,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Action',
#    'Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy']},
#  {'title': 'The Hunger Games: Mockingjay - Part 2',
#   'domestic_gross': 281723902,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 376620235,
#   'worldwide_gross': 658344137,
#   'runtime_minutes': 137,
#   'rating': 'PG-13',
#   'release_month': 'November',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller']},
#  {'title': 'Justice League',
#   'domestic_gross': 229024295,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 428902692,
#   'worldwide_gross': 657926987,
#   'runtime_minutes': None,
#   'rating': 'PG-13',
#   'release_month': 'October',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'title': 'Big Hero 6',
#   'domestic_gross': 222527828,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 435341673,
#   'worldwide_gross': 657869501,
#   'runtime_minutes': 102,
#   'rating': 'PG',
#   'release_month': 'October',
#   'genres': ['Action', 'Adventure', 'Animation', 'Family', 'Sci-Fi']},
#  {'title': 'Fantastic Beasts: The Crimes of Grindelwald',
#   'domestic_gross': 159555901,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 495300000,
#   'worldwide_gross': 654855901,
#   'runtime_minutes': 134,
#   'rating': 'PG-13',
#   'release_month': 'October',
#   'genres': ['Adventure', 'Family', 'Fantasy']},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'domestic_gross': 305413918,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 348850097,
#   'worldwide_gross': 654264015,
#   'runtime_minutes': 143,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Fantasy']},
#  {'title': 'Star Wars: Episode II - Attack of the Clones',
#   'domestic_gross': 310676740,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 343103230,
#   'worldwide_gross': 653779970,
#   'runtime_minutes': 142,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'title': 'Thor: The Dark World',
#   'domestic_gross': 206362140,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 438421000,
#   'worldwide_gross': 644783140,
#   'runtime_minutes': 112,
#   'rating': 'PG-13',
#   'release_month': 'October',
#   'genres': ['Action', 'Adventure', 'Fantasy']},
#  {'title': 'Moana',
#   'domestic_gross': 248757044,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 394593954,
#   'worldwide_gross': 643350998,
#   'runtime_minutes': 107,
#   'rating': 'PG',
#   'release_month': 'November',
#   'genres': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Musical']},
#  {'title': 'Sing',
#   'domestic_gross': 270422425,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 363759497,
#   'worldwide_gross': 634181922,
#   'runtime_minutes': 108,
#   'rating': 'PG',
#   'release_month': 'December',
#   'genres': ['Animation', 'Comedy', 'Family', 'Musical']},
#  {'title': 'Kung Fu Panda',
#   'domestic_gross': 215434591,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 416311606,
#   'worldwide_gross': 631746197,
#   'runtime_minutes': 92,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Animation', 'Comedy', 'Family']},
#  {'title': 'The Incredibles',
#   'domestic_gross': 261441092,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 370165621,
#   'worldwide_gross': 631606713,
#   'runtime_minutes': 115,
#   'rating': None,
#   'release_month': 'November',
#   'genres': ['Action', 'Adventure', 'Animation', 'Family']},
#  {'title': 'The Martian',
#   'domestic_gross': 228433663,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 401728572,
#   'worldwide_gross': 630162235,
#   'runtime_minutes': 144,
#   'rating': 'PG-13',
#   'release_month': 'September',
#   'genres': ['Adventure', 'Drama', 'Sci-Fi']},
#  {'title': 'Hancock',
#   'domestic_gross': 227946274,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 401497154,
#   'worldwide_gross': 629443428,
#   'runtime_minutes': 92,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Drama', 'Fantasy']},
#  {'title': 'Fast Five',
#   'domestic_gross': 209837675,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 416300000,
#   'worldwide_gross': 626137675,
#   'runtime_minutes': 130,
#   'rating': 'PG-13',
#   'release_month': 'April',
#   'genres': ['Action', 'Adventure', 'Crime', 'Thriller']},
#  {'title': 'Men in Black 3',
#   'domestic_gross': 179020854,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 445005922,
#   'worldwide_gross': 624026776,
#   'runtime_minutes': 106,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Comedy', 'Sci-Fi']},
#  {'title': 'Iron Man 2',
#   'domestic_gross': 312433331,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 311500000,
#   'worldwide_gross': 623933331,
#   'runtime_minutes': 124,
#   'rating': 'PG-13',
#   'release_month': 'April',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Ratatouille',
#   'domestic_gross': 206445654,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 417280431,
#   'worldwide_gross': 623726085,
#   'runtime_minutes': 111,
#   'rating': 'G',
#   'release_month': 'June',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'title': 'Ant-Man and the Wasp',
#   'domestic_gross': 216648740,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 406025399,
#   'worldwide_gross': 622674139,
#   'runtime_minutes': 118,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Comedy', 'Sci-Fi']},
#  {'title': 'How to Train Your Dragon 2',
#   'domestic_gross': 177002924,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 444534595,
#   'worldwide_gross': 621537519,
#   'runtime_minutes': 102,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Animation', 'Family', 'Fantasy']},
#  {'title': 'Logan',
#   'domestic_gross': 226277068,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 392744368,
#   'worldwide_gross': 619021436,
#   'runtime_minutes': 137,
#   'rating': 'R',
#   'release_month': 'March',
#   'genres': ['Action', 'Drama', 'Sci-Fi', 'Thriller']},
#  {'title': 'The Lost World: Jurassic Park',
#   'domestic_gross': 229086679,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 389552320,
#   'worldwide_gross': 618638999,
#   'runtime_minutes': 129,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Casino Royale',
#   'domestic_gross': 167445960,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 449055659,
#   'worldwide_gross': 616501619,
#   'runtime_minutes': 144,
#   'rating': 'PG-13',
#   'release_month': 'November',
#   'genres': ['Action', 'Adventure', 'Thriller']},
#  {'title': 'The Passion of the Christ',
#   'domestic_gross': 370782930,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 241271498,
#   'worldwide_gross': 612054428,
#   'runtime_minutes': 127,
#   'rating': 'R',
#   'release_month': 'February',
#   'genres': ['Drama']},
#  {'title': 'Mamma Mia!',
#   'domestic_gross': 144169664,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 465745071,
#   'worldwide_gross': 609914735,
#   'runtime_minutes': 108,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Comedy', 'Musical', 'Romance']},
#  {'title': 'Life of Pi',
#   'domestic_gross': 124987023,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 484029542,
#   'worldwide_gross': 609016565,
#   'runtime_minutes': 127,
#   'rating': 'PG',
#   'release_month': 'November',
#   'genres': ['Adventure', 'Drama', 'Fantasy']},
#  {'title': 'Transformers: The Last Knight',
#   'domestic_gross': 130168683,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 475256474,
#   'worldwide_gross': 605425157,
#   'runtime_minutes': 154,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Madagascar: Escape 2 Africa',
#   'domestic_gross': 180010950,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 423889404,
#   'worldwide_gross': 603900354,
#   'runtime_minutes': 89,
#   'rating': 'PG',
#   'release_month': 'October',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family']},
#  {'title': 'War of the Worlds',
#   'domestic_gross': 234280354,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 369592765,
#   'worldwide_gross': 603873119,
#   'runtime_minutes': 116,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Adventure', 'Sci-Fi', 'Thriller']},
#  {'title': 'Tangled',
#   'domestic_gross': 200821936,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 391640023,
#   'worldwide_gross': 592461959,
#   'runtime_minutes': 100,
#   'rating': 'PG',
#   'release_month': 'November',
#   'genres': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Musical',
#    'Romance']},
#  {'title': 'Quantum of Solace',
#   'domestic_gross': 168368427,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 421212055,
#   'worldwide_gross': 589580482,
#   'runtime_minutes': 106,
#   'rating': 'PG-13',
#   'release_month': 'October',
#   'genres': ['Action', 'Adventure', 'Thriller']},
#  {'title': 'Men in Black',
#   'domestic_gross': 250690539,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 338700000,
#   'worldwide_gross': 589390539,
#   'runtime_minutes': 98,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Comedy', 'Sci-Fi']},
#  {'title': 'The Croods',
#   'domestic_gross': 187168425,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 400036894,
#   'worldwide_gross': 587205319,
#   'runtime_minutes': 98,
#   'rating': 'PG',
#   'release_month': 'March',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'title': 'The Hangover Part II',
#   'domestic_gross': 254464305,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 332300000,
#   'worldwide_gross': 586764305,
#   'runtime_minutes': 102,
#   'rating': 'R',
#   'release_month': 'May',
#   'genres': ['Comedy']},
#  {'title': 'Iron Man',
#   'domestic_gross': 319034126,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 266762121,
#   'worldwide_gross': 585796247,
#   'runtime_minutes': 126,
#   'rating': 'PG-13',
#   'release_month': 'April',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'I Am Legend',
#   'domestic_gross': 256393010,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 329017042,
#   'worldwide_gross': 585410052,
#   'runtime_minutes': 101,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Drama', 'Sci-Fi', 'Thriller']},
#  {'title': 'Ready Player One',
#   'domestic_gross': 137690172,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 445203499,
#   'worldwide_gross': 582893671,
#   'runtime_minutes': 140,
#   'rating': 'PG-13',
#   'release_month': 'March',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Monsters, Inc.',
#   'domestic_gross': 290642256,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 289064814,
#   'worldwide_gross': 579707070,
#   'runtime_minutes': 92,
#   'rating': 'G',
#   'release_month': 'November',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'title': 'Operation Red Sea',
#   'domestic_gross': 1543547,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 577786879,
#   'worldwide_gross': 579330426,
#   'runtime_minutes': 142,
#   'rating': None,
#   'release_month': 'February',
#   'genres': ['Action', 'Drama', 'Thriller', 'War']},
#  {'title': 'Night at the Museum',
#   'domestic_gross': 250863268,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 323617961,
#   'worldwide_gross': 574481229,
#   'runtime_minutes': 108,
#   'rating': 'PG',
#   'release_month': 'December',
#   'genres': ['Adventure', 'Comedy', 'Family', 'Fantasy']},
#  {'title': 'Fifty Shades of Grey',
#   'domestic_gross': 166167230,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 403484237,
#   'worldwide_gross': 569651467,
#   'runtime_minutes': 125,
#   'rating': 'R',
#   'release_month': 'February',
#   'genres': ['Drama', 'Romance', 'Thriller']},
#  {'title': 'Kong: Skull Island',
#   'domestic_gross': 168052812,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 398600000,
#   'worldwide_gross': 566652812,
#   'runtime_minutes': 118,
#   'rating': 'PG-13',
#   'release_month': 'March',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'title': 'The Smurfs',
#   'domestic_gross': 142614158,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 421135165,
#   'worldwide_gross': 563749323,
#   'runtime_minutes': 103,
#   'rating': 'PG',
#   'release_month': 'July',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'title': 'King Kong',
#   'domestic_gross': 218080025,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 344283424,
#   'worldwide_gross': 562363449,
#   'runtime_minutes': 187,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Drama', 'Romance']},
#  {'title': 'Cars 2',
#   'domestic_gross': 191452396,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 368400000,
#   'worldwide_gross': 559852396,
#   'runtime_minutes': 106,
#   'rating': 'G',
#   'release_month': 'June',
#   'genres': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Crime',
#    'Family',
#    'Mystery',
#    'Sci-Fi',
#    'Sport']},
#  {'title': 'Puss in Boots',
#   'domestic_gross': 149260504,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 405726973,
#   'worldwide_gross': 554987477,
#   'runtime_minutes': 90,
#   'rating': 'PG',
#   'release_month': 'October',
#   'genres': ['Action',
#    'Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Mystery']},
#  {'title': 'The Mermaid',
#   'domestic_gross': 3232685,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 550577543,
#   'worldwide_gross': 553810228,
#   'runtime_minutes': 94,
#   'rating': 'R',
#   'release_month': 'February',
#   'genres': ['Comedy', 'Drama', 'Fantasy', 'Romance']},
#  {'title': 'Armageddon',
#   'domestic_gross': 201578182,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 352131606,
#   'worldwide_gross': 553709788,
#   'runtime_minutes': 151,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller']},
#  {'title': 'The Day After Tomorrow',
#   'domestic_gross': 186740799,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 365898772,
#   'worldwide_gross': 552639571,
#   'runtime_minutes': 124,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller']},
#  {'title': 'Ted',
#   'domestic_gross': 218815487,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 330552828,
#   'worldwide_gross': 549368315,
#   'runtime_minutes': 106,
#   'rating': 'R',
#   'release_month': 'June',
#   'genres': ['Comedy']},
#  {'title': 'American Sniper',
#   'domestic_gross': 350126372,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 197300000,
#   'worldwide_gross': 547426372,
#   'runtime_minutes': 133,
#   'rating': 'R',
#   'release_month': 'December',
#   'genres': ['Action', 'Biography', 'Drama', 'War']},
#  {'title': 'Mission: Impossible II',
#   'domestic_gross': 215409889,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 330978219,
#   'worldwide_gross': 546388108,
#   'runtime_minutes': 123,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Thriller']},
#  {'title': 'Detective Chinatown 2',
#   'domestic_gross': 1983984,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 542201172,
#   'worldwide_gross': 544185156,
#   'runtime_minutes': 121,
#   'rating': 'R',
#   'release_month': 'February',
#   'genres': ['Action', 'Comedy', 'Mystery']},
#  {'title': 'X-Men: Apocalypse',
#   'domestic_gross': 155442489,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 388491616,
#   'worldwide_gross': 543934105,
#   'runtime_minutes': 144,
#   'rating': 'PG-13',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'Sherlock Holmes: A Game of Shadows',
#   'domestic_gross': 186848418,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 357000000,
#   'worldwide_gross': 543848418,
#   'runtime_minutes': 129,
#   'rating': 'PG-13',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Mystery']},
#  {'title': 'Despicable Me',
#   'domestic_gross': 251513985,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 291600000,
#   'worldwide_gross': 543113985,
#   'runtime_minutes': 95,
#   'rating': 'PG',
#   'release_month': 'July',
#   'genres': ['Animation', 'Comedy', 'Crime', 'Family', 'Fantasy']},
#  {'title': 'Cinderella',
#   'domestic_gross': 201151353,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 341206978,
#   'worldwide_gross': 542358331,
#   'runtime_minutes': 105,
#   'rating': 'PG',
#   'release_month': 'March',
#   'genres': ['Drama', 'Family', 'Fantasy', 'Romance']},
#  {'title': 'Madagascar',
#   'domestic_gross': 193595521,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 348468325,
#   'worldwide_gross': 542063846,
#   'runtime_minutes': 86,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family']},
#  {'title': 'World War Z',
#   'domestic_gross': 202359711,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 337648165,
#   'worldwide_gross': 540007876,
#   'runtime_minutes': 116,
#   'rating': 'PG-13',
#   'release_month': 'June',
#   'genres': ['Action', 'Adventure', 'Horror', 'Sci-Fi']},
#  {'title': 'Brave',
#   'domestic_gross': 237283207,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 301700000,
#   'worldwide_gross': 538983207,
#   'runtime_minutes': 93,
#   'rating': 'PG',
#   'release_month': 'June',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'title': 'Star Wars: Episode V - The Empire Strikes Back',
#   'domestic_gross': 292753960,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 190685234,
#   'worldwide_gross': 538375067,
#   'runtime_minutes': 124,
#   'rating': 'PG',
#   'release_month': 'May',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'title': 'The Simpsons Movie',
#   'domestic_gross': 183135014,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 353279279,
#   'worldwide_gross': 536414293,
#   'runtime_minutes': 87,
#   'rating': 'PG-13',
#   'release_month': 'July',
#   'genres': ['Adventure', 'Animation', 'Comedy']},
#  {'title': 'The Revenant',
#   'domestic_gross': 183637894,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 349312609,
#   'worldwide_gross': 532950503,
#   'runtime_minutes': 156,
#   'rating': 'R',
#   'release_month': 'December',
#   'genres': ['Action', 'Adventure', 'Drama', 'History', 'Western']},
#  {'title': 'The Meg',
#   'domestic_gross': 145443742,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 384815731,
#   'worldwide_gross': 530259473,
#   'runtime_minutes': 113,
#   'rating': 'PG-13',
#   'release_month': 'August',
#   'genres': ['Action', 'Horror', 'Sci-Fi', 'Thriller']},
#  {'title': 'Ralph Breaks the Internet',
#   'domestic_gross': 201091711,
#   'domestic_opening_gross': 247966675,
#   'international_gross': 328232251,
#   'worldwide_gross': 529323962,
#   'runtime_minutes': 112,
#   'rating': 'PG',
#   'release_month': 'November',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']}]

# %%
lifetime_movies_info = pd.DataFrame(lifetime_movie_data)
lifetime_movies_info.set_index('title', inplace = True)

# %%
lifetime_movies_info.head()

# %%
lifetime_movies = lifetime_movies.merge(lifetime_movies_info, left_index=True, right_index=True)

lifetime_movies.head()

# %% [markdown]
# #### Director & Actors

# %%
url = 'https://www.boxofficemojo.com/title/tt2488496/credits/?ref_=bo_tt_tab'
response = requests.get(url)
page = response.text
soup = BeautifulSoup(page, 'lxml')

# %%
casts = soup.find('table', id = 'principalCast').find_all('a', attrs={'class':'a-link-normal'})
actors = []
for cast in casts:
    cast = cast.text.split('\n')[0]
    actors += [cast]
actors

# %%
movies = pd.DataFrame(movies).T  #transpose
movies.columns = ['link_stub', 'title', 'rank_g_movies', 
                    'lifetime_gross', 'rank_overall', 'year']

g_movies.head()

# %%
g_movies_page_info_list = []

for link in g_movies.link_stub:
    g_movies_page_info_list.append(get_movie_dict(link))

# %% [markdown]
# ### IMDB Top 100 Actors 2018

# %%
url = 'https://www.imdb.com/list/ls023242359/'
response = requests.get(url)
page = response.text
soup = BeautifulSoup(page, 'lxml')

# %%
soup.find_all('span', class_='lister-item-index')[0].text

# %%
soup.find('div', class_='lister-item-content').find_all('a')

# %%
soup.find('div', class_='lister-item-content').find('a').text.split('\n')[0]

# %%
top_list = soup.find('div', class_='lister-list').find_all('a')
top_list

# %%
soup.find('div', class_='lister-list').find_all('a')[1].text.split('\n')[0]

# %%
top_actor = []
for top in top_list:
    top = top.text.split('\n')[0]
    top_actor += [top]
  
top_actor

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver
driver = webdriver.Chrome(chromedriver)
driver.get('https://www.imdb.com/list/ls023242359/')

assert "imdb" in driver.title

continue_link = driver.find_element_by_tag_name('a')
elem = driver.find_elements_by_xpath("//*[@href]/name*")
#x = str(continue_link)
#print(continue_link)
print(elem)

# %%
soup.find('div', class_='lister-list').find_all('a').get('href', ref_='nmls_hd')
