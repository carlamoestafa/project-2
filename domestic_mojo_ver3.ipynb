# %% [markdown]
# # PROJECT - 2

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
import dateutil.parser

# %% [markdown]
# ### Getting  information from a movie page

# %%
url = 'https://www.boxofficemojo.com/title/tt2488496/?ref_=bo_cso_table_1'
response = requests.get(url)
page = response.text
soup = BeautifulSoup(page, 'lxml')
# soup.prettify()

# %% [markdown]
# #### Movie Title

# %%
soup.find('title').text
title_string = soup.find('title').text
title_string
# Out:
# 'Star Wars: Episode VII - The Force Awakens - Box Office Mojo'

# %%
title = title_string[:-18]
title
# Out:
# 'Star Wars: Episode VII - The Force Awakens'

# %% [markdown]
# #### Domestic Gross

# %%
soup.find(class_='mojo-performance-summary-table').find_all('span',class_='money')
# Out:
# [<span class="money">$936,662,225</span>,
#  <span class="money">$1,131,791,908</span>,
#  <span class="money">$2,068,454,133</span>]

# %%
dom_gross = soup.find(class_='mojo-performance-summary-table').find_all('span',class_='money')[0].text
dom_gross
# Out:
# '$936,662,225'

# %% [markdown]
# #### International Gross

# %%
intl_gross = soup.find(class_='mojo-performance-summary-table').find_all('span',class_='money')[1].text
intl_gross
# Out:
# '$1,131,791,908'

# %% [markdown]
# #### Worldwide Gross

# %%
world_gross = soup.find(class_='mojo-performance-summary-table').find_all('span',class_='money')[2].text
world_gross
# Out:
# '$2,068,454,133'

# %% [markdown]
# #### Domestic Openig Gross

# %%
dom_opening_gross = soup.find(class_='mojo-summary-values').find_all('span', class_ = 'money')[0]
dom_opening_gross
# Out:
# <span class="money">$247,966,675</span>

# %% [markdown]
# #### Budget

# %%
prod_budget = soup.find(class_='mojo-summary-values').find_all('span', class_ = 'money')[1]
prod_budget
# Out:
# <span class="money">$245,000,000</span>

# %% [markdown]
# #### Domestic Distributor

# %%
soup.find(class_='mojo-summary-values').find_all('span', class_ = 'money')
# Out:
# [<span class="money">$247,966,675</span>,
#  <span class="money">$245,000,000</span>]

# %%
distributor_reggex = re.compile('Distributor')
soup.find(text=distributor_reggex)
# Out:
# 'Domestic Distributor'

# %%
distr_string = find(text=distributor_reggex).findNext('span').text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-6c59da8698ec> in <module>
# ----> 1 distr_string = find(text=distributor_reggex).findNext('span').text
#
# NameError: name 'find' is not defined

# %%
dist_string = soup.find(text=distributor_reggex).findNext('span').text[:18]
dom_dist = dist_string
dom_dist
# Out:
# 'Walt Disney Studio'

# %% [markdown]
# ### Get Movie (findNext) Values

# %%
def get_movie_value(soup, field_name):
    
    """
    Get a value fro the movie page and take the string attribute of a movie on the page and return
    the value of the next sibling object or None if nothing is found.
    
    """
    obj = soup.find(text=re.compile(field_name))
    if not obj:
        return None
    next_element = obj.findNext()
    
    if next_element:
        return next_element.text
    else:
        return None

# %% [markdown]
# #### Domestic Opening Gross

# %%
dom_opening_gross = soup.find(class_='mojo-summary-values').find_all('span', class_ = 'money')[0].text
dom_opening_gross
# Out:
# '$247,966,675'

# %%
production_budget = soup.find(class_='mojo-summary-values').find_all('span', class_ = 'money')[1].text
production_budget
# Out:
# '$245,000,000'

# %% [markdown]
# #### Runtime

# %%
runtime = get_movie_value(soup, 'Running')
print(runtime)
# Out:
# 2 hr 18 min

# %% [markdown]
# #### Rating

# %%
rating = get_movie_value(soup, 'MPAA')
print(rating)
# Out:
# PG-13

# %% [markdown]
# #### Release Date

# %%
rel_date = get_movie_value(soup, 'Release Date').split('\n')[0]
print(rel_date)
# Out:
# December 16, 2015

# %%
date = dateutil.parser.parse(rel_date)
date.month
# Out:
# 12

# %%
import datetime

a = '2010-01-31'

datee = datetime.datetime.strptime(a, "%Y-%m-%d")


datee.month
Out[9]: 1

datee.year
Out[10]: 2010

datee.day
Out[11]: 31

# %% [markdown]
# #### Genres

# %%
genres = get_movie_value(soup, 'Genres').split()
genres
# Out:
# ['Action', 'Adventure', 'Sci-Fi']

# %% [markdown]
# #### Distributor

# %%
distributor = get_movie_value(soup, 'Distributor')[:35]
distributor
# Out:
# 'Walt Disney Studios Motion Pictures'

# %% [markdown]
# ### Function to convert money and time string into integer values

# %%
def money_to_int(moneystring):
    
    """
    replaces the $ sign and removing the comma separator from the money string
    returns the integer value
    """
    
    moneystring = moneystring.replace('$', '').replace(',', '')
    return int(moneystring)

def runtime_to_minutes(runtimestring):
    
    """
    takes runtimestring in _hr_min format and returns it's value in number of minutes
    """
    
    runtime = runtimestring.split()
    try:
        minutes = int(runtime[0]) * 60 + int(runtime[2])
        return minutes
    except:
        return None
    
def to_date(datestring):
    date = dateutil.parser.parse(datestring)
    return date

# %%
raw_dom_gross = dom_gross
domestic_gross = money_to_int(raw_dom_gross)

raw_intl_gross = intl_gross
international_gross = money_to_int(raw_intl_gross)

raw_world_gross = world_gross
worldwide_gross = money_to_int(raw_world_gross)

raw_opening_gross = dom_opening_gross
domestic_opening_gross = money_to_int(raw_opening_gross)

raw_budget = production_budget
budget = money_to_int(raw_budget)

raw_release_date = get_movie_value(soup,'Release Date').split('\n')[0]
release_date = to_date(raw_release_date)
release_date
# Out:
# datetime.datetime(2015, 12, 16, 0, 0)

# %%
raw_runtime = get_movie_value(soup, 'Running')
runtime_minutes = runtime_to_minutes(raw_runtime)
runtime_minutes
# Out:
# 138

# %% [markdown]
# #### Release date

# %%
raw_release_date = get_movie_value(soup,'Release Date').split('\n')[0]
release_month = to_date(raw_release_date).month
release_month
# Out:
# 12

# %%
release_month = rel_date.split()[0]
release_month
# Out:
# 'December'

# %% [markdown]
# #### Actors

# %%
url = 'https://www.boxofficemojo.com/title/tt2488496/credits/?ref_=bo_tt_tab'
response = requests.get(url)
actor_page = response.text
actor_soup = BeautifulSoup(actor_page, 'lxml')

# %%
casts = actor_soup.find('table', id = 'principalCast').find_all('a', attrs={'class':'a-link-normal'})
actors = []
for cast in casts:
    cast = cast.text.split('\n')[0]
    actors += [cast]
actors
# Out:
# ['Daisy Ridley', 'John Boyega', 'Oscar Isaac', 'Domhnall Gleeson']

# %% [markdown]
# ### Getting the domestic lifetime ranking table

# %%
url = 'https://www.boxofficemojo.com/chart/top_lifetime_gross/?offset=800'
response = requests.get(url)
page = response.text
soup = BeautifulSoup(page, 'lxml')
# print(soup.prettify())

# %%
# finding the table
table = soup.find('table')
# table

# %%
rows = [row for row in table.find_all('tr')]
rows[1].find_all('td')
# Out:
# [<td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">801</td>,
#  <td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0252076/?ref_=bo_cso_table_1">Maid in Manhattan</a></td>,
#  <td class="a-text-right mojo-field-type-money">$94,011,225</td>,
#  <td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2002/?ref_=bo_cso_table_1">2002</a></td>]

# %%
rows[1].find_all('td')[1].find('a')['href']
# Out:
# '/title/tt0252076/?ref_=bo_cso_table_1'

# %% [markdown]
# #### Previewing Lifetime Movie Data

# %%
movies = {}

for row in rows[1:201]:
    items = row.find_all('td')
    link = items[1].find('a')
    title = link.text
    url = link['href']
    movies[title] = [url]+ [i.text for i in items]

movies
# Out:
# {'Maid in Manhattan': ['/title/tt0252076/?ref_=bo_cso_table_1',
#   '801',
#   'Maid in Manhattan',
#   '$94,011,225',
#   '2002'],
#  "He's Just Not That Into You": ['/title/tt1001508/?ref_=bo_cso_table_2',
#   '802',
#   "He's Just Not That Into You",
#   '$93,953,653',
#   '2009'],
#  'Master and Commander: The Far Side of the World': ['/title/tt0311113/?ref_=bo_cso_table_3',
#   '803',
#   'Master and Commander: The Far Side of the World',
#   '$93,927,920',
#   '2003'],
#  'Flight': ['/title/tt1907668/?ref_=bo_cso_table_4',
#   '804',
#   'Flight',
#   '$93,772,375',
#   '2012'],
#  'The Fighter': ['/title/tt0964517/?ref_=bo_cso_table_5',
#   '805',
#   'The Fighter',
#   '$93,617,009',
#   '2010'],
#  "America's Sweethearts": ['/title/tt0265029/?ref_=bo_cso_table_6',
#   '806',
#   "America's Sweethearts",
#   '$93,607,673',
#   '2001'],
#  'Lady and the Tramp': ['/title/tt0048280/?ref_=bo_cso_table_7',
#   '807',
#   'Lady and the Tramp',
#   '$93,602,326',
#   '1955'],
#  'The Bucket List': ['/title/tt0825232/?ref_=bo_cso_table_8',
#   '808',
#   'The Bucket List',
#   '$93,466,502',
#   '2007'],
#  'Tomorrowland': ['/title/tt1964418/?ref_=bo_cso_table_9',
#   '809',
#   'Tomorrowland',
#   '$93,436,322',
#   '2015'],
#  'The Magnificent Seven': ['/title/tt2404435/?ref_=bo_cso_table_10',
#   '810',
#   'The Magnificent Seven',
#   '$93,432,655',
#   '2016'],
#  'Cats & Dogs': ['/title/tt0239395/?ref_=bo_cso_table_11',
#   '811',
#   'Cats & Dogs',
#   '$93,385,515',
#   '2001'],
#  'Space Station 3D': ['/title/tt0290296/?ref_=bo_cso_table_12',
#   '812',
#   'Space Station 3D',
#   '$93,383,953',
#   '2002'],
#  'Two Weeks Notice': ['/title/tt0313737/?ref_=bo_cso_table_13',
#   '813',
#   'Two Weeks Notice',
#   '$93,354,851',
#   '2002'],
#  'Red Dragon': ['/title/tt0289765/?ref_=bo_cso_table_14',
#   '814',
#   'Red Dragon',
#   '$93,149,898',
#   '2002'],
#  'Cinderella': ['/title/tt0042332/?ref_=bo_cso_table_15',
#   '815',
#   'Cinderella',
#   '$93,141,149',
#   '1950'],
#  'When Harry Met Sally...': ['/title/tt0098635/?ref_=bo_cso_table_16',
#   '816',
#   'When Harry Met Sally...',
#   '$93,075,866',
#   '1989'],
#  'Elysium': ['/title/tt1535108/?ref_=bo_cso_table_17',
#   '817',
#   'Elysium',
#   '$93,050,117',
#   '2013'],
#  'Flubber': ['/title/tt0119137/?ref_=bo_cso_table_18',
#   '818',
#   'Flubber',
#   '$92,977,226',
#   '1997'],
#  'Flashdance': ['/title/tt0085549/?ref_=bo_cso_table_19',
#   '819',
#   'Flashdance',
#   '$92,921,203',
#   '1983'],
#  'The Town': ['/title/tt0840361/?ref_=bo_cso_table_20',
#   '820',
#   'The Town',
#   '$92,186,262',
#   '2010'],
#  'Non-Stop': ['/title/tt2024469/?ref_=bo_cso_table_21',
#   '821',
#   'Non-Stop',
#   '$92,168,600',
#   '2014'],
#  'The Client': ['/title/tt0109446/?ref_=bo_cso_table_22',
#   '822',
#   'The Client',
#   '$92,115,211',
#   '1994'],
#  'Blade Runner 2049': ['/title/tt1856101/?ref_=bo_cso_table_23',
#   '823',
#   'Blade Runner 2049',
#   '$92,054,159',
#   '2017'],
#  'John Wick: Chapter 2': ['/title/tt4425200/?ref_=bo_cso_table_24',
#   '824',
#   'John Wick: Chapter 2',
#   '$92,029,184',
#   '2017'],
#  'Star Trek: First Contact': ['/title/tt0117731/?ref_=bo_cso_table_25',
#   '825',
#   'Star Trek: First Contact',
#   '$92,027,888',
#   '1996'],
#  'Think Like a Man': ['/title/tt1621045/?ref_=bo_cso_table_26',
#   '826',
#   'Think Like a Man',
#   '$91,547,205',
#   '2012'],
#  'Kindergarten Cop': ['/title/tt0099938/?ref_=bo_cso_table_27',
#   '827',
#   'Kindergarten Cop',
#   '$91,457,688',
#   '1990'],
#  'Heaven Is for Real': ['/title/tt1929263/?ref_=bo_cso_table_28',
#   '828',
#   'Heaven Is for Real',
#   '$91,443,253',
#   '2014'],
#  'The Haunting': ['/title/tt0171363/?ref_=bo_cso_table_29',
#   '829',
#   'The Haunting',
#   '$91,411,151',
#   '1999'],
#  'Crimson Tide': ['/title/tt0112740/?ref_=bo_cso_table_30',
#   '830',
#   'Crimson Tide',
#   '$91,387,195',
#   '1995'],
#  'Back to School': ['/title/tt0090685/?ref_=bo_cso_table_31',
#   '831',
#   'Back to School',
#   '$91,258,000',
#   '1986'],
#  'Ride Along 2': ['/title/tt2869728/?ref_=bo_cso_table_32',
#   '832',
#   'Ride Along 2',
#   '$91,221,830',
#   '2016'],
#  'Stepmom': ['/title/tt0120686/?ref_=bo_cso_table_33',
#   '833',
#   'Stepmom',
#   '$91,137,662',
#   '1998'],
#  'The Imitation Game': ['/title/tt2084970/?ref_=bo_cso_table_34',
#   '834',
#   'The Imitation Game',
#   '$91,125,683',
#   '2014'],
#  'The Karate Kid': ['/title/tt0087538/?ref_=bo_cso_table_35',
#   '835',
#   'The Karate Kid',
#   '$91,077,276',
#   '1984'],
#  'Save the Last Dance': ['/title/tt0206275/?ref_=bo_cso_table_36',
#   '836',
#   'Save the Last Dance',
#   '$91,057,006',
#   '2001'],
#  'The Scorpion King': ['/title/tt0277296/?ref_=bo_cso_table_37',
#   '837',
#   'The Scorpion King',
#   '$91,047,077',
#   '2002'],
#  'Prince of Persia: The Sands of Time': ['/title/tt0473075/?ref_=bo_cso_table_38',
#   '838',
#   'Prince of Persia: The Sands of Time',
#   '$90,759,676',
#   '2010'],
#  'Antz': ['/title/tt0120587/?ref_=bo_cso_table_39',
#   '839',
#   'Antz',
#   '$90,757,863',
#   '1998'],
#  'Scary Movie 4': ['/title/tt0362120/?ref_=bo_cso_table_40',
#   '840',
#   'Scary Movie 4',
#   '$90,710,620',
#   '2006'],
#  'The Game Plan': ['/title/tt0492956/?ref_=bo_cso_table_41',
#   '841',
#   'The Game Plan',
#   '$90,648,202',
#   '2007'],
#  'Me, Myself & Irene': ['/title/tt0183505/?ref_=bo_cso_table_42',
#   '842',
#   'Me, Myself & Irene',
#   '$90,570,999',
#   '2000'],
#  'High School Musical 3': ['/title/tt0962726/?ref_=bo_cso_table_43',
#   '843',
#   'High School Musical 3',
#   '$90,559,416',
#   '2008'],
#  'Madea Goes to Jail': ['/title/tt1142800/?ref_=bo_cso_table_44',
#   '844',
#   'Madea Goes to Jail',
#   '$90,508,336',
#   '2009'],
#  'Space Cowboys': ['/title/tt0186566/?ref_=bo_cso_table_45',
#   '845',
#   'Space Cowboys',
#   '$90,464,773',
#   '2000'],
#  'Space Jam': ['/title/tt0117705/?ref_=bo_cso_table_46',
#   '846',
#   'Space Jam',
#   '$90,418,342',
#   '1996'],
#  'Get Hard': ['/title/tt2561572/?ref_=bo_cso_table_47',
#   '847',
#   'Get Hard',
#   '$90,411,453',
#   '2015'],
#  'Trading Places': ['/title/tt0086465/?ref_=bo_cso_table_48',
#   '848',
#   'Trading Places',
#   '$90,404,800',
#   '1983'],
#  'RED': ['/title/tt1245526/?ref_=bo_cso_table_49',
#   '849',
#   'RED',
#   '$90,380,162',
#   '2010'],
#  'Planes': ['/title/tt1691917/?ref_=bo_cso_table_50',
#   '850',
#   'Planes',
#   '$90,288,712',
#   '2013'],
#  'Legally Blonde 2': ['/title/tt0333780/?ref_=bo_cso_table_51',
#   '851',
#   'Legally Blonde 2',
#   '$90,186,328',
#   '2003'],
#  'Mystic River': ['/title/tt0327056/?ref_=bo_cso_table_52',
#   '852',
#   'Mystic River',
#   '$90,135,191',
#   '2003'],
#  'Terminator Genisys': ['/title/tt1340138/?ref_=bo_cso_table_53',
#   '853',
#   'Terminator Genisys',
#   '$89,760,956',
#   '2015'],
#  'Flightplan': ['/title/tt0408790/?ref_=bo_cso_table_54',
#   '854',
#   'Flightplan',
#   '$89,707,299',
#   '2005'],
#  "The Emperor's New Groove": ['/title/tt0120917/?ref_=bo_cso_table_55',
#   '855',
#   "The Emperor's New Groove",
#   '$89,521,687',
#   '2000'],
#  'Father of the Bride': ['/title/tt0101862/?ref_=bo_cso_table_56',
#   '856',
#   'Father of the Bride',
#   '$89,325,780',
#   '1991'],
#  'The Lone Ranger': ['/title/tt1210819/?ref_=bo_cso_table_57',
#   '857',
#   'The Lone Ranger',
#   '$89,302,115',
#   '2013'],
#  'Taken 3': ['/title/tt2446042/?ref_=bo_cso_table_58',
#   '858',
#   'Taken 3',
#   '$89,256,424',
#   '2015'],
#  "Don't Breathe": ['/title/tt4160708/?ref_=bo_cso_table_59',
#   '859',
#   "Don't Breathe",
#   '$89,217,875',
#   '2016'],
#  'Scream 3': ['/title/tt0134084/?ref_=bo_cso_table_60',
#   '860',
#   'Scream 3',
#   '$89,143,175',
#   '2000'],
#  'Oblivion': ['/title/tt1483013/?ref_=bo_cso_table_61',
#   '861',
#   'Oblivion',
#   '$89,107,235',
#   '2013'],
#  'The Ugly Truth': ['/title/tt1142988/?ref_=bo_cso_table_62',
#   '862',
#   'The Ugly Truth',
#   '$88,915,214',
#   '2009'],
#  'Percy Jackson & the Olympians: The Lightning Thief': ['/title/tt0814255/?ref_=bo_cso_table_63',
#   '863',
#   'Percy Jackson & the Olympians: The Lightning Thief',
#   '$88,768,303',
#   '2010'],
#  'Failure to Launch': ['/title/tt0427229/?ref_=bo_cso_table_64',
#   '864',
#   'Failure to Launch',
#   '$88,715,192',
#   '2006'],
#  'The Muppets': ['/title/tt1204342/?ref_=bo_cso_table_65',
#   '865',
#   'The Muppets',
#   '$88,631,237',
#   '2011'],
#  'Inside Man': ['/title/tt0454848/?ref_=bo_cso_table_66',
#   '866',
#   'Inside Man',
#   '$88,513,495',
#   '2006'],
#  'Back to the Future Part III': ['/title/tt0099088/?ref_=bo_cso_table_67',
#   '867',
#   'Back to the Future Part III',
#   '$88,277,583',
#   '1990'],
#  'Waterworld': ['/title/tt0114898/?ref_=bo_cso_table_68',
#   '868',
#   'Waterworld',
#   '$88,246,220',
#   '1995'],
#  'Starsky & Hutch': ['/title/tt0335438/?ref_=bo_cso_table_69',
#   '869',
#   'Starsky & Hutch',
#   '$88,237,754',
#   '2004'],
#  'Along Came Polly': ['/title/tt0343135/?ref_=bo_cso_table_70',
#   '870',
#   'Along Came Polly',
#   '$88,097,164',
#   '2004'],
#  'The Hand That Rocks the Cradle': ['/title/tt0104389/?ref_=bo_cso_table_71',
#   '871',
#   'The Hand That Rocks the Cradle',
#   '$88,036,683',
#   '1992'],
#  'Entrapment': ['/title/tt0137494/?ref_=bo_cso_table_72',
#   '872',
#   'Entrapment',
#   '$87,704,396',
#   '1999'],
#  'Peter Pan': ['/title/tt0046183/?ref_=bo_cso_table_73',
#   '873',
#   'Peter Pan',
#   '$87,404,651',
#   '1953'],
#  'Pineapple Express': ['/title/tt0910936/?ref_=bo_cso_table_74',
#   '874',
#   'Pineapple Express',
#   '$87,341,380',
#   '2008'],
#  "Miss Peregrine's Home for Peculiar Children": ['/title/tt1935859/?ref_=bo_cso_table_75',
#   '875',
#   "Miss Peregrine's Home for Peculiar Children",
#   '$87,242,834',
#   '2016'],
#  'Everest': ['/title/tt0120661/?ref_=bo_cso_table_76',
#   '876',
#   'Everest',
#   '$87,178,599',
#   '1998'],
#  'Out of Africa': ['/title/tt0089755/?ref_=bo_cso_table_77',
#   '877',
#   'Out of Africa',
#   '$87,071,205',
#   '1985'],
#  'Sisters': ['/title/tt1850457/?ref_=bo_cso_table_78',
#   '878',
#   'Sisters',
#   '$87,044,645',
#   '2015'],
#  'Saw II': ['/title/tt0432348/?ref_=bo_cso_table_79',
#   '879',
#   'Saw II',
#   '$87,039,965',
#   '2005'],
#  'The Naked Gun 2½: The Smell of Fear': ['/title/tt0102510/?ref_=bo_cso_table_80',
#   '880',
#   'The Naked Gun 2½: The Smell of Fear',
#   '$86,930,411',
#   '1991'],
#  'The Campaign': ['/title/tt1790886/?ref_=bo_cso_table_81',
#   '881',
#   'The Campaign',
#   '$86,907,746',
#   '2012'],
#  'The War of the Roses': ['/title/tt0098621/?ref_=bo_cso_table_82',
#   '882',
#   'The War of the Roses',
#   '$86,888,546',
#   '1989'],
#  'The Amityville Horror': ['/title/tt0078767/?ref_=bo_cso_table_83',
#   '883',
#   'The Amityville Horror',
#   '$86,432,000',
#   '1979'],
#  'Presumed Innocent': ['/title/tt0100404/?ref_=bo_cso_table_84',
#   '884',
#   'Presumed Innocent',
#   '$86,303,188',
#   '1990'],
#  'Young Frankenstein': ['/title/tt0072431/?ref_=bo_cso_table_85',
#   '885',
#   'Young Frankenstein',
#   '$86,273,333',
#   '1974'],
#  'The Accountant': ['/title/tt2140479/?ref_=bo_cso_table_86',
#   '886',
#   'The Accountant',
#   '$86,260,045',
#   '2016'],
#  'Dumb and Dumber To': ['/title/tt2096672/?ref_=bo_cso_table_87',
#   '887',
#   'Dumb and Dumber To',
#   '$86,208,010',
#   '2014'],
#  'The Emoji Movie': ['/title/tt4877122/?ref_=bo_cso_table_88',
#   '888',
#   'The Emoji Movie',
#   '$86,089,513',
#   '2017'],
#  'Mean Girls': ['/title/tt0377092/?ref_=bo_cso_table_89',
#   '889',
#   'Mean Girls',
#   '$86,058,055',
#   '2004'],
#  'Annie': ['/title/tt1823664/?ref_=bo_cso_table_90',
#   '890',
#   'Annie',
#   '$85,911,262',
#   '2014'],
#  'Alvin and the Chipmunks: The Road Chip': ['/title/tt2974918/?ref_=bo_cso_table_91',
#   '891',
#   'Alvin and the Chipmunks: The Road Chip',
#   '$85,886,987',
#   '2015'],
#  'Spy Kids 2: Island of Lost Dreams': ['/title/tt0287717/?ref_=bo_cso_table_92',
#   '892',
#   'Spy Kids 2: Island of Lost Dreams',
#   '$85,846,429',
#   '2002'],
#  'Alita: Battle Angel': ['/title/tt0437086/?ref_=bo_cso_table_93',
#   '893',
#   'Alita: Battle Angel',
#   '$85,838,210',
#   '2019'],
#  'Fury': ['/title/tt2713180/?ref_=bo_cso_table_94',
#   '894',
#   'Fury',
#   '$85,817,906',
#   '2014'],
#  'Pokémon: The First Movie - Mewtwo Strikes Back': ['/title/tt0190641/?ref_=bo_cso_table_95',
#   '895',
#   'Pokémon: The First Movie - Mewtwo Strikes Back',
#   '$85,744,662',
#   '1999'],
#  'Real Steel': ['/title/tt0433035/?ref_=bo_cso_table_96',
#   '896',
#   'Real Steel',
#   '$85,468,508',
#   '2011'],
#  'The SpongeBob SquarePants Movie': ['/title/tt0345950/?ref_=bo_cso_table_97',
#   '897',
#   'The SpongeBob SquarePants Movie',
#   '$85,417,988',
#   '2004'],
#  'Power Rangers': ['/title/tt3717490/?ref_=bo_cso_table_98',
#   '898',
#   'Power Rangers',
#   '$85,364,450',
#   '2017'],
#  'Brother Bear': ['/title/tt0328880/?ref_=bo_cso_table_99',
#   '899',
#   'Brother Bear',
#   '$85,336,277',
#   '2003'],
#  'Stripes': ['/title/tt0083131/?ref_=bo_cso_table_100',
#   '900',
#   'Stripes',
#   '$85,297,000',
#   '1981'],
#  'Anchorman: The Legend of Ron Burgundy': ['/title/tt0357413/?ref_=bo_cso_table_101',
#   '901',
#   'Anchorman: The Legend of Ron Burgundy',
#   '$85,288,303',
#   '2004'],
#  'Every Which Way but Loose': ['/title/tt0077523/?ref_=bo_cso_table_102',
#   '902',
#   'Every Which Way but Loose',
#   '$85,196,485',
#   '1978'],
#  'Rocky II': ['/title/tt0079817/?ref_=bo_cso_table_103',
#   '903',
#   'Rocky II',
#   '$85,182,160',
#   '1979'],
#  'Aliens': ['/title/tt0090605/?ref_=bo_cso_table_104',
#   '904',
#   'Aliens',
#   '$85,160,248',
#   '1986'],
#  'Open Season': ['/title/tt0400717/?ref_=bo_cso_table_105',
#   '905',
#   'Open Season',
#   '$85,105,259',
#   '2006'],
#  'Green Book': ['/title/tt6966692/?ref_=bo_cso_table_106',
#   '906',
#   'Green Book',
#   '$85,080,171',
#   '2018'],
#  'The Expendables 2': ['/title/tt1764651/?ref_=bo_cso_table_107',
#   '907',
#   'The Expendables 2',
#   '$85,028,192',
#   '2012'],
#  'Dangerous Minds': ['/title/tt0112792/?ref_=bo_cso_table_108',
#   '908',
#   'Dangerous Minds',
#   '$84,919,401',
#   '1995'],
#  'Paranormal Activity 2': ['/title/tt1536044/?ref_=bo_cso_table_109',
#   '909',
#   'Paranormal Activity 2',
#   '$84,752,907',
#   '2010'],
#  'Steel Magnolias': ['/title/tt0098384/?ref_=bo_cso_table_110',
#   '910',
#   'Steel Magnolias',
#   '$84,614,512',
#   '1989'],
#  'The Poseidon Adventure': ['/title/tt0069113/?ref_=bo_cso_table_111',
#   '911',
#   'The Poseidon Adventure',
#   '$84,563,118',
#   '1972'],
#  'Tammy': ['/title/tt2103254/?ref_=bo_cso_table_112',
#   '912',
#   'Tammy',
#   '$84,525,432',
#   '2014'],
#  'The Santa Clause 3: The Escape Clause': ['/title/tt0452681/?ref_=bo_cso_table_113',
#   '913',
#   'The Santa Clause 3: The Escape Clause',
#   '$84,500,122',
#   '2006'],
#  'Ferdinand': ['/title/tt3411444/?ref_=bo_cso_table_114',
#   '914',
#   'Ferdinand',
#   '$84,410,380',
#   '2017'],
#  'Crazy, Stupid, Love.': ['/title/tt1570728/?ref_=bo_cso_table_115',
#   '915',
#   'Crazy, Stupid, Love.',
#   '$84,351,197',
#   '2011'],
#  'Annabelle': ['/title/tt3322940/?ref_=bo_cso_table_116',
#   '916',
#   'Annabelle',
#   '$84,273,813',
#   '2014'],
#  'Pinocchio': ['/title/tt0032910/?ref_=bo_cso_table_117',
#   '917',
#   'Pinocchio',
#   '$84,254,167',
#   '1940'],
#  'Scooby-Doo 2: Monsters Unleashed': ['/title/tt0331632/?ref_=bo_cso_table_118',
#   '918',
#   'Scooby-Doo 2: Monsters Unleashed',
#   '$84,216,833',
#   '2004'],
#  'Birds of Prey': ['/title/tt7713068/?ref_=bo_cso_table_119',
#   '919',
#   'Birds of Prey',
#   '$84,158,461',
#   '2020'],
#  'Atlantis: The Lost Empire': ['/title/tt0230011/?ref_=bo_cso_table_120',
#   '920',
#   'Atlantis: The Lost Empire',
#   '$84,056,472',
#   '2001'],
#  'Cliffhanger': ['/title/tt0106582/?ref_=bo_cso_table_121',
#   '921',
#   'Cliffhanger',
#   '$84,049,211',
#   '1993'],
#  'The Other Woman': ['/title/tt2203939/?ref_=bo_cso_table_122',
#   '922',
#   'The Other Woman',
#   '$83,911,193',
#   '2014'],
#  'The X Files': ['/title/tt0120902/?ref_=bo_cso_table_123',
#   '923',
#   'The X Files',
#   '$83,898,313',
#   '1998'],
#  'Penguins of Madagascar': ['/title/tt1911658/?ref_=bo_cso_table_124',
#   '924',
#   'Penguins of Madagascar',
#   '$83,850,911',
#   '2014'],
#  'Die Hard': ['/title/tt0095016/?ref_=bo_cso_table_125',
#   '925',
#   'Die Hard',
#   '$83,844,093',
#   '1988'],
#  'Up in the Air': ['/title/tt1193138/?ref_=bo_cso_table_126',
#   '926',
#   'Up in the Air',
#   '$83,823,381',
#   '2009'],
#  'Wrath of the Titans': ['/title/tt1646987/?ref_=bo_cso_table_127',
#   '927',
#   'Wrath of the Titans',
#   '$83,670,083',
#   '2012'],
#  'Insidious: Chapter 2': ['/title/tt2226417/?ref_=bo_cso_table_128',
#   '928',
#   'Insidious: Chapter 2',
#   '$83,586,447',
#   '2013'],
#  'Under Siege': ['/title/tt0105690/?ref_=bo_cso_table_129',
#   '929',
#   'Under Siege',
#   '$83,563,139',
#   '1992'],
#  'Battle Los Angeles': ['/title/tt1217613/?ref_=bo_cso_table_130',
#   '930',
#   'Battle Los Angeles',
#   '$83,552,429',
#   '2011'],
#  'Immortals': ['/title/tt1253864/?ref_=bo_cso_table_131',
#   '931',
#   'Immortals',
#   '$83,504,017',
#   '2011'],
#  'I Can Only Imagine': ['/title/tt6450186/?ref_=bo_cso_table_132',
#   '932',
#   'I Can Only Imagine',
#   '$83,482,352',
#   '2018'],
#  'Apocalypse Now': ['/title/tt0078788/?ref_=bo_cso_table_133',
#   '933',
#   'Apocalypse Now',
#   '$83,471,511',
#   '1979'],
#  'Airplane!': ['/title/tt0080339/?ref_=bo_cso_table_134',
#   '934',
#   'Airplane!',
#   '$83,453,539',
#   '1980'],
#  'Patriot Games': ['/title/tt0105112/?ref_=bo_cso_table_135',
#   '935',
#   'Patriot Games',
#   '$83,351,587',
#   '1992'],
#  'Saving Mr. Banks': ['/title/tt2140373/?ref_=bo_cso_table_136',
#   '936',
#   'Saving Mr. Banks',
#   '$83,301,580',
#   '2013'],
#  'Smallfoot': ['/title/tt6182908/?ref_=bo_cso_table_137',
#   '937',
#   'Smallfoot',
#   '$83,240,103',
#   '2018'],
#  'Good Boys': ['/title/tt6977338/?ref_=bo_cso_table_138',
#   '938',
#   'Good Boys',
#   '$83,140,306',
#   '2019'],
#  'Valkyrie': ['/title/tt0985699/?ref_=bo_cso_table_139',
#   '939',
#   'Valkyrie',
#   '$83,077,833',
#   '2008'],
#  'Brokeback Mountain': ['/title/tt0388795/?ref_=bo_cso_table_140',
#   '940',
#   'Brokeback Mountain',
#   '$83,043,761',
#   '2005'],
#  'Turbo': ['/title/tt1860353/?ref_=bo_cso_table_141',
#   '941',
#   'Turbo',
#   '$83,028,128',
#   '2013'],
#  'Disclosure': ['/title/tt0109635/?ref_=bo_cso_table_142',
#   '942',
#   'Disclosure',
#   '$83,015,089',
#   '1994'],
#  "Charlotte's Web": ['/title/tt0413895/?ref_=bo_cso_table_143',
#   '943',
#   "Charlotte's Web",
#   '$82,985,708',
#   '2006'],
#  'Monster-in-Law': ['/title/tt0369735/?ref_=bo_cso_table_144',
#   '944',
#   'Monster-in-Law',
#   '$82,931,301',
#   '2005'],
#  'Are We There Yet?': ['/title/tt0368578/?ref_=bo_cso_table_145',
#   '945',
#   'Are We There Yet?',
#   '$82,674,398',
#   '2005'],
#  'Days of Thunder': ['/title/tt0099371/?ref_=bo_cso_table_146',
#   '946',
#   'Days of Thunder',
#   '$82,670,733',
#   '1990'],
#  'Freddy vs. Jason': ['/title/tt0329101/?ref_=bo_cso_table_147',
#   '947',
#   'Freddy vs. Jason',
#   '$82,622,655',
#   '2003'],
#  'Star Trek: The Motion Picture': ['/title/tt0079945/?ref_=bo_cso_table_148',
#   '948',
#   'Star Trek: The Motion Picture',
#   '$82,604,699',
#   '1979'],
#  'The Descendants': ['/title/tt1033575/?ref_=bo_cso_table_149',
#   '949',
#   'The Descendants',
#   '$82,584,160',
#   '2011'],
#  'Cheaper by the Dozen 2': ['/title/tt0452598/?ref_=bo_cso_table_150',
#   '950',
#   'Cheaper by the Dozen 2',
#   '$82,571,173',
#   '2005'],
#  "Mr. Holland's Opus": ['/title/tt0113862/?ref_=bo_cso_table_151',
#   '951',
#   "Mr. Holland's Opus",
#   '$82,569,971',
#   '1995'],
#  "Bram Stoker's Dracula": ['/title/tt0103874/?ref_=bo_cso_table_152',
#   '952',
#   "Bram Stoker's Dracula",
#   '$82,522,790',
#   '1992'],
#  'Fried Green Tomatoes': ['/title/tt0101921/?ref_=bo_cso_table_153',
#   '953',
#   'Fried Green Tomatoes',
#   '$82,418,501',
#   '1991'],
#  "Let's Be Cops": ['/title/tt1924435/?ref_=bo_cso_table_154',
#   '954',
#   "Let's Be Cops",
#   '$82,390,774',
#   '2014'],
#  'Blade II': ['/title/tt0187738/?ref_=bo_cso_table_155',
#   '955',
#   'Blade II',
#   '$82,348,319',
#   '2002'],
#  'Beowulf': ['/title/tt0442933/?ref_=bo_cso_table_156',
#   '956',
#   'Beowulf',
#   '$82,280,579',
#   '2007'],
#  'Bridge to Terabithia': ['/title/tt0398808/?ref_=bo_cso_table_157',
#   '957',
#   'Bridge to Terabithia',
#   '$82,272,442',
#   '2007'],
#  'The Pink Panther': ['/title/tt0383216/?ref_=bo_cso_table_158',
#   '958',
#   'The Pink Panther',
#   '$82,226,474',
#   '2006'],
#  'Teenage Mutant Ninja Turtles: Out of the Shadows': ['/title/tt3949660/?ref_=bo_cso_table_159',
#   '959',
#   'Teenage Mutant Ninja Turtles: Out of the Shadows',
#   '$82,051,601',
#   '2016'],
#  'The Post': ['/title/tt6294822/?ref_=bo_cso_table_160',
#   '960',
#   'The Post',
#   '$81,903,458',
#   '2017'],
#  'Alien': ['/title/tt0078748/?ref_=bo_cso_table_161',
#   '961',
#   'Alien',
#   '$81,900,459',
#   '1979'],
#  'Jaws 2': ['/title/tt0077766/?ref_=bo_cso_table_162',
#   '962',
#   'Jaws 2',
#   '$81,766,007',
#   '1978'],
#  'Maze Runner: The Scorch Trials': ['/title/tt4046784/?ref_=bo_cso_table_163',
#   '963',
#   'Maze Runner: The Scorch Trials',
#   '$81,697,192',
#   '2015'],
#  'Heaven Can Wait': ['/title/tt0077663/?ref_=bo_cso_table_164',
#   '964',
#   'Heaven Can Wait',
#   '$81,640,278',
#   '1978'],
#  'Eight Below': ['/title/tt0397313/?ref_=bo_cso_table_165',
#   '965',
#   'Eight Below',
#   '$81,612,565',
#   '2006'],
#  'MASH': ['/title/tt0066026/?ref_=bo_cso_table_166',
#   '966',
#   'MASH',
#   '$81,600,000',
#   '1970'],
#  'Unstoppable': ['/title/tt0477080/?ref_=bo_cso_table_167',
#   '967',
#   'Unstoppable',
#   '$81,562,942',
#   '2010'],
#  'Payback': ['/title/tt0120784/?ref_=bo_cso_table_168',
#   '968',
#   'Payback',
#   '$81,526,121',
#   '1999'],
#  'Ted 2': ['/title/tt2637276/?ref_=bo_cso_table_169',
#   '969',
#   'Ted 2',
#   '$81,476,385',
#   '2015'],
#  'The Talented Mr. Ripley': ['/title/tt0134119/?ref_=bo_cso_table_170',
#   '970',
#   'The Talented Mr. Ripley',
#   '$81,298,265',
#   '1999'],
#  'School of Rock': ['/title/tt0332379/?ref_=bo_cso_table_171',
#   '971',
#   'School of Rock',
#   '$81,261,177',
#   '2003'],
#  'Police Academy': ['/title/tt0087928/?ref_=bo_cso_table_172',
#   '972',
#   'Police Academy',
#   '$81,198,894',
#   '1984'],
#  'Snow Dogs': ['/title/tt0281373/?ref_=bo_cso_table_173',
#   '973',
#   'Snow Dogs',
#   '$81,172,560',
#   '2002'],
#  '21': ['/title/tt0478087/?ref_=bo_cso_table_174',
#   '974',
#   '21',
#   '$81,159,365',
#   '2008'],
#  'While You Were Sleeping': ['/title/tt0114924/?ref_=bo_cso_table_175',
#   '975',
#   'While You Were Sleeping',
#   '$81,057,016',
#   '1995'],
#  'Congo': ['/title/tt0112715/?ref_=bo_cso_table_176',
#   '976',
#   'Congo',
#   '$81,022,101',
#   '1995'],
#  'The Notebook': ['/title/tt0332280/?ref_=bo_cso_table_177',
#   '977',
#   'The Notebook',
#   '$81,001,787',
#   '2004'],
#  'Jimmy Neutron: Boy Genius': ['/title/tt0268397/?ref_=bo_cso_table_178',
#   '978',
#   'Jimmy Neutron: Boy Genius',
#   '$80,936,232',
#   '2001'],
#  'Another 48 Hrs.': ['/title/tt0099044/?ref_=bo_cso_table_179',
#   '979',
#   'Another 48 Hrs.',
#   '$80,818,974',
#   '1990'],
#  'Moonstruck': ['/title/tt0093565/?ref_=bo_cso_table_180',
#   '980',
#   'Moonstruck',
#   '$80,640,528',
#   '1987'],
#  'Eat Pray Love': ['/title/tt0879870/?ref_=bo_cso_table_181',
#   '981',
#   'Eat Pray Love',
#   '$80,574,010',
#   '2010'],
#  'The Texas Chainsaw Massacre': ['/title/tt0324216/?ref_=bo_cso_table_182',
#   '982',
#   'The Texas Chainsaw Massacre',
#   '$80,571,655',
#   '2003'],
#  'Zookeeper': ['/title/tt1222817/?ref_=bo_cso_table_183',
#   '983',
#   'Zookeeper',
#   '$80,360,843',
#   '2011'],
#  'Alien vs. Predator': ['/title/tt0370263/?ref_=bo_cso_table_184',
#   '984',
#   'Alien vs. Predator',
#   '$80,282,231',
#   '2004'],
#  'What Happens in Vegas': ['/title/tt1033643/?ref_=bo_cso_table_185',
#   '985',
#   'What Happens in Vegas',
#   '$80,277,646',
#   '2008'],
#  'The Dukes of Hazzard': ['/title/tt0377818/?ref_=bo_cso_table_186',
#   '986',
#   'The Dukes of Hazzard',
#   '$80,270,227',
#   '2005'],
#  'The Wedding Singer': ['/title/tt0120888/?ref_=bo_cso_table_187',
#   '987',
#   'The Wedding Singer',
#   '$80,245,725',
#   '1998'],
#  'Saw III': ['/title/tt0489270/?ref_=bo_cso_table_188',
#   '988',
#   'Saw III',
#   '$80,238,724',
#   '2006'],
#  'The Mummy': ['/title/tt2345759/?ref_=bo_cso_table_189',
#   '989',
#   'The Mummy',
#   '$80,227,895',
#   '2017'],
#  'Disturbia': ['/title/tt0486822/?ref_=bo_cso_table_190',
#   '990',
#   'Disturbia',
#   '$80,209,692',
#   '2007'],
#  'Nacho Libre': ['/title/tt0457510/?ref_=bo_cso_table_191',
#   '991',
#   'Nacho Libre',
#   '$80,197,993',
#   '2006'],
#  'Jumper': ['/title/tt0489099/?ref_=bo_cso_table_192',
#   '992',
#   'Jumper',
#   '$80,172,128',
#   '2008'],
#  'Goosebumps': ['/title/tt1051904/?ref_=bo_cso_table_193',
#   '993',
#   'Goosebumps',
#   '$80,080,379',
#   '2015'],
#  'Jack Reacher': ['/title/tt0790724/?ref_=bo_cso_table_194',
#   '994',
#   'Jack Reacher',
#   '$80,070,736',
#   '2012'],
#  'Cloverfield': ['/title/tt1060277/?ref_=bo_cso_table_195',
#   '995',
#   'Cloverfield',
#   '$80,048,433',
#   '2008'],
#  'Footloose': ['/title/tt0087277/?ref_=bo_cso_table_196',
#   '996',
#   'Footloose',
#   '$80,035,402',
#   '1984'],
#  'Dear John': ['/title/tt0989757/?ref_=bo_cso_table_197',
#   '997',
#   'Dear John',
#   '$80,014,842',
#   '2010'],
#  'Men in Black: International': ['/title/tt2283336/?ref_=bo_cso_table_198',
#   '998',
#   'Men in Black: International',
#   '$80,001,807',
#   '2019'],
#  'A Star Is Born': ['/title/tt0075265/?ref_=bo_cso_table_199',
#   '999',
#   'A Star Is Born',
#   '$80,000,000',
#   '1976'],
#  'Knowing': ['/title/tt0448011/?ref_=bo_cso_table_200',
#   '1,000',
#   'Knowing',
#   '$79,957,634',
#   '2009']}

# %%
lifetime_movies = pd.DataFrame(movies).T
lifetime_movies.columns = ['link_stub', 'rank', 'title', 'domestic_gross','release_year']
lifetime_movies
# Out:
#                                                                                link_stub  \
# Maid in Manhattan                                  /title/tt0252076/?ref_=bo_cso_table_1
# He's Just Not That Into You                        /title/tt1001508/?ref_=bo_cso_table_2
# Master and Commander: The Far Side of the World    /title/tt0311113/?ref_=bo_cso_table_3
# Flight                                             /title/tt1907668/?ref_=bo_cso_table_4
# The Fighter                                        /title/tt0964517/?ref_=bo_cso_table_5
# ...                                                                                  ...
# Footloose                                        /title/tt0087277/?ref_=bo_cso_table_196
# Dear John                                        /title/tt0989757/?ref_=bo_cso_table_197
# Men in Black: International                      /title/tt2283336/?ref_=bo_cso_table_198
# A Star Is Born                                   /title/tt0075265/?ref_=bo_cso_table_199
# Knowing                                          /title/tt0448011/?ref_=bo_cso_table_200
#
#                                                   rank  \
# Maid in Manhattan                                  801
# He's Just Not That Into You                        802
# Master and Commander: The Far Side of the World    803
# Flight                                             804
# The Fighter                                        805
# ...                                                ...
# Footloose                                          996
# Dear John                                          997
# Men in Black: International                        998
# A Star Is Born                                     999
# Knowing                                          1,000
#
#                                                                                            title  \
# Maid in Manhattan                                                              Maid in Manhattan
# He's Just Not That Into You                                          He's Just Not That Into You
# Master and Commander: The Far Side of the World  Master and Commander: The Far Side of the World
# Flight                                                                                    Flight
# The Fighter                                                                          The Fighter
# ...                                                                                          ...
# Footloose                                                                              Footloose
# Dear John                                                                              Dear John
# Men in Black: International                                          Men in Black: International
# A Star Is Born                                                                    A Star Is Born
# Knowing                                                                                  Knowing
#
#                                                 domestic_gross release_year
# Maid in Manhattan                                  $94,011,225         2002
# He's Just Not That Into You                        $93,953,653         2009
# Master and Commander: The Far Side of the World    $93,927,920         2003
# Flight                                             $93,772,375         2012
# The Fighter                                        $93,617,009         2010
# ...                                                        ...          ...
# Footloose                                          $80,035,402         1984
# Dear John                                          $80,014,842         2010
# Men in Black: International                        $80,001,807         2019
# A Star Is Born                                     $80,000,000         1976
# Knowing                                            $79,957,634         2009
#
# [200 rows x 5 columns]

# %% [markdown]
# #### Storing movie page data into a dictionary

# %%
def get_movie_dict(link):
    """
    From BoxOfficeMojo link stub, request movie html, parse with BeautifulSoup, and
    collect 
        - title 
        - domestic gross
        - runtime 
        - MPAA rating
        - full release date
    Return information as a dictionary
    
    """
    
    base_url = 'https://www.boxofficemojo.com'
    
    #Create full url to scrape
    url = base_url + link
    
    #Request HTML and parse
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page,"lxml")
    
    headers = ['title', 'domestic_opening_gross', 'budget', 'domestic_gross', 'international_gross', 
               'worldwide_gross','runtime_minutes', 'rating', 'release_month', 'release_date','genres']
    
    #Get title
    title_string = soup.find('title').text
    title = title_string[:-18]

    #Get domestic gross
    raw_dom_gross = soup.find(class_='mojo-performance-summary-table').find_all('span',class_='money')[0].text
    domestic_gross = money_to_int(raw_dom_gross)
    
    #dom_gross = money_to_int(dom_gross)
    
    #Get international_gross   
    try:
        raw_intl_gross = soup.find(class_='mojo-performance-summary-table').find_all('span',class_='money')[1].text
        international_gross = money_to_int(raw_intl_gross)
    except:
        international_gross = 0
    
    #Get worldwide gross
    try:
        raw_world_gross = soup.find(class_='mojo-performance-summary-table').find_all('span',class_='money')[2].text
        worldwide_gross = money_to_int(raw_world_gross)
    except:
        worldwide_gross = 0
    
    #Get domestic opening gross
    try:
        raw_opening_gross = soup.find(class_='mojo-summary-values').find_all('span', class_ = 'money')[0].text
        domestic_opening_gross = money_to_int(raw_opening_gross)
    except:
        domestic_opening_gross = 0
    
    
    #Get budget
    try:
        raw_budget = soup.find(class_='mojo-summary-values').find_all('span', class_ = 'money')[1].text
        budget = money_to_int(raw_budget)
    except:
        budget = 0
    
    #Get distributor
    try:
        distributor = get_movie_value(soup, 'Distributor')[:18]
    except:
        distributor = ''
    
    #Get runtime
    raw_runtime = get_movie_value(soup, 'Running')
    runtime_minutes = runtime_to_minutes(raw_runtime)
    
    #Get rating
    rating = get_movie_value(soup, 'MPAA')
    
    #Get genres
    raw_genres = get_movie_value(soup, 'Genres').split()
    genres = ' '
    for e in raw_genres:
        genres += e+'\n '
        

    
    #Get release month
    raw_release_date = get_movie_value(soup,'Release Date').split('\n')[0]
    release_month = to_date(raw_release_date).month
   
    #Get release date
    raw_release_date = get_movie_value(soup,'Release Date').split('\n')[0]
    release_date = to_date(raw_release_date)
    
    
    #Create movie dictionary and return
    movie_dict = dict(zip(headers, [title,
                                    domestic_opening_gross,
                                    budget,
                                    domestic_gross,
                                    international_gross,
                                    worldwide_gross,
                                    runtime_minutes,
                                    rating,
                                    release_month,
                                    release_date,
                                    genres]))

    return movie_dict

# %%
lifetime_movie_data = []
for link in lifetime_movies.link_stub:
    lifetime_movie_data.append(get_movie_dict(link))

# %%
lifetime_movie_data
# Out:
# [{'title': 'Maid in Manhattan',
#   'domestic_opening_gross': 18711407,
#   'budget': 55000000,
#   'domestic_gross': 94011225,
#   'international_gross': 60895468,
#   'worldwide_gross': 154906693,
#   'runtime_minutes': 105,
#   'rating': 'PG-13',
#   'release_month': 12,
#   'release_date': datetime.datetime(2002, 12, 13, 0, 0),
#   'genres': ' Comedy\n Drama\n Romance\n '},
#  {'title': "He's Just Not That Into You",
#   'domestic_opening_gross': 27785487,
#   'budget': 0,
#   'domestic_gross': 93953653,
#   'international_gross': 84912505,
#   'worldwide_gross': 178866158,
#   'runtime_minutes': 129,
#   'rating': 'PG-13',
#   'release_month': 2,
#   'release_date': datetime.datetime(2009, 2, 5, 0, 0),
#   'genres': ' Comedy\n Drama\n Romance\n '},
#  {'title': 'Master and Commander: The Far Side of the World',
#   'domestic_opening_gross': 25105990,
#   'budget': 150000000,
#   'domestic_gross': 93927920,
#   'international_gross': 117694615,
#   'worldwide_gross': 211622535,
#   'runtime_minutes': 138,
#   'rating': 'PG-13',
#   'release_month': 11,
#   'release_date': datetime.datetime(2003, 11, 14, 0, 0),
#   'genres': ' Action\n Adventure\n Drama\n History\n War\n '},
#  {'title': 'Flight',
#   'domestic_opening_gross': 24900566,
#   'budget': 31000000,
#   'domestic_gross': 93772375,
#   'international_gross': 68000000,
#   'worldwide_gross': 161772375,
#   'runtime_minutes': 138,
#   'rating': 'R',
#   'release_month': 11,
#   'release_date': datetime.datetime(2012, 11, 2, 0, 0),
#   'genres': ' Drama\n Thriller\n '},
#  {'title': 'The Fighter',
#   'domestic_opening_gross': 300010,
#   'budget': 25000000,
#   'domestic_gross': 93617009,
#   'international_gross': 35573860,
#   'worldwide_gross': 129190869,
#   'runtime_minutes': 116,
#   'rating': 'R',
#   'release_month': 11,
#   'release_date': datetime.datetime(2009, 11, 20, 0, 0),
#   'genres': ' Biography\n Drama\n Sport\n '},
#  {'title': "America's Sweethearts",
#   'domestic_opening_gross': 30181877,
#   'budget': 46000000,
#   'domestic_gross': 93607673,
#   'international_gross': 44700000,
#   'worldwide_gross': 138307673,
#   'runtime_minutes': 102,
#   'rating': 'PG-13',
#   'release_month': 7,
#   'release_date': datetime.datetime(2001, 7, 20, 0, 0),
#   'genres': ' Comedy\n Romance\n '},
#  {'title': 'Lady and the Tramp',
#   'domestic_opening_gross': 4000000,
#   'budget': 0,
#   'domestic_gross': 93602326,
#   'international_gross': 331068,
#   'worldwide_gross': 93933394,
#   'runtime_minutes': 76,
#   'rating': 'G',
#   'release_month': 6,
#   'release_date': datetime.datetime(1955, 6, 22, 0, 0),
#   'genres': ' Adventure\n Animation\n Comedy\n Drama\n Family\n Romance\n '},
#  {'title': 'The Bucket List',
#   'domestic_opening_gross': 335837,
#   'budget': 45000000,
#   'domestic_gross': 93466502,
#   'international_gross': 81906000,
#   'worldwide_gross': 175372502,
#   'runtime_minutes': 97,
#   'rating': 'PG-13',
#   'release_month': 12,
#   'release_date': datetime.datetime(2007, 12, 25, 0, 0),
#   'genres': ' Adventure\n Comedy\n Drama\n '},
#  {'title': 'Tomorrowland',
#   'domestic_opening_gross': 33028165,
#   'budget': 190000000,
#   'domestic_gross': 93436322,
#   'international_gross': 115599346,
#   'worldwide_gross': 209035668,
#   'runtime_minutes': 130,
#   'rating': 'PG',
#   'release_month': 5,
#   'release_date': datetime.datetime(2015, 5, 20, 0, 0),
#   'genres': ' Action\n Adventure\n Family\n Fantasy\n Mystery\n Sci-Fi\n '},
#  {'title': 'The Magnificent Seven',
#   'domestic_opening_gross': 34703397,
#   'budget': 90000000,
#   'domestic_gross': 93432655,
#   'international_gross': 68927981,
#   'worldwide_gross': 162360636,
#   'runtime_minutes': 132,
#   'rating': 'PG-13',
#   'release_month': 9,
#   'release_date': datetime.datetime(2016, 9, 14, 0, 0),
#   'genres': ' Action\n Adventure\n Western\n '},
#  {'title': 'Cats & Dogs',
#   'domestic_opening_gross': 21707617,
#   'budget': 60000000,
#   'domestic_gross': 93385515,
#   'international_gross': 107301977,
#   'worldwide_gross': 200687492,
#   'runtime_minutes': 87,
#   'rating': 'PG',
#   'release_month': 7,
#   'release_date': datetime.datetime(2001, 7, 4, 0, 0),
#   'genres': ' Action\n Comedy\n Family\n Fantasy\n '},
#  {'title': 'Space Station 3D',
#   'domestic_opening_gross': 489488,
#   'budget': 0,
#   'domestic_gross': 93383953,
#   'international_gross': 34979928,
#   'worldwide_gross': 128363881,
#   'runtime_minutes': None,
#   'rating': None,
#   'release_month': 4,
#   'release_date': datetime.datetime(2002, 4, 19, 0, 0),
#   'genres': ' Documentary\n '},
#  {'title': 'Two Weeks Notice',
#   'domestic_opening_gross': 14328494,
#   'budget': 60000000,
#   'domestic_gross': 93354851,
#   'international_gross': 105688391,
#   'worldwide_gross': 199043242,
#   'runtime_minutes': 101,
#   'rating': 'PG-13',
#   'release_month': 12,
#   'release_date': datetime.datetime(2002, 12, 20, 0, 0),
#   'genres': ' Comedy\n Romance\n '},
#  {'title': 'Red Dragon',
#   'domestic_opening_gross': 36540945,
#   'budget': 78000000,
#   'domestic_gross': 93149898,
#   'international_gross': 116046400,
#   'worldwide_gross': 209196298,
#   'runtime_minutes': 124,
#   'rating': 'R',
#   'release_month': 10,
#   'release_date': datetime.datetime(2002, 10, 4, 0, 0),
#   'genres': ' Crime\n Drama\n Thriller\n '},
#  {'title': 'Cinderella',
#   'domestic_opening_gross': 0,
#   'budget': 0,
#   'domestic_gross': 93141149,
#   'international_gross': 3242181,
#   'worldwide_gross': 96383330,
#   'runtime_minutes': 74,
#   'rating': 'G',
#   'release_month': 3,
#   'release_date': datetime.datetime(1950, 3, 4, 0, 0),
#   'genres': ' Animation\n Family\n Fantasy\n Musical\n Romance\n '},
#  {'title': 'When Harry Met Sally...',
#   'domestic_opening_gross': 1094453,
#   'budget': 0,
#   'domestic_gross': 93075866,
#   'international_gross': 155634,
#   'worldwide_gross': 93231500,
#   'runtime_minutes': 95,
#   'rating': None,
#   'release_month': 7,
#   'release_date': datetime.datetime(1989, 7, 14, 0, 0),
#   'genres': ' Comedy\n Drama\n Romance\n '},
#  {'title': 'Elysium',
#   'domestic_opening_gross': 29807393,
#   'budget': 115000000,
#   'domestic_gross': 93050117,
#   'international_gross': 193090583,
#   'worldwide_gross': 286140700,
#   'runtime_minutes': 109,
#   'rating': 'R',
#   'release_month': 8,
#   'release_date': datetime.datetime(2013, 8, 8, 0, 0),
#   'genres': ' Action\n Drama\n Sci-Fi\n '},
#  {'title': 'Flubber',
#   'domestic_opening_gross': 26725207,
#   'budget': 0,
#   'domestic_gross': 92977226,
#   'international_gross': 85000000,
#   'worldwide_gross': 177977226,
#   'runtime_minutes': 93,
#   'rating': 'PG',
#   'release_month': 11,
#   'release_date': datetime.datetime(1997, 11, 26, 0, 0),
#   'genres': ' Comedy\n Family\n Sci-Fi\n '},
#  {'title': 'Flashdance',
#   'domestic_opening_gross': 4076124,
#   'budget': 0,
#   'domestic_gross': 92921203,
#   'international_gross': 92921203,
#   'worldwide_gross': 0,
#   'runtime_minutes': 95,
#   'rating': None,
#   'release_month': 4,
#   'release_date': datetime.datetime(1983, 4, 15, 0, 0),
#   'genres': ' Drama\n Music\n Romance\n '},
#  {'title': 'The Town',
#   'domestic_opening_gross': 23808032,
#   'budget': 37000000,
#   'domestic_gross': 92186262,
#   'international_gross': 61839874,
#   'worldwide_gross': 154026136,
#   'runtime_minutes': 125,
#   'rating': 'R',
#   'release_month': 9,
#   'release_date': datetime.datetime(2010, 9, 15, 0, 0),
#   'genres': ' Crime\n Drama\n Thriller\n '},
#  {'title': 'Non-Stop',
#   'domestic_opening_gross': 28875635,
#   'budget': 50000000,
#   'domestic_gross': 92168600,
#   'international_gross': 130641000,
#   'worldwide_gross': 222809600,
#   'runtime_minutes': 106,
#   'rating': 'PG-13',
#   'release_month': 2,
#   'release_date': datetime.datetime(2014, 2, 19, 0, 0),
#   'genres': ' Action\n Mystery\n Thriller\n '},
#  {'title': 'The Client',
#   'domestic_opening_gross': 17174262,
#   'budget': 0,
#   'domestic_gross': 92115211,
#   'international_gross': 25500000,
#   'worldwide_gross': 117615211,
#   'runtime_minutes': 119,
#   'rating': 'PG-13',
#   'release_month': 7,
#   'release_date': datetime.datetime(1994, 7, 22, 0, 0),
#   'genres': ' Crime\n Drama\n Mystery\n Thriller\n '},
#  {'title': 'Blade Runner 2049',
#   'domestic_opening_gross': 32753122,
#   'budget': 150000000,
#   'domestic_gross': 92054159,
#   'international_gross': 167186366,
#   'worldwide_gross': 259240525,
#   'runtime_minutes': 164,
#   'rating': 'R',
#   'release_month': 10,
#   'release_date': datetime.datetime(2017, 10, 4, 0, 0),
#   'genres': ' Action\n Drama\n Mystery\n Sci-Fi\n Thriller\n '},
#  {'title': 'John Wick: Chapter 2',
#   'domestic_opening_gross': 30436123,
#   'budget': 0,
#   'domestic_gross': 92029184,
#   'international_gross': 79518618,
#   'worldwide_gross': 171547802,
#   'runtime_minutes': 122,
#   'rating': 'R',
#   'release_month': 2,
#   'release_date': datetime.datetime(2017, 2, 8, 0, 0),
#   'genres': ' Action\n Crime\n Thriller\n '},
#  {'title': 'Star Trek: First Contact',
#   'domestic_opening_gross': 30716131,
#   'budget': 0,
#   'domestic_gross': 92027888,
#   'international_gross': 54000000,
#   'worldwide_gross': 146027888,
#   'runtime_minutes': 111,
#   'rating': 'PG-13',
#   'release_month': 11,
#   'release_date': datetime.datetime(1996, 11, 22, 0, 0),
#   'genres': ' Action\n Adventure\n Drama\n Sci-Fi\n Thriller\n '},
#  {'title': 'Think Like a Man',
#   'domestic_opening_gross': 33636303,
#   'budget': 12000000,
#   'domestic_gross': 91547205,
#   'international_gross': 4523302,
#   'worldwide_gross': 96070507,
#   'runtime_minutes': 123,
#   'rating': 'PG-13',
#   'release_month': 4,
#   'release_date': datetime.datetime(2012, 4, 20, 0, 0),
#   'genres': ' Comedy\n Romance\n '},
#  {'title': 'Kindergarten Cop',
#   'domestic_opening_gross': 7918560,
#   'budget': 15000000,
#   'domestic_gross': 91457688,
#   'international_gross': 110500000,
#   'worldwide_gross': 201957688,
#   'runtime_minutes': 111,
#   'rating': None,
#   'release_month': 12,
#   'release_date': datetime.datetime(1990, 12, 22, 0, 0),
#   'genres': ' Action\n Comedy\n Crime\n '},
#  {'title': 'Heaven Is for Real',
#   'domestic_opening_gross': 22522221,
#   'budget': 12000000,
#   'domestic_gross': 91443253,
#   'international_gross': 10444766,
#   'worldwide_gross': 101888019,
#   'runtime_minutes': 99,
#   'rating': 'PG',
#   'release_month': 4,
#   'release_date': datetime.datetime(2014, 4, 16, 0, 0),
#   'genres': ' Biography\n Drama\n Family\n '},
#  {'title': 'The Haunting',
#   'domestic_opening_gross': 33435140,
#   'budget': 80000000,
#   'domestic_gross': 91411151,
#   'international_gross': 85900000,
#   'worldwide_gross': 177311151,
#   'runtime_minutes': 113,
#   'rating': 'PG-13',
#   'release_month': 7,
#   'release_date': datetime.datetime(1999, 7, 23, 0, 0),
#   'genres': ' Fantasy\n Horror\n Mystery\n Thriller\n '},
#  {'title': 'Crimson Tide',
#   'domestic_opening_gross': 18612190,
#   'budget': 0,
#   'domestic_gross': 91387195,
#   'international_gross': 66000000,
#   'worldwide_gross': 157387195,
#   'runtime_minutes': 116,
#   'rating': 'R',
#   'release_month': 5,
#   'release_date': datetime.datetime(1995, 5, 12, 0, 0),
#   'genres': ' Action\n Drama\n Thriller\n War\n '},
#  {'title': 'Back to School',
#   'domestic_opening_gross': 8881035,
#   'budget': 0,
#   'domestic_gross': 91258000,
#   'international_gross': 91258000,
#   'worldwide_gross': 0,
#   'runtime_minutes': 96,
#   'rating': None,
#   'release_month': 6,
#   'release_date': datetime.datetime(1986, 6, 13, 0, 0),
#   'genres': ' Comedy\n Romance\n Sport\n '},
#  {'title': 'Ride Along 2',
#   'domestic_opening_gross': 35243095,
#   'budget': 40000000,
#   'domestic_gross': 91221830,
#   'international_gross': 33386608,
#   'worldwide_gross': 124608438,
#   'runtime_minutes': 102,
#   'rating': 'PG-13',
#   'release_month': 1,
#   'release_date': datetime.datetime(2015, 1, 15, 0, 0),
#   'genres': ' Action\n Comedy\n Crime\n '},
#  {'title': 'Stepmom',
#   'domestic_opening_gross': 19142440,
#   'budget': 50000000,
#   'domestic_gross': 91137662,
#   'international_gross': 68573131,
#   'worldwide_gross': 159710793,
#   'runtime_minutes': 125,
#   'rating': 'PG-13',
#   'release_month': 12,
#   'release_date': datetime.datetime(1998, 12, 25, 0, 0),
#   'genres': ' Comedy\n Drama\n '},
#  {'title': 'The Imitation Game',
#   'domestic_opening_gross': 479352,
#   'budget': 0,
#   'domestic_gross': 91125683,
#   'international_gross': 142430025,
#   'worldwide_gross': 233555708,
#   'runtime_minutes': 114,
#   'rating': 'PG-13',
#   'release_month': 11,
#   'release_date': datetime.datetime(2014, 11, 14, 0, 0),
#   'genres': ' Biography\n Drama\n Thriller\n War\n '},
#  {'title': 'The Karate Kid',
#   'domestic_opening_gross': 5031753,
#   'budget': 0,
#   'domestic_gross': 91077276,
#   'international_gross': 42043,
#   'worldwide_gross': 91119319,
#   'runtime_minutes': 126,
#   'rating': None,
#   'release_month': 6,
#   'release_date': datetime.datetime(1984, 6, 22, 0, 0),
#   'genres': ' Action\n Drama\n Family\n Sport\n '},
#  {'title': 'Save the Last Dance',
#   'domestic_opening_gross': 23444930,
#   'budget': 0,
#   'domestic_gross': 91057006,
#   'international_gross': 40649803,
#   'worldwide_gross': 131706809,
#   'runtime_minutes': 112,
#   'rating': 'PG-13',
#   'release_month': 1,
#   'release_date': datetime.datetime(2001, 1, 12, 0, 0),
#   'genres': ' Drama\n Music\n Romance\n '},
#  {'title': 'The Scorpion King',
#   'domestic_opening_gross': 36075875,
#   'budget': 60000000,
#   'domestic_gross': 91047077,
#   'international_gross': 89583830,
#   'worldwide_gross': 180630907,
#   'runtime_minutes': 92,
#   'rating': 'PG-13',
#   'release_month': 4,
#   'release_date': datetime.datetime(2002, 4, 18, 0, 0),
#   'genres': ' Action\n Adventure\n Fantasy\n '},
#  {'title': 'Prince of Persia: The Sands of Time',
#   'domestic_opening_gross': 30095259,
#   'budget': 200000000,
#   'domestic_gross': 90759676,
#   'international_gross': 245606000,
#   'worldwide_gross': 336365676,
#   'runtime_minutes': 116,
#   'rating': 'PG-13',
#   'release_month': 7,
#   'release_date': datetime.datetime(2009, 7, 16, 0, 0),
#   'genres': ' Action\n Adventure\n Fantasy\n '},
#  {'title': 'Antz',
#   'domestic_opening_gross': 17195160,
#   'budget': 105000000,
#   'domestic_gross': 90757863,
#   'international_gross': 81000000,
#   'worldwide_gross': 171757863,
#   'runtime_minutes': 83,
#   'rating': 'PG',
#   'release_month': 10,
#   'release_date': datetime.datetime(1998, 10, 2, 0, 0),
#   'genres': ' Adventure\n Animation\n Comedy\n Family\n '},
#  {'title': 'Scary Movie 4',
#   'domestic_opening_gross': 40222875,
#   'budget': 45000000,
#   'domestic_gross': 90710620,
#   'international_gross': 87552000,
#   'worldwide_gross': 178262620,
#   'runtime_minutes': 83,
#   'rating': 'PG-13',
#   'release_month': 4,
#   'release_date': datetime.datetime(2006, 4, 12, 0, 0),
#   'genres': ' Comedy\n Horror\n '},
#  {'title': 'The Game Plan',
#   'domestic_opening_gross': 22950971,
#   'budget': 0,
#   'domestic_gross': 90648202,
#   'international_gross': 57232341,
#   'worldwide_gross': 147880543,
#   'runtime_minutes': 110,
#   'rating': 'PG',
#   'release_month': 9,
#   'release_date': datetime.datetime(2007, 9, 28, 0, 0),
#   'genres': ' Comedy\n Family\n Sport\n '},
#  {'title': 'Me, Myself & Irene',
#   'domestic_opening_gross': 24209385,
#   'budget': 51000000,
#   'domestic_gross': 90570999,
#   'international_gross': 58700000,
#   'worldwide_gross': 149270999,
#   'runtime_minutes': 116,
#   'rating': 'R',
#   'release_month': 6,
#   'release_date': datetime.datetime(2000, 6, 23, 0, 0),
#   'genres': ' Comedy\n '},
#  {'title': 'High School Musical 3',
#   'domestic_opening_gross': 42030184,
#   'budget': 11000000,
#   'domestic_gross': 90559416,
#   'international_gross': 162349761,
#   'worldwide_gross': 252909177,
#   'runtime_minutes': 112,
#   'rating': 'G',
#   'release_month': 10,
#   'release_date': datetime.datetime(2008, 10, 22, 0, 0),
#   'genres': ' Comedy\n Drama\n Family\n Music\n Musical\n Romance\n '},
#  {'title': 'Madea Goes to Jail',
#   'domestic_opening_gross': 41030947,
#   'budget': 0,
#   'domestic_gross': 90508336,
#   'international_gross': 90508336,
#   'worldwide_gross': 0,
#   'runtime_minutes': 103,
#   'rating': 'PG-13',
#   'release_month': 2,
#   'release_date': datetime.datetime(2009, 2, 20, 0, 0),
#   'genres': ' Comedy\n Crime\n Drama\n '},
#  {'title': 'Space Cowboys',
#   'domestic_opening_gross': 18093776,
#   'budget': 65000000,
#   'domestic_gross': 90464773,
#   'international_gross': 38419359,
#   'worldwide_gross': 128884132,
#   'runtime_minutes': 130,
#   'rating': 'PG-13',
#   'release_month': 8,
#   'release_date': datetime.datetime(2000, 8, 4, 0, 0),
#   'genres': ' Action\n Adventure\n Thriller\n '},
#  {'title': 'Space Jam',
#   'domestic_opening_gross': 27528529,
#   'budget': 0,
#   'domestic_gross': 90418342,
#   'international_gross': 140000000,
#   'worldwide_gross': 230418342,
#   'runtime_minutes': 88,
#   'rating': 'PG',
#   'release_month': 11,
#   'release_date': datetime.datetime(1996, 11, 15, 0, 0),
#   'genres': ' Adventure\n Animation\n Comedy\n Family\n Sci-Fi\n Sport\n '},
#  {'title': 'Get Hard',
#   'domestic_opening_gross': 33803253,
#   'budget': 40000000,
#   'domestic_gross': 90411453,
#   'international_gross': 21300000,
#   'worldwide_gross': 111711453,
#   'runtime_minutes': 100,
#   'rating': 'R',
#   'release_month': 3,
#   'release_date': datetime.datetime(2015, 3, 26, 0, 0),
#   'genres': ' Comedy\n Crime\n '},
#  {'title': 'Trading Places',
#   'domestic_opening_gross': 7348200,
#   'budget': 0,
#   'domestic_gross': 90404800,
#   'international_gross': 90404800,
#   'worldwide_gross': 0,
#   'runtime_minutes': 116,
#   'rating': None,
#   'release_month': 6,
#   'release_date': datetime.datetime(1983, 6, 10, 0, 0),
#   'genres': ' Comedy\n '},
#  {'title': 'RED',
#   'domestic_opening_gross': 21761408,
#   'budget': 58000000,
#   'domestic_gross': 90380162,
#   'international_gross': 108626225,
#   'worldwide_gross': 199006387,
#   'runtime_minutes': 111,
#   'rating': 'PG-13',
#   'release_month': 10,
#   'release_date': datetime.datetime(2010, 10, 14, 0, 0),
#   'genres': ' Action\n Comedy\n Crime\n Thriller\n '},
#  {'title': 'Planes',
#   'domestic_opening_gross': 22232291,
#   'budget': 50000000,
#   'domestic_gross': 90288712,
#   'international_gross': 148970000,
#   'worldwide_gross': 239258712,
#   'runtime_minutes': 91,
#   'rating': 'PG',
#   'release_month': 8,
#   'release_date': datetime.datetime(2013, 8, 9, 0, 0),
#   'genres': ' Adventure\n Animation\n Comedy\n Family\n '},
#  {'title': 'Legally Blonde 2',
#   'domestic_opening_gross': 22220670,
#   'budget': 45000000,
#   'domestic_gross': 90186328,
#   'international_gross': 34728514,
#   'worldwide_gross': 124914842,
#   'runtime_minutes': 95,
#   'rating': 'PG-13',
#   'release_month': 7,
#   'release_date': datetime.datetime(2003, 7, 2, 0, 0),
#   'genres': ' Comedy\n '},
#  {'title': 'Mystic River',
#   'domestic_opening_gross': 640815,
#   'budget': 25000000,
#   'domestic_gross': 90135191,
#   'international_gross': 66460000,
#   'worldwide_gross': 156595191,
#   'runtime_minutes': 138,
#   'rating': 'R',
#   'release_month': 10,
#   'release_date': datetime.datetime(2003, 10, 8, 0, 0),
#   'genres': ' Crime\n Drama\n Mystery\n Thriller\n '},
#  {'title': 'Terminator Genisys',
#   'domestic_opening_gross': 27018486,
#   'budget': 155000000,
#   'domestic_gross': 89760956,
#   'international_gross': 350842581,
#   'worldwide_gross': 440603537,
#   'runtime_minutes': 126,
#   'rating': 'PG-13',
#   'release_month': 6,
#   'release_date': datetime.datetime(2015, 6, 25, 0, 0),
#   'genres': ' Action\n Adventure\n Sci-Fi\n Thriller\n '},
#  {'title': 'Flightplan',
#   'domestic_opening_gross': 24629938,
#   'budget': 0,
#   'domestic_gross': 89707299,
#   'international_gross': 133680000,
#   'worldwide_gross': 223387299,
#   'runtime_minutes': 98,
#   'rating': 'PG-13',
#   'release_month': 9,
#   'release_date': datetime.datetime(2005, 9, 23, 0, 0),
#   'genres': ' Drama\n Mystery\n Thriller\n '},
#  {'title': "The Emperor's New Groove",
#   'domestic_opening_gross': 9812302,
#   'budget': 100000000,
#   'domestic_gross': 89521687,
#   'international_gross': 80025000,
#   'worldwide_gross': 169546687,
#   'runtime_minutes': 78,
#   'rating': None,
#   'release_month': 12,
#   'release_date': datetime.datetime(2000, 12, 15, 0, 0),
#   'genres': ' Adventure\n Animation\n Comedy\n Family\n Fantasy\n '},
#  {'title': 'Father of the Bride',
#   'domestic_opening_gross': 7031146,
#   'budget': 0,
#   'domestic_gross': 89325780,
#   'international_gross': 89325780,
#   'worldwide_gross': 0,
#   'runtime_minutes': 105,
#   'rating': None,
#   'release_month': 12,
#   'release_date': datetime.datetime(1991, 12, 20, 0, 0),
#   'genres': ' Comedy\n Family\n Romance\n '},
#  {'title': 'The Lone Ranger',
#   'domestic_opening_gross': 29210849,
#   'budget': 215000000,
#   'domestic_gross': 89302115,
#   'international_gross': 171200000,
#   'worldwide_gross': 260502115,
#   'runtime_minutes': 150,
#   'rating': 'PG-13',
#   'release_month': 7,
#   'release_date': datetime.datetime(2013, 7, 3, 0, 0),
#   'genres': ' Action\n Adventure\n Western\n '},
#  {'title': 'Taken 3',
#   'domestic_opening_gross': 39201657,
#   'budget': 48000000,
#   'domestic_gross': 89256424,
#   'international_gross': 237222717,
#   'worldwide_gross': 326479141,
#   'runtime_minutes': 108,
#   'rating': 'PG-13',
#   'release_month': 1,
#   'release_date': datetime.datetime(2015, 1, 1, 0, 0),
#   'genres': ' Action\n Thriller\n '},
#  {'title': "Don't Breathe",
#   'domestic_opening_gross': 26411706,
#   'budget': 9900000,
#   'domestic_gross': 89217875,
#   'international_gross': 68612612,
#   'worldwide_gross': 157830487,
#   'runtime_minutes': 88,
#   'rating': 'R',
#   'release_month': 8,
#   'release_date': datetime.datetime(2016, 8, 25, 0, 0),
#   'genres': ' Crime\n Horror\n Thriller\n '},
#  {'title': 'Scream 3',
#   'domestic_opening_gross': 34713342,
#   'budget': 40000000,
#   'domestic_gross': 89143175,
#   'international_gross': 72691101,
#   'worldwide_gross': 161834276,
#   'runtime_minutes': 116,
#   'rating': 'R',
#   'release_month': 2,
#   'release_date': datetime.datetime(2000, 2, 4, 0, 0),
#   'genres': ' Horror\n Mystery\n '},
#  {'title': 'Oblivion',
#   'domestic_opening_gross': 37054485,
#   'budget': 120000000,
#   'domestic_gross': 89107235,
#   'international_gross': 197061337,
#   'worldwide_gross': 286168572,
#   'runtime_minutes': 124,
#   'rating': 'PG-13',
#   'release_month': 4,
#   'release_date': datetime.datetime(2013, 4, 10, 0, 0),
#   'genres': ' Action\n Adventure\n Sci-Fi\n '},
#  {'title': 'The Ugly Truth',
#   'domestic_opening_gross': 27605576,
#   'budget': 38000000,
#   'domestic_gross': 88915214,
#   'international_gross': 232767386,
#   'worldwide_gross': 321682600,
#   'runtime_minutes': 96,
#   'rating': 'R',
#   'release_month': 2,
#   'release_date': datetime.datetime(2009, 2, 26, 0, 0),
#   'genres': ' Comedy\n Romance\n '},
#  {'title': 'Percy Jackson & the Olympians: The Lightning Thief',
#   'domestic_opening_gross': 31236067,
#   'budget': 95000000,
#   'domestic_gross': 88768303,
#   'international_gross': 137728906,
#   'worldwide_gross': 226497209,
#   'runtime_minutes': 118,
#   'rating': 'PG',
#   'release_month': 2,
#   'release_date': datetime.datetime(2010, 2, 10, 0, 0),
#   'genres': ' Adventure\n Family\n Fantasy\n '},
#  {'title': 'Failure to Launch',
#   'domestic_opening_gross': 24411322,
#   'budget': 50000000,
#   'domestic_gross': 88715192,
#   'international_gross': 41508966,
#   'worldwide_gross': 130224158,
#   'runtime_minutes': 97,
#   'rating': 'PG-13',
#   'release_month': 3,
#   'release_date': datetime.datetime(2006, 3, 9, 0, 0),
#   'genres': ' Comedy\n Romance\n '},
#  {'title': 'The Muppets',
#   'domestic_opening_gross': 29239026,
#   'budget': 45000000,
#   'domestic_gross': 88631237,
#   'international_gross': 76553000,
#   'worldwide_gross': 165184237,
#   'runtime_minutes': None,
#   'rating': 'PG',
#   'release_month': 11,
#   'release_date': datetime.datetime(2011, 11, 23, 0, 0),
#   'genres': ' Adventure\n Comedy\n Family\n Musical\n '},
#  {'title': 'Inside Man',
#   'domestic_opening_gross': 28954945,
#   'budget': 45000000,
#   'domestic_gross': 88513495,
#   'international_gross': 97490096,
#   'worldwide_gross': 186003591,
#   'runtime_minutes': 129,
#   'rating': 'R',
#   'release_month': 3,
#   'release_date': datetime.datetime(2006, 3, 23, 0, 0),
#   'genres': ' Crime\n Drama\n Mystery\n Thriller\n '},
#  {'title': 'Back to the Future Part III',
#   'domestic_opening_gross': 19089645,
#   'budget': 40000000,
#   'domestic_gross': 88277583,
#   'international_gross': 156800000,
#   'worldwide_gross': 244527583,
#   'runtime_minutes': 118,
#   'rating': None,
#   'release_month': 5,
#   'release_date': datetime.datetime(1990, 5, 25, 0, 0),
#   'genres': ' Adventure\n Comedy\n Sci-Fi\n Western\n '},
#  {'title': 'Waterworld',
#   'domestic_opening_gross': 21171780,
#   'budget': 175000000,
#   'domestic_gross': 88246220,
#   'international_gross': 175972000,
#   'worldwide_gross': 264218220,
#   'runtime_minutes': 135,
#   'rating': 'PG-13',
#   'release_month': 7,
#   'release_date': datetime.datetime(1995, 7, 28, 0, 0),
#   'genres': ' Action\n Adventure\n Sci-Fi\n '},
#  {'title': 'Starsky & Hutch',
#   'domestic_opening_gross': 28103367,
#   'budget': 60000000,
#   'domestic_gross': 88237754,
#   'international_gross': 82030996,
#   'worldwide_gross': 170268750,
#   'runtime_minutes': 101,
#   'rating': 'PG-13',
#   'release_month': 3,
#   'release_date': datetime.datetime(2004, 3, 5, 0, 0),
#   'genres': ' Comedy\n Crime\n '},
#  {'title': 'Along Came Polly',
#   'domestic_opening_gross': 27721185,
#   'budget': 42000000,
#   'domestic_gross': 88097164,
#   'international_gross': 90214565,
#   'worldwide_gross': 178311729,
#   'runtime_minutes': 90,
#   'rating': 'PG-13',
#   'release_month': 1,
#   'release_date': datetime.datetime(2004, 1, 16, 0, 0),
#   'genres': ' Comedy\n Romance\n '},
#  {'title': 'The Hand That Rocks the Cradle',
#   'domestic_opening_gross': 7675016,
#   'budget': 0,
#   'domestic_gross': 88036683,
#   'international_gross': 88036683,
#   'worldwide_gross': 0,
#   'runtime_minutes': 110,
#   'rating': 'R',
#   'release_month': 1,
#   'release_date': datetime.datetime(1992, 1, 10, 0, 0),
#   'genres': ' Drama\n Thriller\n '},
#  {'title': 'Entrapment',
#   'domestic_opening_gross': 20145595,
#   'budget': 66000000,
#   'domestic_gross': 87704396,
#   'international_gross': 124700000,
#   'worldwide_gross': 212404396,
#   'runtime_minutes': 113,
#   'rating': 'PG-13',
#   'release_month': 4,
#   'release_date': datetime.datetime(1999, 4, 30, 0, 0),
#   'genres': ' Action\n Crime\n Romance\n Thriller\n '},
#  {'title': 'Peter Pan',
#   'domestic_opening_gross': 4000000,
#   'budget': 0,
#   'domestic_gross': 87404651,
#   'international_gross': 87404651,
#   'worldwide_gross': 0,
#   'runtime_minutes': 77,
#   'rating': 'G',
#   'release_month': 2,
#   'release_date': datetime.datetime(1953, 2, 5, 0, 0),
#   'genres': ' Adventure\n Animation\n Family\n Fantasy\n Musical\n '},
#  {'title': 'Pineapple Express',
#   'domestic_opening_gross': 23245025,
#   'budget': 27000000,
#   'domestic_gross': 87341380,
#   'international_gross': 14283463,
#   'worldwide_gross': 101624843,
#   'runtime_minutes': 111,
#   'rating': 'R',
#   'release_month': 8,
#   'release_date': datetime.datetime(2008, 8, 6, 0, 0),
#   'genres': ' Action\n Comedy\n Crime\n '},
#  {'title': "Miss Peregrine's Home for Peculiar Children",
#   'domestic_opening_gross': 28871140,
#   'budget': 110000000,
#   'domestic_gross': 87242834,
#   'international_gross': 209239612,
#   'worldwide_gross': 296482446,
#   'runtime_minutes': 127,
#   'rating': 'PG-13',
#   'release_month': 9,
#   'release_date': datetime.datetime(2016, 9, 28, 0, 0),
#   'genres': ' Adventure\n Drama\n Family\n Fantasy\n Thriller\n '},
#  {'title': 'Everest',
#   'domestic_opening_gross': 364244,
#   'budget': 0,
#   'domestic_gross': 87178599,
#   'international_gross': 40811529,
#   'worldwide_gross': 87178599,
#   'runtime_minutes': None,
#   'rating': None,
#   'release_month': 3,
#   'release_date': datetime.datetime(1998, 3, 6, 0, 0),
#   'genres': ' Documentary\n Short\n '},
#  {'title': 'Out of Africa',
#   'domestic_opening_gross': 3637290,
#   'budget': 0,
#   'domestic_gross': 87071205,
#   'international_gross': 140443000,
#   'worldwide_gross': 227514205,
#   'runtime_minutes': 161,
#   'rating': None,
#   'release_month': 12,
#   'release_date': datetime.datetime(1985, 12, 20, 0, 0),
#   'genres': ' Biography\n Drama\n Romance\n '},
#  {'title': 'Sisters',
#   'domestic_opening_gross': 13922855,
#   'budget': 30000000,
#   'domestic_gross': 87044645,
#   'international_gross': 17966408,
#   'worldwide_gross': 105011053,
#   'runtime_minutes': 118,
#   'rating': 'R',
#   'release_month': 12,
#   'release_date': datetime.datetime(2015, 12, 18, 0, 0),
#   'genres': ' Comedy\n '},
#  {'title': 'Saw II',
#   'domestic_opening_gross': 31725652,
#   'budget': 4000000,
#   'domestic_gross': 87039965,
#   'international_gross': 60708540,
#   'worldwide_gross': 147748505,
#   'runtime_minutes': 93,
#   'rating': 'R',
#   'release_month': 10,
#   'release_date': datetime.datetime(2005, 10, 28, 0, 0),
#   'genres': ' Horror\n Mystery\n '},
#  {'title': 'The Naked Gun 2½: The Smell of Fear',
#   'domestic_opening_gross': 20817139,
#   'budget': 23000000,
#   'domestic_gross': 86930411,
#   'international_gross': 86930411,
#   'worldwide_gross': 0,
#   'runtime_minutes': 85,
#   'rating': None,
#   'release_month': 6,
#   'release_date': datetime.datetime(1991, 6, 28, 0, 0),
#   'genres': ' Comedy\n Crime\n '},
#  {'title': 'The Campaign',
#   'domestic_opening_gross': 26588460,
#   'budget': 0,
#   'domestic_gross': 86907746,
#   'international_gross': 18000000,
#   'worldwide_gross': 104907746,
#   'runtime_minutes': 85,
#   'rating': 'R',
#   'release_month': 8,
#   'release_date': datetime.datetime(2012, 8, 9, 0, 0),
#   'genres': ' Comedy\n '},
#  {'title': 'The War of the Roses',
#   'domestic_opening_gross': 9488794,
#   'budget': 0,
#   'domestic_gross': 86888546,
#   'international_gross': 73300000,
#   'worldwide_gross': 160188546,
#   'runtime_minutes': 116,
#   'rating': None,
#   'release_month': 12,
#   'release_date': datetime.datetime(1989, 12, 8, 0, 0),
#   'genres': ' Comedy\n Romance\n '},
#  {'title': 'The Amityville Horror',
#   'domestic_opening_gross': 7843467,
#   'budget': 0,
#   'domestic_gross': 86432000,
#   'international_gross': 86432000,
#   'worldwide_gross': 0,
#   'runtime_minutes': 117,
#   'rating': None,
#   'release_month': 7,
#   'release_date': datetime.datetime(1979, 7, 27, 0, 0),
#   'genres': ' Horror\n '},
#  {'title': 'Presumed Innocent',
#   'domestic_opening_gross': 11718981,
#   'budget': 0,
#   'domestic_gross': 86303188,
#   'international_gross': 135000000,
#   'worldwide_gross': 221303188,
#   'runtime_minutes': 127,
#   'rating': None,
#   'release_month': 7,
#   'release_date': datetime.datetime(1990, 7, 27, 0, 0),
#   'genres': ' Mystery\n Thriller\n '},
#  {'title': 'Young Frankenstein',
#   'domestic_opening_gross': 2800000,
#   'budget': 0,
#   'domestic_gross': 86273333,
#   'international_gross': 86273333,
#   'worldwide_gross': 0,
#   'runtime_minutes': 106,
#   'rating': None,
#   'release_month': 12,
#   'release_date': datetime.datetime(1974, 12, 15, 0, 0),
#   'genres': ' Comedy\n '},
#  {'title': 'The Accountant',
#   'domestic_opening_gross': 24710273,
#   'budget': 44000000,
#   'domestic_gross': 86260045,
#   'international_gross': 68900000,
#   'worldwide_gross': 155160045,
#   'runtime_minutes': 128,
#   'rating': 'R',
#   'release_month': 10,
#   'release_date': datetime.datetime(2016, 10, 13, 0, 0),
#   'genres': ' Action\n Crime\n Drama\n Thriller\n '},
#  {'title': 'Dumb and Dumber To',
#   'domestic_opening_gross': 36111775,
#   'budget': 40000000,
#   'domestic_gross': 86208010,
#   'international_gross': 83629000,
#   'worldwide_gross': 169837010,
#   'runtime_minutes': 109,
#   'rating': 'PG-13',
#   'release_month': 11,
#   'release_date': datetime.datetime(2014, 11, 12, 0, 0),
#   'genres': ' Comedy\n '},
#  {'title': 'The Emoji Movie',
#   'domestic_opening_gross': 24531923,
#   'budget': 50000000,
#   'domestic_gross': 86089513,
#   'international_gross': 131687133,
#   'worldwide_gross': 217776646,
#   'runtime_minutes': 86,
#   'rating': 'PG',
#   'release_month': 7,
#   'release_date': datetime.datetime(2017, 7, 27, 0, 0),
#   'genres': ' Adventure\n Animation\n Comedy\n Family\n Fantasy\n '},
#  {'title': 'Mean Girls',
#   'domestic_opening_gross': 24432195,
#   'budget': 17000000,
#   'domestic_gross': 86058055,
#   'international_gross': 44068222,
#   'worldwide_gross': 130126277,
#   'runtime_minutes': 97,
#   'rating': 'PG-13',
#   'release_month': 4,
#   'release_date': datetime.datetime(2004, 4, 30, 0, 0),
#   'genres': ' Comedy\n '},
#  {'title': 'Annie',
#   'domestic_opening_gross': 15861939,
#   'budget': 65000000,
#   'domestic_gross': 85911262,
#   'international_gross': 50942244,
#   'worldwide_gross': 136853506,
#   'runtime_minutes': 118,
#   'rating': 'PG',
#   'release_month': 12,
#   'release_date': datetime.datetime(2014, 12, 17, 0, 0),
#   'genres': ' Comedy\n Drama\n Family\n Musical\n '},
#  {'title': 'Alvin and the Chipmunks: The Road Chip',
#   'domestic_opening_gross': 14287159,
#   'budget': 0,
#   'domestic_gross': 85886987,
#   'international_gross': 148911649,
#   'worldwide_gross': 234798636,
#   'runtime_minutes': 92,
#   'rating': 'PG',
#   'release_month': 12,
#   'release_date': datetime.datetime(2015, 12, 18, 0, 0),
#   'genres': ' Adventure\n Animation\n Comedy\n Family\n Fantasy\n Music\n '},
#  {'title': 'Spy Kids 2: Island of Lost Dreams',
#   'domestic_opening_gross': 16711716,
#   'budget': 38000000,
#   'domestic_gross': 85846429,
#   'international_gross': 33876929,
#   'worldwide_gross': 119723358,
#   'runtime_minutes': 100,
#   'rating': 'PG',
#   'release_month': 8,
#   'release_date': datetime.datetime(2002, 8, 7, 0, 0),
#   'genres': ' Action\n Adventure\n Comedy\n Family\n Sci-Fi\n '},
#  {'title': 'Alita: Battle Angel',
#   'domestic_opening_gross': 28525613,
#   'budget': 170000000,
#   'domestic_gross': 85838210,
#   'international_gross': 319142333,
#   'worldwide_gross': 404980543,
#   'runtime_minutes': 122,
#   'rating': 'PG-13',
#   'release_month': 2,
#   'release_date': datetime.datetime(2019, 2, 5, 0, 0),
#   'genres': ' Action\n Adventure\n Sci-Fi\n Thriller\n '},
#  {'title': 'Fury',
#   'domestic_opening_gross': 23702421,
#   'budget': 68000000,
#   'domestic_gross': 85817906,
#   'international_gross': 126004791,
#   'worldwide_gross': 211822697,
#   'runtime_minutes': 134,
#   'rating': 'R',
#   'release_month': 10,
#   'release_date': datetime.datetime(2014, 10, 17, 0, 0),
#   'genres': ' Action\n Drama\n War\n '},
#  {'title': 'Pokémon: The First Movie - Mewtwo Strikes Back',
#   'domestic_opening_gross': 31036678,
#   'budget': 30000000,
#   'domestic_gross': 85744662,
#   'international_gross': 77900000,
#   'worldwide_gross': 163644662,
#   'runtime_minutes': 96,
#   'rating': None,
#   'release_month': 11,
#   'release_date': datetime.datetime(1999, 11, 10, 0, 0),
#   'genres': ' Action\n Adventure\n Animation\n Family\n Fantasy\n Sci-Fi\n Sport\n '},
#  {'title': 'Real Steel',
#   'domestic_opening_gross': 27319677,
#   'budget': 0,
#   'domestic_gross': 85468508,
#   'international_gross': 213800000,
#   'worldwide_gross': 299268508,
#   'runtime_minutes': 127,
#   'rating': 'PG-13',
#   'release_month': 10,
#   'release_date': datetime.datetime(2011, 10, 5, 0, 0),
#   'genres': ' Action\n Drama\n Sci-Fi\n Sport\n '},
#  {'title': 'The SpongeBob SquarePants Movie',
#   'domestic_opening_gross': 32018216,
#   'budget': 30000000,
#   'domestic_gross': 85417988,
#   'international_gross': 55649139,
#   'worldwide_gross': 141067127,
#   'runtime_minutes': 87,
#   'rating': 'PG',
#   'release_month': 11,
#   'release_date': datetime.datetime(2004, 11, 19, 0, 0),
#   'genres': ' Action\n Adventure\n Animation\n Comedy\n Family\n Fantasy\n '},
#  {'title': 'Power Rangers',
#   'domestic_opening_gross': 40300288,
#   'budget': 100000000,
#   'domestic_gross': 85364450,
#   'international_gross': 56972790,
#   'worldwide_gross': 142337240,
#   'runtime_minutes': 124,
#   'rating': 'PG-13',
#   'release_month': 3,
#   'release_date': datetime.datetime(2017, 3, 22, 0, 0),
#   'genres': ' Action\n Adventure\n Sci-Fi\n '},
#  {'title': 'Brother Bear',
#   'domestic_opening_gross': 291940,
#   'budget': 0,
#   'domestic_gross': 85336277,
#   'international_gross': 165061521,
#   'worldwide_gross': 250397798,
#   'runtime_minutes': 85,
#   'rating': None,
#   'release_month': 10,
#   'release_date': datetime.datetime(2003, 10, 24, 0, 0),
#   'genres': ' Adventure\n Animation\n Comedy\n Family\n Fantasy\n '},
#  {'title': 'Stripes',
#   'domestic_opening_gross': 6130197,
#   'budget': 0,
#   'domestic_gross': 85297000,
#   'international_gross': 85297000,
#   'worldwide_gross': 0,
#   'runtime_minutes': 106,
#   'rating': 'R',
#   'release_month': 6,
#   'release_date': datetime.datetime(1981, 6, 26, 0, 0),
#   'genres': ' Comedy\n War\n '},
#  {'title': 'Anchorman: The Legend of Ron Burgundy',
#   'domestic_opening_gross': 28416365,
#   'budget': 26000000,
#   'domestic_gross': 85288303,
#   'international_gross': 5361427,
#   'worldwide_gross': 90649730,
#   'runtime_minutes': 94,
#   'rating': 'PG-13',
#   'release_month': 7,
#   'release_date': datetime.datetime(2004, 7, 9, 0, 0),
#   'genres': ' Comedy\n '},
#  {'title': 'Every Which Way but Loose',
#   'domestic_opening_gross': 10272294,
#   'budget': 0,
#   'domestic_gross': 85196485,
#   'international_gross': 85196485,
#   'worldwide_gross': 0,
#   'runtime_minutes': 114,
#   'rating': None,
#   'release_month': 12,
#   'release_date': datetime.datetime(1978, 12, 20, 0, 0),
#   'genres': ' Action\n Comedy\n '},
#  {'title': 'Rocky II',
#   'domestic_opening_gross': 6390537,
#   'budget': 0,
#   'domestic_gross': 85182160,
#   'international_gross': 5695,
#   'worldwide_gross': 85187855,
#   'runtime_minutes': 119,
#   'rating': None,
#   'release_month': 6,
#   'release_date': datetime.datetime(1979, 6, 15, 0, 0),
#   'genres': ' Drama\n Sport\n '},
#  {'title': 'Aliens',
#   'domestic_opening_gross': 10052042,
#   'budget': 0,
#   'domestic_gross': 85160248,
#   'international_gross': 45900000,
#   'worldwide_gross': 131060248,
#   'runtime_minutes': 137,
#   'rating': 'R',
#   'release_month': 7,
#   'release_date': datetime.datetime(1986, 7, 18, 0, 0),
#   'genres': ' Action\n Adventure\n Sci-Fi\n Thriller\n '},
#  {'title': 'Open Season',
#   'domestic_opening_gross': 23624548,
#   'budget': 85000000,
#   'domestic_gross': 85105259,
#   'international_gross': 115706430,
#   'worldwide_gross': 200811689,
#   'runtime_minutes': 86,
#   'rating': 'PG',
#   'release_month': 9,
#   'release_date': datetime.datetime(2006, 9, 29, 0, 0),
#   'genres': ' Adventure\n Animation\n Comedy\n Family\n Fantasy\n '},
#  {'title': 'Green Book',
#   'domestic_opening_gross': 320429,
#   'budget': 23000000,
#   'domestic_gross': 85080171,
#   'international_gross': 236672485,
#   'worldwide_gross': 321752656,
#   'runtime_minutes': 130,
#   'rating': 'PG-13',
#   'release_month': 11,
#   'release_date': datetime.datetime(2018, 11, 16, 0, 0),
#   'genres': ' Biography\n Comedy\n Drama\n Music\n '},
#  {'title': 'The Expendables 2',
#   'domestic_opening_gross': 28591370,
#   'budget': 100000000,
#   'domestic_gross': 85028192,
#   'international_gross': 229947763,
#   'worldwide_gross': 314975955,
#   'runtime_minutes': 103,
#   'rating': 'R',
#   'release_month': 8,
#   'release_date': datetime.datetime(2012, 8, 15, 0, 0),
#   'genres': ' Action\n Adventure\n Thriller\n '},
#  {'title': 'Dangerous Minds',
#   'domestic_opening_gross': 14931503,
#   'budget': 0,
#   'domestic_gross': 84919401,
#   'international_gross': 94600000,
#   'worldwide_gross': 179519401,
#   'runtime_minutes': 99,
#   'rating': 'R',
#   'release_month': 8,
#   'release_date': datetime.datetime(1995, 8, 11, 0, 0),
#   'genres': ' Biography\n Drama\n '},
#  {'title': 'Paranormal Activity 2',
#   'domestic_opening_gross': 40678424,
#   'budget': 3000000,
#   'domestic_gross': 84752907,
#   'international_gross': 92759125,
#   'worldwide_gross': 177512032,
#   'runtime_minutes': 91,
#   'rating': 'R',
#   'release_month': 10,
#   'release_date': datetime.datetime(2010, 10, 20, 0, 0),
#   'genres': ' Horror\n Mystery\n '},
#  {'title': 'Steel Magnolias',
#   'domestic_opening_gross': 5425440,
#   'budget': 0,
#   'domestic_gross': 84614512,
#   'international_gross': 12145000,
#   'worldwide_gross': 95904091,
#   'runtime_minutes': 117,
#   'rating': None,
#   'release_month': 11,
#   'release_date': datetime.datetime(1989, 11, 17, 0, 0),
#   'genres': ' Comedy\n Drama\n Romance\n '},
#  {'title': 'The Poseidon Adventure',
#   'domestic_opening_gross': 264850,
#   'budget': 0,
#   'domestic_gross': 84563118,
#   'international_gross': 84563118,
#   'worldwide_gross': 0,
#   'runtime_minutes': 117,
#   'rating': None,
#   'release_month': 12,
#   'release_date': datetime.datetime(1972, 12, 13, 0, 0),
#   'genres': ' Action\n Adventure\n Drama\n Thriller\n '},
#  {'title': 'Tammy',
#   'domestic_opening_gross': 21577049,
#   'budget': 20000000,
#   'domestic_gross': 84525432,
#   'international_gross': 15850000,
#   'worldwide_gross': 100375432,
#   'runtime_minutes': 97,
#   'rating': 'R',
#   'release_month': 7,
#   'release_date': datetime.datetime(2014, 7, 2, 0, 0),
#   'genres': ' Comedy\n Romance\n '},
#  {'title': 'The Santa Clause 3: The Escape Clause',
#   'domestic_opening_gross': 19504038,
#   'budget': 0,
#   'domestic_gross': 84500122,
#   'international_gross': 26268000,
#   'worldwide_gross': 110768122,
#   'runtime_minutes': 97,
#   'rating': 'G',
#   'release_month': 11,
#   'release_date': datetime.datetime(2006, 11, 2, 0, 0),
#   'genres': ' Adventure\n Comedy\n Family\n Fantasy\n '},
#  {'title': 'Ferdinand',
#   'domestic_opening_gross': 13401586,
#   'budget': 111000000,
#   'domestic_gross': 84410380,
#   'international_gross': 211658819,
#   'worldwide_gross': 296069199,
#   'runtime_minutes': 108,
#   'rating': 'PG',
#   'release_month': 12,
#   'release_date': datetime.datetime(2017, 12, 13, 0, 0),
#   'genres': ' Adventure\n Animation\n Comedy\n Family\n Fantasy\n '},
#  {'title': 'Crazy, Stupid, Love.',
#   'domestic_opening_gross': 19104303,
#   'budget': 50000000,
#   'domestic_gross': 84351197,
#   'international_gross': 60700000,
#   'worldwide_gross': 145051197,
#   'runtime_minutes': 118,
#   'rating': 'PG-13',
#   'release_month': 7,
#   'release_date': datetime.datetime(2011, 7, 28, 0, 0),
#   'genres': ' Comedy\n Drama\n Romance\n '},
#  {'title': 'Annabelle',
#   'domestic_opening_gross': 37134255,
#   'budget': 6500000,
#   'domestic_gross': 84273813,
#   'international_gross': 173305469,
#   'worldwide_gross': 257579282,
#   'runtime_minutes': 99,
#   'rating': 'R',
#   'release_month': 9,
#   'release_date': datetime.datetime(2014, 9, 23, 0, 0),
#   'genres': ' Horror\n Mystery\n Thriller\n '},
#  {'title': 'Pinocchio',
#   'domestic_opening_gross': 0,
#   'budget': 0,
#   'domestic_gross': 84254167,
#   'international_gross': 37637878,
#   'worldwide_gross': 121892045,
#   'runtime_minutes': 88,
#   'rating': 'G',
#   'release_month': 2,
#   'release_date': datetime.datetime(1940, 2, 9, 0, 0),
#   'genres': ' Animation\n Comedy\n Family\n Fantasy\n Musical\n '},
#  {'title': 'Scooby-Doo 2: Monsters Unleashed',
#   'domestic_opening_gross': 29438331,
#   'budget': 0,
#   'domestic_gross': 84216833,
#   'international_gross': 97000000,
#   'worldwide_gross': 181216833,
#   'runtime_minutes': 93,
#   'rating': 'PG',
#   'release_month': 3,
#   'release_date': datetime.datetime(2004, 3, 26, 0, 0),
#   'genres': ' Adventure\n Comedy\n Family\n Fantasy\n Horror\n Mystery\n Sci-Fi\n '},
#  {'title': 'Birds of Prey',
#   'domestic_opening_gross': 33010017,
#   'budget': 84500000,
#   'domestic_gross': 84158461,
#   'international_gross': 117700000,
#   'worldwide_gross': 201858461,
#   'runtime_minutes': 109,
#   'rating': 'R',
#   'release_month': 2,
#   'release_date': datetime.datetime(2020, 2, 5, 0, 0),
#   'genres': ' Action\n Adventure\n Comedy\n Crime\n '},
#  {'title': 'Atlantis: The Lost Empire',
#   'domestic_opening_gross': 329011,
#   'budget': 120000000,
#   'domestic_gross': 84056472,
#   'international_gross': 101997253,
#   'worldwide_gross': 186053725,
#   'runtime_minutes': 95,
#   'rating': 'PG',
#   'release_month': 6,
#   'release_date': datetime.datetime(2001, 6, 8, 0, 0),
#   'genres': ' Action\n Adventure\n Animation\n Family\n Fantasy\n Sci-Fi\n '},
#  {'title': 'Cliffhanger',
#   'domestic_opening_gross': 16176967,
#   'budget': 70000000,
#   'domestic_gross': 84049211,
#   'international_gross': 170951000,
#   'worldwide_gross': 255000211,
#   'runtime_minutes': 113,
#   'rating': 'R',
#   'release_month': 5,
#   'release_date': datetime.datetime(1993, 5, 28, 0, 0),
#   'genres': ' Action\n Adventure\n Thriller\n '},
#  {'title': 'The Other Woman',
#   'domestic_opening_gross': 24763752,
#   'budget': 40000000,
#   'domestic_gross': 83911193,
#   'international_gross': 112799203,
#   'worldwide_gross': 196710396,
#   'runtime_minutes': 109,
#   'rating': 'PG-13',
#   'release_month': 4,
#   'release_date': datetime.datetime(2014, 4, 17, 0, 0),
#   'genres': ' Comedy\n Romance\n '},
#  {'title': 'The X Files',
#   'domestic_opening_gross': 30138758,
#   'budget': 0,
#   'domestic_gross': 83898313,
#   'international_gross': 105278110,
#   'worldwide_gross': 189176423,
#   'runtime_minutes': 121,
#   'rating': 'PG-13',
#   'release_month': 6,
#   'release_date': datetime.datetime(1998, 6, 19, 0, 0),
#   'genres': ' Drama\n Mystery\n Sci-Fi\n Thriller\n '},
#  {'title': 'Penguins of Madagascar',
#   'domestic_opening_gross': 25447444,
#   'budget': 132000000,
#   'domestic_gross': 83850911,
#   'international_gross': 289664710,
#   'worldwide_gross': 373515621,
#   'runtime_minutes': 92,
#   'rating': 'PG',
#   'release_month': 11,
#   'release_date': datetime.datetime(2014, 11, 14, 0, 0),
#   'genres': ' Adventure\n Animation\n Comedy\n Family\n Sci-Fi\n '},
#  {'title': 'Die Hard',
#   'domestic_opening_gross': 601851,
#   'budget': 28000000,
#   'domestic_gross': 83844093,
#   'international_gross': 57759104,
#   'worldwide_gross': 141603197,
#   'runtime_minutes': 132,
#   'rating': None,
#   'release_month': 7,
#   'release_date': datetime.datetime(1988, 7, 15, 0, 0),
#   'genres': ' Action\n Thriller\n '},
#  {'title': 'Up in the Air',
#   'domestic_opening_gross': 1181450,
#   'budget': 25000000,
#   'domestic_gross': 83823381,
#   'international_gross': 83019358,
#   'worldwide_gross': 166842739,
#   'runtime_minutes': 109,
#   'rating': 'R',
#   'release_month': 12,
#   'release_date': datetime.datetime(2009, 12, 4, 0, 0),
#   'genres': ' Comedy\n Drama\n Romance\n '},
#  {'title': 'Wrath of the Titans',
#   'domestic_opening_gross': 33457188,
#   'budget': 150000000,
#   'domestic_gross': 83670083,
#   'international_gross': 218300000,
#   'worldwide_gross': 301970083,
#   'runtime_minutes': 99,
#   'rating': 'PG-13',
#   'release_month': 3,
#   'release_date': datetime.datetime(2012, 3, 28, 0, 0),
#   'genres': ' Action\n Adventure\n Fantasy\n '},
#  {'title': 'Insidious: Chapter 2',
#   'domestic_opening_gross': 40272103,
#   'budget': 5000000,
#   'domestic_gross': 83586447,
#   'international_gross': 78332871,
#   'worldwide_gross': 161919318,
#   'runtime_minutes': 106,
#   'rating': 'PG-13',
#   'release_month': 9,
#   'release_date': datetime.datetime(2013, 9, 13, 0, 0),
#   'genres': ' Horror\n Mystery\n Thriller\n '},
#  {'title': 'Under Siege',
#   'domestic_opening_gross': 15760003,
#   'budget': 0,
#   'domestic_gross': 83563139,
#   'international_gross': 73000000,
#   'worldwide_gross': 156563139,
#   'runtime_minutes': 103,
#   'rating': 'R',
#   'release_month': 10,
#   'release_date': datetime.datetime(1992, 10, 9, 0, 0),
#   'genres': ' Action\n Thriller\n '},
#  {'title': 'Battle Los Angeles',
#   'domestic_opening_gross': 35573187,
#   'budget': 70000000,
#   'domestic_gross': 83552429,
#   'international_gross': 128266925,
#   'worldwide_gross': 211819354,
#   'runtime_minutes': 116,
#   'rating': 'PG-13',
#   'release_month': 3,
#   'release_date': datetime.datetime(2011, 3, 9, 0, 0),
#   'genres': ' Action\n Sci-Fi\n '},
#  {'title': 'Immortals',
#   'domestic_opening_gross': 32206425,
#   'budget': 75000000,
#   'domestic_gross': 83504017,
#   'international_gross': 143400000,
#   'worldwide_gross': 226904017,
#   'runtime_minutes': 110,
#   'rating': 'R',
#   'release_month': 11,
#   'release_date': datetime.datetime(2011, 11, 10, 0, 0),
#   'genres': ' Action\n Drama\n Fantasy\n Romance\n '},
#  {'title': 'I Can Only Imagine',
#   'domestic_opening_gross': 17108914,
#   'budget': 7000000,
#   'domestic_gross': 83482352,
#   'international_gross': 2604529,
#   'worldwide_gross': 86086881,
#   'runtime_minutes': 110,
#   'rating': 'PG',
#   'release_month': 3,
#   'release_date': datetime.datetime(2018, 3, 15, 0, 0),
#   'genres': ' Biography\n Drama\n Family\n Music\n '},
#  {'title': 'Apocalypse Now',
#   'domestic_opening_gross': 118558,
#   'budget': 0,
#   'domestic_gross': 83471511,
#   'international_gross': 8672994,
#   'worldwide_gross': 92144505,
#   'runtime_minutes': 147,
#   'rating': 'R',
#   'release_month': 8,
#   'release_date': datetime.datetime(1979, 8, 15, 0, 0),
#   'genres': ' Drama\n Mystery\n War\n '},
#  {'title': 'Airplane!',
#   'domestic_opening_gross': 3500000,
#   'budget': 0,
#   'domestic_gross': 83453539,
#   'international_gross': 83453539,
#   'worldwide_gross': 0,
#   'runtime_minutes': 88,
#   'rating': None,
#   'release_month': 6,
#   'release_date': datetime.datetime(1980, 6, 27, 0, 0),
#   'genres': ' Comedy\n '},
#  {'title': 'Patriot Games',
#   'domestic_opening_gross': 18511191,
#   'budget': 45000000,
#   'domestic_gross': 83351587,
#   'international_gross': 94700000,
#   'worldwide_gross': 178051587,
#   'runtime_minutes': 117,
#   'rating': 'R',
# ...
#  {'title': 'Beowulf',
#   'domestic_opening_gross': 27515871,
#   'budget': 150000000,
#   'domestic_gross': 82280579,
#   'international_gross': 114113166,
#   'worldwide_gross': 196393745,
#   'runtime_minutes': 115,
#   'rating': 'PG-13',
#   'release_month': 11,
#   'release_date': datetime.datetime(2007, 11, 14, 0, 0),
#   'genres': ' Action\n Adventure\n Animation\n Fantasy\n '},
#  {'title': 'Bridge to Terabithia',
#   'domestic_opening_gross': 22564612,
#   'budget': 0,
#   'domestic_gross': 82272442,
#   'international_gross': 55314621,
#   'worldwide_gross': 137587063,
#   'runtime_minutes': 96,
#   'rating': 'PG',
#   'release_month': 2,
#   'release_date': datetime.datetime(2007, 2, 16, 0, 0),
#   'genres': ' Drama\n Family\n Fantasy\n '},
#  {'title': 'The Pink Panther',
#   'domestic_opening_gross': 20220412,
#   'budget': 80000000,
#   'domestic_gross': 82226474,
#   'international_gross': 81889423,
#   'worldwide_gross': 164115897,
#   'runtime_minutes': 93,
#   'rating': 'PG',
#   'release_month': 2,
#   'release_date': datetime.datetime(2006, 2, 9, 0, 0),
#   'genres': ' Adventure\n Comedy\n Crime\n Family\n Mystery\n '},
#  {'title': 'Teenage Mutant Ninja Turtles: Out of the Shadows',
#   'domestic_opening_gross': 35316382,
#   'budget': 135000000,
#   'domestic_gross': 82051601,
#   'international_gross': 163572247,
#   'worldwide_gross': 245623848,
#   'runtime_minutes': 112,
#   'rating': 'PG-13',
#   'release_month': 6,
#   'release_date': datetime.datetime(2016, 6, 2, 0, 0),
#   'genres': ' Action\n Adventure\n Comedy\n Sci-Fi\n '},
#  {'title': 'The Post',
#   'domestic_opening_gross': 526011,
#   'budget': 50000000,
#   'domestic_gross': 81903458,
#   'international_gross': 97866009,
#   'worldwide_gross': 179769467,
#   'runtime_minutes': 116,
#   'rating': 'PG-13',
#   'release_month': 12,
#   'release_date': datetime.datetime(2017, 12, 22, 0, 0),
#   'genres': ' Drama\n '},
#  {'title': 'Alien',
#   'domestic_opening_gross': 3527881,
#   'budget': 11000000,
#   'domestic_gross': 81900459,
#   'international_gross': 24385063,
#   'worldwide_gross': 106285522,
#   'runtime_minutes': 117,
#   'rating': 'R',
#   'release_month': 5,
#   'release_date': datetime.datetime(1979, 5, 25, 0, 0),
#   'genres': ' Horror\n Sci-Fi\n '},
#  {'title': 'Jaws 2',
#   'domestic_opening_gross': 9866023,
#   'budget': 0,
#   'domestic_gross': 81766007,
#   'international_gross': 106118000,
#   'worldwide_gross': 187884007,
#   'runtime_minutes': 116,
#   'rating': None,
#   'release_month': 6,
#   'release_date': datetime.datetime(1978, 6, 16, 0, 0),
#   'genres': ' Adventure\n Horror\n Thriller\n '},
#  {'title': 'Maze Runner: The Scorch Trials',
#   'domestic_opening_gross': 30316510,
#   'budget': 61000000,
#   'domestic_gross': 81697192,
#   'international_gross': 230598864,
#   'worldwide_gross': 312296056,
#   'runtime_minutes': 131,
#   'rating': 'PG-13',
#   'release_month': 9,
#   'release_date': datetime.datetime(2015, 9, 9, 0, 0),
#   'genres': ' Action\n Adventure\n Sci-Fi\n Thriller\n '},
#  {'title': 'Heaven Can Wait',
#   'domestic_opening_gross': 3652486,
#   'budget': 0,
#   'domestic_gross': 81640278,
#   'international_gross': 81640278,
#   'worldwide_gross': 0,
#   'runtime_minutes': 101,
#   'rating': None,
#   'release_month': 6,
#   'release_date': datetime.datetime(1978, 6, 28, 0, 0),
#   'genres': ' Comedy\n Fantasy\n Romance\n Sport\n '},
#  {'title': 'Eight Below',
#   'domestic_opening_gross': 20188176,
#   'budget': 40000000,
#   'domestic_gross': 81612565,
#   'international_gross': 38843429,
#   'worldwide_gross': 120455994,
#   'runtime_minutes': None,
#   'rating': 'PG',
#   'release_month': 2,
#   'release_date': datetime.datetime(2006, 2, 17, 0, 0),
#   'genres': ' Adventure\n Drama\n Family\n '},
#  {'title': 'MASH',
#   'domestic_opening_gross': 3500000,
#   'budget': 0,
#   'domestic_gross': 81600000,
#   'international_gross': 81600000,
#   'worldwide_gross': 0,
#   'runtime_minutes': 116,
#   'rating': 'R',
#   'release_month': 1,
#   'release_date': datetime.datetime(1970, 1, 25, 0, 0),
#   'genres': ' Comedy\n Drama\n War\n '},
#  {'title': 'Unstoppable',
#   'domestic_opening_gross': 22688457,
#   'budget': 100000000,
#   'domestic_gross': 81562942,
#   'international_gross': 86242524,
#   'worldwide_gross': 167805466,
#   'runtime_minutes': 98,
#   'rating': 'PG-13',
#   'release_month': 11,
#   'release_date': datetime.datetime(2010, 11, 10, 0, 0),
#   'genres': ' Action\n Thriller\n '},
#  {'title': 'Payback',
#   'domestic_opening_gross': 21221526,
#   'budget': 90000000,
#   'domestic_gross': 81526121,
#   'international_gross': 80100000,
#   'worldwide_gross': 161626121,
#   'runtime_minutes': 100,
#   'rating': 'R',
#   'release_month': 2,
#   'release_date': datetime.datetime(1999, 2, 5, 0, 0),
#   'genres': ' Action\n Crime\n Drama\n Thriller\n '},
#  {'title': 'Ted 2',
#   'domestic_opening_gross': 33507870,
#   'budget': 68000000,
#   'domestic_gross': 81476385,
#   'international_gross': 134387221,
#   'worldwide_gross': 215863606,
#   'runtime_minutes': 115,
#   'rating': 'R',
#   'release_month': 6,
#   'release_date': datetime.datetime(2015, 6, 19, 0, 0),
#   'genres': ' Comedy\n '},
#  {'title': 'The Talented Mr. Ripley',
#   'domestic_opening_gross': 12738237,
#   'budget': 40000000,
#   'domestic_gross': 81298265,
#   'international_gross': 47500000,
#   'worldwide_gross': 128798265,
#   'runtime_minutes': 139,
#   'rating': 'R',
#   'release_month': 12,
#   'release_date': datetime.datetime(1999, 12, 25, 0, 0),
#   'genres': ' Crime\n Drama\n Thriller\n '},
#  {'title': 'School of Rock',
#   'domestic_opening_gross': 19622714,
#   'budget': 35000000,
#   'domestic_gross': 81261177,
#   'international_gross': 49834813,
#   'worldwide_gross': 131095990,
#   'runtime_minutes': 109,
#   'rating': 'PG-13',
#   'release_month': 10,
#   'release_date': datetime.datetime(2003, 10, 3, 0, 0),
#   'genres': ' Comedy\n Music\n '},
#  {'title': 'Police Academy',
#   'domestic_opening_gross': 8570007,
#   'budget': 0,
#   'domestic_gross': 81198894,
#   'international_gross': 81198894,
#   'worldwide_gross': 0,
#   'runtime_minutes': 96,
#   'rating': None,
#   'release_month': 3,
#   'release_date': datetime.datetime(1984, 3, 23, 0, 0),
#   'genres': ' Comedy\n '},
#  {'title': 'Snow Dogs',
#   'domestic_opening_gross': 17814259,
#   'budget': 33000000,
#   'domestic_gross': 81172560,
#   'international_gross': 33862530,
#   'worldwide_gross': 115035090,
#   'runtime_minutes': 99,
#   'rating': 'PG',
#   'release_month': 1,
#   'release_date': datetime.datetime(2002, 1, 18, 0, 0),
#   'genres': ' Adventure\n Comedy\n Family\n Sport\n '},
#  {'title': '21',
#   'domestic_opening_gross': 24105943,
#   'budget': 35000000,
#   'domestic_gross': 81159365,
#   'international_gross': 78649005,
#   'worldwide_gross': 159808370,
#   'runtime_minutes': 123,
#   'rating': 'PG-13',
#   'release_month': 3,
#   'release_date': datetime.datetime(2008, 3, 28, 0, 0),
#   'genres': ' Crime\n Drama\n History\n Thriller\n '},
#  {'title': 'While You Were Sleeping',
#   'domestic_opening_gross': 9288915,
#   'budget': 17000000,
#   'domestic_gross': 81057016,
#   'international_gross': 101000000,
#   'worldwide_gross': 182057016,
#   'runtime_minutes': 103,
#   'rating': 'PG',
#   'release_month': 4,
#   'release_date': datetime.datetime(1995, 4, 21, 0, 0),
#   'genres': ' Comedy\n Drama\n Romance\n '},
#  {'title': 'Congo',
#   'domestic_opening_gross': 24642539,
#   'budget': 0,
#   'domestic_gross': 81022101,
#   'international_gross': 71000000,
#   'worldwide_gross': 152022101,
#   'runtime_minutes': 109,
#   'rating': 'PG-13',
#   'release_month': 6,
#   'release_date': datetime.datetime(1995, 6, 9, 0, 0),
#   'genres': ' Action\n Adventure\n Mystery\n Sci-Fi\n '},
#  {'title': 'The Notebook',
#   'domestic_opening_gross': 13464745,
#   'budget': 29000000,
#   'domestic_gross': 81001787,
#   'international_gross': 36813122,
#   'worldwide_gross': 117814909,
#   'runtime_minutes': 123,
#   'rating': 'PG-13',
#   'release_month': 6,
#   'release_date': datetime.datetime(2004, 6, 25, 0, 0),
#   'genres': ' Drama\n Romance\n '},
#  {'title': 'Jimmy Neutron: Boy Genius',
#   'domestic_opening_gross': 13832786,
#   'budget': 30000000,
#   'domestic_gross': 80936232,
#   'international_gross': 22056304,
#   'worldwide_gross': 102992536,
#   'runtime_minutes': 82,
#   'rating': None,
#   'release_month': 12,
#   'release_date': datetime.datetime(2001, 12, 21, 0, 0),
#   'genres': ' Action\n Adventure\n Animation\n Comedy\n Family\n Sci-Fi\n '},
#  {'title': 'Another 48 Hrs.',
#   'domestic_opening_gross': 19475559,
#   'budget': 0,
#   'domestic_gross': 80818974,
#   'international_gross': 72700000,
#   'worldwide_gross': 153518974,
#   'runtime_minutes': 93,
#   'rating': None,
#   'release_month': 6,
#   'release_date': datetime.datetime(1990, 6, 8, 0, 0),
#   'genres': ' Action\n Comedy\n Crime\n Drama\n Mystery\n Thriller\n '},
#  {'title': 'Moonstruck',
#   'domestic_opening_gross': 127599,
#   'budget': 0,
#   'domestic_gross': 80640528,
#   'international_gross': 80640528,
#   'worldwide_gross': 0,
#   'runtime_minutes': 102,
#   'rating': None,
#   'release_month': 12,
#   'release_date': datetime.datetime(1987, 12, 18, 0, 0),
#   'genres': ' Comedy\n Drama\n Romance\n '},
#  {'title': 'Eat Pray Love',
#   'domestic_opening_gross': 23104523,
#   'budget': 60000000,
#   'domestic_gross': 80574010,
#   'international_gross': 124020006,
#   'worldwide_gross': 204594016,
#   'runtime_minutes': 133,
#   'rating': 'PG-13',
#   'release_month': 8,
#   'release_date': datetime.datetime(2010, 8, 13, 0, 0),
#   'genres': ' Biography\n Drama\n Romance\n '},
#  {'title': 'The Texas Chainsaw Massacre',
#   'domestic_opening_gross': 29100000,
#   'budget': 9500000,
#   'domestic_gross': 80571655,
#   'international_gross': 26792250,
#   'worldwide_gross': 107363905,
#   'runtime_minutes': 98,
#   'rating': 'R',
#   'release_month': 10,
#   'release_date': datetime.datetime(2003, 10, 17, 0, 0),
#   'genres': ' Horror\n '},
#  {'title': 'Zookeeper',
#   'domestic_opening_gross': 20065617,
#   'budget': 80000000,
#   'domestic_gross': 80360843,
#   'international_gross': 89491916,
#   'worldwide_gross': 169852759,
#   'runtime_minutes': 102,
#   'rating': 'PG',
#   'release_month': 7,
#   'release_date': datetime.datetime(2011, 7, 6, 0, 0),
#   'genres': ' Comedy\n Family\n Fantasy\n Romance\n '},
#  {'title': 'Alien vs. Predator',
#   'domestic_opening_gross': 38291056,
#   'budget': 60000000,
#   'domestic_gross': 80282231,
#   'international_gross': 97144859,
#   'worldwide_gross': 177427090,
#   'runtime_minutes': 101,
#   'rating': 'PG-13',
#   'release_month': 8,
#   'release_date': datetime.datetime(2004, 8, 12, 0, 0),
#   'genres': ' Action\n Adventure\n Horror\n Sci-Fi\n Thriller\n '},
#  {'title': 'What Happens in Vegas',
#   'domestic_opening_gross': 20172474,
#   'budget': 35000000,
#   'domestic_gross': 80277646,
#   'international_gross': 139097916,
#   'worldwide_gross': 219375562,
#   'runtime_minutes': 99,
#   'rating': 'PG-13',
#   'release_month': 5,
#   'release_date': datetime.datetime(2008, 5, 7, 0, 0),
#   'genres': ' Comedy\n Romance\n '},
#  {'title': 'The Dukes of Hazzard',
#   'domestic_opening_gross': 30675314,
#   'budget': 50000000,
#   'domestic_gross': 80270227,
#   'international_gross': 30799288,
#   'worldwide_gross': 111069515,
#   'runtime_minutes': 104,
#   'rating': 'PG-13',
#   'release_month': 8,
#   'release_date': datetime.datetime(2005, 8, 5, 0, 0),
#   'genres': ' Comedy\n '},
#  {'title': 'The Wedding Singer',
#   'domestic_opening_gross': 18865080,
#   'budget': 18000000,
#   'domestic_gross': 80245725,
#   'international_gross': 43061262,
#   'worldwide_gross': 123306987,
#   'runtime_minutes': 97,
#   'rating': 'PG-13',
#   'release_month': 2,
#   'release_date': datetime.datetime(1998, 2, 13, 0, 0),
#   'genres': ' Comedy\n Music\n Romance\n '},
#  {'title': 'Saw III',
#   'domestic_opening_gross': 33610391,
#   'budget': 10000000,
#   'domestic_gross': 80238724,
#   'international_gross': 84635551,
#   'worldwide_gross': 164874275,
#   'runtime_minutes': 108,
#   'rating': 'R',
#   'release_month': 10,
#   'release_date': datetime.datetime(2006, 10, 27, 0, 0),
#   'genres': ' Crime\n Horror\n Mystery\n Thriller\n '},
#  {'title': 'The Mummy',
#   'domestic_opening_gross': 31688375,
#   'budget': 125000000,
#   'domestic_gross': 80227895,
#   'international_gross': 329003712,
#   'worldwide_gross': 409231607,
#   'runtime_minutes': 111,
#   'rating': 'PG-13',
#   'release_month': 6,
#   'release_date': datetime.datetime(2017, 6, 6, 0, 0),
#   'genres': ' Action\n Adventure\n Fantasy\n Thriller\n '},
#  {'title': 'Disturbia',
#   'domestic_opening_gross': 22224982,
#   'budget': 20000000,
#   'domestic_gross': 80209692,
#   'international_gross': 37904528,
#   'worldwide_gross': 118114220,
#   'runtime_minutes': 105,
#   'rating': 'PG-13',
#   'release_month': 4,
#   'release_date': datetime.datetime(2007, 4, 12, 0, 0),
#   'genres': ' Crime\n Drama\n Mystery\n Thriller\n '},
#  {'title': 'Nacho Libre',
#   'domestic_opening_gross': 28309599,
#   'budget': 35000000,
#   'domestic_gross': 80197993,
#   'international_gross': 19057467,
#   'worldwide_gross': 99255460,
#   'runtime_minutes': 92,
#   'rating': 'PG',
#   'release_month': 6,
#   'release_date': datetime.datetime(2006, 6, 16, 0, 0),
#   'genres': ' Comedy\n Family\n Sport\n '},
#  {'title': 'Jumper',
#   'domestic_opening_gross': 27354808,
#   'budget': 85000000,
#   'domestic_gross': 80172128,
#   'international_gross': 144959985,
#   'worldwide_gross': 225132113,
#   'runtime_minutes': 88,
#   'rating': 'PG-13',
#   'release_month': 2,
#   'release_date': datetime.datetime(2008, 2, 13, 0, 0),
#   'genres': ' Action\n Adventure\n Sci-Fi\n Thriller\n '},
#  {'title': 'Goosebumps',
#   'domestic_opening_gross': 23618556,
#   'budget': 58000000,
#   'domestic_gross': 80080379,
#   'international_gross': 78181045,
#   'worldwide_gross': 158261424,
#   'runtime_minutes': 103,
#   'rating': 'PG',
#   'release_month': 10,
#   'release_date': datetime.datetime(2015, 10, 14, 0, 0),
#   'genres': ' Adventure\n Comedy\n Family\n Fantasy\n Horror\n '},
#  {'title': 'Jack Reacher',
#   'domestic_opening_gross': 15210156,
#   'budget': 60000000,
#   'domestic_gross': 80070736,
#   'international_gross': 138269859,
#   'worldwide_gross': 218340595,
#   'runtime_minutes': 130,
#   'rating': 'PG-13',
#   'release_month': 12,
#   'release_date': datetime.datetime(2012, 12, 20, 0, 0),
#   'genres': ' Action\n Thriller\n '},
#  {'title': 'Cloverfield',
#   'domestic_opening_gross': 40058229,
#   'budget': 25000000,
#   'domestic_gross': 80048433,
#   'international_gross': 92345747,
#   'worldwide_gross': 172394180,
#   'runtime_minutes': 85,
#   'rating': 'PG-13',
#   'release_month': 1,
#   'release_date': datetime.datetime(2008, 1, 17, 0, 0),
#   'genres': ' Action\n Horror\n Sci-Fi\n Thriller\n '},
#  {'title': 'Footloose',
#   'domestic_opening_gross': 8556935,
#   'budget': 8200000,
#   'domestic_gross': 80035402,
#   'international_gross': 3662,
#   'worldwide_gross': 80039064,
#   'runtime_minutes': 107,
#   'rating': None,
#   'release_month': 2,
#   'release_date': datetime.datetime(1984, 2, 17, 0, 0),
#   'genres': ' Drama\n Music\n Romance\n '},
#  {'title': 'Dear John',
#   'domestic_opening_gross': 30468614,
#   'budget': 25000000,
#   'domestic_gross': 80014842,
#   'international_gross': 34969824,
#   'worldwide_gross': 114984666,
#   'runtime_minutes': 108,
#   'rating': 'PG-13',
#   'release_month': 2,
#   'release_date': datetime.datetime(2010, 2, 5, 0, 0),
#   'genres': ' Drama\n Romance\n War\n '},
#  {'title': 'Men in Black: International',
#   'domestic_opening_gross': 30035838,
#   'budget': 110000000,
#   'domestic_gross': 80001807,
#   'international_gross': 173888894,
#   'worldwide_gross': 253890701,
#   'runtime_minutes': 114,
#   'rating': 'PG-13',
#   'release_month': 6,
#   'release_date': datetime.datetime(2019, 6, 12, 0, 0),
#   'genres': ' Action\n Adventure\n Comedy\n Sci-Fi\n '},
#  {'title': 'A Star Is Born',
#   'domestic_opening_gross': 0,
#   'budget': 0,
#   'domestic_gross': 80000000,
#   'international_gross': 80000000,
#   'worldwide_gross': 0,
#   'runtime_minutes': 139,
#   'rating': None,
#   'release_month': 12,
#   'release_date': datetime.datetime(1976, 12, 19, 0, 0),
#   'genres': ' Drama\n Music\n Romance\n '},
#  {'title': 'Knowing',
#   'domestic_opening_gross': 24604751,
#   'budget': 50000000,
#   'domestic_gross': 79957634,
#   'international_gross': 103700864,
#   'worldwide_gross': 183658498,
#   'runtime_minutes': 121,
#   'rating': 'PG-13',
#   'release_month': 5,
#   'release_date': datetime.datetime(2007, 5, 16, 0, 0),
#   'genres': ' Action\n Drama\n Sci-Fi\n Thriller\n '}]

# %%
lifetime_movies_info = pd.DataFrame(lifetime_movie_data)
lifetime_movies_info.set_index('title', inplace = True)

# %%
lifetime_movies_info.head()
# Out:
#                                                  domestic_opening_gross  \
# title
# Maid in Manhattan                                              18711407
# He's Just Not That Into You                                    27785487
# Master and Commander: The Far Side of the World                25105990
# Flight                                                         24900566
# The Fighter                                                      300010
#
#                                                     budget  domestic_gross  \
# title
# Maid in Manhattan                                 55000000        94011225
# He's Just Not That Into You                              0        93953653
# Master and Commander: The Far Side of the World  150000000        93927920
# Flight                                            31000000        93772375
# The Fighter                                       25000000        93617009
#
#                                                  international_gross  \
# title
# Maid in Manhattan                                           60895468
# He's Just Not That Into You                                 84912505
# Master and Commander: The Far Side of the World            117694615
# Flight                                                      68000000
# The Fighter                                                 35573860
#
#                                                  worldwide_gross  \
# title
# Maid in Manhattan                                      154906693
# He's Just Not That Into You                            178866158
# Master and Commander: The Far Side of the World        211622535
# Flight                                                 161772375
# The Fighter                                            129190869
#
#                                                  runtime_minutes rating  \
# title
# Maid in Manhattan                                          105.0  PG-13
# He's Just Not That Into You                                129.0  PG-13
# Master and Commander: The Far Side of the World            138.0  PG-13
# Flight                                                     138.0      R
# The Fighter                                                116.0      R
#
#                                                  release_month release_date  \
# title
# Maid in Manhattan                                           12   2002-12-13
# He's Just Not That Into You                                  2   2009-02-05
# Master and Commander: The Far Side of the World             11   2003-11-14
# Flight                                                      11   2012-11-02
# The Fighter                                                 11   2009-11-20
#
#                                                                                          genres
# title
# Maid in Manhattan                                                   Comedy\n Drama\n Romance\n
# He's Just Not That Into You                                         Comedy\n Drama\n Romance\n
# Master and Commander: The Far Side of the World   Action\n Adventure\n Drama\n History\n War\n
# Flight                                                                      Drama\n Thriller\n
# The Fighter                                                        Biography\n Drama\n Sport\n

# %%
# change number according to page
lifetime_movies_info_5 = lifetime_movies_info
lifetime_movies_5 = lifetime_movies
lifetime_movies_5 = lifetime_movies_5.merge(lifetime_movies_info_5, left_index=True, right_index = True)
lifetime_movies_5.head()
# Out:
#                                                                              link_stub  \
# Maid in Manhattan                                /title/tt0252076/?ref_=bo_cso_table_1
# He's Just Not That Into You                      /title/tt1001508/?ref_=bo_cso_table_2
# Master and Commander: The Far Side of the World  /title/tt0311113/?ref_=bo_cso_table_3
# Flight                                           /title/tt1907668/?ref_=bo_cso_table_4
# The Fighter                                      /title/tt0964517/?ref_=bo_cso_table_5
#
#                                                 rank  \
# Maid in Manhattan                                801
# He's Just Not That Into You                      802
# Master and Commander: The Far Side of the World  803
# Flight                                           804
# The Fighter                                      805
#
#                                                                                            title  \
# Maid in Manhattan                                                              Maid in Manhattan
# He's Just Not That Into You                                          He's Just Not That Into You
# Master and Commander: The Far Side of the World  Master and Commander: The Far Side of the World
# Flight                                                                                    Flight
# The Fighter                                                                          The Fighter
#
#                                                 domestic_gross_x release_year  \
# Maid in Manhattan                                    $94,011,225         2002
# He's Just Not That Into You                          $93,953,653         2009
# Master and Commander: The Far Side of the World      $93,927,920         2003
# Flight                                               $93,772,375         2012
# The Fighter                                          $93,617,009         2010
#
#                                                  domestic_opening_gross  \
# Maid in Manhattan                                              18711407
# He's Just Not That Into You                                    27785487
# Master and Commander: The Far Side of the World                25105990
# Flight                                                         24900566
# The Fighter                                                      300010
#
#                                                     budget  domestic_gross_y  \
# Maid in Manhattan                                 55000000          94011225
# He's Just Not That Into You                              0          93953653
# Master and Commander: The Far Side of the World  150000000          93927920
# Flight                                            31000000          93772375
# The Fighter                                       25000000          93617009
#
#                                                  international_gross  \
# Maid in Manhattan                                           60895468
# He's Just Not That Into You                                 84912505
# Master and Commander: The Far Side of the World            117694615
# Flight                                                      68000000
# The Fighter                                                 35573860
#
#                                                  worldwide_gross  \
# Maid in Manhattan                                      154906693
# He's Just Not That Into You                            178866158
# Master and Commander: The Far Side of the World        211622535
# Flight                                                 161772375
# The Fighter                                            129190869
#
#                                                  runtime_minutes rating  \
# Maid in Manhattan                                          105.0  PG-13
# He's Just Not That Into You                                129.0  PG-13
# Master and Commander: The Far Side of the World            138.0  PG-13
# Flight                                                     138.0      R
# The Fighter                                                116.0      R
#
#                                                  release_month release_date  \
# Maid in Manhattan                                           12   2002-12-13
# He's Just Not That Into You                                  2   2009-02-05
# Master and Commander: The Far Side of the World             11   2003-11-14
# Flight                                                      11   2012-11-02
# The Fighter                                                 11   2009-11-20
#
#                                                                                    genres
# Maid in Manhattan                                                [Comedy, Drama, Romance]
# He's Just Not That Into You                                      [Comedy, Drama, Romance]
# Master and Commander: The Far Side of the World  [Action, Adventure, Drama, History, War]
# Flight                                                                  [Drama, Thriller]
# The Fighter                                                     [Biography, Drama, Sport]

# %%
#lifetime_movies = lifetime_movies.merge(lifetime_movies_info, left_index=True, right_index=True)

#lifetime_movies.head()
# Out:
#                                                                         link_stub  \
# Star Wars: Episode VII - The Force Awakens  /title/tt2488496/?ref_=bo_cso_table_1
# Avengers: Endgame                           /title/tt4154796/?ref_=bo_cso_table_2
# Avatar                                      /title/tt0499549/?ref_=bo_cso_table_3
# Black Panther                               /title/tt1825683/?ref_=bo_cso_table_4
# Avengers: Infinity War                      /title/tt4154756/?ref_=bo_cso_table_5
#
#                                            rank  \
# Star Wars: Episode VII - The Force Awakens    1
# Avengers: Endgame                             2
# Avatar                                        3
# Black Panther                                 4
# Avengers: Infinity War                        5
#
#                                                                                  title  \
# Star Wars: Episode VII - The Force Awakens  Star Wars: Episode VII - The Force Awakens
# Avengers: Endgame                                                    Avengers: Endgame
# Avatar                                                                          Avatar
# Black Panther                                                            Black Panther
# Avengers: Infinity War                                          Avengers: Infinity War
#
#                                            domestic_gross_x release_year  \
# Star Wars: Episode VII - The Force Awakens     $936,662,225         2015
# Avengers: Endgame                              $858,373,000         2019
# Avatar                                         $760,507,625         2009
# Black Panther                                  $700,426,566         2018
# Avengers: Infinity War                         $678,815,482         2018
#
#                                             domestic_opening_gross_x  \
# Star Wars: Episode VII - The Force Awakens                 247966675
# Avengers: Endgame                                          357115007
# Avatar                                                      77025481
# Black Panther                                              202003951
# Avengers: Infinity War                                     257698183
#
#                                              budget_x  domestic_gross_y  \
# Star Wars: Episode VII - The Force Awakens  245000000         936662225
# Avengers: Endgame                           356000000         858373000
# Avatar                                      237000000         760507625
# Black Panther                                       0         700426566
# Avengers: Infinity War                              0         678815482
#
#                                             international_gross_x  \
# Star Wars: Episode VII - The Force Awakens             1131791908
# Avengers: Endgame                                      1939427564
# Avatar                                                 2029931467
# Black Panther                                           647171407
# Avengers: Infinity War                                 1369544272
#
#                                             worldwide_gross_x  ...  \
# Star Wars: Episode VII - The Force Awakens         2068454133  ...
# Avengers: Endgame                                  2797800564  ...
# Avatar                                             2790439092  ...
# Black Panther                                      1347597973  ...
# Avengers: Infinity War                             2048359754  ...
#
#                                             domestic_opening_gross_y  \
# Star Wars: Episode VII - The Force Awakens                 247966675
# Avengers: Endgame                                          357115007
# Avatar                                                      77025481
# Black Panther                                              202003951
# Avengers: Infinity War                                     257698183
#
#                                              budget_y  domestic_gross  \
# Star Wars: Episode VII - The Force Awakens  245000000       936662225
# Avengers: Endgame                           356000000       858373000
# Avatar                                      237000000       760507625
# Black Panther                                       0       700426566
# Avengers: Infinity War                              0       678815482
#
#                                            international_gross_y  \
# Star Wars: Episode VII - The Force Awakens            1131791908
# Avengers: Endgame                                     1939427564
# Avatar                                                2029931467
# Black Panther                                          647171407
# Avengers: Infinity War                                1369544272
#
#                                            worldwide_gross_y  \
# Star Wars: Episode VII - The Force Awakens        2068454133
# Avengers: Endgame                                 2797800564
# Avatar                                            2790439092
# Black Panther                                     1347597973
# Avengers: Infinity War                            2048359754
#
#                                             runtime_minutes_y  rating_y  \
# Star Wars: Episode VII - The Force Awakens              138.0     PG-13
# Avengers: Endgame                                       181.0     PG-13
# Avatar                                                  162.0     PG-13
# Black Panther                                           134.0     PG-13
# Avengers: Infinity War                                  149.0     PG-13
#
#                                             release_month_y  release_date_y  \
# Star Wars: Episode VII - The Force Awakens               12      2015-12-16
# Avengers: Endgame                                         4      2019-04-24
# Avatar                                                   12      2009-12-16
# Black Panther                                             2      2018-02-13
# Avengers: Infinity War                                    4      2018-04-25
#
#                                                                         genres_y
# Star Wars: Episode VII - The Force Awakens           [Action, Adventure, Sci-Fi]
# Avengers: Endgame                             [Action, Adventure, Drama, Sci-Fi]
# Avatar                                      [Action, Adventure, Fantasy, Sci-Fi]
# Black Panther                                        [Action, Adventure, Sci-Fi]
# Avengers: Infinity War                               [Action, Adventure, Sci-Fi]
#
# [5 rows x 25 columns]

# %%
#change number page
lifetime_movies_5.to_csv('lifetime_movies_5.csv')

# %%
df1 = pd.read_csv('lifetime_movies.csv')
df2 = pd.read_csv('lifetime_movies_2.csv')
df3 = pd.read_csv('lifetime_movies_3.csv')
df4 = pd.read_csv('lifetime_movies_4.csv')
df5 = pd.read_csv('lifetime_movies_5.csv')
frames = [df1, df2, df3, df4, df5]
movie_list = pd.concat(frames)
movie_list.to_csv('movie_list.csv')
df = pd.read_csv('movie_list.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              996 non-null    int64
#  1   Unnamed: 0.1            996 non-null    object
#  2   link_stub               996 non-null    object
#  3   rank                    996 non-null    object
#  4   title                   996 non-null    object
#  5   domestic_gross_x        996 non-null    object
#  6   release_year            996 non-null    int64
#  7   domestic_opening_gross  996 non-null    int64
#  8   budget                  996 non-null    int64
#  9   domestic_gross_y        996 non-null    int64
#  10  international_gross     996 non-null    int64
#  11  worldwide_gross         996 non-null    int64
#  12  runtime_minutes         975 non-null    float64
#  13  rating                  867 non-null    object
#  14  release_month           996 non-null    int64
#  15  release_date            996 non-null    object
#  16  genres                  996 non-null    object
# dtypes: float64(1), int64(8), object(8)
# memory usage: 132.4+ KB

# %% [markdown]
# ### IMDB Top 100 Actors 2018

# %%
url = 'https://www.imdb.com/list/ls023242359/'
response = requests.get(url)
page = response.text
soup = BeautifulSoup(page, 'lxml')

# %%
soup.find_all('span', class_='lister-item-index')[0].text

# %%
soup.find('div', class_='lister-item-content').find_all('a')

# %%
soup.find('div', class_='lister-item-content').find('a').text.split('\n')[0]

# %%
top_list = soup.find('div', class_='lister-list').find_all('a')
top_list

# %%
soup.find('div', class_='lister-list').find_all('a')[1].text.split('\n')[0]

# %%
top_actor = []
for top in top_list:
    top = top.text.split('\n')[0]
    top_actor += [top]
  
top_actor

# %%
soup.find('div', class_='lister-list').find_all('a').get('href', ref_='nmls_hd')

# %%
url='https://www.the-numbers.com/movie/budgets/all'
response = requests.get(url)
page = response.text
soup = BeautifulSoup(page, 'lxml')

# %%
#soup.find_all('td', class_="data")

# %%
# Rank:
rank = soup.find_all('td', class_="data")[0].text
rank
# Out:
# '1'

# %%
# Budget
prod_budget = soup.find_all('td', class_="data")
prod_budget
# Out:
# [<td class="data">1</td>,
#  <td class="data"> $400,000,000</td>,
#  <td class="data"> $858,373,000</td>,
#  <td class="data"> $2,797,800,564</td>,
#  <td class="data">2</td>,
#  <td class="data"> $379,000,000</td>,
#  <td class="data"> $241,063,875</td>,
#  <td class="data"> $1,045,663,875</td>,
#  <td class="data">3</td>,
#  <td class="data"> $365,000,000</td>,
#  <td class="data"> $459,005,868</td>,
#  <td class="data"> $1,396,099,202</td>,
#  <td class="data">4</td>,
#  <td class="data"> $306,000,000</td>,
#  <td class="data"> $936,662,225</td>,
#  <td class="data"> $2,065,478,084</td>,
#  <td class="data">5</td>,
#  <td class="data"> $300,000,000</td>,
#  <td class="data"> $678,815,482</td>,
#  <td class="data"> $2,044,540,523</td>,
#  <td class="data">6</td>,
#  <td class="data"> $300,000,000</td>,
#  <td class="data"> $309,420,425</td>,
#  <td class="data"> $963,420,425</td>,
#  <td class="data">7</td>,
#  <td class="data"> $300,000,000</td>,
#  <td class="data"> $229,024,295</td>,
#  <td class="data"> $655,945,209</td>,
#  <td class="data">8</td>,
#  <td class="data"> $300,000,000</td>,
#  <td class="data"> $200,074,175</td>,
#  <td class="data"> $879,500,760</td>,
#  <td class="data">9</td>,
#  <td class="data"> $275,000,000</td>,
#  <td class="data"> $515,202,542</td>,
#  <td class="data"> $1,072,944,222</td>,
#  <td class="data">10</td>,
#  <td class="data"> $275,000,000</td>,
#  <td class="data"> $213,767,512</td>,
#  <td class="data"> $393,151,347</td>,
#  <td class="data">11</td>,
#  <td class="data"> $263,700,000</td>,
#  <td class="data"> $73,058,679</td>,
#  <td class="data"> $282,778,100</td>,
#  <td class="data">12</td>,
#  <td class="data"> $263,000,000</td>,
#  <td class="data"> $330,360,194</td>,
#  <td class="data"> $872,395,091</td>,
#  <td class="data">13</td>,
#  <td class="data"> $260,000,000</td>,
#  <td class="data"> $543,638,043</td>,
#  <td class="data"> $1,654,381,934</td>,
#  <td class="data">14</td>,
#  <td class="data"> $260,000,000</td>,
#  <td class="data"> $200,821,936</td>,
#  <td class="data"> $585,727,091</td>,
#  <td class="data">15</td>,
#  <td class="data"> $258,000,000</td>,
#  <td class="data"> $336,530,303</td>,
#  <td class="data"> $894,860,230</td>,
#  <td class="data">16</td>,
#  <td class="data"> $250,000,000</td>,
#  <td class="data"> $408,084,349</td>,
#  <td class="data"> $1,151,918,521</td>,
#  <td class="data">17</td>,
#  <td class="data"> $250,000,000</td>,
#  <td class="data"> $302,089,278</td>,
#  <td class="data"> $930,673,167</td>,
#  <td class="data">18</td>,
#  <td class="data"> $250,000,000</td>,
#  <td class="data"> $258,241,522</td>,
#  <td class="data"> $960,238,087</td>,
#  <td class="data">19</td>,
#  <td class="data"> $250,000,000</td>,
#  <td class="data"> $255,119,788</td>,
#  <td class="data"> $943,328,905</td>,
#  <td class="data">20</td>,
#  <td class="data"> $250,000,000</td>,
#  <td class="data"> $225,764,765</td>,
#  <td class="data"> $1,236,703,796</td>,
#  <td class="data">21</td>,
#  <td class="data"> $250,000,000</td>,
#  <td class="data"> $0</td>,
#  <td class="data"> $0</td>,
#  <td class="data">22</td>,
#  <td class="data"> $237,000,000</td>,
#  <td class="data"> $760,507,625</td>,
#  <td class="data"> $2,788,701,337</td>,
#  <td class="data">23</td>,
#  <td class="data"> $232,000,000</td>,
#  <td class="data"> $200,120,000</td>,
#  <td class="data"> $391,081,192</td>,
#  <td class="data">24</td>,
#  <td class="data"> $230,000,000</td>,
#  <td class="data"> $448,139,099</td>,
#  <td class="data"> $1,082,228,107</td>,
#  <td class="data">25</td>,
#  <td class="data"> $230,000,000</td>,
#  <td class="data"> $172,558,876</td>,
#  <td class="data"> $788,241,137</td>,
#  <td class="data">26</td>,
#  <td class="data"> $230,000,000</td>,
#  <td class="data"> $169,368,427</td>,
#  <td class="data"> $591,692,078</td>,
#  <td class="data">27</td>,
#  <td class="data"> $225,000,000</td>,
#  <td class="data"> $623,357,910</td>,
#  <td class="data"> $1,515,100,211</td>,
#  <td class="data">28</td>,
#  <td class="data"> $225,000,000</td>,
#  <td class="data"> $423,315,812</td>,
#  <td class="data"> $1,066,215,812</td>,
#  <td class="data">29</td>,
#  <td class="data"> $225,000,000</td>,
#  <td class="data"> $291,045,518</td>,
#  <td class="data"> $667,999,518</td>,
#  <td class="data">30</td>,
#  <td class="data"> $225,000,000</td>,
#  <td class="data"> $141,621,490</td>,
#  <td class="data"> $417,341,288</td>,
#  <td class="data">31</td>,
#  <td class="data"> $225,000,000</td>,
#  <td class="data"> $89,302,115</td>,
#  <td class="data"> $260,002,115</td>,
#  <td class="data">32</td>,
#  <td class="data"> $220,000,000</td>,
#  <td class="data"> $262,030,663</td>,
#  <td class="data"> $757,890,267</td>,
#  <td class="data">33</td>,
#  <td class="data"> $220,000,000</td>,
#  <td class="data"> $65,233,400</td>,
#  <td class="data"> $313,477,717</td>,
#  <td class="data">34</td>,
#  <td class="data"> $217,000,000</td>,
#  <td class="data"> $130,168,683</td>,
#  <td class="data"> $602,893,340</td>,
#  <td class="data">35</td>,
#  <td class="data"> $215,000,000</td>,
#  <td class="data"> $652,270,625</td>,
#  <td class="data"> $1,669,943,967</td>,
#  <td class="data">36</td>,
#  <td class="data"> $215,000,000</td>,
#  <td class="data"> $179,020,854</td>,
#  <td class="data"> $654,213,485</td>,
#  <td class="data">37</td>,
#  <td class="data"> $210,000,000</td>,
#  <td class="data"> $402,111,870</td>,
#  <td class="data"> $836,519,699</td>,
#  <td class="data">38</td>,
#  <td class="data"> $210,000,000</td>,
#  <td class="data"> $245,439,076</td>,
#  <td class="data"> $1,104,054,072</td>,
#  <td class="data">39</td>,
#  <td class="data"> $210,000,000</td>,
#  <td class="data"> $234,362,462</td>,
#  <td class="data"> $459,260,946</td>,
#  <td class="data">40</td>,
#  <td class="data"> $210,000,000</td>,
#  <td class="data"> $105,487,148</td>,
#  <td class="data"> $322,459,006</td>,
#  <td class="data">41</td>,
#  <td class="data"> $207,000,000</td>,
#  <td class="data"> $218,080,025</td>,
#  <td class="data"> $550,517,357</td>,
#  <td class="data">42</td>,
#  <td class="data"> $205,000,000</td>,
#  <td class="data"> $70,107,728</td>,
#  <td class="data"> $367,262,558</td>,
#  <td class="data">43</td>,
#  <td class="data"> $205,000,000</td>,
#  <td class="data"> $57,929,000</td>,
#  <td class="data"> $363,129,000</td>,
#  <td class="data">44</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $700,059,566</td>,
#  <td class="data"> $1,336,494,321</td>,
#  <td class="data">45</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $659,363,944</td>,
#  <td class="data"> $2,207,986,545</td>,
#  <td class="data">46</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $620,181,382</td>,
#  <td class="data"> $1,332,539,889</td>,
#  <td class="data">47</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $608,581,744</td>,
#  <td class="data"> $1,242,805,359</td>,
#  <td class="data">48</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $532,177,324</td>,
#  <td class="data"> $1,055,135,598</td>,
#  <td class="data">49</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $486,295,561</td>,
#  <td class="data"> $1,025,006,125</td>,
#  <td class="data">50</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $434,038,008</td>,
#  <td class="data"> $1,073,357,481</td>,
#  <td class="data">51</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $415,004,880</td>,
#  <td class="data"> $1,068,879,522</td>,
#  <td class="data">52</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $408,992,272</td>,
#  <td class="data"> $1,215,392,272</td>,
#  <td class="data">53</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $389,813,101</td>,
#  <td class="data"> $869,113,101</td>,
#  <td class="data">54</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $373,524,485</td>,
#  <td class="data"> $794,697,557</td>,
#  <td class="data">55</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $334,191,110</td>,
#  <td class="data"> $1,025,491,110</td>,
#  <td class="data">56</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $304,360,277</td>,
#  <td class="data"> $1,110,526,981</td>,
#  <td class="data">57</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $303,003,568</td>,
#  <td class="data"> $1,017,003,568</td>,
#  <td class="data">58</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $268,488,329</td>,
#  <td class="data"> $743,588,329</td>,
#  <td class="data">59</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $234,770,996</td>,
#  <td class="data"> $490,359,051</td>,
#  <td class="data">60</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $233,921,534</td>,
#  <td class="data"> $747,862,775</td>,
#  <td class="data">61</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $202,853,933</td>,
#  <td class="data"> $708,996,336</td>,
#  <td class="data">62</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $191,450,875</td>,
#  <td class="data"> $560,155,383</td>,
#  <td class="data">63</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $173,956,935</td>,
#  <td class="data"> $759,765,123</td>,
#  <td class="data">64</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $172,062,763</td>,
#  <td class="data"> $400,062,763</td>,
#  <td class="data">65</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $166,112,167</td>,
#  <td class="data"> $757,677,748</td>,
#  <td class="data">66</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $159,555,901</td>,
#  <td class="data"> $651,280,475</td>,
#  <td class="data">67</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $125,322,469</td>,
#  <td class="data"> $365,491,792</td>,
#  <td class="data">68</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $116,601,172</td>,
#  <td class="data"> $219,535,492</td>,
#  <td class="data">69</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $90,759,676</td>,
#  <td class="data"> $336,359,676</td>,
#  <td class="data">70</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $65,845,974</td>,
#  <td class="data"> $246,356,895</td>,
#  <td class="data">71</td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $0</td>,
#  <td class="data"> $69,963,700</td>,
#  <td class="data">72</td>,
#  <td class="data"> $195,000,000</td>,
#  <td class="data"> $352,390,543</td>,
#  <td class="data"> $1,123,794,079</td>,
#  <td class="data">73</td>,
#  <td class="data"> $195,000,000</td>,
#  <td class="data"> $80,101,125</td>,
#  <td class="data"> $409,953,905</td>,
#  <td class="data">74</td>,
#  <td class="data"> $195,000,000</td>,
#  <td class="data"> $65,187,603</td>,
#  <td class="data"> $197,687,603</td>,
#  <td class="data">75</td>,
#  <td class="data"> $190,000,000</td>,
#  <td class="data"> $353,007,020</td>,
#  <td class="data"> $1,517,179,709</td>,
#  <td class="data">76</td>,
#  <td class="data"> $190,000,000</td>,
#  <td class="data"> $228,778,661</td>,
#  <td class="data"> $467,381,584</td>,
#  <td class="data">77</td>,
#  <td class="data"> $190,000,000</td>,
#  <td class="data"> $202,359,711</td>,
#  <td class="data"> $531,514,650</td>,
#  <td class="data">78</td>,
#  <td class="data"> $190,000,000</td>,
#  <td class="data"> $144,840,419</td>,
#  <td class="data"> $353,640,419</td>,
#  <td class="data">79</td>,
#  <td class="data"> $190,000,000</td>,
#  <td class="data"> $137,855,863</td>,
#  <td class="data"> $315,709,697</td>,
#  <td class="data">80</td>,
#  <td class="data"> $190,000,000</td>,
#  <td class="data"> $101,802,906</td>,
#  <td class="data"> $411,002,906</td>,
#  <td class="data">81</td>,
#  <td class="data"> $187,500,000</td>,
#  <td class="data"> $123,087,120</td>,
#  <td class="data"> $333,771,037</td>,
#  <td class="data">82</td>,
#  <td class="data"> $186,000,000</td>,
#  <td class="data"> $318,604,126</td>,
#  <td class="data"> $585,171,547</td>,
#  <td class="data">83</td>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $533,720,947</td>,
#  <td class="data"> $999,434,419</td>,
#  <td class="data">84</td>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $317,101,119</td>,
#  <td class="data"> $786,635,413</td>,
#  <td class="data">85</td>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $237,282,182</td>,
#  <td class="data"> $554,606,532</td>,
#  <td class="data">86</td>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $168,052,812</td>,
#  <td class="data"> $561,072,059</td>,
#  <td class="data">87</td>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $158,848,340</td>,
#  <td class="data"> $335,673,708</td>,
#  <td class="data">88</td>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $113,929,605</td>,
#  <td class="data"> $489,346,495</td>,
#  <td class="data">89</td>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $92,054,159</td>,
#  <td class="data"> $259,136,784</td>,
#  <td class="data">90</td>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $62,253,077</td>,
#  <td class="data"> $250,372,367</td>,
#  <td class="data">91</td>,
#  <td class="data"> $182,000,000</td>,
#  <td class="data"> $355,559,216</td>,
#  <td class="data"> $1,046,918,234</td>,
#  <td class="data">92</td>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $315,058,289</td>,
#  <td class="data"> $850,482,778</td>,
#  <td class="data">93</td>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $291,710,957</td>,
#  <td class="data"> $720,539,572</td>,
#  <td class="data">94</td>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $241,407,328</td>,
#  <td class="data"> $758,536,735</td>,
#  <td class="data">95</td>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $234,037,575</td>,
#  <td class="data"> $811,724,385</td>,
#  <td class="data">96</td>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $223,808,164</td>,
#  <td class="data"> $532,508,025</td>,
#  <td class="data">97</td>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $140,125,968</td>,
#  <td class="data"> $256,585,882</td>,
#  <td class="data">98</td>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $126,643,061</td>,
#  <td class="data"> $348,902,025</td>,
#  <td class="data">99</td>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $73,864,507</td>,
#  <td class="data"> $180,047,784</td>,
#  <td class="data">100</td>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $40,479,370</td>,
#  <td class="data"> $215,098,356</td>]

# %%
prod_budget = soup.find_all('td', class_="data")
prod_buddg

# %%
soup.find('table').find_all('td','href'=='/movie/')
# Out:
# [<td class="data">1</td>,
#  <td><a href="/box-office-chart/daily/2019/04/23">Apr 23, 2019</a></td>,
#  <td><b><a href="/movie/Avengers-Endgame-(2019)#tab=summary">Avengers: Endgame</a></b></td>,
#  <td class="data"> $400,000,000</td>,
#  <td class="data"> $858,373,000</td>,
#  <td class="data"> $2,797,800,564</td>,
#  <td class="data">2</td>,
#  <td><a href="/box-office-chart/daily/2011/05/20">May 20, 2011</a></td>,
#  <td><b><a href="/movie/Pirates-of-the-Caribbean-On-Stranger-Tides#tab=summary">Pirates of the Caribbean: On Stranger Tides</a></b></td>,
#  <td class="data"> $379,000,000</td>,
#  <td class="data"> $241,063,875</td>,
#  <td class="data"> $1,045,663,875</td>,
#  <td class="data">3</td>,
#  <td><a href="/box-office-chart/daily/2015/04/22">Apr 22, 2015</a></td>,
#  <td><b><a href="/movie/Avengers-Age-of-Ultron#tab=summary">Avengers: Age of Ultron</a></b></td>,
#  <td class="data"> $365,000,000</td>,
#  <td class="data"> $459,005,868</td>,
#  <td class="data"> $1,396,099,202</td>,
#  <td class="data">4</td>,
#  <td><a href="/box-office-chart/daily/2015/12/16">Dec 16, 2015</a></td>,
#  <td><b><a href="/movie/Star-Wars-Ep-VII-The-Force-Awakens#tab=summary">Star Wars Ep. VII: The Force Awakens</a></b></td>,
#  <td class="data"> $306,000,000</td>,
#  <td class="data"> $936,662,225</td>,
#  <td class="data"> $2,065,478,084</td>,
#  <td class="data">5</td>,
#  <td><a href="/box-office-chart/daily/2018/04/25">Apr 25, 2018</a></td>,
#  <td><b><a href="/movie/Avengers-Infinity-War#tab=summary">Avengers: Infinity War</a></b></td>,
#  <td class="data"> $300,000,000</td>,
#  <td class="data"> $678,815,482</td>,
#  <td class="data"> $2,044,540,523</td>,
#  <td class="data">6</td>,
#  <td><a href="/box-office-chart/daily/2007/05/24">May 24, 2007</a></td>,
#  <td><b><a href="/movie/Pirates-of-the-Caribbean-At-Worlds-End#tab=summary">Pirates of the Caribbean: At Worldâs End</a></b></td>,
#  <td class="data"> $300,000,000</td>,
#  <td class="data"> $309,420,425</td>,
#  <td class="data"> $963,420,425</td>,
#  <td class="data">7</td>,
#  <td><a href="/box-office-chart/daily/2017/11/13">Nov 13, 2017</a></td>,
#  <td><b><a href="/movie/Justice-League-(2017)#tab=summary">Justice League</a></b></td>,
#  <td class="data"> $300,000,000</td>,
#  <td class="data"> $229,024,295</td>,
#  <td class="data"> $655,945,209</td>,
#  <td class="data">8</td>,
#  <td><a href="/box-office-chart/daily/2015/10/06">Oct 6, 2015</a></td>,
#  <td><b><a href="/movie/Spectre#tab=summary">Spectre</a></b></td>,
#  <td class="data"> $300,000,000</td>,
#  <td class="data"> $200,074,175</td>,
#  <td class="data"> $879,500,760</td>,
#  <td class="data">9</td>,
#  <td><a href="/box-office-chart/daily/2019/12/18">Dec 18, 2019</a></td>,
#  <td><b><a href="/movie/Star-Wars-The-Rise-of-Skywalker-(2019)#tab=summary">Star Wars: The Rise of Skywalker</a></b></td>,
#  <td class="data"> $275,000,000</td>,
#  <td class="data"> $515,202,542</td>,
#  <td class="data"> $1,072,944,222</td>,
#  <td class="data">10</td>,
#  <td><a href="/box-office-chart/daily/2018/05/23">May 23, 2018</a></td>,
#  <td><b><a href="/movie/Solo-A-Star-Wars-Story#tab=summary">Solo: A Star Wars Story</a></b></td>,
#  <td class="data"> $275,000,000</td>,
#  <td class="data"> $213,767,512</td>,
#  <td class="data"> $393,151,347</td>,
#  <td class="data">11</td>,
#  <td><a href="/box-office-chart/daily/2012/03/07">Mar 7, 2012</a></td>,
#  <td><b><a href="/movie/John-Carter-of-Mars#tab=summary">John Carter</a></b></td>,
#  <td class="data"> $263,700,000</td>,
#  <td class="data"> $73,058,679</td>,
#  <td class="data"> $282,778,100</td>,
#  <td class="data">12</td>,
#  <td><a href="/box-office-chart/daily/2016/03/23">Mar 23, 2016</a></td>,
#  <td><b><a href="/movie/Batman-v-Superman-Dawn-of-Justice#tab=summary">Batman v Superman: Dawn of Justice</a></b></td>,
#  <td class="data"> $263,000,000</td>,
#  <td class="data"> $330,360,194</td>,
#  <td class="data"> $872,395,091</td>,
#  <td class="data">13</td>,
#  <td><a href="/box-office-chart/daily/2019/07/11">Jul 11, 2019</a></td>,
#  <td><b><a href="/movie/Lion-King-The-(Live-Action)-(2019)#tab=summary">The Lion King</a></b></td>,
#  <td class="data"> $260,000,000</td>,
#  <td class="data"> $543,638,043</td>,
#  <td class="data"> $1,654,381,934</td>,
#  <td class="data">14</td>,
#  <td><a href="/box-office-chart/daily/2010/11/24">Nov 24, 2010</a></td>,
#  <td><b><a href="/movie/Tangled#tab=summary">Tangled</a></b></td>,
#  <td class="data"> $260,000,000</td>,
#  <td class="data"> $200,821,936</td>,
#  <td class="data"> $585,727,091</td>,
#  <td class="data">15</td>,
#  <td><a href="/box-office-chart/daily/2007/05/04">May 4, 2007</a></td>,
#  <td><b><a href="/movie/Spider-Man-3#tab=summary">Spider-Man 3</a></b></td>,
#  <td class="data"> $258,000,000</td>,
#  <td class="data"> $336,530,303</td>,
#  <td class="data"> $894,860,230</td>,
#  <td class="data">16</td>,
#  <td><a href="/box-office-chart/daily/2016/04/22">Apr 22, 2016</a></td>,
#  <td><b><a href="/movie/Captain-America-Civil-War#tab=summary">Captain America: Civil War</a></b></td>,
#  <td class="data"> $250,000,000</td>,
#  <td class="data"> $408,084,349</td>,
#  <td class="data"> $1,151,918,521</td>,
#  <td class="data">17</td>,
#  <td><a href="/box-office-chart/daily/2009/07/15">Jul 15, 2009</a></td>,
#  <td><b><a href="/movie/Harry-Potter-and-the-Half-Blood-Prince#tab=summary">Harry Potter and the Half-Blood Prince</a></b></td>,
#  <td class="data"> $250,000,000</td>,
#  <td class="data"> $302,089,278</td>,
#  <td class="data"> $930,673,167</td>,
#  <td class="data">18</td>,
#  <td><a href="/box-office-chart/daily/2013/12/12">Dec 12, 2013</a></td>,
#  <td><b><a href="/movie/Hobbit-The-Desolation-of-Smaug-The#tab=summary">The Hobbit: The Desolation of Smaug</a></b></td>,
#  <td class="data"> $250,000,000</td>,
#  <td class="data"> $258,241,522</td>,
#  <td class="data"> $960,238,087</td>,
#  <td class="data">19</td>,
#  <td><a href="/box-office-chart/daily/2014/12/10">Dec 10, 2014</a></td>,
#  <td><b><a href="/movie/Hobbit-The-Battle-of-the-Five-Armies-The#tab=summary">The Hobbit: The Battle of the Five Armies</a></b></td>,
#  <td class="data"> $250,000,000</td>,
#  <td class="data"> $255,119,788</td>,
#  <td class="data"> $943,328,905</td>,
#  <td class="data">20</td>,
#  <td><a href="/box-office-chart/daily/2017/04/07">Apr 7, 2017</a></td>,
#  <td><b><a href="/movie/Fate-of-the-Furious-The#tab=summary">The Fate of the Furious</a></b></td>,
#  <td class="data"> $250,000,000</td>,
#  <td class="data"> $225,764,765</td>,
#  <td class="data"> $1,236,703,796</td>,
#  <td class="data">21</td>,
#  <td><a href="/box-office-chart/daily/2021/03/31">Mar 31, 2021</a></td>,
#  <td><b><a href="/movie/No-Time-to-Die-(2020)#tab=summary">No Time to Die</a></b></td>,
#  <td class="data"> $250,000,000</td>,
#  <td class="data"> $0</td>,
#  <td class="data"> $0</td>,
#  <td class="data">22</td>,
#  <td><a href="/box-office-chart/daily/2009/12/17">Dec 17, 2009</a></td>,
#  <td><b><a href="/movie/Avatar#tab=summary">Avatar</a></b></td>,
#  <td class="data"> $237,000,000</td>,
#  <td class="data"> $760,507,625</td>,
#  <td class="data"> $2,788,701,337</td>,
#  <td class="data">23</td>,
#  <td><a href="/box-office-chart/daily/2006/06/28">Jun 28, 2006</a></td>,
#  <td><b><a href="/movie/Superman-Returns#tab=summary">Superman Returns</a></b></td>,
#  <td class="data"> $232,000,000</td>,
#  <td class="data"> $200,120,000</td>,
#  <td class="data"> $391,081,192</td>,
#  <td class="data">24</td>,
#  <td><a href="/box-office-chart/daily/2012/07/19">Jul 19, 2012</a></td>,
#  <td><b><a href="/movie/Dark-Knight-Rises-The#tab=summary">The Dark Knight Rises</a></b></td>,
#  <td class="data"> $230,000,000</td>,
#  <td class="data"> $448,139,099</td>,
#  <td class="data"> $1,082,228,107</td>,
#  <td class="data">25</td>,
#  <td><a href="/box-office-chart/daily/2017/05/23">May 23, 2017</a></td>,
#  <td><b><a href="/movie/Pirates-of-the-Caribbean-Dead-Men-Tell-No-Tales#tab=summary">Pirates of the Caribbean: Dead Men Tell No Tales</a></b></td>,
#  <td class="data"> $230,000,000</td>,
#  <td class="data"> $172,558,876</td>,
#  <td class="data"> $788,241,137</td>,
#  <td class="data">26</td>,
#  <td><a href="/box-office-chart/daily/2008/11/14">Nov 14, 2008</a></td>,
#  <td><b><a href="/movie/Quantum-of-Solace#tab=summary">Quantum of Solace</a></b></td>,
#  <td class="data"> $230,000,000</td>,
#  <td class="data"> $169,368,427</td>,
#  <td class="data"> $591,692,078</td>,
#  <td class="data">27</td>,
#  <td><a href="/box-office-chart/daily/2012/04/25">Apr 25, 2012</a></td>,
#  <td><b><a href="/movie/Avengers-The-(2012)#tab=summary">The Avengers</a></b></td>,
#  <td class="data"> $225,000,000</td>,
#  <td class="data"> $623,357,910</td>,
#  <td class="data"> $1,515,100,211</td>,
#  <td class="data">28</td>,
#  <td><a href="/box-office-chart/daily/2006/07/06">Jul 6, 2006</a></td>,
#  <td><b><a href="/movie/Pirates-of-the-Caribbean-Dead-Mans-Chest#tab=summary">Pirates of the Caribbean: Dead Manâs Chest</a></b></td>,
#  <td class="data"> $225,000,000</td>,
#  <td class="data"> $423,315,812</td>,
#  <td class="data"> $1,066,215,812</td>,
#  <td class="data">29</td>,
#  <td><a href="/box-office-chart/daily/2013/06/14">Jun 14, 2013</a></td>,
#  <td><b><a href="/movie/Man-of-Steel#tab=summary">Man of Steel</a></b></td>,
#  <td class="data"> $225,000,000</td>,
#  <td class="data"> $291,045,518</td>,
#  <td class="data"> $667,999,518</td>,
#  <td class="data">30</td>,
#  <td><a href="/box-office-chart/daily/2008/05/16">May 16, 2008</a></td>,
#  <td><b><a href="/movie/Chronicles-of-Narnia-Prince-Caspian-The#tab=summary">The Chronicles of Narnia: Prince Caspian</a></b></td>,
#  <td class="data"> $225,000,000</td>,
#  <td class="data"> $141,621,490</td>,
#  <td class="data"> $417,341,288</td>,
#  <td class="data">31</td>,
#  <td><a href="/box-office-chart/daily/2013/07/02">Jul 2, 2013</a></td>,
#  <td><b><a href="/movie/Lone-Ranger-The#tab=summary">The Lone Ranger</a></b></td>,
#  <td class="data"> $225,000,000</td>,
#  <td class="data"> $89,302,115</td>,
#  <td class="data"> $260,002,115</td>,
#  <td class="data">32</td>,
#  <td><a href="/box-office-chart/daily/2012/06/27">Jun 27, 2012</a></td>,
#  <td><b><a href="/movie/Amazing-Spider-Man-The#tab=summary">The Amazing Spider-Man</a></b></td>,
#  <td class="data"> $220,000,000</td>,
#  <td class="data"> $262,030,663</td>,
#  <td class="data"> $757,890,267</td>,
#  <td class="data">33</td>,
#  <td><a href="/box-office-chart/daily/2012/04/11">Apr 11, 2012</a></td>,
#  <td><b><a href="/movie/Battleship#tab=summary">Battleship</a></b></td>,
#  <td class="data"> $220,000,000</td>,
#  <td class="data"> $65,233,400</td>,
#  <td class="data"> $313,477,717</td>,
#  <td class="data">34</td>,
#  <td><a href="/box-office-chart/daily/2017/06/20">Jun 20, 2017</a></td>,
#  <td><b><a href="/movie/Transformers-The-Last-Knight#tab=summary">Transformers: The Last Knight</a></b></td>,
#  <td class="data"> $217,000,000</td>,
#  <td class="data"> $130,168,683</td>,
#  <td class="data"> $602,893,340</td>,
#  <td class="data">35</td>,
#  <td><a href="/box-office-chart/daily/2015/06/09">Jun 9, 2015</a></td>,
#  <td><b><a href="/movie/Jurassic-World#tab=summary">Jurassic World</a></b></td>,
#  <td class="data"> $215,000,000</td>,
#  <td class="data"> $652,270,625</td>,
#  <td class="data"> $1,669,943,967</td>,
#  <td class="data">36</td>,
#  <td><a href="/box-office-chart/daily/2012/05/23">May 23, 2012</a></td>,
#  <td><b><a href="/movie/Men-in-Black-3#tab=summary">Men in Black 3</a></b></td>,
#  <td class="data"> $215,000,000</td>,
#  <td class="data"> $179,020,854</td>,
#  <td class="data"> $654,213,485</td>,
#  <td class="data">37</td>,
#  <td><a href="/box-office-chart/daily/2009/06/24">Jun 24, 2009</a></td>,
#  <td><b><a href="/movie/Transformers-Revenge-of-the-Fallen#tab=summary">Transformers: Revenge of the Fallen</a></b></td>,
#  <td class="data"> $210,000,000</td>,
#  <td class="data"> $402,111,870</td>,
#  <td class="data"> $836,519,699</td>,
#  <td class="data">38</td>,
#  <td><a href="/box-office-chart/daily/2014/06/25">Jun 25, 2014</a></td>,
#  <td><b><a href="/movie/Transformers-Age-of-Extinction#tab=summary">Transformers: Age of Extinction</a></b></td>,
#  <td class="data"> $210,000,000</td>,
#  <td class="data"> $245,439,076</td>,
#  <td class="data"> $1,104,054,072</td>,
#  <td class="data">39</td>,
#  <td><a href="/box-office-chart/daily/2006/05/26">May 26, 2006</a></td>,
#  <td><b><a href="/movie/X-Men-The-Last-Stand#tab=summary">X-Men: The Last Stand</a></b></td>,
#  <td class="data"> $210,000,000</td>,
#  <td class="data"> $234,362,462</td>,
#  <td class="data"> $459,260,946</td>,
#  <td class="data">40</td>,
#  <td><a href="/box-office-chart/daily/2010/05/14">May 14, 2010</a></td>,
#  <td><b><a href="/movie/Robin-Hood-(2010)#tab=summary">Robin Hood</a></b></td>,
#  <td class="data"> $210,000,000</td>,
#  <td class="data"> $105,487,148</td>,
#  <td class="data"> $322,459,006</td>,
#  <td class="data">41</td>,
#  <td><a href="/box-office-chart/daily/2005/12/14">Dec 14, 2005</a></td>,
#  <td><b><a href="/movie/King-Kong-(2005)#tab=summary">King Kong</a></b></td>,
#  <td class="data"> $207,000,000</td>,
#  <td class="data"> $218,080,025</td>,
#  <td class="data"> $550,517,357</td>,
#  <td class="data">42</td>,
#  <td><a href="/box-office-chart/daily/2007/12/07">Dec 7, 2007</a></td>,
#  <td><b><a href="/movie/His-Dark-Materials-The-Golden-Compass#tab=summary">The Golden Compass</a></b></td>,
#  <td class="data"> $205,000,000</td>,
#  <td class="data"> $70,107,728</td>,
#  <td class="data"> $367,262,558</td>,
#  <td class="data">43</td>,
#  <td><a href="/box-office-chart/daily/2020/08/26">Aug 26, 2020</a></td>,
#  <td><b><a href="/movie/Tenet-(2020)#tab=summary">Tenet</a></b></td>,
#  <td class="data"> $205,000,000</td>,
#  <td class="data"> $57,929,000</td>,
#  <td class="data"> $363,129,000</td>,
#  <td class="data">44</td>,
#  <td><a href="/box-office-chart/daily/2018/02/13">Feb 13, 2018</a></td>,
#  <td><b><a href="/movie/Black-Panther#tab=summary">Black Panther</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $700,059,566</td>,
#  <td class="data"> $1,336,494,321</td>,
#  <td class="data">45</td>,
#  <td><a href="/box-office-chart/daily/1997/12/18">Dec 18, 1997</a></td>,
#  <td><b><a href="/movie/Titanic-(1997)#tab=summary">Titanic</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $659,363,944</td>,
#  <td class="data"> $2,207,986,545</td>,
#  <td class="data">46</td>,
#  <td><a href="/box-office-chart/daily/2017/12/13">Dec 13, 2017</a></td>,
#  <td><b><a href="/movie/Star-Wars-Ep-VIII-The-Last-Jedi#tab=summary">Star Wars Ep. VIII: The Last Jedi</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $620,181,382</td>,
#  <td class="data"> $1,332,539,889</td>,
#  <td class="data">47</td>,
#  <td><a href="/box-office-chart/daily/2018/06/15">Jun 15, 2018</a></td>,
#  <td><b><a href="/movie/Incredibles-2#tab=summary">Incredibles 2</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $608,581,744</td>,
#  <td class="data"> $1,242,805,359</td>,
#  <td class="data">48</td>,
#  <td><a href="/box-office-chart/daily/2016/12/14">Dec 14, 2016</a></td>,
#  <td><b><a href="/movie/Rogue-One-A-Star-Wars-Story#tab=summary">Rogue One: A Star Wars Story</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $532,177,324</td>,
#  <td class="data"> $1,055,135,598</td>,
#  <td class="data">49</td>,
#  <td><a href="/box-office-chart/daily/2016/06/16">Jun 16, 2016</a></td>,
#  <td><b><a href="/movie/Finding-Dory#tab=summary">Finding Dory</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $486,295,561</td>,
#  <td class="data"> $1,025,006,125</td>,
#  <td class="data">50</td>,
#  <td><a href="/box-office-chart/daily/2019/06/20">Jun 20, 2019</a></td>,
#  <td><b><a href="/movie/Toy-Story-4-(2019)#tab=summary">Toy Story 4</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $434,038,008</td>,
#  <td class="data"> $1,073,357,481</td>,
#  <td class="data">51</td>,
#  <td><a href="/box-office-chart/daily/2010/06/18">Jun 18, 2010</a></td>,
#  <td><b><a href="/movie/Toy-Story-3#tab=summary">Toy Story 3</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $415,004,880</td>,
#  <td class="data"> $1,068,879,522</td>,
#  <td class="data">52</td>,
#  <td><a href="/box-office-chart/daily/2013/04/24">Apr 24, 2013</a></td>,
#  <td><b><a href="/movie/Iron-Man-3#tab=summary">Iron Man 3</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $408,992,272</td>,
#  <td class="data"> $1,215,392,272</td>,
#  <td class="data">53</td>,
#  <td><a href="/box-office-chart/daily/2017/04/28">Apr 28, 2017</a></td>,
#  <td><b><a href="/movie/Guardians-of-the-Galaxy-Vol-2#tab=summary">Guardians of the Galaxy Vol 2</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $389,813,101</td>,
#  <td class="data"> $869,113,101</td>,
#  <td class="data">54</td>,
#  <td><a href="/box-office-chart/daily/2004/06/30">Jun 30, 2004</a></td>,
#  <td><b><a href="/movie/Spider-Man-2#tab=summary">Spider-Man 2</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $373,524,485</td>,
#  <td class="data"> $794,697,557</td>,
#  <td class="data">55</td>,
#  <td><a href="/box-office-chart/daily/2010/03/04">Mar 4, 2010</a></td>,
#  <td><b><a href="/movie/Alice-in-Wonderland-(2010)#tab=summary">Alice in Wonderland</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $334,191,110</td>,
#  <td class="data"> $1,025,491,110</td>,
#  <td class="data">56</td>,
#  <td><a href="/box-office-chart/daily/2012/10/26">Oct 26, 2012</a></td>,
#  <td><b><a href="/movie/Skyfall#tab=summary">Skyfall</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $304,360,277</td>,
#  <td class="data"> $1,110,526,981</td>,
#  <td class="data">57</td>,
#  <td><a href="/box-office-chart/daily/2012/12/11">Dec 11, 2012</a></td>,
#  <td><b><a href="/movie/Hobbit-An-Unexpected-Journey-The#tab=summary">The Hobbit: An Unexpected Journey</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $303,003,568</td>,
#  <td class="data"> $1,017,003,568</td>,
#  <td class="data">58</td>,
#  <td><a href="/box-office-chart/daily/2013/06/21">Jun 21, 2013</a></td>,
#  <td><b><a href="/movie/Monsters-University#tab=summary">Monsters University</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $268,488,329</td>,
#  <td class="data"> $743,588,329</td>,
#  <td class="data">59</td>,
#  <td><a href="/box-office-chart/daily/2013/03/08">Mar 8, 2013</a></td>,
#  <td><b><a href="/movie/Oz-The-Great-and-Powerful#tab=summary">Oz the Great and Powerful</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $234,770,996</td>,
#  <td class="data"> $490,359,051</td>,
#  <td class="data">60</td>,
#  <td><a href="/box-office-chart/daily/2014/05/21">May 21, 2014</a></td>,
#  <td><b><a href="/movie/X-Men-Days-of-Future-Past#tab=summary">X-Men: Days of Future Past</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $233,921,534</td>,
#  <td class="data"> $747,862,775</td>,
#  <td class="data">61</td>,
#  <td><a href="/box-office-chart/daily/2014/04/16">Apr 16, 2014</a></td>,
#  <td><b><a href="/movie/Amazing-Spider-Man-2-The#tab=summary">The Amazing Spider-Man 2</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $202,853,933</td>,
#  <td class="data"> $708,996,336</td>,
#  <td class="data">62</td>,
#  <td><a href="/box-office-chart/daily/2011/06/23">Jun 23, 2011</a></td>,
#  <td><b><a href="/movie/Cars-2#tab=summary">Cars 2</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $191,450,875</td>,
#  <td class="data"> $560,155,383</td>,
#  <td class="data">63</td>,
#  <td><a href="/box-office-chart/daily/2019/07/31">Jul 31, 2019</a></td>,
#  <td><b><a href="/movie/Fast-and-Furious-Presents-Hobbs-and-Shaw-(2019)#tab=summary">Fast &amp; Furious Presents: Hobbs &amp; Shaw</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $173,956,935</td>,
#  <td class="data"> $759,765,123</td>,
#  <td class="data">64</td>,
#  <td><a href="/box-office-chart/daily/2010/12/17">Dec 17, 2010</a></td>,
#  <td><b><a href="/movie/Tron-Legacy#tab=summary">Tron: Legacy</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $172,062,763</td>,
#  <td class="data"> $400,062,763</td>,
#  <td class="data">65</td>,
#  <td><a href="/box-office-chart/daily/2009/11/12">Nov 12, 2009</a></td>,
#  <td><b><a href="/movie/2012#tab=summary">2012</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $166,112,167</td>,
#  <td class="data"> $757,677,748</td>,
#  <td class="data">66</td>,
#  <td><a href="/box-office-chart/daily/2018/11/14">Nov 14, 2018</a></td>,
#  <td><b><a href="/movie/Fantastic-Beasts-The-Crimes-of-Grindelwald-(2018)#tab=summary">Fantastic Beasts: The Crimes of Grindelwald</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $159,555,901</td>,
#  <td class="data"> $651,280,475</td>,
#  <td class="data">67</td>,
#  <td><a href="/box-office-chart/daily/2009/05/21">May 21, 2009</a></td>,
#  <td><b><a href="/movie/Terminator-Salvation#tab=summary">Terminator Salvation</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $125,322,469</td>,
#  <td class="data"> $365,491,792</td>,
#  <td class="data">68</td>,
#  <td><a href="/box-office-chart/daily/2011/06/17">Jun 17, 2011</a></td>,
#  <td><b><a href="/movie/Green-Lantern-(2011)#tab=summary">Green Lantern</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $116,601,172</td>,
#  <td class="data"> $219,535,492</td>,
#  <td class="data">69</td>,
#  <td><a href="/box-office-chart/daily/2010/05/28">May 28, 2010</a></td>,
#  <td><b><a href="/movie/Prince-of-Persia-Sands-of-Time#tab=summary">Prince of Persia: Sands of Time</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $90,759,676</td>,
#  <td class="data"> $336,359,676</td>,
#  <td class="data">70</td>,
#  <td><a href="/box-office-chart/daily/2019/06/05">Jun 5, 2019</a></td>,
#  <td><b><a href="/movie/Dark-Phoenix-(2019)#tab=summary">Dark Phoenix</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $65,845,974</td>,
#  <td class="data"> $246,356,895</td>,
#  <td class="data">71</td>,
#  <td><a href="/box-office-chart/daily/2020/09/04">Sep 4, 2020</a></td>,
#  <td><b><a href="/movie/Mulan-(2020)#tab=summary">Mulan</a></b></td>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $0</td>,
#  <td class="data"> $69,963,700</td>,
#  <td class="data">72</td>,
#  <td><a href="/box-office-chart/daily/2011/06/29">Jun 29, 2011</a></td>,
#  <td><b><a href="/movie/Transformers-Dark-of-the-Moon-(2011)#tab=summary">Transformers: Dark of the Moon</a></b></td>,
#  <td class="data"> $195,000,000</td>,
#  <td class="data"> $352,390,543</td>,
#  <td class="data"> $1,123,794,079</td>,
#  <td class="data">73</td>,
#  <td><a href="/box-office-chart/daily/2017/06/02">Jun 2, 2017</a></td>,
#  <td><b><a href="/movie/Mummy-The-(2017)#tab=summary">The Mummy</a></b></td>,
#  <td class="data"> $195,000,000</td>,
#  <td class="data"> $80,101,125</td>,
#  <td class="data"> $409,953,905</td>,
#  <td class="data">74</td>,
#  <td><a href="/box-office-chart/daily/2013/02/27">Feb 27, 2013</a></td>,
#  <td><b><a href="/movie/Jack-the-Giant-Slayer#tab=summary">Jack the Giant Slayer</a></b></td>,
#  <td class="data"> $195,000,000</td>,
#  <td class="data"> $65,187,603</td>,
#  <td class="data"> $197,687,603</td>,
#  <td class="data">75</td>,
#  <td><a href="/box-office-chart/daily/2015/04/01">Apr 1, 2015</a></td>,
#  <td><b><a href="/movie/Furious-7#tab=summary">Furious 7</a></b></td>,
#  <td class="data"> $190,000,000</td>,
#  <td class="data"> $353,007,020</td>,
#  <td class="data"> $1,517,179,709</td>,
#  <td class="data">76</td>,
#  <td><a href="/box-office-chart/daily/2013/05/16">May 16, 2013</a></td>,
#  <td><b><a href="/movie/Star-Trek-Into-Darkness#tab=summary">Star Trek Into Darkness</a></b></td>,
#  <td class="data"> $190,000,000</td>,
#  <td class="data"> $228,778,661</td>,
#  <td class="data"> $467,381,584</td>,
#  <td class="data">77</td>,
#  <td><a href="/box-office-chart/daily/2013/06/19">Jun 19, 2013</a></td>,
#  <td><b><a href="/movie/World-War-Z#tab=summary">World War Z</a></b></td>,
#  <td class="data"> $190,000,000</td>,
#  <td class="data"> $202,359,711</td>,
#  <td class="data"> $531,514,650</td>,
#  <td class="data">78</td>,
#  <td><a href="/box-office-chart/daily/2013/05/10">May 10, 2013</a></td>,
#  <td><b><a href="/movie/Great-Gatsby-The-(2011)#tab=summary">The Great Gatsby</a></b></td>,
#  <td class="data"> $190,000,000</td>,
#  <td class="data"> $144,840,419</td>,
#  <td class="data"> $353,640,419</td>,
#  <td class="data">79</td>,
#  <td><a href="/box-office-chart/daily/2009/11/06">Nov 6, 2009</a></td>,
#  <td><b><a href="/movie/Disneys-A-Christmas-Carol#tab=summary">Disneyâs A Christmas Carol</a></b></td>,
#  <td class="data"> $190,000,000</td>,
#  <td class="data"> $137,855,863</td>,
#  <td class="data"> $315,709,697</td>,
#  <td class="data">80</td>,
#  <td><a href="/box-office-chart/daily/2013/07/11">Jul 11, 2013</a></td>,
#  <td><b><a href="/movie/Pacific-Rim#tab=summary">Pacific Rim</a></b></td>,
#  <td class="data"> $190,000,000</td>,
#  <td class="data"> $101,802,906</td>,
#  <td class="data"> $411,002,906</td>,
#  <td class="data">81</td>,
#  <td><a href="/box-office-chart/daily/2015/11/25">Nov 25, 2015</a></td>,
#  <td><b><a href="/movie/Good-Dinosaur-The#tab=summary">The Good Dinosaur</a></b></td>,
#  <td class="data"> $187,500,000</td>,
#  <td class="data"> $123,087,120</td>,
#  <td class="data"> $333,771,037</td>,
#  <td class="data">82</td>,
#  <td><a href="/box-office-chart/daily/2008/05/02">May 2, 2008</a></td>,
#  <td><b><a href="/movie/Iron-Man#tab=summary">Iron Man</a></b></td>,
#  <td class="data"> $186,000,000</td>,
#  <td class="data"> $318,604,126</td>,
#  <td class="data"> $585,171,547</td>,
#  <td class="data">83</td>,
#  <td><a href="/box-office-chart/daily/2008/07/11">Jul 11, 2008</a></td>,
#  <td><b><a href="/movie/Dark-Knight-The#tab=summary">The Dark Knight</a></b></td>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $533,720,947</td>,
#  <td class="data"> $999,434,419</td>,
#  <td class="data">84</td>,
#  <td><a href="/box-office-chart/daily/2008/05/22">May 22, 2008</a></td>,
#  <td><b><a href="/movie/Indiana-Jones-and-the-Kingdom-of-the-Crystal-Skull#tab=summary">Indiana Jones and the Kingdom of the Crystal Skull</a></b></td>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $317,101,119</td>,
#  <td class="data"> $786,635,413</td>,
#  <td class="data">85</td>,
#  <td><a href="/box-office-chart/daily/2012/06/21">Jun 21, 2012</a></td>,
#  <td><b><a href="/movie/Brave#tab=summary">Brave</a></b></td>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $237,282,182</td>,
#  <td class="data"> $554,606,532</td>,
#  <td class="data">86</td>,
#  <td><a href="/box-office-chart/daily/2017/02/23">Feb 23, 2017</a></td>,
#  <td><b><a href="/movie/Kong-Skull-Island#tab=summary">Kong: Skull Island</a></b></td>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $168,052,812</td>,
#  <td class="data"> $561,072,059</td>,
#  <td class="data">87</td>,
#  <td><a href="/box-office-chart/daily/2016/07/21">Jul 21, 2016</a></td>,
#  <td><b><a href="/movie/Star-Trek-Beyond#tab=summary">Star Trek Beyond</a></b></td>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $158,848,340</td>,
#  <td class="data"> $335,673,708</td>,
#  <td class="data">88</td>,
#  <td><a href="/box-office-chart/daily/2019/10/17">Oct 17, 2019</a></td>,
#  <td><b><a href="/movie/Maleficent-Mistress-of-Evil-(2019)#tab=summary">Maleficent: Mistress of Evil</a></b></td>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $113,929,605</td>,
#  <td class="data"> $489,346,495</td>,
#  <td class="data">89</td>,
#  <td><a href="/box-office-chart/daily/2017/09/29">Sep 29, 2017</a></td>,
#  <td><b><a href="/movie/Blade-Runner-2049#tab=summary">Blade Runner 2049</a></b></td>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $92,054,159</td>,
#  <td class="data"> $259,136,784</td>,
#  <td class="data">90</td>,
#  <td><a href="/box-office-chart/daily/2019/10/25">Oct 25, 2019</a></td>,
#  <td><b><a href="/movie/Terminator-Dark-Fate-(2019)#tab=summary">Terminator: Dark Fate</a></b></td>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $62,253,077</td>,
#  <td class="data"> $250,372,367</td>,
#  <td class="data">91</td>,
#  <td><a href="/box-office-chart/daily/2019/05/22">May 22, 2019</a></td>,
#  <td><b><a href="/movie/Aladdin-(2019)#tab=summary">Aladdin</a></b></td>,
#  <td class="data"> $182,000,000</td>,
#  <td class="data"> $355,559,216</td>,
#  <td class="data"> $1,046,918,234</td>,
#  <td class="data">92</td>,
#  <td><a href="/box-office-chart/daily/2017/10/25">Oct 25, 2017</a></td>,
#  <td><b><a href="/movie/Thor-Ragnarok#tab=summary">Thor: Ragnarok</a></b></td>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $315,058,289</td>,
#  <td class="data"> $850,482,778</td>,
#  <td class="data">93</td>,
#  <td><a href="/box-office-chart/daily/2005/12/09">Dec 9, 2005</a></td>,
#  <td><b><a href="/movie/Chronicles-of-Narnia-The-Lion-the-Witch-and-the-Wardrobe-The#tab=summary">The Chronicles of Narnia: The Lion, the Witch a…</a></b></td>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $291,710,957</td>,
#  <td class="data"> $720,539,572</td>,
#  <td class="data">94</td>,
#  <td><a href="/box-office-chart/daily/2014/05/28">May 28, 2014</a></td>,
#  <td><b><a href="/movie/Maleficent#tab=summary">Maleficent</a></b></td>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $241,407,328</td>,
#  <td class="data"> $758,536,735</td>,
#  <td class="data">95</td>,
#  <td><a href="/box-office-chart/daily/2016/11/14">Nov 14, 2016</a></td>,
#  <td><b><a href="/movie/Fantastic-Beasts-and-Where-to-Find-Them#tab=summary">Fantastic Beasts and Where to Find Them</a></b></td>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $234,037,575</td>,
#  <td class="data"> $811,724,385</td>,
#  <td class="data">96</td>,
#  <td><a href="/box-office-chart/daily/2008/06/27">Jun 27, 2008</a></td>,
#  <td><b><a href="/movie/WALL-E#tab=summary">WALL-E</a></b></td>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $223,808,164</td>,
#  <td class="data"> $532,508,025</td>,
#  <td class="data">97</td>,
#  <td><a href="/box-office-chart/daily/2007/08/10">Aug 10, 2007</a></td>,
#  <td><b><a href="/movie/Rush-Hour-3#tab=summary">Rush Hour 3</a></b></td>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $140,125,968</td>,
#  <td class="data"> $256,585,882</td>,
#  <td class="data">98</td>,
#  <td><a href="/box-office-chart/daily/2016/06/27">Jun 27, 2016</a></td>,
#  <td><b><a href="/movie/Legend-of-Tarzan-The#tab=summary">The Legend of Tarzan</a></b></td>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $126,643,061</td>,
#  <td class="data"> $348,902,025</td>,
#  <td class="data">99</td>,
#  <td><a href="/box-office-chart/daily/2011/11/23">Nov 23, 2011</a></td>,
#  <td><b><a href="/movie/Hugo#tab=summary">Hugo</a></b></td>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $73,864,507</td>,
#  <td class="data"> $180,047,784</td>,
#  <td class="data">100</td>,
#  <td><a href="/box-office-chart/daily/2017/07/20">Jul 20, 2017</a></td>,
#  <td><b><a href="/movie/Valerian-and-the-City-of-a-Thousand-Planets-(France)#tab=summary">Valerian and the City of a Thousand Planets</a></b></td>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $40,479,370</td>,
#  <td class="data"> $215,098,356</td>]

# %%
soup.find('table').find_all('a')
# Out:
# [<a href="/box-office-chart/daily/2019/04/23">Apr 23, 2019</a>,
#  <a href="/movie/Avengers-Endgame-(2019)#tab=summary">Avengers: Endgame</a>,
#  <a href="/box-office-chart/daily/2011/05/20">May 20, 2011</a>,
#  <a href="/movie/Pirates-of-the-Caribbean-On-Stranger-Tides#tab=summary">Pirates of the Caribbean: On Stranger Tides</a>,
#  <a href="/box-office-chart/daily/2015/04/22">Apr 22, 2015</a>,
#  <a href="/movie/Avengers-Age-of-Ultron#tab=summary">Avengers: Age of Ultron</a>,
#  <a href="/box-office-chart/daily/2015/12/16">Dec 16, 2015</a>,
#  <a href="/movie/Star-Wars-Ep-VII-The-Force-Awakens#tab=summary">Star Wars Ep. VII: The Force Awakens</a>,
#  <a href="/box-office-chart/daily/2018/04/25">Apr 25, 2018</a>,
#  <a href="/movie/Avengers-Infinity-War#tab=summary">Avengers: Infinity War</a>,
#  <a href="/box-office-chart/daily/2007/05/24">May 24, 2007</a>,
#  <a href="/movie/Pirates-of-the-Caribbean-At-Worlds-End#tab=summary">Pirates of the Caribbean: At Worldâs End</a>,
#  <a href="/box-office-chart/daily/2017/11/13">Nov 13, 2017</a>,
#  <a href="/movie/Justice-League-(2017)#tab=summary">Justice League</a>,
#  <a href="/box-office-chart/daily/2015/10/06">Oct 6, 2015</a>,
#  <a href="/movie/Spectre#tab=summary">Spectre</a>,
#  <a href="/box-office-chart/daily/2019/12/18">Dec 18, 2019</a>,
#  <a href="/movie/Star-Wars-The-Rise-of-Skywalker-(2019)#tab=summary">Star Wars: The Rise of Skywalker</a>,
#  <a href="/box-office-chart/daily/2018/05/23">May 23, 2018</a>,
#  <a href="/movie/Solo-A-Star-Wars-Story#tab=summary">Solo: A Star Wars Story</a>,
#  <a href="/box-office-chart/daily/2012/03/07">Mar 7, 2012</a>,
#  <a href="/movie/John-Carter-of-Mars#tab=summary">John Carter</a>,
#  <a href="/box-office-chart/daily/2016/03/23">Mar 23, 2016</a>,
#  <a href="/movie/Batman-v-Superman-Dawn-of-Justice#tab=summary">Batman v Superman: Dawn of Justice</a>,
#  <a href="/box-office-chart/daily/2019/07/11">Jul 11, 2019</a>,
#  <a href="/movie/Lion-King-The-(Live-Action)-(2019)#tab=summary">The Lion King</a>,
#  <a href="/box-office-chart/daily/2010/11/24">Nov 24, 2010</a>,
#  <a href="/movie/Tangled#tab=summary">Tangled</a>,
#  <a href="/box-office-chart/daily/2007/05/04">May 4, 2007</a>,
#  <a href="/movie/Spider-Man-3#tab=summary">Spider-Man 3</a>,
#  <a href="/box-office-chart/daily/2016/04/22">Apr 22, 2016</a>,
#  <a href="/movie/Captain-America-Civil-War#tab=summary">Captain America: Civil War</a>,
#  <a href="/box-office-chart/daily/2009/07/15">Jul 15, 2009</a>,
#  <a href="/movie/Harry-Potter-and-the-Half-Blood-Prince#tab=summary">Harry Potter and the Half-Blood Prince</a>,
#  <a href="/box-office-chart/daily/2013/12/12">Dec 12, 2013</a>,
#  <a href="/movie/Hobbit-The-Desolation-of-Smaug-The#tab=summary">The Hobbit: The Desolation of Smaug</a>,
#  <a href="/box-office-chart/daily/2014/12/10">Dec 10, 2014</a>,
#  <a href="/movie/Hobbit-The-Battle-of-the-Five-Armies-The#tab=summary">The Hobbit: The Battle of the Five Armies</a>,
#  <a href="/box-office-chart/daily/2017/04/07">Apr 7, 2017</a>,
#  <a href="/movie/Fate-of-the-Furious-The#tab=summary">The Fate of the Furious</a>,
#  <a href="/box-office-chart/daily/2021/03/31">Mar 31, 2021</a>,
#  <a href="/movie/No-Time-to-Die-(2020)#tab=summary">No Time to Die</a>,
#  <a href="/box-office-chart/daily/2009/12/17">Dec 17, 2009</a>,
#  <a href="/movie/Avatar#tab=summary">Avatar</a>,
#  <a href="/box-office-chart/daily/2006/06/28">Jun 28, 2006</a>,
#  <a href="/movie/Superman-Returns#tab=summary">Superman Returns</a>,
#  <a href="/box-office-chart/daily/2012/07/19">Jul 19, 2012</a>,
#  <a href="/movie/Dark-Knight-Rises-The#tab=summary">The Dark Knight Rises</a>,
#  <a href="/box-office-chart/daily/2017/05/23">May 23, 2017</a>,
#  <a href="/movie/Pirates-of-the-Caribbean-Dead-Men-Tell-No-Tales#tab=summary">Pirates of the Caribbean: Dead Men Tell No Tales</a>,
#  <a href="/box-office-chart/daily/2008/11/14">Nov 14, 2008</a>,
#  <a href="/movie/Quantum-of-Solace#tab=summary">Quantum of Solace</a>,
#  <a href="/box-office-chart/daily/2012/04/25">Apr 25, 2012</a>,
#  <a href="/movie/Avengers-The-(2012)#tab=summary">The Avengers</a>,
#  <a href="/box-office-chart/daily/2006/07/06">Jul 6, 2006</a>,
#  <a href="/movie/Pirates-of-the-Caribbean-Dead-Mans-Chest#tab=summary">Pirates of the Caribbean: Dead Manâs Chest</a>,
#  <a href="/box-office-chart/daily/2013/06/14">Jun 14, 2013</a>,
#  <a href="/movie/Man-of-Steel#tab=summary">Man of Steel</a>,
#  <a href="/box-office-chart/daily/2008/05/16">May 16, 2008</a>,
#  <a href="/movie/Chronicles-of-Narnia-Prince-Caspian-The#tab=summary">The Chronicles of Narnia: Prince Caspian</a>,
#  <a href="/box-office-chart/daily/2013/07/02">Jul 2, 2013</a>,
#  <a href="/movie/Lone-Ranger-The#tab=summary">The Lone Ranger</a>,
#  <a href="/box-office-chart/daily/2012/06/27">Jun 27, 2012</a>,
#  <a href="/movie/Amazing-Spider-Man-The#tab=summary">The Amazing Spider-Man</a>,
#  <a href="/box-office-chart/daily/2012/04/11">Apr 11, 2012</a>,
#  <a href="/movie/Battleship#tab=summary">Battleship</a>,
#  <a href="/box-office-chart/daily/2017/06/20">Jun 20, 2017</a>,
#  <a href="/movie/Transformers-The-Last-Knight#tab=summary">Transformers: The Last Knight</a>,
#  <a href="/box-office-chart/daily/2015/06/09">Jun 9, 2015</a>,
#  <a href="/movie/Jurassic-World#tab=summary">Jurassic World</a>,
#  <a href="/box-office-chart/daily/2012/05/23">May 23, 2012</a>,
#  <a href="/movie/Men-in-Black-3#tab=summary">Men in Black 3</a>,
#  <a href="/box-office-chart/daily/2009/06/24">Jun 24, 2009</a>,
#  <a href="/movie/Transformers-Revenge-of-the-Fallen#tab=summary">Transformers: Revenge of the Fallen</a>,
#  <a href="/box-office-chart/daily/2014/06/25">Jun 25, 2014</a>,
#  <a href="/movie/Transformers-Age-of-Extinction#tab=summary">Transformers: Age of Extinction</a>,
#  <a href="/box-office-chart/daily/2006/05/26">May 26, 2006</a>,
#  <a href="/movie/X-Men-The-Last-Stand#tab=summary">X-Men: The Last Stand</a>,
#  <a href="/box-office-chart/daily/2010/05/14">May 14, 2010</a>,
#  <a href="/movie/Robin-Hood-(2010)#tab=summary">Robin Hood</a>,
#  <a href="/box-office-chart/daily/2005/12/14">Dec 14, 2005</a>,
#  <a href="/movie/King-Kong-(2005)#tab=summary">King Kong</a>,
#  <a href="/box-office-chart/daily/2007/12/07">Dec 7, 2007</a>,
#  <a href="/movie/His-Dark-Materials-The-Golden-Compass#tab=summary">The Golden Compass</a>,
#  <a href="/box-office-chart/daily/2020/08/26">Aug 26, 2020</a>,
#  <a href="/movie/Tenet-(2020)#tab=summary">Tenet</a>,
#  <a href="/box-office-chart/daily/2018/02/13">Feb 13, 2018</a>,
#  <a href="/movie/Black-Panther#tab=summary">Black Panther</a>,
#  <a href="/box-office-chart/daily/1997/12/18">Dec 18, 1997</a>,
#  <a href="/movie/Titanic-(1997)#tab=summary">Titanic</a>,
#  <a href="/box-office-chart/daily/2017/12/13">Dec 13, 2017</a>,
#  <a href="/movie/Star-Wars-Ep-VIII-The-Last-Jedi#tab=summary">Star Wars Ep. VIII: The Last Jedi</a>,
#  <a href="/box-office-chart/daily/2018/06/15">Jun 15, 2018</a>,
#  <a href="/movie/Incredibles-2#tab=summary">Incredibles 2</a>,
#  <a href="/box-office-chart/daily/2016/12/14">Dec 14, 2016</a>,
#  <a href="/movie/Rogue-One-A-Star-Wars-Story#tab=summary">Rogue One: A Star Wars Story</a>,
#  <a href="/box-office-chart/daily/2016/06/16">Jun 16, 2016</a>,
#  <a href="/movie/Finding-Dory#tab=summary">Finding Dory</a>,
#  <a href="/box-office-chart/daily/2019/06/20">Jun 20, 2019</a>,
#  <a href="/movie/Toy-Story-4-(2019)#tab=summary">Toy Story 4</a>,
#  <a href="/box-office-chart/daily/2010/06/18">Jun 18, 2010</a>,
#  <a href="/movie/Toy-Story-3#tab=summary">Toy Story 3</a>,
#  <a href="/box-office-chart/daily/2013/04/24">Apr 24, 2013</a>,
#  <a href="/movie/Iron-Man-3#tab=summary">Iron Man 3</a>,
#  <a href="/box-office-chart/daily/2017/04/28">Apr 28, 2017</a>,
#  <a href="/movie/Guardians-of-the-Galaxy-Vol-2#tab=summary">Guardians of the Galaxy Vol 2</a>,
#  <a href="/box-office-chart/daily/2004/06/30">Jun 30, 2004</a>,
#  <a href="/movie/Spider-Man-2#tab=summary">Spider-Man 2</a>,
#  <a href="/box-office-chart/daily/2010/03/04">Mar 4, 2010</a>,
#  <a href="/movie/Alice-in-Wonderland-(2010)#tab=summary">Alice in Wonderland</a>,
#  <a href="/box-office-chart/daily/2012/10/26">Oct 26, 2012</a>,
#  <a href="/movie/Skyfall#tab=summary">Skyfall</a>,
#  <a href="/box-office-chart/daily/2012/12/11">Dec 11, 2012</a>,
#  <a href="/movie/Hobbit-An-Unexpected-Journey-The#tab=summary">The Hobbit: An Unexpected Journey</a>,
#  <a href="/box-office-chart/daily/2013/06/21">Jun 21, 2013</a>,
#  <a href="/movie/Monsters-University#tab=summary">Monsters University</a>,
#  <a href="/box-office-chart/daily/2013/03/08">Mar 8, 2013</a>,
#  <a href="/movie/Oz-The-Great-and-Powerful#tab=summary">Oz the Great and Powerful</a>,
#  <a href="/box-office-chart/daily/2014/05/21">May 21, 2014</a>,
#  <a href="/movie/X-Men-Days-of-Future-Past#tab=summary">X-Men: Days of Future Past</a>,
#  <a href="/box-office-chart/daily/2014/04/16">Apr 16, 2014</a>,
#  <a href="/movie/Amazing-Spider-Man-2-The#tab=summary">The Amazing Spider-Man 2</a>,
#  <a href="/box-office-chart/daily/2011/06/23">Jun 23, 2011</a>,
#  <a href="/movie/Cars-2#tab=summary">Cars 2</a>,
#  <a href="/box-office-chart/daily/2019/07/31">Jul 31, 2019</a>,
#  <a href="/movie/Fast-and-Furious-Presents-Hobbs-and-Shaw-(2019)#tab=summary">Fast &amp; Furious Presents: Hobbs &amp; Shaw</a>,
#  <a href="/box-office-chart/daily/2010/12/17">Dec 17, 2010</a>,
#  <a href="/movie/Tron-Legacy#tab=summary">Tron: Legacy</a>,
#  <a href="/box-office-chart/daily/2009/11/12">Nov 12, 2009</a>,
#  <a href="/movie/2012#tab=summary">2012</a>,
#  <a href="/box-office-chart/daily/2018/11/14">Nov 14, 2018</a>,
#  <a href="/movie/Fantastic-Beasts-The-Crimes-of-Grindelwald-(2018)#tab=summary">Fantastic Beasts: The Crimes of Grindelwald</a>,
#  <a href="/box-office-chart/daily/2009/05/21">May 21, 2009</a>,
#  <a href="/movie/Terminator-Salvation#tab=summary">Terminator Salvation</a>,
#  <a href="/box-office-chart/daily/2011/06/17">Jun 17, 2011</a>,
#  <a href="/movie/Green-Lantern-(2011)#tab=summary">Green Lantern</a>,
#  <a href="/box-office-chart/daily/2010/05/28">May 28, 2010</a>,
#  <a href="/movie/Prince-of-Persia-Sands-of-Time#tab=summary">Prince of Persia: Sands of Time</a>,
#  <a href="/box-office-chart/daily/2019/06/05">Jun 5, 2019</a>,
#  <a href="/movie/Dark-Phoenix-(2019)#tab=summary">Dark Phoenix</a>,
#  <a href="/box-office-chart/daily/2020/09/04">Sep 4, 2020</a>,
#  <a href="/movie/Mulan-(2020)#tab=summary">Mulan</a>,
#  <a href="/box-office-chart/daily/2011/06/29">Jun 29, 2011</a>,
#  <a href="/movie/Transformers-Dark-of-the-Moon-(2011)#tab=summary">Transformers: Dark of the Moon</a>,
#  <a href="/box-office-chart/daily/2017/06/02">Jun 2, 2017</a>,
#  <a href="/movie/Mummy-The-(2017)#tab=summary">The Mummy</a>,
#  <a href="/box-office-chart/daily/2013/02/27">Feb 27, 2013</a>,
#  <a href="/movie/Jack-the-Giant-Slayer#tab=summary">Jack the Giant Slayer</a>,
#  <a href="/box-office-chart/daily/2015/04/01">Apr 1, 2015</a>,
#  <a href="/movie/Furious-7#tab=summary">Furious 7</a>,
#  <a href="/box-office-chart/daily/2013/05/16">May 16, 2013</a>,
#  <a href="/movie/Star-Trek-Into-Darkness#tab=summary">Star Trek Into Darkness</a>,
#  <a href="/box-office-chart/daily/2013/06/19">Jun 19, 2013</a>,
#  <a href="/movie/World-War-Z#tab=summary">World War Z</a>,
#  <a href="/box-office-chart/daily/2013/05/10">May 10, 2013</a>,
#  <a href="/movie/Great-Gatsby-The-(2011)#tab=summary">The Great Gatsby</a>,
#  <a href="/box-office-chart/daily/2009/11/06">Nov 6, 2009</a>,
#  <a href="/movie/Disneys-A-Christmas-Carol#tab=summary">Disneyâs A Christmas Carol</a>,
#  <a href="/box-office-chart/daily/2013/07/11">Jul 11, 2013</a>,
#  <a href="/movie/Pacific-Rim#tab=summary">Pacific Rim</a>,
#  <a href="/box-office-chart/daily/2015/11/25">Nov 25, 2015</a>,
#  <a href="/movie/Good-Dinosaur-The#tab=summary">The Good Dinosaur</a>,
#  <a href="/box-office-chart/daily/2008/05/02">May 2, 2008</a>,
#  <a href="/movie/Iron-Man#tab=summary">Iron Man</a>,
#  <a href="/box-office-chart/daily/2008/07/11">Jul 11, 2008</a>,
#  <a href="/movie/Dark-Knight-The#tab=summary">The Dark Knight</a>,
#  <a href="/box-office-chart/daily/2008/05/22">May 22, 2008</a>,
#  <a href="/movie/Indiana-Jones-and-the-Kingdom-of-the-Crystal-Skull#tab=summary">Indiana Jones and the Kingdom of the Crystal Skull</a>,
#  <a href="/box-office-chart/daily/2012/06/21">Jun 21, 2012</a>,
#  <a href="/movie/Brave#tab=summary">Brave</a>,
#  <a href="/box-office-chart/daily/2017/02/23">Feb 23, 2017</a>,
#  <a href="/movie/Kong-Skull-Island#tab=summary">Kong: Skull Island</a>,
#  <a href="/box-office-chart/daily/2016/07/21">Jul 21, 2016</a>,
#  <a href="/movie/Star-Trek-Beyond#tab=summary">Star Trek Beyond</a>,
#  <a href="/box-office-chart/daily/2019/10/17">Oct 17, 2019</a>,
#  <a href="/movie/Maleficent-Mistress-of-Evil-(2019)#tab=summary">Maleficent: Mistress of Evil</a>,
#  <a href="/box-office-chart/daily/2017/09/29">Sep 29, 2017</a>,
#  <a href="/movie/Blade-Runner-2049#tab=summary">Blade Runner 2049</a>,
#  <a href="/box-office-chart/daily/2019/10/25">Oct 25, 2019</a>,
#  <a href="/movie/Terminator-Dark-Fate-(2019)#tab=summary">Terminator: Dark Fate</a>,
#  <a href="/box-office-chart/daily/2019/05/22">May 22, 2019</a>,
#  <a href="/movie/Aladdin-(2019)#tab=summary">Aladdin</a>,
#  <a href="/box-office-chart/daily/2017/10/25">Oct 25, 2017</a>,
#  <a href="/movie/Thor-Ragnarok#tab=summary">Thor: Ragnarok</a>,
#  <a href="/box-office-chart/daily/2005/12/09">Dec 9, 2005</a>,
#  <a href="/movie/Chronicles-of-Narnia-The-Lion-the-Witch-and-the-Wardrobe-The#tab=summary">The Chronicles of Narnia: The Lion, the Witch a…</a>,
#  <a href="/box-office-chart/daily/2014/05/28">May 28, 2014</a>,
#  <a href="/movie/Maleficent#tab=summary">Maleficent</a>,
#  <a href="/box-office-chart/daily/2016/11/14">Nov 14, 2016</a>,
#  <a href="/movie/Fantastic-Beasts-and-Where-to-Find-Them#tab=summary">Fantastic Beasts and Where to Find Them</a>,
#  <a href="/box-office-chart/daily/2008/06/27">Jun 27, 2008</a>,
#  <a href="/movie/WALL-E#tab=summary">WALL-E</a>,
#  <a href="/box-office-chart/daily/2007/08/10">Aug 10, 2007</a>,
#  <a href="/movie/Rush-Hour-3#tab=summary">Rush Hour 3</a>,
#  <a href="/box-office-chart/daily/2016/06/27">Jun 27, 2016</a>,
#  <a href="/movie/Legend-of-Tarzan-The#tab=summary">The Legend of Tarzan</a>,
#  <a href="/box-office-chart/daily/2011/11/23">Nov 23, 2011</a>,
#  <a href="/movie/Hugo#tab=summary">Hugo</a>,
#  <a href="/box-office-chart/daily/2017/07/20">Jul 20, 2017</a>,
#  <a href="/movie/Valerian-and-the-City-of-a-Thousand-Planets-(France)#tab=summary">Valerian and the City of a Thousand Planets</a>]

# %%
soup.find('table').find_all('a')[1]
# Out:
# <a href="/movie/Avengers-Endgame-(2019)#tab=summary">Avengers: Endgame</a>

# %%
soup.find('table').find_all('a')[1].findNext()
# Out:
# <td class="data"> $400,000,000</td>

# %%
soup.find('table').find_all('href'=='/movie/*')
# Out:
# [<tr><th> </th><th>Release<br/>Date</th><th>Movie</th><th>Production<br/>Budget</th><th>Domestic<br/>Gross</th><th>Worldwide<br/>Gross</th></tr>,
#  <th> </th>,
#  <th>Release<br/>Date</th>,
#  <br/>,
#  <th>Movie</th>,
#  <th>Production<br/>Budget</th>,
#  <br/>,
#  <th>Domestic<br/>Gross</th>,
#  <br/>,
#  <th>Worldwide<br/>Gross</th>,
#  <br/>,
#  <tr><td class="data">1</td>
#  <td><a href="/box-office-chart/daily/2019/04/23">Apr 23, 2019</a></td>
#  <td><b><a href="/movie/Avengers-Endgame-(2019)#tab=summary">Avengers: Endgame</a></b></td>
#  <td class="data"> $400,000,000</td>
#  <td class="data"> $858,373,000</td>
#  <td class="data"> $2,797,800,564</td>
#  </tr>,
#  <td class="data">1</td>,
#  <td><a href="/box-office-chart/daily/2019/04/23">Apr 23, 2019</a></td>,
#  <a href="/box-office-chart/daily/2019/04/23">Apr 23, 2019</a>,
#  <td><b><a href="/movie/Avengers-Endgame-(2019)#tab=summary">Avengers: Endgame</a></b></td>,
#  <b><a href="/movie/Avengers-Endgame-(2019)#tab=summary">Avengers: Endgame</a></b>,
#  <a href="/movie/Avengers-Endgame-(2019)#tab=summary">Avengers: Endgame</a>,
#  <td class="data"> $400,000,000</td>,
#  <td class="data"> $858,373,000</td>,
#  <td class="data"> $2,797,800,564</td>,
#  <tr><td class="data">2</td>
#  <td><a href="/box-office-chart/daily/2011/05/20">May 20, 2011</a></td>
#  <td><b><a href="/movie/Pirates-of-the-Caribbean-On-Stranger-Tides#tab=summary">Pirates of the Caribbean: On Stranger Tides</a></b></td>
#  <td class="data"> $379,000,000</td>
#  <td class="data"> $241,063,875</td>
#  <td class="data"> $1,045,663,875</td>
#  </tr>,
#  <td class="data">2</td>,
#  <td><a href="/box-office-chart/daily/2011/05/20">May 20, 2011</a></td>,
#  <a href="/box-office-chart/daily/2011/05/20">May 20, 2011</a>,
#  <td><b><a href="/movie/Pirates-of-the-Caribbean-On-Stranger-Tides#tab=summary">Pirates of the Caribbean: On Stranger Tides</a></b></td>,
#  <b><a href="/movie/Pirates-of-the-Caribbean-On-Stranger-Tides#tab=summary">Pirates of the Caribbean: On Stranger Tides</a></b>,
#  <a href="/movie/Pirates-of-the-Caribbean-On-Stranger-Tides#tab=summary">Pirates of the Caribbean: On Stranger Tides</a>,
#  <td class="data"> $379,000,000</td>,
#  <td class="data"> $241,063,875</td>,
#  <td class="data"> $1,045,663,875</td>,
#  <tr><td class="data">3</td>
#  <td><a href="/box-office-chart/daily/2015/04/22">Apr 22, 2015</a></td>
#  <td><b><a href="/movie/Avengers-Age-of-Ultron#tab=summary">Avengers: Age of Ultron</a></b></td>
#  <td class="data"> $365,000,000</td>
#  <td class="data"> $459,005,868</td>
#  <td class="data"> $1,396,099,202</td>
#  </tr>,
#  <td class="data">3</td>,
#  <td><a href="/box-office-chart/daily/2015/04/22">Apr 22, 2015</a></td>,
#  <a href="/box-office-chart/daily/2015/04/22">Apr 22, 2015</a>,
#  <td><b><a href="/movie/Avengers-Age-of-Ultron#tab=summary">Avengers: Age of Ultron</a></b></td>,
#  <b><a href="/movie/Avengers-Age-of-Ultron#tab=summary">Avengers: Age of Ultron</a></b>,
#  <a href="/movie/Avengers-Age-of-Ultron#tab=summary">Avengers: Age of Ultron</a>,
#  <td class="data"> $365,000,000</td>,
#  <td class="data"> $459,005,868</td>,
#  <td class="data"> $1,396,099,202</td>,
#  <tr><td class="data">4</td>
#  <td><a href="/box-office-chart/daily/2015/12/16">Dec 16, 2015</a></td>
#  <td><b><a href="/movie/Star-Wars-Ep-VII-The-Force-Awakens#tab=summary">Star Wars Ep. VII: The Force Awakens</a></b></td>
#  <td class="data"> $306,000,000</td>
#  <td class="data"> $936,662,225</td>
#  <td class="data"> $2,065,478,084</td>
#  </tr>,
#  <td class="data">4</td>,
#  <td><a href="/box-office-chart/daily/2015/12/16">Dec 16, 2015</a></td>,
#  <a href="/box-office-chart/daily/2015/12/16">Dec 16, 2015</a>,
#  <td><b><a href="/movie/Star-Wars-Ep-VII-The-Force-Awakens#tab=summary">Star Wars Ep. VII: The Force Awakens</a></b></td>,
#  <b><a href="/movie/Star-Wars-Ep-VII-The-Force-Awakens#tab=summary">Star Wars Ep. VII: The Force Awakens</a></b>,
#  <a href="/movie/Star-Wars-Ep-VII-The-Force-Awakens#tab=summary">Star Wars Ep. VII: The Force Awakens</a>,
#  <td class="data"> $306,000,000</td>,
#  <td class="data"> $936,662,225</td>,
#  <td class="data"> $2,065,478,084</td>,
#  <tr><td class="data">5</td>
#  <td><a href="/box-office-chart/daily/2018/04/25">Apr 25, 2018</a></td>
#  <td><b><a href="/movie/Avengers-Infinity-War#tab=summary">Avengers: Infinity War</a></b></td>
#  <td class="data"> $300,000,000</td>
#  <td class="data"> $678,815,482</td>
#  <td class="data"> $2,044,540,523</td>
#  </tr>,
#  <td class="data">5</td>,
#  <td><a href="/box-office-chart/daily/2018/04/25">Apr 25, 2018</a></td>,
#  <a href="/box-office-chart/daily/2018/04/25">Apr 25, 2018</a>,
#  <td><b><a href="/movie/Avengers-Infinity-War#tab=summary">Avengers: Infinity War</a></b></td>,
#  <b><a href="/movie/Avengers-Infinity-War#tab=summary">Avengers: Infinity War</a></b>,
#  <a href="/movie/Avengers-Infinity-War#tab=summary">Avengers: Infinity War</a>,
#  <td class="data"> $300,000,000</td>,
#  <td class="data"> $678,815,482</td>,
#  <td class="data"> $2,044,540,523</td>,
#  <tr><td class="data">6</td>
#  <td><a href="/box-office-chart/daily/2007/05/24">May 24, 2007</a></td>
#  <td><b><a href="/movie/Pirates-of-the-Caribbean-At-Worlds-End#tab=summary">Pirates of the Caribbean: At Worldâs End</a></b></td>
#  <td class="data"> $300,000,000</td>
#  <td class="data"> $309,420,425</td>
#  <td class="data"> $963,420,425</td>
#  </tr>,
#  <td class="data">6</td>,
#  <td><a href="/box-office-chart/daily/2007/05/24">May 24, 2007</a></td>,
#  <a href="/box-office-chart/daily/2007/05/24">May 24, 2007</a>,
#  <td><b><a href="/movie/Pirates-of-the-Caribbean-At-Worlds-End#tab=summary">Pirates of the Caribbean: At Worldâs End</a></b></td>,
#  <b><a href="/movie/Pirates-of-the-Caribbean-At-Worlds-End#tab=summary">Pirates of the Caribbean: At Worldâs End</a></b>,
#  <a href="/movie/Pirates-of-the-Caribbean-At-Worlds-End#tab=summary">Pirates of the Caribbean: At Worldâs End</a>,
#  <td class="data"> $300,000,000</td>,
#  <td class="data"> $309,420,425</td>,
#  <td class="data"> $963,420,425</td>,
#  <tr><td class="data">7</td>
#  <td><a href="/box-office-chart/daily/2017/11/13">Nov 13, 2017</a></td>
#  <td><b><a href="/movie/Justice-League-(2017)#tab=summary">Justice League</a></b></td>
#  <td class="data"> $300,000,000</td>
#  <td class="data"> $229,024,295</td>
#  <td class="data"> $655,945,209</td>
#  </tr>,
#  <td class="data">7</td>,
#  <td><a href="/box-office-chart/daily/2017/11/13">Nov 13, 2017</a></td>,
#  <a href="/box-office-chart/daily/2017/11/13">Nov 13, 2017</a>,
#  <td><b><a href="/movie/Justice-League-(2017)#tab=summary">Justice League</a></b></td>,
#  <b><a href="/movie/Justice-League-(2017)#tab=summary">Justice League</a></b>,
#  <a href="/movie/Justice-League-(2017)#tab=summary">Justice League</a>,
#  <td class="data"> $300,000,000</td>,
#  <td class="data"> $229,024,295</td>,
#  <td class="data"> $655,945,209</td>,
#  <tr><td class="data">8</td>
#  <td><a href="/box-office-chart/daily/2015/10/06">Oct 6, 2015</a></td>
#  <td><b><a href="/movie/Spectre#tab=summary">Spectre</a></b></td>
#  <td class="data"> $300,000,000</td>
#  <td class="data"> $200,074,175</td>
#  <td class="data"> $879,500,760</td>
#  </tr>,
#  <td class="data">8</td>,
#  <td><a href="/box-office-chart/daily/2015/10/06">Oct 6, 2015</a></td>,
#  <a href="/box-office-chart/daily/2015/10/06">Oct 6, 2015</a>,
#  <td><b><a href="/movie/Spectre#tab=summary">Spectre</a></b></td>,
#  <b><a href="/movie/Spectre#tab=summary">Spectre</a></b>,
#  <a href="/movie/Spectre#tab=summary">Spectre</a>,
#  <td class="data"> $300,000,000</td>,
#  <td class="data"> $200,074,175</td>,
#  <td class="data"> $879,500,760</td>,
#  <tr><td class="data">9</td>
#  <td><a href="/box-office-chart/daily/2019/12/18">Dec 18, 2019</a></td>
#  <td><b><a href="/movie/Star-Wars-The-Rise-of-Skywalker-(2019)#tab=summary">Star Wars: The Rise of Skywalker</a></b></td>
#  <td class="data"> $275,000,000</td>
#  <td class="data"> $515,202,542</td>
#  <td class="data"> $1,072,944,222</td>
#  </tr>,
#  <td class="data">9</td>,
#  <td><a href="/box-office-chart/daily/2019/12/18">Dec 18, 2019</a></td>,
#  <a href="/box-office-chart/daily/2019/12/18">Dec 18, 2019</a>,
#  <td><b><a href="/movie/Star-Wars-The-Rise-of-Skywalker-(2019)#tab=summary">Star Wars: The Rise of Skywalker</a></b></td>,
#  <b><a href="/movie/Star-Wars-The-Rise-of-Skywalker-(2019)#tab=summary">Star Wars: The Rise of Skywalker</a></b>,
#  <a href="/movie/Star-Wars-The-Rise-of-Skywalker-(2019)#tab=summary">Star Wars: The Rise of Skywalker</a>,
#  <td class="data"> $275,000,000</td>,
#  <td class="data"> $515,202,542</td>,
#  <td class="data"> $1,072,944,222</td>,
#  <tr><td class="data">10</td>
#  <td><a href="/box-office-chart/daily/2018/05/23">May 23, 2018</a></td>
#  <td><b><a href="/movie/Solo-A-Star-Wars-Story#tab=summary">Solo: A Star Wars Story</a></b></td>
#  <td class="data"> $275,000,000</td>
#  <td class="data"> $213,767,512</td>
#  <td class="data"> $393,151,347</td>
#  </tr>,
#  <td class="data">10</td>,
#  <td><a href="/box-office-chart/daily/2018/05/23">May 23, 2018</a></td>,
#  <a href="/box-office-chart/daily/2018/05/23">May 23, 2018</a>,
#  <td><b><a href="/movie/Solo-A-Star-Wars-Story#tab=summary">Solo: A Star Wars Story</a></b></td>,
#  <b><a href="/movie/Solo-A-Star-Wars-Story#tab=summary">Solo: A Star Wars Story</a></b>,
#  <a href="/movie/Solo-A-Star-Wars-Story#tab=summary">Solo: A Star Wars Story</a>,
#  <td class="data"> $275,000,000</td>,
#  <td class="data"> $213,767,512</td>,
#  <td class="data"> $393,151,347</td>,
#  <tr><td class="data">11</td>
#  <td><a href="/box-office-chart/daily/2012/03/07">Mar 7, 2012</a></td>
#  <td><b><a href="/movie/John-Carter-of-Mars#tab=summary">John Carter</a></b></td>
#  <td class="data"> $263,700,000</td>
#  <td class="data"> $73,058,679</td>
#  <td class="data"> $282,778,100</td>
#  </tr>,
#  <td class="data">11</td>,
#  <td><a href="/box-office-chart/daily/2012/03/07">Mar 7, 2012</a></td>,
#  <a href="/box-office-chart/daily/2012/03/07">Mar 7, 2012</a>,
#  <td><b><a href="/movie/John-Carter-of-Mars#tab=summary">John Carter</a></b></td>,
#  <b><a href="/movie/John-Carter-of-Mars#tab=summary">John Carter</a></b>,
#  <a href="/movie/John-Carter-of-Mars#tab=summary">John Carter</a>,
#  <td class="data"> $263,700,000</td>,
#  <td class="data"> $73,058,679</td>,
#  <td class="data"> $282,778,100</td>,
#  <tr><td class="data">12</td>
#  <td><a href="/box-office-chart/daily/2016/03/23">Mar 23, 2016</a></td>
#  <td><b><a href="/movie/Batman-v-Superman-Dawn-of-Justice#tab=summary">Batman v Superman: Dawn of Justice</a></b></td>
#  <td class="data"> $263,000,000</td>
#  <td class="data"> $330,360,194</td>
#  <td class="data"> $872,395,091</td>
#  </tr>,
#  <td class="data">12</td>,
#  <td><a href="/box-office-chart/daily/2016/03/23">Mar 23, 2016</a></td>,
#  <a href="/box-office-chart/daily/2016/03/23">Mar 23, 2016</a>,
#  <td><b><a href="/movie/Batman-v-Superman-Dawn-of-Justice#tab=summary">Batman v Superman: Dawn of Justice</a></b></td>,
#  <b><a href="/movie/Batman-v-Superman-Dawn-of-Justice#tab=summary">Batman v Superman: Dawn of Justice</a></b>,
#  <a href="/movie/Batman-v-Superman-Dawn-of-Justice#tab=summary">Batman v Superman: Dawn of Justice</a>,
#  <td class="data"> $263,000,000</td>,
#  <td class="data"> $330,360,194</td>,
#  <td class="data"> $872,395,091</td>,
#  <tr><td class="data">13</td>
#  <td><a href="/box-office-chart/daily/2019/07/11">Jul 11, 2019</a></td>
#  <td><b><a href="/movie/Lion-King-The-(Live-Action)-(2019)#tab=summary">The Lion King</a></b></td>
#  <td class="data"> $260,000,000</td>
#  <td class="data"> $543,638,043</td>
#  <td class="data"> $1,654,381,934</td>
#  </tr>,
#  <td class="data">13</td>,
#  <td><a href="/box-office-chart/daily/2019/07/11">Jul 11, 2019</a></td>,
#  <a href="/box-office-chart/daily/2019/07/11">Jul 11, 2019</a>,
#  <td><b><a href="/movie/Lion-King-The-(Live-Action)-(2019)#tab=summary">The Lion King</a></b></td>,
#  <b><a href="/movie/Lion-King-The-(Live-Action)-(2019)#tab=summary">The Lion King</a></b>,
#  <a href="/movie/Lion-King-The-(Live-Action)-(2019)#tab=summary">The Lion King</a>,
#  <td class="data"> $260,000,000</td>,
#  <td class="data"> $543,638,043</td>,
#  <td class="data"> $1,654,381,934</td>,
#  <tr><td class="data">14</td>
#  <td><a href="/box-office-chart/daily/2010/11/24">Nov 24, 2010</a></td>
#  <td><b><a href="/movie/Tangled#tab=summary">Tangled</a></b></td>
#  <td class="data"> $260,000,000</td>
#  <td class="data"> $200,821,936</td>
#  <td class="data"> $585,727,091</td>
#  </tr>,
#  <td class="data">14</td>,
#  <td><a href="/box-office-chart/daily/2010/11/24">Nov 24, 2010</a></td>,
#  <a href="/box-office-chart/daily/2010/11/24">Nov 24, 2010</a>,
#  <td><b><a href="/movie/Tangled#tab=summary">Tangled</a></b></td>,
#  <b><a href="/movie/Tangled#tab=summary">Tangled</a></b>,
#  <a href="/movie/Tangled#tab=summary">Tangled</a>,
#  <td class="data"> $260,000,000</td>,
#  <td class="data"> $200,821,936</td>,
#  <td class="data"> $585,727,091</td>,
#  <tr><td class="data">15</td>
#  <td><a href="/box-office-chart/daily/2007/05/04">May 4, 2007</a></td>
#  <td><b><a href="/movie/Spider-Man-3#tab=summary">Spider-Man 3</a></b></td>
#  <td class="data"> $258,000,000</td>
#  <td class="data"> $336,530,303</td>
#  <td class="data"> $894,860,230</td>
#  </tr>,
#  <td class="data">15</td>,
#  <td><a href="/box-office-chart/daily/2007/05/04">May 4, 2007</a></td>,
#  <a href="/box-office-chart/daily/2007/05/04">May 4, 2007</a>,
#  <td><b><a href="/movie/Spider-Man-3#tab=summary">Spider-Man 3</a></b></td>,
#  <b><a href="/movie/Spider-Man-3#tab=summary">Spider-Man 3</a></b>,
#  <a href="/movie/Spider-Man-3#tab=summary">Spider-Man 3</a>,
#  <td class="data"> $258,000,000</td>,
#  <td class="data"> $336,530,303</td>,
#  <td class="data"> $894,860,230</td>,
#  <tr><td class="data">16</td>
#  <td><a href="/box-office-chart/daily/2016/04/22">Apr 22, 2016</a></td>
#  <td><b><a href="/movie/Captain-America-Civil-War#tab=summary">Captain America: Civil War</a></b></td>
#  <td class="data"> $250,000,000</td>
#  <td class="data"> $408,084,349</td>
#  <td class="data"> $1,151,918,521</td>
#  </tr>,
#  <td class="data">16</td>,
#  <td><a href="/box-office-chart/daily/2016/04/22">Apr 22, 2016</a></td>,
#  <a href="/box-office-chart/daily/2016/04/22">Apr 22, 2016</a>,
#  <td><b><a href="/movie/Captain-America-Civil-War#tab=summary">Captain America: Civil War</a></b></td>,
#  <b><a href="/movie/Captain-America-Civil-War#tab=summary">Captain America: Civil War</a></b>,
#  <a href="/movie/Captain-America-Civil-War#tab=summary">Captain America: Civil War</a>,
#  <td class="data"> $250,000,000</td>,
#  <td class="data"> $408,084,349</td>,
#  <td class="data"> $1,151,918,521</td>,
#  <tr><td class="data">17</td>
#  <td><a href="/box-office-chart/daily/2009/07/15">Jul 15, 2009</a></td>
#  <td><b><a href="/movie/Harry-Potter-and-the-Half-Blood-Prince#tab=summary">Harry Potter and the Half-Blood Prince</a></b></td>
#  <td class="data"> $250,000,000</td>
#  <td class="data"> $302,089,278</td>
#  <td class="data"> $930,673,167</td>
#  </tr>,
#  <td class="data">17</td>,
#  <td><a href="/box-office-chart/daily/2009/07/15">Jul 15, 2009</a></td>,
#  <a href="/box-office-chart/daily/2009/07/15">Jul 15, 2009</a>,
#  <td><b><a href="/movie/Harry-Potter-and-the-Half-Blood-Prince#tab=summary">Harry Potter and the Half-Blood Prince</a></b></td>,
#  <b><a href="/movie/Harry-Potter-and-the-Half-Blood-Prince#tab=summary">Harry Potter and the Half-Blood Prince</a></b>,
#  <a href="/movie/Harry-Potter-and-the-Half-Blood-Prince#tab=summary">Harry Potter and the Half-Blood Prince</a>,
#  <td class="data"> $250,000,000</td>,
#  <td class="data"> $302,089,278</td>,
#  <td class="data"> $930,673,167</td>,
#  <tr><td class="data">18</td>
#  <td><a href="/box-office-chart/daily/2013/12/12">Dec 12, 2013</a></td>
#  <td><b><a href="/movie/Hobbit-The-Desolation-of-Smaug-The#tab=summary">The Hobbit: The Desolation of Smaug</a></b></td>
#  <td class="data"> $250,000,000</td>
#  <td class="data"> $258,241,522</td>
#  <td class="data"> $960,238,087</td>
#  </tr>,
#  <td class="data">18</td>,
#  <td><a href="/box-office-chart/daily/2013/12/12">Dec 12, 2013</a></td>,
#  <a href="/box-office-chart/daily/2013/12/12">Dec 12, 2013</a>,
#  <td><b><a href="/movie/Hobbit-The-Desolation-of-Smaug-The#tab=summary">The Hobbit: The Desolation of Smaug</a></b></td>,
#  <b><a href="/movie/Hobbit-The-Desolation-of-Smaug-The#tab=summary">The Hobbit: The Desolation of Smaug</a></b>,
#  <a href="/movie/Hobbit-The-Desolation-of-Smaug-The#tab=summary">The Hobbit: The Desolation of Smaug</a>,
#  <td class="data"> $250,000,000</td>,
#  <td class="data"> $258,241,522</td>,
#  <td class="data"> $960,238,087</td>,
#  <tr><td class="data">19</td>
#  <td><a href="/box-office-chart/daily/2014/12/10">Dec 10, 2014</a></td>
#  <td><b><a href="/movie/Hobbit-The-Battle-of-the-Five-Armies-The#tab=summary">The Hobbit: The Battle of the Five Armies</a></b></td>
#  <td class="data"> $250,000,000</td>
#  <td class="data"> $255,119,788</td>
#  <td class="data"> $943,328,905</td>
#  </tr>,
#  <td class="data">19</td>,
#  <td><a href="/box-office-chart/daily/2014/12/10">Dec 10, 2014</a></td>,
#  <a href="/box-office-chart/daily/2014/12/10">Dec 10, 2014</a>,
#  <td><b><a href="/movie/Hobbit-The-Battle-of-the-Five-Armies-The#tab=summary">The Hobbit: The Battle of the Five Armies</a></b></td>,
#  <b><a href="/movie/Hobbit-The-Battle-of-the-Five-Armies-The#tab=summary">The Hobbit: The Battle of the Five Armies</a></b>,
#  <a href="/movie/Hobbit-The-Battle-of-the-Five-Armies-The#tab=summary">The Hobbit: The Battle of the Five Armies</a>,
#  <td class="data"> $250,000,000</td>,
#  <td class="data"> $255,119,788</td>,
#  <td class="data"> $943,328,905</td>,
#  <tr><td class="data">20</td>
#  <td><a href="/box-office-chart/daily/2017/04/07">Apr 7, 2017</a></td>
#  <td><b><a href="/movie/Fate-of-the-Furious-The#tab=summary">The Fate of the Furious</a></b></td>
#  <td class="data"> $250,000,000</td>
#  <td class="data"> $225,764,765</td>
#  <td class="data"> $1,236,703,796</td>
#  </tr>,
#  <td class="data">20</td>,
#  <td><a href="/box-office-chart/daily/2017/04/07">Apr 7, 2017</a></td>,
#  <a href="/box-office-chart/daily/2017/04/07">Apr 7, 2017</a>,
#  <td><b><a href="/movie/Fate-of-the-Furious-The#tab=summary">The Fate of the Furious</a></b></td>,
#  <b><a href="/movie/Fate-of-the-Furious-The#tab=summary">The Fate of the Furious</a></b>,
#  <a href="/movie/Fate-of-the-Furious-The#tab=summary">The Fate of the Furious</a>,
#  <td class="data"> $250,000,000</td>,
#  <td class="data"> $225,764,765</td>,
#  <td class="data"> $1,236,703,796</td>,
#  <tr><td class="data">21</td>
#  <td><a href="/box-office-chart/daily/2021/03/31">Mar 31, 2021</a></td>
#  <td><b><a href="/movie/No-Time-to-Die-(2020)#tab=summary">No Time to Die</a></b></td>
#  <td class="data"> $250,000,000</td>
#  <td class="data"> $0</td>
#  <td class="data"> $0</td>
#  </tr>,
#  <td class="data">21</td>,
#  <td><a href="/box-office-chart/daily/2021/03/31">Mar 31, 2021</a></td>,
#  <a href="/box-office-chart/daily/2021/03/31">Mar 31, 2021</a>,
#  <td><b><a href="/movie/No-Time-to-Die-(2020)#tab=summary">No Time to Die</a></b></td>,
#  <b><a href="/movie/No-Time-to-Die-(2020)#tab=summary">No Time to Die</a></b>,
#  <a href="/movie/No-Time-to-Die-(2020)#tab=summary">No Time to Die</a>,
#  <td class="data"> $250,000,000</td>,
#  <td class="data"> $0</td>,
#  <td class="data"> $0</td>,
#  <tr><td class="data">22</td>
#  <td><a href="/box-office-chart/daily/2009/12/17">Dec 17, 2009</a></td>
#  <td><b><a href="/movie/Avatar#tab=summary">Avatar</a></b></td>
#  <td class="data"> $237,000,000</td>
#  <td class="data"> $760,507,625</td>
#  <td class="data"> $2,788,701,337</td>
#  </tr>,
#  <td class="data">22</td>,
#  <td><a href="/box-office-chart/daily/2009/12/17">Dec 17, 2009</a></td>,
#  <a href="/box-office-chart/daily/2009/12/17">Dec 17, 2009</a>,
#  <td><b><a href="/movie/Avatar#tab=summary">Avatar</a></b></td>,
#  <b><a href="/movie/Avatar#tab=summary">Avatar</a></b>,
#  <a href="/movie/Avatar#tab=summary">Avatar</a>,
#  <td class="data"> $237,000,000</td>,
#  <td class="data"> $760,507,625</td>,
#  <td class="data"> $2,788,701,337</td>,
#  <tr><td class="data">23</td>
#  <td><a href="/box-office-chart/daily/2006/06/28">Jun 28, 2006</a></td>
#  <td><b><a href="/movie/Superman-Returns#tab=summary">Superman Returns</a></b></td>
#  <td class="data"> $232,000,000</td>
#  <td class="data"> $200,120,000</td>
#  <td class="data"> $391,081,192</td>
#  </tr>,
#  <td class="data">23</td>,
#  <td><a href="/box-office-chart/daily/2006/06/28">Jun 28, 2006</a></td>,
#  <a href="/box-office-chart/daily/2006/06/28">Jun 28, 2006</a>,
#  <td><b><a href="/movie/Superman-Returns#tab=summary">Superman Returns</a></b></td>,
#  <b><a href="/movie/Superman-Returns#tab=summary">Superman Returns</a></b>,
#  <a href="/movie/Superman-Returns#tab=summary">Superman Returns</a>,
#  <td class="data"> $232,000,000</td>,
#  <td class="data"> $200,120,000</td>,
#  <td class="data"> $391,081,192</td>,
#  <tr><td class="data">24</td>
#  <td><a href="/box-office-chart/daily/2012/07/19">Jul 19, 2012</a></td>
#  <td><b><a href="/movie/Dark-Knight-Rises-The#tab=summary">The Dark Knight Rises</a></b></td>
#  <td class="data"> $230,000,000</td>
#  <td class="data"> $448,139,099</td>
#  <td class="data"> $1,082,228,107</td>
#  </tr>,
#  <td class="data">24</td>,
#  <td><a href="/box-office-chart/daily/2012/07/19">Jul 19, 2012</a></td>,
#  <a href="/box-office-chart/daily/2012/07/19">Jul 19, 2012</a>,
#  <td><b><a href="/movie/Dark-Knight-Rises-The#tab=summary">The Dark Knight Rises</a></b></td>,
#  <b><a href="/movie/Dark-Knight-Rises-The#tab=summary">The Dark Knight Rises</a></b>,
#  <a href="/movie/Dark-Knight-Rises-The#tab=summary">The Dark Knight Rises</a>,
#  <td class="data"> $230,000,000</td>,
#  <td class="data"> $448,139,099</td>,
#  <td class="data"> $1,082,228,107</td>,
#  <tr><td class="data">25</td>
#  <td><a href="/box-office-chart/daily/2017/05/23">May 23, 2017</a></td>
#  <td><b><a href="/movie/Pirates-of-the-Caribbean-Dead-Men-Tell-No-Tales#tab=summary">Pirates of the Caribbean: Dead Men Tell No Tales</a></b></td>
#  <td class="data"> $230,000,000</td>
#  <td class="data"> $172,558,876</td>
#  <td class="data"> $788,241,137</td>
#  </tr>,
#  <td class="data">25</td>,
#  <td><a href="/box-office-chart/daily/2017/05/23">May 23, 2017</a></td>,
#  <a href="/box-office-chart/daily/2017/05/23">May 23, 2017</a>,
#  <td><b><a href="/movie/Pirates-of-the-Caribbean-Dead-Men-Tell-No-Tales#tab=summary">Pirates of the Caribbean: Dead Men Tell No Tales</a></b></td>,
#  <b><a href="/movie/Pirates-of-the-Caribbean-Dead-Men-Tell-No-Tales#tab=summary">Pirates of the Caribbean: Dead Men Tell No Tales</a></b>,
#  <a href="/movie/Pirates-of-the-Caribbean-Dead-Men-Tell-No-Tales#tab=summary">Pirates of the Caribbean: Dead Men Tell No Tales</a>,
#  <td class="data"> $230,000,000</td>,
#  <td class="data"> $172,558,876</td>,
#  <td class="data"> $788,241,137</td>,
#  <tr><td class="data">26</td>
#  <td><a href="/box-office-chart/daily/2008/11/14">Nov 14, 2008</a></td>
#  <td><b><a href="/movie/Quantum-of-Solace#tab=summary">Quantum of Solace</a></b></td>
#  <td class="data"> $230,000,000</td>
#  <td class="data"> $169,368,427</td>
#  <td class="data"> $591,692,078</td>
#  </tr>,
#  <td class="data">26</td>,
#  <td><a href="/box-office-chart/daily/2008/11/14">Nov 14, 2008</a></td>,
#  <a href="/box-office-chart/daily/2008/11/14">Nov 14, 2008</a>,
#  <td><b><a href="/movie/Quantum-of-Solace#tab=summary">Quantum of Solace</a></b></td>,
#  <b><a href="/movie/Quantum-of-Solace#tab=summary">Quantum of Solace</a></b>,
#  <a href="/movie/Quantum-of-Solace#tab=summary">Quantum of Solace</a>,
#  <td class="data"> $230,000,000</td>,
#  <td class="data"> $169,368,427</td>,
#  <td class="data"> $591,692,078</td>,
#  <tr><td class="data">27</td>
#  <td><a href="/box-office-chart/daily/2012/04/25">Apr 25, 2012</a></td>
#  <td><b><a href="/movie/Avengers-The-(2012)#tab=summary">The Avengers</a></b></td>
#  <td class="data"> $225,000,000</td>
#  <td class="data"> $623,357,910</td>
#  <td class="data"> $1,515,100,211</td>
#  </tr>,
#  <td class="data">27</td>,
#  <td><a href="/box-office-chart/daily/2012/04/25">Apr 25, 2012</a></td>,
#  <a href="/box-office-chart/daily/2012/04/25">Apr 25, 2012</a>,
#  <td><b><a href="/movie/Avengers-The-(2012)#tab=summary">The Avengers</a></b></td>,
#  <b><a href="/movie/Avengers-The-(2012)#tab=summary">The Avengers</a></b>,
#  <a href="/movie/Avengers-The-(2012)#tab=summary">The Avengers</a>,
#  <td class="data"> $225,000,000</td>,
#  <td class="data"> $623,357,910</td>,
#  <td class="data"> $1,515,100,211</td>,
#  <tr><td class="data">28</td>
#  <td><a href="/box-office-chart/daily/2006/07/06">Jul 6, 2006</a></td>
#  <td><b><a href="/movie/Pirates-of-the-Caribbean-Dead-Mans-Chest#tab=summary">Pirates of the Caribbean: Dead Manâs Chest</a></b></td>
#  <td class="data"> $225,000,000</td>
#  <td class="data"> $423,315,812</td>
#  <td class="data"> $1,066,215,812</td>
#  </tr>,
#  <td class="data">28</td>,
#  <td><a href="/box-office-chart/daily/2006/07/06">Jul 6, 2006</a></td>,
#  <a href="/box-office-chart/daily/2006/07/06">Jul 6, 2006</a>,
#  <td><b><a href="/movie/Pirates-of-the-Caribbean-Dead-Mans-Chest#tab=summary">Pirates of the Caribbean: Dead Manâs Chest</a></b></td>,
#  <b><a href="/movie/Pirates-of-the-Caribbean-Dead-Mans-Chest#tab=summary">Pirates of the Caribbean: Dead Manâs Chest</a></b>,
#  <a href="/movie/Pirates-of-the-Caribbean-Dead-Mans-Chest#tab=summary">Pirates of the Caribbean: Dead Manâs Chest</a>,
#  <td class="data"> $225,000,000</td>,
#  <td class="data"> $423,315,812</td>,
#  <td class="data"> $1,066,215,812</td>,
#  <tr><td class="data">29</td>
#  <td><a href="/box-office-chart/daily/2013/06/14">Jun 14, 2013</a></td>
#  <td><b><a href="/movie/Man-of-Steel#tab=summary">Man of Steel</a></b></td>
#  <td class="data"> $225,000,000</td>
#  <td class="data"> $291,045,518</td>
#  <td class="data"> $667,999,518</td>
#  </tr>,
#  <td class="data">29</td>,
#  <td><a href="/box-office-chart/daily/2013/06/14">Jun 14, 2013</a></td>,
#  <a href="/box-office-chart/daily/2013/06/14">Jun 14, 2013</a>,
#  <td><b><a href="/movie/Man-of-Steel#tab=summary">Man of Steel</a></b></td>,
#  <b><a href="/movie/Man-of-Steel#tab=summary">Man of Steel</a></b>,
#  <a href="/movie/Man-of-Steel#tab=summary">Man of Steel</a>,
#  <td class="data"> $225,000,000</td>,
#  <td class="data"> $291,045,518</td>,
#  <td class="data"> $667,999,518</td>,
#  <tr><td class="data">30</td>
#  <td><a href="/box-office-chart/daily/2008/05/16">May 16, 2008</a></td>
#  <td><b><a href="/movie/Chronicles-of-Narnia-Prince-Caspian-The#tab=summary">The Chronicles of Narnia: Prince Caspian</a></b></td>
#  <td class="data"> $225,000,000</td>
#  <td class="data"> $141,621,490</td>
#  <td class="data"> $417,341,288</td>
#  </tr>,
#  <td class="data">30</td>,
#  <td><a href="/box-office-chart/daily/2008/05/16">May 16, 2008</a></td>,
#  <a href="/box-office-chart/daily/2008/05/16">May 16, 2008</a>,
#  <td><b><a href="/movie/Chronicles-of-Narnia-Prince-Caspian-The#tab=summary">The Chronicles of Narnia: Prince Caspian</a></b></td>,
#  <b><a href="/movie/Chronicles-of-Narnia-Prince-Caspian-The#tab=summary">The Chronicles of Narnia: Prince Caspian</a></b>,
#  <a href="/movie/Chronicles-of-Narnia-Prince-Caspian-The#tab=summary">The Chronicles of Narnia: Prince Caspian</a>,
#  <td class="data"> $225,000,000</td>,
#  <td class="data"> $141,621,490</td>,
#  <td class="data"> $417,341,288</td>,
#  <tr><td class="data">31</td>
#  <td><a href="/box-office-chart/daily/2013/07/02">Jul 2, 2013</a></td>
#  <td><b><a href="/movie/Lone-Ranger-The#tab=summary">The Lone Ranger</a></b></td>
#  <td class="data"> $225,000,000</td>
#  <td class="data"> $89,302,115</td>
#  <td class="data"> $260,002,115</td>
#  </tr>,
#  <td class="data">31</td>,
#  <td><a href="/box-office-chart/daily/2013/07/02">Jul 2, 2013</a></td>,
#  <a href="/box-office-chart/daily/2013/07/02">Jul 2, 2013</a>,
#  <td><b><a href="/movie/Lone-Ranger-The#tab=summary">The Lone Ranger</a></b></td>,
#  <b><a href="/movie/Lone-Ranger-The#tab=summary">The Lone Ranger</a></b>,
#  <a href="/movie/Lone-Ranger-The#tab=summary">The Lone Ranger</a>,
#  <td class="data"> $225,000,000</td>,
#  <td class="data"> $89,302,115</td>,
#  <td class="data"> $260,002,115</td>,
#  <tr><td class="data">32</td>
#  <td><a href="/box-office-chart/daily/2012/06/27">Jun 27, 2012</a></td>
#  <td><b><a href="/movie/Amazing-Spider-Man-The#tab=summary">The Amazing Spider-Man</a></b></td>
#  <td class="data"> $220,000,000</td>
#  <td class="data"> $262,030,663</td>
#  <td class="data"> $757,890,267</td>
#  </tr>,
#  <td class="data">32</td>,
#  <td><a href="/box-office-chart/daily/2012/06/27">Jun 27, 2012</a></td>,
#  <a href="/box-office-chart/daily/2012/06/27">Jun 27, 2012</a>,
#  <td><b><a href="/movie/Amazing-Spider-Man-The#tab=summary">The Amazing Spider-Man</a></b></td>,
#  <b><a href="/movie/Amazing-Spider-Man-The#tab=summary">The Amazing Spider-Man</a></b>,
#  <a href="/movie/Amazing-Spider-Man-The#tab=summary">The Amazing Spider-Man</a>,
#  <td class="data"> $220,000,000</td>,
#  <td class="data"> $262,030,663</td>,
#  <td class="data"> $757,890,267</td>,
#  <tr><td class="data">33</td>
#  <td><a href="/box-office-chart/daily/2012/04/11">Apr 11, 2012</a></td>
#  <td><b><a href="/movie/Battleship#tab=summary">Battleship</a></b></td>
#  <td class="data"> $220,000,000</td>
#  <td class="data"> $65,233,400</td>
#  <td class="data"> $313,477,717</td>
#  </tr>,
#  <td class="data">33</td>,
#  <td><a href="/box-office-chart/daily/2012/04/11">Apr 11, 2012</a></td>,
#  <a href="/box-office-chart/daily/2012/04/11">Apr 11, 2012</a>,
#  <td><b><a href="/movie/Battleship#tab=summary">Battleship</a></b></td>,
#  <b><a href="/movie/Battleship#tab=summary">Battleship</a></b>,
#  <a href="/movie/Battleship#tab=summary">Battleship</a>,
#  <td class="data"> $220,000,000</td>,
#  <td class="data"> $65,233,400</td>,
#  <td class="data"> $313,477,717</td>,
#  <tr><td class="data">34</td>
#  <td><a href="/box-office-chart/daily/2017/06/20">Jun 20, 2017</a></td>
#  <td><b><a href="/movie/Transformers-The-Last-Knight#tab=summary">Transformers: The Last Knight</a></b></td>
#  <td class="data"> $217,000,000</td>
#  <td class="data"> $130,168,683</td>
#  <td class="data"> $602,893,340</td>
#  </tr>,
#  <td class="data">34</td>,
#  <td><a href="/box-office-chart/daily/2017/06/20">Jun 20, 2017</a></td>,
#  <a href="/box-office-chart/daily/2017/06/20">Jun 20, 2017</a>,
#  <td><b><a href="/movie/Transformers-The-Last-Knight#tab=summary">Transformers: The Last Knight</a></b></td>,
#  <b><a href="/movie/Transformers-The-Last-Knight#tab=summary">Transformers: The Last Knight</a></b>,
#  <a href="/movie/Transformers-The-Last-Knight#tab=summary">Transformers: The Last Knight</a>,
#  <td class="data"> $217,000,000</td>,
#  <td class="data"> $130,168,683</td>,
#  <td class="data"> $602,893,340</td>,
#  <tr><td class="data">35</td>
#  <td><a href="/box-office-chart/daily/2015/06/09">Jun 9, 2015</a></td>
#  <td><b><a href="/movie/Jurassic-World#tab=summary">Jurassic World</a></b></td>
#  <td class="data"> $215,000,000</td>
#  <td class="data"> $652,270,625</td>
#  <td class="data"> $1,669,943,967</td>
#  </tr>,
#  <td class="data">35</td>,
#  <td><a href="/box-office-chart/daily/2015/06/09">Jun 9, 2015</a></td>,
#  <a href="/box-office-chart/daily/2015/06/09">Jun 9, 2015</a>,
#  <td><b><a href="/movie/Jurassic-World#tab=summary">Jurassic World</a></b></td>,
#  <b><a href="/movie/Jurassic-World#tab=summary">Jurassic World</a></b>,
#  <a href="/movie/Jurassic-World#tab=summary">Jurassic World</a>,
#  <td class="data"> $215,000,000</td>,
#  <td class="data"> $652,270,625</td>,
#  <td class="data"> $1,669,943,967</td>,
#  <tr><td class="data">36</td>
#  <td><a href="/box-office-chart/daily/2012/05/23">May 23, 2012</a></td>
#  <td><b><a href="/movie/Men-in-Black-3#tab=summary">Men in Black 3</a></b></td>
#  <td class="data"> $215,000,000</td>
#  <td class="data"> $179,020,854</td>
#  <td class="data"> $654,213,485</td>
#  </tr>,
#  <td class="data">36</td>,
#  <td><a href="/box-office-chart/daily/2012/05/23">May 23, 2012</a></td>,
#  <a href="/box-office-chart/daily/2012/05/23">May 23, 2012</a>,
#  <td><b><a href="/movie/Men-in-Black-3#tab=summary">Men in Black 3</a></b></td>,
#  <b><a href="/movie/Men-in-Black-3#tab=summary">Men in Black 3</a></b>,
#  <a href="/movie/Men-in-Black-3#tab=summary">Men in Black 3</a>,
#  <td class="data"> $215,000,000</td>,
#  <td class="data"> $179,020,854</td>,
#  <td class="data"> $654,213,485</td>,
#  <tr><td class="data">37</td>
#  <td><a href="/box-office-chart/daily/2009/06/24">Jun 24, 2009</a></td>
#  <td><b><a href="/movie/Transformers-Revenge-of-the-Fallen#tab=summary">Transformers: Revenge of the Fallen</a></b></td>
#  <td class="data"> $210,000,000</td>
#  <td class="data"> $402,111,870</td>
#  <td class="data"> $836,519,699</td>
#  </tr>,
#  <td class="data">37</td>,
#  <td><a href="/box-office-chart/daily/2009/06/24">Jun 24, 2009</a></td>,
#  <a href="/box-office-chart/daily/2009/06/24">Jun 24, 2009</a>,
#  <td><b><a href="/movie/Transformers-Revenge-of-the-Fallen#tab=summary">Transformers: Revenge of the Fallen</a></b></td>,
#  <b><a href="/movie/Transformers-Revenge-of-the-Fallen#tab=summary">Transformers: Revenge of the Fallen</a></b>,
#  <a href="/movie/Transformers-Revenge-of-the-Fallen#tab=summary">Transformers: Revenge of the Fallen</a>,
#  <td class="data"> $210,000,000</td>,
#  <td class="data"> $402,111,870</td>,
#  <td class="data"> $836,519,699</td>,
#  <tr><td class="data">38</td>
#  <td><a href="/box-office-chart/daily/2014/06/25">Jun 25, 2014</a></td>
#  <td><b><a href="/movie/Transformers-Age-of-Extinction#tab=summary">Transformers: Age of Extinction</a></b></td>
#  <td class="data"> $210,000,000</td>
#  <td class="data"> $245,439,076</td>
#  <td class="data"> $1,104,054,072</td>
#  </tr>,
#  <td class="data">38</td>,
#  <td><a href="/box-office-chart/daily/2014/06/25">Jun 25, 2014</a></td>,
#  <a href="/box-office-chart/daily/2014/06/25">Jun 25, 2014</a>,
#  <td><b><a href="/movie/Transformers-Age-of-Extinction#tab=summary">Transformers: Age of Extinction</a></b></td>,
#  <b><a href="/movie/Transformers-Age-of-Extinction#tab=summary">Transformers: Age of Extinction</a></b>,
#  <a href="/movie/Transformers-Age-of-Extinction#tab=summary">Transformers: Age of Extinction</a>,
#  <td class="data"> $210,000,000</td>,
#  <td class="data"> $245,439,076</td>,
#  <td class="data"> $1,104,054,072</td>,
#  <tr><td class="data">39</td>
#  <td><a href="/box-office-chart/daily/2006/05/26">May 26, 2006</a></td>
#  <td><b><a href="/movie/X-Men-The-Last-Stand#tab=summary">X-Men: The Last Stand</a></b></td>
#  <td class="data"> $210,000,000</td>
#  <td class="data"> $234,362,462</td>
#  <td class="data"> $459,260,946</td>
#  </tr>,
#  <td class="data">39</td>,
#  <td><a href="/box-office-chart/daily/2006/05/26">May 26, 2006</a></td>,
#  <a href="/box-office-chart/daily/2006/05/26">May 26, 2006</a>,
#  <td><b><a href="/movie/X-Men-The-Last-Stand#tab=summary">X-Men: The Last Stand</a></b></td>,
#  <b><a href="/movie/X-Men-The-Last-Stand#tab=summary">X-Men: The Last Stand</a></b>,
#  <a href="/movie/X-Men-The-Last-Stand#tab=summary">X-Men: The Last Stand</a>,
#  <td class="data"> $210,000,000</td>,
#  <td class="data"> $234,362,462</td>,
#  <td class="data"> $459,260,946</td>,
#  <tr><td class="data">40</td>
#  <td><a href="/box-office-chart/daily/2010/05/14">May 14, 2010</a></td>
#  <td><b><a href="/movie/Robin-Hood-(2010)#tab=summary">Robin Hood</a></b></td>
#  <td class="data"> $210,000,000</td>
#  <td class="data"> $105,487,148</td>
#  <td class="data"> $322,459,006</td>
#  </tr>,
#  <td class="data">40</td>,
#  <td><a href="/box-office-chart/daily/2010/05/14">May 14, 2010</a></td>,
#  <a href="/box-office-chart/daily/2010/05/14">May 14, 2010</a>,
#  <td><b><a href="/movie/Robin-Hood-(2010)#tab=summary">Robin Hood</a></b></td>,
#  <b><a href="/movie/Robin-Hood-(2010)#tab=summary">Robin Hood</a></b>,
#  <a href="/movie/Robin-Hood-(2010)#tab=summary">Robin Hood</a>,
#  <td class="data"> $210,000,000</td>,
#  <td class="data"> $105,487,148</td>,
#  <td class="data"> $322,459,006</td>,
#  <tr><td class="data">41</td>
#  <td><a href="/box-office-chart/daily/2005/12/14">Dec 14, 2005</a></td>
#  <td><b><a href="/movie/King-Kong-(2005)#tab=summary">King Kong</a></b></td>
#  <td class="data"> $207,000,000</td>
#  <td class="data"> $218,080,025</td>
#  <td class="data"> $550,517,357</td>
#  </tr>,
#  <td class="data">41</td>,
#  <td><a href="/box-office-chart/daily/2005/12/14">Dec 14, 2005</a></td>,
#  <a href="/box-office-chart/daily/2005/12/14">Dec 14, 2005</a>,
#  <td><b><a href="/movie/King-Kong-(2005)#tab=summary">King Kong</a></b></td>,
#  <b><a href="/movie/King-Kong-(2005)#tab=summary">King Kong</a></b>,
#  <a href="/movie/King-Kong-(2005)#tab=summary">King Kong</a>,
#  <td class="data"> $207,000,000</td>,
#  <td class="data"> $218,080,025</td>,
#  <td class="data"> $550,517,357</td>,
#  <tr><td class="data">42</td>
#  <td><a href="/box-office-chart/daily/2007/12/07">Dec 7, 2007</a></td>
#  <td><b><a href="/movie/His-Dark-Materials-The-Golden-Compass#tab=summary">The Golden Compass</a></b></td>
#  <td class="data"> $205,000,000</td>
#  <td class="data"> $70,107,728</td>
#  <td class="data"> $367,262,558</td>
#  </tr>,
#  <td class="data">42</td>,
#  <td><a href="/box-office-chart/daily/2007/12/07">Dec 7, 2007</a></td>,
#  <a href="/box-office-chart/daily/2007/12/07">Dec 7, 2007</a>,
#  <td><b><a href="/movie/His-Dark-Materials-The-Golden-Compass#tab=summary">The Golden Compass</a></b></td>,
#  <b><a href="/movie/His-Dark-Materials-The-Golden-Compass#tab=summary">The Golden Compass</a></b>,
#  <a href="/movie/His-Dark-Materials-The-Golden-Compass#tab=summary">The Golden Compass</a>,
#  <td class="data"> $205,000,000</td>,
#  <td class="data"> $70,107,728</td>,
#  <td class="data"> $367,262,558</td>,
#  <tr><td class="data">43</td>
#  <td><a href="/box-office-chart/daily/2020/08/26">Aug 26, 2020</a></td>
#  <td><b><a href="/movie/Tenet-(2020)#tab=summary">Tenet</a></b></td>
#  <td class="data"> $205,000,000</td>
#  <td class="data"> $57,929,000</td>
#  <td class="data"> $363,129,000</td>
#  </tr>,
#  <td class="data">43</td>,
#  <td><a href="/box-office-chart/daily/2020/08/26">Aug 26, 2020</a></td>,
#  <a href="/box-office-chart/daily/2020/08/26">Aug 26, 2020</a>,
#  <td><b><a href="/movie/Tenet-(2020)#tab=summary">Tenet</a></b></td>,
#  <b><a href="/movie/Tenet-(2020)#tab=summary">Tenet</a></b>,
#  <a href="/movie/Tenet-(2020)#tab=summary">Tenet</a>,
#  <td class="data"> $205,000,000</td>,
#  <td class="data"> $57,929,000</td>,
#  <td class="data"> $363,129,000</td>,
#  <tr><td class="data">44</td>
#  <td><a href="/box-office-chart/daily/2018/02/13">Feb 13, 2018</a></td>
#  <td><b><a href="/movie/Black-Panther#tab=summary">Black Panther</a></b></td>
#  <td class="data"> $200,000,000</td>
#  <td class="data"> $700,059,566</td>
#  <td class="data"> $1,336,494,321</td>
#  </tr>,
#  <td class="data">44</td>,
#  <td><a href="/box-office-chart/daily/2018/02/13">Feb 13, 2018</a></td>,
#  <a href="/box-office-chart/daily/2018/02/13">Feb 13, 2018</a>,
#  <td><b><a href="/movie/Black-Panther#tab=summary">Black Panther</a></b></td>,
#  <b><a href="/movie/Black-Panther#tab=summary">Black Panther</a></b>,
#  <a href="/movie/Black-Panther#tab=summary">Black Panther</a>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $700,059,566</td>,
#  <td class="data"> $1,336,494,321</td>,
#  <tr><td class="data">45</td>
#  <td><a href="/box-office-chart/daily/1997/12/18">Dec 18, 1997</a></td>
#  <td><b><a href="/movie/Titanic-(1997)#tab=summary">Titanic</a></b></td>
#  <td class="data"> $200,000,000</td>
#  <td class="data"> $659,363,944</td>
#  <td class="data"> $2,207,986,545</td>
#  </tr>,
#  <td class="data">45</td>,
#  <td><a href="/box-office-chart/daily/1997/12/18">Dec 18, 1997</a></td>,
#  <a href="/box-office-chart/daily/1997/12/18">Dec 18, 1997</a>,
#  <td><b><a href="/movie/Titanic-(1997)#tab=summary">Titanic</a></b></td>,
#  <b><a href="/movie/Titanic-(1997)#tab=summary">Titanic</a></b>,
#  <a href="/movie/Titanic-(1997)#tab=summary">Titanic</a>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $659,363,944</td>,
#  <td class="data"> $2,207,986,545</td>,
#  <tr><td class="data">46</td>
#  <td><a href="/box-office-chart/daily/2017/12/13">Dec 13, 2017</a></td>
#  <td><b><a href="/movie/Star-Wars-Ep-VIII-The-Last-Jedi#tab=summary">Star Wars Ep. VIII: The Last Jedi</a></b></td>
#  <td class="data"> $200,000,000</td>
#  <td class="data"> $620,181,382</td>
#  <td class="data"> $1,332,539,889</td>
#  </tr>,
#  <td class="data">46</td>,
#  <td><a href="/box-office-chart/daily/2017/12/13">Dec 13, 2017</a></td>,
#  <a href="/box-office-chart/daily/2017/12/13">Dec 13, 2017</a>,
#  <td><b><a href="/movie/Star-Wars-Ep-VIII-The-Last-Jedi#tab=summary">Star Wars Ep. VIII: The Last Jedi</a></b></td>,
#  <b><a href="/movie/Star-Wars-Ep-VIII-The-Last-Jedi#tab=summary">Star Wars Ep. VIII: The Last Jedi</a></b>,
#  <a href="/movie/Star-Wars-Ep-VIII-The-Last-Jedi#tab=summary">Star Wars Ep. VIII: The Last Jedi</a>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $620,181,382</td>,
#  <td class="data"> $1,332,539,889</td>,
#  <tr><td class="data">47</td>
#  <td><a href="/box-office-chart/daily/2018/06/15">Jun 15, 2018</a></td>
#  <td><b><a href="/movie/Incredibles-2#tab=summary">Incredibles 2</a></b></td>
#  <td class="data"> $200,000,000</td>
#  <td class="data"> $608,581,744</td>
#  <td class="data"> $1,242,805,359</td>
#  </tr>,
#  <td class="data">47</td>,
#  <td><a href="/box-office-chart/daily/2018/06/15">Jun 15, 2018</a></td>,
#  <a href="/box-office-chart/daily/2018/06/15">Jun 15, 2018</a>,
#  <td><b><a href="/movie/Incredibles-2#tab=summary">Incredibles 2</a></b></td>,
#  <b><a href="/movie/Incredibles-2#tab=summary">Incredibles 2</a></b>,
#  <a href="/movie/Incredibles-2#tab=summary">Incredibles 2</a>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $608,581,744</td>,
#  <td class="data"> $1,242,805,359</td>,
#  <tr><td class="data">48</td>
#  <td><a href="/box-office-chart/daily/2016/12/14">Dec 14, 2016</a></td>
#  <td><b><a href="/movie/Rogue-One-A-Star-Wars-Story#tab=summary">Rogue One: A Star Wars Story</a></b></td>
#  <td class="data"> $200,000,000</td>
#  <td class="data"> $532,177,324</td>
#  <td class="data"> $1,055,135,598</td>
#  </tr>,
#  <td class="data">48</td>,
#  <td><a href="/box-office-chart/daily/2016/12/14">Dec 14, 2016</a></td>,
#  <a href="/box-office-chart/daily/2016/12/14">Dec 14, 2016</a>,
#  <td><b><a href="/movie/Rogue-One-A-Star-Wars-Story#tab=summary">Rogue One: A Star Wars Story</a></b></td>,
#  <b><a href="/movie/Rogue-One-A-Star-Wars-Story#tab=summary">Rogue One: A Star Wars Story</a></b>,
#  <a href="/movie/Rogue-One-A-Star-Wars-Story#tab=summary">Rogue One: A Star Wars Story</a>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $532,177,324</td>,
#  <td class="data"> $1,055,135,598</td>,
#  <tr><td class="data">49</td>
#  <td><a href="/box-office-chart/daily/2016/06/16">Jun 16, 2016</a></td>
#  <td><b><a href="/movie/Finding-Dory#tab=summary">Finding Dory</a></b></td>
#  <td class="data"> $200,000,000</td>
#  <td class="data"> $486,295,561</td>
#  <td class="data"> $1,025,006,125</td>
#  </tr>,
#  <td class="data">49</td>,
#  <td><a href="/box-office-chart/daily/2016/06/16">Jun 16, 2016</a></td>,
#  <a href="/box-office-chart/daily/2016/06/16">Jun 16, 2016</a>,
#  <td><b><a href="/movie/Finding-Dory#tab=summary">Finding Dory</a></b></td>,
#  <b><a href="/movie/Finding-Dory#tab=summary">Finding Dory</a></b>,
#  <a href="/movie/Finding-Dory#tab=summary">Finding Dory</a>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $486,295,561</td>,
#  <td class="data"> $1,025,006,125</td>,
#  <tr><td class="data">50</td>
#  <td><a href="/box-office-chart/daily/2019/06/20">Jun 20, 2019</a></td>
#  <td><b><a href="/movie/Toy-Story-4-(2019)#tab=summary">Toy Story 4</a></b></td>
#  <td class="data"> $200,000,000</td>
#  <td class="data"> $434,038,008</td>
#  <td class="data"> $1,073,357,481</td>
#  </tr>,
#  <td class="data">50</td>,
#  <td><a href="/box-office-chart/daily/2019/06/20">Jun 20, 2019</a></td>,
#  <a href="/box-office-chart/daily/2019/06/20">Jun 20, 2019</a>,
#  <td><b><a href="/movie/Toy-Story-4-(2019)#tab=summary">Toy Story 4</a></b></td>,
#  <b><a href="/movie/Toy-Story-4-(2019)#tab=summary">Toy Story 4</a></b>,
#  <a href="/movie/Toy-Story-4-(2019)#tab=summary">Toy Story 4</a>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $434,038,008</td>,
#  <td class="data"> $1,073,357,481</td>,
#  <tr><td class="data">51</td>
#  <td><a href="/box-office-chart/daily/2010/06/18">Jun 18, 2010</a></td>
#  <td><b><a href="/movie/Toy-Story-3#tab=summary">Toy Story 3</a></b></td>
#  <td class="data"> $200,000,000</td>
#  <td class="data"> $415,004,880</td>
#  <td class="data"> $1,068,879,522</td>
#  </tr>,
#  <td class="data">51</td>,
#  <td><a href="/box-office-chart/daily/2010/06/18">Jun 18, 2010</a></td>,
#  <a href="/box-office-chart/daily/2010/06/18">Jun 18, 2010</a>,
#  <td><b><a href="/movie/Toy-Story-3#tab=summary">Toy Story 3</a></b></td>,
#  <b><a href="/movie/Toy-Story-3#tab=summary">Toy Story 3</a></b>,
#  <a href="/movie/Toy-Story-3#tab=summary">Toy Story 3</a>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $415,004,880</td>,
#  <td class="data"> $1,068,879,522</td>,
#  <tr><td class="data">52</td>
#  <td><a href="/box-office-chart/daily/2013/04/24">Apr 24, 2013</a></td>
#  <td><b><a href="/movie/Iron-Man-3#tab=summary">Iron Man 3</a></b></td>
#  <td class="data"> $200,000,000</td>
#  <td class="data"> $408,992,272</td>
#  <td class="data"> $1,215,392,272</td>
#  </tr>,
#  <td class="data">52</td>,
#  <td><a href="/box-office-chart/daily/2013/04/24">Apr 24, 2013</a></td>,
#  <a href="/box-office-chart/daily/2013/04/24">Apr 24, 2013</a>,
#  <td><b><a href="/movie/Iron-Man-3#tab=summary">Iron Man 3</a></b></td>,
#  <b><a href="/movie/Iron-Man-3#tab=summary">Iron Man 3</a></b>,
#  <a href="/movie/Iron-Man-3#tab=summary">Iron Man 3</a>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $408,992,272</td>,
#  <td class="data"> $1,215,392,272</td>,
#  <tr><td class="data">53</td>
#  <td><a href="/box-office-chart/daily/2017/04/28">Apr 28, 2017</a></td>
#  <td><b><a href="/movie/Guardians-of-the-Galaxy-Vol-2#tab=summary">Guardians of the Galaxy Vol 2</a></b></td>
#  <td class="data"> $200,000,000</td>
#  <td class="data"> $389,813,101</td>
#  <td class="data"> $869,113,101</td>
#  </tr>,
#  <td class="data">53</td>,
#  <td><a href="/box-office-chart/daily/2017/04/28">Apr 28, 2017</a></td>,
#  <a href="/box-office-chart/daily/2017/04/28">Apr 28, 2017</a>,
#  <td><b><a href="/movie/Guardians-of-the-Galaxy-Vol-2#tab=summary">Guardians of the Galaxy Vol 2</a></b></td>,
#  <b><a href="/movie/Guardians-of-the-Galaxy-Vol-2#tab=summary">Guardians of the Galaxy Vol 2</a></b>,
#  <a href="/movie/Guardians-of-the-Galaxy-Vol-2#tab=summary">Guardians of the Galaxy Vol 2</a>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $389,813,101</td>,
#  <td class="data"> $869,113,101</td>,
#  <tr><td class="data">54</td>
#  <td><a href="/box-office-chart/daily/2004/06/30">Jun 30, 2004</a></td>
#  <td><b><a href="/movie/Spider-Man-2#tab=summary">Spider-Man 2</a></b></td>
#  <td class="data"> $200,000,000</td>
#  <td class="data"> $373,524,485</td>
#  <td class="data"> $794,697,557</td>
#  </tr>,
#  <td class="data">54</td>,
#  <td><a href="/box-office-chart/daily/2004/06/30">Jun 30, 2004</a></td>,
#  <a href="/box-office-chart/daily/2004/06/30">Jun 30, 2004</a>,
#  <td><b><a href="/movie/Spider-Man-2#tab=summary">Spider-Man 2</a></b></td>,
#  <b><a href="/movie/Spider-Man-2#tab=summary">Spider-Man 2</a></b>,
#  <a href="/movie/Spider-Man-2#tab=summary">Spider-Man 2</a>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $373,524,485</td>,
#  <td class="data"> $794,697,557</td>,
#  <tr><td class="data">55</td>
#  <td><a href="/box-office-chart/daily/2010/03/04">Mar 4, 2010</a></td>
#  <td><b><a href="/movie/Alice-in-Wonderland-(2010)#tab=summary">Alice in Wonderland</a></b></td>
#  <td class="data"> $200,000,000</td>
#  <td class="data"> $334,191,110</td>
#  <td class="data"> $1,025,491,110</td>
#  </tr>,
#  <td class="data">55</td>,
#  <td><a href="/box-office-chart/daily/2010/03/04">Mar 4, 2010</a></td>,
#  <a href="/box-office-chart/daily/2010/03/04">Mar 4, 2010</a>,
#  <td><b><a href="/movie/Alice-in-Wonderland-(2010)#tab=summary">Alice in Wonderland</a></b></td>,
#  <b><a href="/movie/Alice-in-Wonderland-(2010)#tab=summary">Alice in Wonderland</a></b>,
#  <a href="/movie/Alice-in-Wonderland-(2010)#tab=summary">Alice in Wonderland</a>,
#  <td class="data"> $200,000,000</td>,
#  <td class="data"> $334,191,110</td>,
#  <td class="data"> $1,025,491,110</td>,
#  <tr><td class="data">56</td>
#  <td><a href="/box-office-chart/daily/2012/10/26">Oct 26, 2012</a></td>
#  <td><b><a href="/movie/Skyfall#tab=summary">Skyfall</a></b></td>
#  <td class="data"> $200,000,000</td>
#  <td class="data"> $304,360,277</td>
#  <td class="data"> $1,110,526,981</td>
#  </tr>,
#  <td class="data">56</td>,
# ...
#  <td class="data"> $101,802,906</td>,
#  <td class="data"> $411,002,906</td>,
#  <tr><td class="data">81</td>
#  <td><a href="/box-office-chart/daily/2015/11/25">Nov 25, 2015</a></td>
#  <td><b><a href="/movie/Good-Dinosaur-The#tab=summary">The Good Dinosaur</a></b></td>
#  <td class="data"> $187,500,000</td>
#  <td class="data"> $123,087,120</td>
#  <td class="data"> $333,771,037</td>
#  </tr>,
#  <td class="data">81</td>,
#  <td><a href="/box-office-chart/daily/2015/11/25">Nov 25, 2015</a></td>,
#  <a href="/box-office-chart/daily/2015/11/25">Nov 25, 2015</a>,
#  <td><b><a href="/movie/Good-Dinosaur-The#tab=summary">The Good Dinosaur</a></b></td>,
#  <b><a href="/movie/Good-Dinosaur-The#tab=summary">The Good Dinosaur</a></b>,
#  <a href="/movie/Good-Dinosaur-The#tab=summary">The Good Dinosaur</a>,
#  <td class="data"> $187,500,000</td>,
#  <td class="data"> $123,087,120</td>,
#  <td class="data"> $333,771,037</td>,
#  <tr><td class="data">82</td>
#  <td><a href="/box-office-chart/daily/2008/05/02">May 2, 2008</a></td>
#  <td><b><a href="/movie/Iron-Man#tab=summary">Iron Man</a></b></td>
#  <td class="data"> $186,000,000</td>
#  <td class="data"> $318,604,126</td>
#  <td class="data"> $585,171,547</td>
#  </tr>,
#  <td class="data">82</td>,
#  <td><a href="/box-office-chart/daily/2008/05/02">May 2, 2008</a></td>,
#  <a href="/box-office-chart/daily/2008/05/02">May 2, 2008</a>,
#  <td><b><a href="/movie/Iron-Man#tab=summary">Iron Man</a></b></td>,
#  <b><a href="/movie/Iron-Man#tab=summary">Iron Man</a></b>,
#  <a href="/movie/Iron-Man#tab=summary">Iron Man</a>,
#  <td class="data"> $186,000,000</td>,
#  <td class="data"> $318,604,126</td>,
#  <td class="data"> $585,171,547</td>,
#  <tr><td class="data">83</td>
#  <td><a href="/box-office-chart/daily/2008/07/11">Jul 11, 2008</a></td>
#  <td><b><a href="/movie/Dark-Knight-The#tab=summary">The Dark Knight</a></b></td>
#  <td class="data"> $185,000,000</td>
#  <td class="data"> $533,720,947</td>
#  <td class="data"> $999,434,419</td>
#  </tr>,
#  <td class="data">83</td>,
#  <td><a href="/box-office-chart/daily/2008/07/11">Jul 11, 2008</a></td>,
#  <a href="/box-office-chart/daily/2008/07/11">Jul 11, 2008</a>,
#  <td><b><a href="/movie/Dark-Knight-The#tab=summary">The Dark Knight</a></b></td>,
#  <b><a href="/movie/Dark-Knight-The#tab=summary">The Dark Knight</a></b>,
#  <a href="/movie/Dark-Knight-The#tab=summary">The Dark Knight</a>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $533,720,947</td>,
#  <td class="data"> $999,434,419</td>,
#  <tr><td class="data">84</td>
#  <td><a href="/box-office-chart/daily/2008/05/22">May 22, 2008</a></td>
#  <td><b><a href="/movie/Indiana-Jones-and-the-Kingdom-of-the-Crystal-Skull#tab=summary">Indiana Jones and the Kingdom of the Crystal Skull</a></b></td>
#  <td class="data"> $185,000,000</td>
#  <td class="data"> $317,101,119</td>
#  <td class="data"> $786,635,413</td>
#  </tr>,
#  <td class="data">84</td>,
#  <td><a href="/box-office-chart/daily/2008/05/22">May 22, 2008</a></td>,
#  <a href="/box-office-chart/daily/2008/05/22">May 22, 2008</a>,
#  <td><b><a href="/movie/Indiana-Jones-and-the-Kingdom-of-the-Crystal-Skull#tab=summary">Indiana Jones and the Kingdom of the Crystal Skull</a></b></td>,
#  <b><a href="/movie/Indiana-Jones-and-the-Kingdom-of-the-Crystal-Skull#tab=summary">Indiana Jones and the Kingdom of the Crystal Skull</a></b>,
#  <a href="/movie/Indiana-Jones-and-the-Kingdom-of-the-Crystal-Skull#tab=summary">Indiana Jones and the Kingdom of the Crystal Skull</a>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $317,101,119</td>,
#  <td class="data"> $786,635,413</td>,
#  <tr><td class="data">85</td>
#  <td><a href="/box-office-chart/daily/2012/06/21">Jun 21, 2012</a></td>
#  <td><b><a href="/movie/Brave#tab=summary">Brave</a></b></td>
#  <td class="data"> $185,000,000</td>
#  <td class="data"> $237,282,182</td>
#  <td class="data"> $554,606,532</td>
#  </tr>,
#  <td class="data">85</td>,
#  <td><a href="/box-office-chart/daily/2012/06/21">Jun 21, 2012</a></td>,
#  <a href="/box-office-chart/daily/2012/06/21">Jun 21, 2012</a>,
#  <td><b><a href="/movie/Brave#tab=summary">Brave</a></b></td>,
#  <b><a href="/movie/Brave#tab=summary">Brave</a></b>,
#  <a href="/movie/Brave#tab=summary">Brave</a>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $237,282,182</td>,
#  <td class="data"> $554,606,532</td>,
#  <tr><td class="data">86</td>
#  <td><a href="/box-office-chart/daily/2017/02/23">Feb 23, 2017</a></td>
#  <td><b><a href="/movie/Kong-Skull-Island#tab=summary">Kong: Skull Island</a></b></td>
#  <td class="data"> $185,000,000</td>
#  <td class="data"> $168,052,812</td>
#  <td class="data"> $561,072,059</td>
#  </tr>,
#  <td class="data">86</td>,
#  <td><a href="/box-office-chart/daily/2017/02/23">Feb 23, 2017</a></td>,
#  <a href="/box-office-chart/daily/2017/02/23">Feb 23, 2017</a>,
#  <td><b><a href="/movie/Kong-Skull-Island#tab=summary">Kong: Skull Island</a></b></td>,
#  <b><a href="/movie/Kong-Skull-Island#tab=summary">Kong: Skull Island</a></b>,
#  <a href="/movie/Kong-Skull-Island#tab=summary">Kong: Skull Island</a>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $168,052,812</td>,
#  <td class="data"> $561,072,059</td>,
#  <tr><td class="data">87</td>
#  <td><a href="/box-office-chart/daily/2016/07/21">Jul 21, 2016</a></td>
#  <td><b><a href="/movie/Star-Trek-Beyond#tab=summary">Star Trek Beyond</a></b></td>
#  <td class="data"> $185,000,000</td>
#  <td class="data"> $158,848,340</td>
#  <td class="data"> $335,673,708</td>
#  </tr>,
#  <td class="data">87</td>,
#  <td><a href="/box-office-chart/daily/2016/07/21">Jul 21, 2016</a></td>,
#  <a href="/box-office-chart/daily/2016/07/21">Jul 21, 2016</a>,
#  <td><b><a href="/movie/Star-Trek-Beyond#tab=summary">Star Trek Beyond</a></b></td>,
#  <b><a href="/movie/Star-Trek-Beyond#tab=summary">Star Trek Beyond</a></b>,
#  <a href="/movie/Star-Trek-Beyond#tab=summary">Star Trek Beyond</a>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $158,848,340</td>,
#  <td class="data"> $335,673,708</td>,
#  <tr><td class="data">88</td>
#  <td><a href="/box-office-chart/daily/2019/10/17">Oct 17, 2019</a></td>
#  <td><b><a href="/movie/Maleficent-Mistress-of-Evil-(2019)#tab=summary">Maleficent: Mistress of Evil</a></b></td>
#  <td class="data"> $185,000,000</td>
#  <td class="data"> $113,929,605</td>
#  <td class="data"> $489,346,495</td>
#  </tr>,
#  <td class="data">88</td>,
#  <td><a href="/box-office-chart/daily/2019/10/17">Oct 17, 2019</a></td>,
#  <a href="/box-office-chart/daily/2019/10/17">Oct 17, 2019</a>,
#  <td><b><a href="/movie/Maleficent-Mistress-of-Evil-(2019)#tab=summary">Maleficent: Mistress of Evil</a></b></td>,
#  <b><a href="/movie/Maleficent-Mistress-of-Evil-(2019)#tab=summary">Maleficent: Mistress of Evil</a></b>,
#  <a href="/movie/Maleficent-Mistress-of-Evil-(2019)#tab=summary">Maleficent: Mistress of Evil</a>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $113,929,605</td>,
#  <td class="data"> $489,346,495</td>,
#  <tr><td class="data">89</td>
#  <td><a href="/box-office-chart/daily/2017/09/29">Sep 29, 2017</a></td>
#  <td><b><a href="/movie/Blade-Runner-2049#tab=summary">Blade Runner 2049</a></b></td>
#  <td class="data"> $185,000,000</td>
#  <td class="data"> $92,054,159</td>
#  <td class="data"> $259,136,784</td>
#  </tr>,
#  <td class="data">89</td>,
#  <td><a href="/box-office-chart/daily/2017/09/29">Sep 29, 2017</a></td>,
#  <a href="/box-office-chart/daily/2017/09/29">Sep 29, 2017</a>,
#  <td><b><a href="/movie/Blade-Runner-2049#tab=summary">Blade Runner 2049</a></b></td>,
#  <b><a href="/movie/Blade-Runner-2049#tab=summary">Blade Runner 2049</a></b>,
#  <a href="/movie/Blade-Runner-2049#tab=summary">Blade Runner 2049</a>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $92,054,159</td>,
#  <td class="data"> $259,136,784</td>,
#  <tr><td class="data">90</td>
#  <td><a href="/box-office-chart/daily/2019/10/25">Oct 25, 2019</a></td>
#  <td><b><a href="/movie/Terminator-Dark-Fate-(2019)#tab=summary">Terminator: Dark Fate</a></b></td>
#  <td class="data"> $185,000,000</td>
#  <td class="data"> $62,253,077</td>
#  <td class="data"> $250,372,367</td>
#  </tr>,
#  <td class="data">90</td>,
#  <td><a href="/box-office-chart/daily/2019/10/25">Oct 25, 2019</a></td>,
#  <a href="/box-office-chart/daily/2019/10/25">Oct 25, 2019</a>,
#  <td><b><a href="/movie/Terminator-Dark-Fate-(2019)#tab=summary">Terminator: Dark Fate</a></b></td>,
#  <b><a href="/movie/Terminator-Dark-Fate-(2019)#tab=summary">Terminator: Dark Fate</a></b>,
#  <a href="/movie/Terminator-Dark-Fate-(2019)#tab=summary">Terminator: Dark Fate</a>,
#  <td class="data"> $185,000,000</td>,
#  <td class="data"> $62,253,077</td>,
#  <td class="data"> $250,372,367</td>,
#  <tr><td class="data">91</td>
#  <td><a href="/box-office-chart/daily/2019/05/22">May 22, 2019</a></td>
#  <td><b><a href="/movie/Aladdin-(2019)#tab=summary">Aladdin</a></b></td>
#  <td class="data"> $182,000,000</td>
#  <td class="data"> $355,559,216</td>
#  <td class="data"> $1,046,918,234</td>
#  </tr>,
#  <td class="data">91</td>,
#  <td><a href="/box-office-chart/daily/2019/05/22">May 22, 2019</a></td>,
#  <a href="/box-office-chart/daily/2019/05/22">May 22, 2019</a>,
#  <td><b><a href="/movie/Aladdin-(2019)#tab=summary">Aladdin</a></b></td>,
#  <b><a href="/movie/Aladdin-(2019)#tab=summary">Aladdin</a></b>,
#  <a href="/movie/Aladdin-(2019)#tab=summary">Aladdin</a>,
#  <td class="data"> $182,000,000</td>,
#  <td class="data"> $355,559,216</td>,
#  <td class="data"> $1,046,918,234</td>,
#  <tr><td class="data">92</td>
#  <td><a href="/box-office-chart/daily/2017/10/25">Oct 25, 2017</a></td>
#  <td><b><a href="/movie/Thor-Ragnarok#tab=summary">Thor: Ragnarok</a></b></td>
#  <td class="data"> $180,000,000</td>
#  <td class="data"> $315,058,289</td>
#  <td class="data"> $850,482,778</td>
#  </tr>,
#  <td class="data">92</td>,
#  <td><a href="/box-office-chart/daily/2017/10/25">Oct 25, 2017</a></td>,
#  <a href="/box-office-chart/daily/2017/10/25">Oct 25, 2017</a>,
#  <td><b><a href="/movie/Thor-Ragnarok#tab=summary">Thor: Ragnarok</a></b></td>,
#  <b><a href="/movie/Thor-Ragnarok#tab=summary">Thor: Ragnarok</a></b>,
#  <a href="/movie/Thor-Ragnarok#tab=summary">Thor: Ragnarok</a>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $315,058,289</td>,
#  <td class="data"> $850,482,778</td>,
#  <tr><td class="data">93</td>
#  <td><a href="/box-office-chart/daily/2005/12/09">Dec 9, 2005</a></td>
#  <td><b><a href="/movie/Chronicles-of-Narnia-The-Lion-the-Witch-and-the-Wardrobe-The#tab=summary">The Chronicles of Narnia: The Lion, the Witch a…</a></b></td>
#  <td class="data"> $180,000,000</td>
#  <td class="data"> $291,710,957</td>
#  <td class="data"> $720,539,572</td>
#  </tr>,
#  <td class="data">93</td>,
#  <td><a href="/box-office-chart/daily/2005/12/09">Dec 9, 2005</a></td>,
#  <a href="/box-office-chart/daily/2005/12/09">Dec 9, 2005</a>,
#  <td><b><a href="/movie/Chronicles-of-Narnia-The-Lion-the-Witch-and-the-Wardrobe-The#tab=summary">The Chronicles of Narnia: The Lion, the Witch a…</a></b></td>,
#  <b><a href="/movie/Chronicles-of-Narnia-The-Lion-the-Witch-and-the-Wardrobe-The#tab=summary">The Chronicles of Narnia: The Lion, the Witch a…</a></b>,
#  <a href="/movie/Chronicles-of-Narnia-The-Lion-the-Witch-and-the-Wardrobe-The#tab=summary">The Chronicles of Narnia: The Lion, the Witch a…</a>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $291,710,957</td>,
#  <td class="data"> $720,539,572</td>,
#  <tr><td class="data">94</td>
#  <td><a href="/box-office-chart/daily/2014/05/28">May 28, 2014</a></td>
#  <td><b><a href="/movie/Maleficent#tab=summary">Maleficent</a></b></td>
#  <td class="data"> $180,000,000</td>
#  <td class="data"> $241,407,328</td>
#  <td class="data"> $758,536,735</td>
#  </tr>,
#  <td class="data">94</td>,
#  <td><a href="/box-office-chart/daily/2014/05/28">May 28, 2014</a></td>,
#  <a href="/box-office-chart/daily/2014/05/28">May 28, 2014</a>,
#  <td><b><a href="/movie/Maleficent#tab=summary">Maleficent</a></b></td>,
#  <b><a href="/movie/Maleficent#tab=summary">Maleficent</a></b>,
#  <a href="/movie/Maleficent#tab=summary">Maleficent</a>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $241,407,328</td>,
#  <td class="data"> $758,536,735</td>,
#  <tr><td class="data">95</td>
#  <td><a href="/box-office-chart/daily/2016/11/14">Nov 14, 2016</a></td>
#  <td><b><a href="/movie/Fantastic-Beasts-and-Where-to-Find-Them#tab=summary">Fantastic Beasts and Where to Find Them</a></b></td>
#  <td class="data"> $180,000,000</td>
#  <td class="data"> $234,037,575</td>
#  <td class="data"> $811,724,385</td>
#  </tr>,
#  <td class="data">95</td>,
#  <td><a href="/box-office-chart/daily/2016/11/14">Nov 14, 2016</a></td>,
#  <a href="/box-office-chart/daily/2016/11/14">Nov 14, 2016</a>,
#  <td><b><a href="/movie/Fantastic-Beasts-and-Where-to-Find-Them#tab=summary">Fantastic Beasts and Where to Find Them</a></b></td>,
#  <b><a href="/movie/Fantastic-Beasts-and-Where-to-Find-Them#tab=summary">Fantastic Beasts and Where to Find Them</a></b>,
#  <a href="/movie/Fantastic-Beasts-and-Where-to-Find-Them#tab=summary">Fantastic Beasts and Where to Find Them</a>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $234,037,575</td>,
#  <td class="data"> $811,724,385</td>,
#  <tr><td class="data">96</td>
#  <td><a href="/box-office-chart/daily/2008/06/27">Jun 27, 2008</a></td>
#  <td><b><a href="/movie/WALL-E#tab=summary">WALL-E</a></b></td>
#  <td class="data"> $180,000,000</td>
#  <td class="data"> $223,808,164</td>
#  <td class="data"> $532,508,025</td>
#  </tr>,
#  <td class="data">96</td>,
#  <td><a href="/box-office-chart/daily/2008/06/27">Jun 27, 2008</a></td>,
#  <a href="/box-office-chart/daily/2008/06/27">Jun 27, 2008</a>,
#  <td><b><a href="/movie/WALL-E#tab=summary">WALL-E</a></b></td>,
#  <b><a href="/movie/WALL-E#tab=summary">WALL-E</a></b>,
#  <a href="/movie/WALL-E#tab=summary">WALL-E</a>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $223,808,164</td>,
#  <td class="data"> $532,508,025</td>,
#  <tr><td class="data">97</td>
#  <td><a href="/box-office-chart/daily/2007/08/10">Aug 10, 2007</a></td>
#  <td><b><a href="/movie/Rush-Hour-3#tab=summary">Rush Hour 3</a></b></td>
#  <td class="data"> $180,000,000</td>
#  <td class="data"> $140,125,968</td>
#  <td class="data"> $256,585,882</td>
#  </tr>,
#  <td class="data">97</td>,
#  <td><a href="/box-office-chart/daily/2007/08/10">Aug 10, 2007</a></td>,
#  <a href="/box-office-chart/daily/2007/08/10">Aug 10, 2007</a>,
#  <td><b><a href="/movie/Rush-Hour-3#tab=summary">Rush Hour 3</a></b></td>,
#  <b><a href="/movie/Rush-Hour-3#tab=summary">Rush Hour 3</a></b>,
#  <a href="/movie/Rush-Hour-3#tab=summary">Rush Hour 3</a>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $140,125,968</td>,
#  <td class="data"> $256,585,882</td>,
#  <tr><td class="data">98</td>
#  <td><a href="/box-office-chart/daily/2016/06/27">Jun 27, 2016</a></td>
#  <td><b><a href="/movie/Legend-of-Tarzan-The#tab=summary">The Legend of Tarzan</a></b></td>
#  <td class="data"> $180,000,000</td>
#  <td class="data"> $126,643,061</td>
#  <td class="data"> $348,902,025</td>
#  </tr>,
#  <td class="data">98</td>,
#  <td><a href="/box-office-chart/daily/2016/06/27">Jun 27, 2016</a></td>,
#  <a href="/box-office-chart/daily/2016/06/27">Jun 27, 2016</a>,
#  <td><b><a href="/movie/Legend-of-Tarzan-The#tab=summary">The Legend of Tarzan</a></b></td>,
#  <b><a href="/movie/Legend-of-Tarzan-The#tab=summary">The Legend of Tarzan</a></b>,
#  <a href="/movie/Legend-of-Tarzan-The#tab=summary">The Legend of Tarzan</a>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $126,643,061</td>,
#  <td class="data"> $348,902,025</td>,
#  <tr><td class="data">99</td>
#  <td><a href="/box-office-chart/daily/2011/11/23">Nov 23, 2011</a></td>
#  <td><b><a href="/movie/Hugo#tab=summary">Hugo</a></b></td>
#  <td class="data"> $180,000,000</td>
#  <td class="data"> $73,864,507</td>
#  <td class="data"> $180,047,784</td>
#  </tr>,
#  <td class="data">99</td>,
#  <td><a href="/box-office-chart/daily/2011/11/23">Nov 23, 2011</a></td>,
#  <a href="/box-office-chart/daily/2011/11/23">Nov 23, 2011</a>,
#  <td><b><a href="/movie/Hugo#tab=summary">Hugo</a></b></td>,
#  <b><a href="/movie/Hugo#tab=summary">Hugo</a></b>,
#  <a href="/movie/Hugo#tab=summary">Hugo</a>,
#  <td class="data"> $180,000,000</td>,
#  <td class="data"> $73,864,507</td>,
#  ...]
